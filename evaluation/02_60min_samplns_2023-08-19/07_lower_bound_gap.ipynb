# %% [markdown]
# # How close are previous algorithms to the smallest possible sample size and how much closer can we get with SampLNS
#
# We don't know the actual smallest possible sample sizes, but we have a lower bound that we can use.

# %% [markdown]
# Let us first load the data from the experiment with solved each of the 44 small to medium instance 5 times with each of the previous algorithms. Then these samples were optimized for 900s by SampLNS.

# %%
import pandas as pd

# %%
samplns_data = pd.read_json("./05_clean_data.json.zip")
baseline_data = pd.read_json("./00_simple_baseline_data.json.zip")
from _conf import EXTENDED_BASELINE_DATA
extended_baseline_data = pd.read_json(EXTENDED_BASELINE_DATA)
extended_baseline_data = pd.concat([baseline_data, extended_baseline_data])
baseline_data
# Out:
#      instance_name  num_vars  num_clauses baseline_alg baseline_alg_conf  \
# 0        calculate         9           15    FIDE-ICPL                t2
# 1        calculate         9           15    FIDE-ICPL                t2
# 2        calculate         9           15    FIDE-ICPL                t2
# 3        calculate         9           15    FIDE-ICPL                t2
# 4        calculate         9           15    FIDE-ICPL                t2
# ...            ...       ...          ...          ...               ...
# 2745        freetz     31012       102705         YASA       t2_m10_null
# 2746        freetz     31012       102705         YASA       t2_m10_null
# 2747        freetz     31012       102705         YASA       t2_m10_null
# 2748        freetz     31012       102705         YASA       t2_m10_null
# 2749        freetz     31012       102705         YASA       t2_m10_null
#
#       runtime  sample_size                 path_to_baseline_sample
# 0       1.484          9.0  2023-03-01_13-51-03/1_1_0_1_sample.csv
# 1       1.280          9.0  2023-03-01_13-51-03/1_1_0_2_sample.csv
# 2       1.289          9.0  2023-03-01_13-51-03/1_1_0_3_sample.csv
# 3       1.274          9.0  2023-03-01_13-51-03/1_1_0_4_sample.csv
# 4       1.277          9.0  2023-03-01_13-51-03/1_1_0_5_sample.csv
# ...       ...          ...                                     ...
# 2745  900.008          NaN                                    None
# 2746  900.008          NaN                                    None
# 2747  900.010          NaN                                    None
# 2748  900.009          NaN                                    None
# 2749  900.008          NaN                                    None
#
# [2750 rows x 8 columns]

# %%
extended_baseline_data
# Out:
#      instance_name  num_vars  num_clauses   baseline_alg baseline_alg_conf  \
# 0        calculate         9           15      FIDE-ICPL                t2
# 1        calculate         9           15      FIDE-ICPL                t2
# 2        calculate         9           15      FIDE-ICPL                t2
# 3        calculate         9           15      FIDE-ICPL                t2
# 4        calculate         9           15      FIDE-ICPL                t2
# ..             ...       ...          ...            ...               ...
# 507        m5272c3      1336         3111  ACTS-IPOF-CSP                t2
# 508      sam7ex256      1345         3155  ACTS-IPOF-CSP                t2
# 509    phycore229x      1373         3185  ACTS-IPOF-CSP                t2
# 510  FreeBSD-8_0_0      1397        15692  ACTS-IPOF-CSP                t2
# 511         ea2468      1408         3319  ACTS-IPOF-CSP                t2
#
#         runtime  sample_size                 path_to_baseline_sample
# 0         1.484          9.0  2023-03-01_13-51-03/1_1_0_1_sample.csv
# 1         1.280          9.0  2023-03-01_13-51-03/1_1_0_2_sample.csv
# 2         1.289          9.0  2023-03-01_13-51-03/1_1_0_3_sample.csv
# 3         1.274          9.0  2023-03-01_13-51-03/1_1_0_4_sample.csv
# 4         1.277          9.0  2023-03-01_13-51-03/1_1_0_5_sample.csv
# ..          ...          ...                                     ...
# 507  900030.000          NaN                                    None
# 508  900028.000          NaN                                    None
# 509  900032.000          NaN                                    None
# 510  900009.000          NaN                                    None
# 511  900037.000          NaN                                    None
#
# [3262 rows x 8 columns]

# %%
baseline_data = extended_baseline_data

# %%
best_lower_bound = samplns_data.groupby(["instance_name"])["lower_bound"].max().reset_index().rename(columns={"lower_bound": "best_lower_bound"})
best_lower_bound.to_json("./out/07_best_lower_bounds.json.zip")
best_lower_bound
# Out:
#                   instance_name  best_lower_bound
# 0                           APL                 7
# 1                     APL-Model                 8
# 2               BankingSoftware                28
# 3                 BattleofTanks               256
# 4                    ChatClient                 7
# 5                          DMIE                16
# 6                        E-Shop                 8
# 7                    EMBToolkit              1872
# 8                        FameDB                 8
# 9                    FeatureIDE                 7
# 10                FreeBSD-8_0_0                30
# 11                          PPU                12
# 12                     SafeBali                11
# 13                  SortingLine                 9
# 14                     TightVNC                 8
# 15                       Violet                15
# 16            WaterlooGenerated                82
# 17                     XSEngine                32
# 18                     aaed2000                51
# 19                     am31_sim                28
# 20             atlas_mips32_4kc                33
# 21                        axTLS                10
# 22                  berkeleyDB1                15
# 23                  berkeleyDB2                11
# 24               busybox-1_18_0                12
# 25               busybox-1_29_2                19
# 26  busybox_2007-01-24_09-14-09                21
# 27  busybox_2020-12-16_21-53-05                18
# 28                    calculate                 5
# 29                          car                 5
# 30                         dell                31
# 31              eCos-3-0_i386pc                33
# 32                       ea2468                31
# 33                        email                 6
# 34   fiasco_2017-09-26_11-30-56               225
# 35   fiasco_2020-12-01_14-09-14               196
# 36           financial_services              4304
# 37                fs_2017-05-22               396
# 38                          gpl                16
# 39              integrator_arm7                32
# 40                          lcm                 6
# 41  soletta_2015-06-26_18-38-56                24
# 42   toybox_2006-10-31_23-30-06                 8
# 43   toybox_2020-12-06_00-02-46                 7
# 44   uclibc_2008-06-05_13-46-47               505
# 45   uclibc_2020-12-24_11-54-53               365

# %%
best_lower_bound["internal_best"] = best_lower_bound["best_lower_bound"]
from _conf import EXTERNAL_BOUNDS
external_best_lb = pd.concat([pd.read_csv(p) for p in EXTERNAL_BOUNDS]).groupby(["instance_name"])["best_lower_bound"].max().reset_index()
best_lower_bound = pd.concat([best_lower_bound, external_best_lb]).groupby(["instance_name"])[["best_lower_bound", "internal_best"]].max().reset_index()
best_lower_bound
# Out:
#                   instance_name  best_lower_bound  internal_best
# 0                           APL                 7            7.0
# 1                     APL-Model                 8            8.0
# 2               BankingSoftware                28           28.0
# 3                 BattleofTanks               256          256.0
# 4                    ChatClient                 7            7.0
# 5                          DMIE                16           16.0
# 6                        E-Shop                10            8.0
# 7                    EMBToolkit              1872         1872.0
# 8                        FameDB                 8            8.0
# 9                    FeatureIDE                 7            7.0
# 10                FreeBSD-8_0_0                30           30.0
# 11                          PPU                12           12.0
# 12                     SafeBali                11           11.0
# 13                  SortingLine                 9            9.0
# 14                     TightVNC                 8            8.0
# 15                       Violet                15           15.0
# 16            WaterlooGenerated                82           82.0
# 17                     XSEngine                32           32.0
# 18                     aaed2000                51           51.0
# 19                     am31_sim                29           28.0
# 20             atlas_mips32_4kc                33           33.0
# 21                        axTLS                10           10.0
# 22                  berkeleyDB1                15           15.0
# 23                  berkeleyDB2                12           11.0
# 24               busybox-1_18_0                13           12.0
# 25               busybox-1_29_2                20           19.0
# 26  busybox_2007-01-24_09-14-09                21           21.0
# 27  busybox_2020-12-16_21-53-05                18           18.0
# 28                    calculate                 5            5.0
# 29                          car                 5            5.0
# 30                         dell                31           31.0
# 31              eCos-3-0_i386pc                33           33.0
# 32                       ea2468                32           31.0
# 33                        email                 6            6.0
# 34   fiasco_2017-09-26_11-30-56               225          225.0
# 35   fiasco_2020-12-01_14-09-14               196          196.0
# 36           financial_services              4304         4304.0
# 37                fs_2017-05-22               396          396.0
# 38                          gpl                16           16.0
# 39              integrator_arm7                32           32.0
# 40                          lcm                 6            6.0
# 41  soletta_2015-06-26_18-38-56                24           24.0
# 42   toybox_2006-10-31_23-30-06                 8            8.0
# 43   toybox_2020-12-06_00-02-46                 8            7.0
# 44   uclibc_2008-06-05_13-46-47               505          505.0
# 45   uclibc_2020-12-24_11-54-53               365          365.0

# %%
samplns_data = samplns_data[["instance_name", "upper_bound"]]
samplns_data = samplns_data.merge(best_lower_bound, on="instance_name")
samplns_data["gap"] =100*( 1- (samplns_data["best_lower_bound"]/ samplns_data["upper_bound"]))
samplns_data["algorithm_name"] = "SampLNS"
samplns_data
# Out:
#                   instance_name  upper_bound  best_lower_bound  internal_best  \
# 0    toybox_2006-10-31_23-30-06            8                 8            8.0
# 1    toybox_2006-10-31_23-30-06            8                 8            8.0
# 2    toybox_2006-10-31_23-30-06            8                 8            8.0
# 3    toybox_2006-10-31_23-30-06            8                 8            8.0
# 4    toybox_2006-10-31_23-30-06            8                 8            8.0
# ..                          ...          ...               ...            ...
# 225                       email            6                 6            6.0
# 226                       email            6                 6            6.0
# 227                       email            6                 6            6.0
# 228                       email            6                 6            6.0
# 229                       email            6                 6            6.0
#
#      gap algorithm_name
# 0    0.0        SampLNS
# 1    0.0        SampLNS
# 2    0.0        SampLNS
# 3    0.0        SampLNS
# 4    0.0        SampLNS
# ..   ...            ...
# 225  0.0        SampLNS
# 226  0.0        SampLNS
# 227  0.0        SampLNS
# 228  0.0        SampLNS
# 229  0.0        SampLNS
#
# [230 rows x 6 columns]

# %%
baseline_data = baseline_data[["instance_name", "sample_size", "baseline_alg", "baseline_alg_conf"]]
baseline_data = baseline_data.merge(best_lower_bound, on="instance_name")
baseline_data["gap"] = 100*(1-(baseline_data["best_lower_bound"]/baseline_data["sample_size"]))
def baseline_alg_name(row):
    settings = row["baseline_alg_conf"]
    if "_m" in settings:
        m = settings.split("_m")[-1].split("_")[0]
        return f"{row['baseline_alg']}(m={m})"
    return row["baseline_alg"]
baseline_data["algorithm_name"] = baseline_data.apply(baseline_alg_name, axis=1)
#baseline_data.rename(columns={"baseline_alg": "Algorithm"})
baseline_data
# Out:
#      instance_name  sample_size   baseline_alg baseline_alg_conf  \
# 0        calculate          9.0      FIDE-ICPL                t2
# 1        calculate          9.0      FIDE-ICPL                t2
# 2        calculate          9.0      FIDE-ICPL                t2
# 3        calculate          9.0      FIDE-ICPL                t2
# 4        calculate          9.0      FIDE-ICPL                t2
# ...            ...          ...            ...               ...
# 2653        ea2468         65.0           YASA       t2_m10_null
# 2654        ea2468          NaN   ACTS-IPOG-FT                t2
# 2655        ea2468          NaN  ACTS-IPOG-CSP                t2
# 2656        ea2468          NaN   ACTS-IPOF-FT                t2
# 2657        ea2468          NaN  ACTS-IPOF-CSP                t2
#
#       best_lower_bound  internal_best        gap algorithm_name
# 0                    5            5.0  44.444444      FIDE-ICPL
# 1                    5            5.0  44.444444      FIDE-ICPL
# 2                    5            5.0  44.444444      FIDE-ICPL
# 3                    5            5.0  44.444444      FIDE-ICPL
# 4                    5            5.0  44.444444      FIDE-ICPL
# ...                ...            ...        ...            ...
# 2653                32           31.0  50.769231     YASA(m=10)
# 2654                32           31.0        NaN   ACTS-IPOG-FT
# 2655                32           31.0        NaN  ACTS-IPOG-CSP
# 2656                32           31.0        NaN   ACTS-IPOF-FT
# 2657                32           31.0        NaN  ACTS-IPOF-CSP
#
# [2658 rows x 8 columns]

# %%
gaps = pd.concat([samplns_data[["algorithm_name", "instance_name", "gap"]], baseline_data[['algorithm_name','instance_name', 'gap']]])
gaps
# Out:
#      algorithm_name               instance_name        gap
# 0           SampLNS  toybox_2006-10-31_23-30-06   0.000000
# 1           SampLNS  toybox_2006-10-31_23-30-06   0.000000
# 2           SampLNS  toybox_2006-10-31_23-30-06   0.000000
# 3           SampLNS  toybox_2006-10-31_23-30-06   0.000000
# 4           SampLNS  toybox_2006-10-31_23-30-06   0.000000
# ...             ...                         ...        ...
# 2653     YASA(m=10)                      ea2468  50.769231
# 2654   ACTS-IPOG-FT                      ea2468        NaN
# 2655  ACTS-IPOG-CSP                      ea2468        NaN
# 2656   ACTS-IPOF-FT                      ea2468        NaN
# 2657  ACTS-IPOF-CSP                      ea2468        NaN
#
# [2888 rows x 3 columns]

# %%
gaps["algorithm_name"].unique().tolist()
# Out:
# ['SampLNS',
#  'FIDE-ICPL',
#  'FIDE-Chvatal',
#  'Incling',
#  'FIDE-YASA(m=1)',
#  'FIDE-YASA(m=3)',
#  'FIDE-YASA(m=5)',
#  'FIDE-YASA(m=10)',
#  'YASA(m=1)',
#  'YASA(m=3)',
#  'YASA(m=5)',
#  'YASA(m=10)',
#  'ACTS-IPOG-FT',
#  'ACTS-IPOG-CSP',
#  'ACTS-IPOF-FT',
#  'ACTS-IPOF-CSP']

# %%
algorithm_selection = ['SampLNS',
 'FIDE-ICPL',
 'FIDE-Chvatal',
 'Incling',
 'FIDE-YASA(m=1)',
 'FIDE-YASA(m=3)',
 'FIDE-YASA(m=5)',
 'FIDE-YASA(m=10)',
  'ACTS-IPOG-FT',
 'ACTS-IPOG-CSP',
 'ACTS-IPOF-FT',
 'ACTS-IPOF-CSP']
t = gaps[gaps["algorithm_name"].isin(algorithm_selection)].copy()
t.dropna(inplace=True)
t = t.groupby("instance_name")[["algorithm_name"]].nunique()
instances_solved_by_all = t[t["algorithm_name"] == len(algorithm_selection)].index.tolist()
instances_solved_by_all
# Out:
# ['APL',
#  'APL-Model',
#  'ChatClient',
#  'FameDB',
#  'FeatureIDE',
#  'axTLS',
#  'calculate',
#  'car',
#  'dell',
#  'email',
#  'gpl',
#  'lcm']

# %%
print(len(instances_solved_by_all), "instances solved by all")
# Out:
# 12 instances solved by all

# %%
t = gaps[gaps["instance_name"].isin(instances_solved_by_all)].copy()
t["Instances"] = f"Common subset [{len(instances_solved_by_all)}]"
gaps["Instances"] = "Ignore unsolved"
gaps = pd.concat([gaps, t], ignore_index=True)
gaps
# Out:
#      algorithm_name               instance_name        gap           Instances
# 0           SampLNS  toybox_2006-10-31_23-30-06   0.000000     Ignore unsolved
# 1           SampLNS  toybox_2006-10-31_23-30-06   0.000000     Ignore unsolved
# 2           SampLNS  toybox_2006-10-31_23-30-06   0.000000     Ignore unsolved
# 3           SampLNS  toybox_2006-10-31_23-30-06   0.000000     Ignore unsolved
# 4           SampLNS  toybox_2006-10-31_23-30-06   0.000000     Ignore unsolved
# ...             ...                         ...        ...                 ...
# 3651     YASA(m=10)                       axTLS  37.500000  Common subset [12]
# 3652   ACTS-IPOG-FT                       axTLS  47.368421  Common subset [12]
# 3653  ACTS-IPOG-CSP                       axTLS  47.368421  Common subset [12]
# 3654   ACTS-IPOF-FT                       axTLS  47.368421  Common subset [12]
# 3655  ACTS-IPOF-CSP                       axTLS  47.368421  Common subset [12]
#
# [3656 rows x 4 columns]

# %%
gaps["solved"] = 0.0
gaps.loc[~gaps["gap"].isna(), "solved"]=1
gaps.groupby(["algorithm_name"])[["gap"]].mean()
# Out:
#                        gap
# algorithm_name
# ACTS-IPOF-CSP    33.355221
# ACTS-IPOF-FT     34.227927
# ACTS-IPOG-CSP    34.613582
# ACTS-IPOG-FT     34.946004
# FIDE-Chvatal     38.881918
# FIDE-ICPL        38.872792
# FIDE-YASA(m=1)   34.616335
# FIDE-YASA(m=10)  27.718553
# FIDE-YASA(m=3)   29.476919
# FIDE-YASA(m=5)   28.753263
# Incling          45.938131
# SampLNS           6.887182
# YASA(m=1)        32.787477
# YASA(m=10)       26.855969
# YASA(m=3)        29.033939
# YASA(m=5)        28.145843

# %%
num_instances_solved_by_alg = gaps.dropna().groupby("algorithm_name")["instance_name"].nunique().to_dict()
num_instances_solved_by_alg
# Out:
# {'ACTS-IPOF-CSP': 13,
#  'ACTS-IPOF-FT': 14,
#  'ACTS-IPOG-CSP': 14,
#  'ACTS-IPOG-FT': 14,
#  'FIDE-Chvatal': 37,
#  'FIDE-ICPL': 45,
#  'FIDE-YASA(m=1)': 46,
#  'FIDE-YASA(m=10)': 46,
#  'FIDE-YASA(m=3)': 46,
#  'FIDE-YASA(m=5)': 46,
#  'Incling': 45,
#  'SampLNS': 46,
#  'YASA(m=1)': 46,
#  'YASA(m=10)': 46,
#  'YASA(m=3)': 46,
#  'YASA(m=5)': 46}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

t = gaps[gaps["algorithm_name"].isin(algorithm_selection)].copy()

f, ax = plt.subplots(figsize=(6, 3))
t["algorithm_name"] = t["algorithm_name"].apply(lambda s: f"{s} [{num_instances_solved_by_alg[s]}]")
t["algorithm_name"] = t["algorithm_name"].str.replace("FIDE-", "")
plt.title("Lower is better")
sns.barplot(data=t, y="algorithm_name", x="gap", hue="Instances")
plt.xlabel("Difference to best known lower bound (%)")
plt.ylabel("Algorithm [# solved]")
plt.legend(loc="lower right", title="Evaluation method")
plt.xlim(0, 65)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

t = gaps[gaps["algorithm_name"].isin(algorithm_selection)].copy()
t = t[t["Instances"]=="Ignore unsolved"]
f, ax = plt.subplots(figsize=(6, 3))
t["algorithm_name"] = t["algorithm_name"].apply(lambda s: f"{s} [{num_instances_solved_by_alg[s]}]")
t["algorithm_name"] = t["algorithm_name"].str.replace("FIDE-", "")
plt.title("Lower is better")
sns.barplot(data=t, y="algorithm_name", x="gap")
plt.xlabel("Difference to best known lower bound (%)")
plt.ylabel("Algorithm [# solved]")
#plt.legend(loc="lower right", title="Evaluation method")
plt.xlim(0, 65)
plt.show()
