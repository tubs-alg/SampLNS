# %%
import pandas as pd

data = pd.read_json("./05_clean_data.json.zip")
data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0          16           13         YASA        t2_m1_null             0.202
# 1          28           39         YASA        t2_m1_null             0.214
# 2         119          346         YASA        t2_m1_null             0.302
# 3          28           40         YASA        t2_m1_null             0.213
# 4          46          244         YASA        t2_m1_null             0.253
# ..        ...          ...          ...               ...               ...
# 225       557         4992         YASA        t2_m1_null             2.509
# 226        39           77         YASA        t2_m1_null             0.227
# 227        96          183         YASA        t2_m1_null             0.258
# 228       326          499         YASA        t2_m1_null             0.487
# 229       272         1670         YASA        t2_m1_null             1.274
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      10   2023-03-01_13-51-03/5_1_7_1_sample.csv
# 1                      12  2023-03-01_13-51-03/11_1_7_1_sample.csv
# 2                      22  2023-03-01_13-51-03/20_1_7_4_sample.csv
# 3                      15  2023-03-01_13-51-03/12_1_7_1_sample.csv
# 4                      38  2023-03-01_13-51-03/15_1_7_5_sample.csv
# ..                    ...                                      ...
# 225                   398  2023-03-01_13-51-03/33_1_7_5_sample.csv
# 226                    17  2023-03-01_13-51-03/14_1_7_1_sample.csv
# 227                    17  2023-03-01_13-51-03/18_1_7_5_sample.csv
# 228                    22  2023-03-01_13-51-03/28_1_7_5_sample.csv
# 229                   369  2023-03-01_13-51-03/27_1_7_1_sample.csv
#
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                   instance_name  lower_bound  upper_bound  \
# 0    toybox_2006-10-31_23-30-06            8            8
# 1                      TightVNC            8            8
# 2                   berkeleyDB2           11           12
# 3                     APL-Model            8            8
# 4                          dell           31           31
# ..                          ...          ...          ...
# 225               fs_2017-05-22          396          396
# 226                 SortingLine            9            9
# 227                       axTLS           10           11
# 228                      E-Shop            8           12
# 229  uclibc_2020-12-24_11-54-53          365          365
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 232, 'nbrhd_confs': 8, 'iter...              0.202
# 1    [{'nbrhd_tuples': 249, 'nbrhd_confs': 9, 'iter...              0.214
# 2    [{'nbrhd_tuples': 198, 'nbrhd_confs': 6, 'iter...              0.302
# 3    [{'nbrhd_tuples': 242, 'nbrhd_confs': 10, 'ite...              0.213
# 4    [{'nbrhd_tuples': 246, 'nbrhd_confs': 22, 'ite...              0.253
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...              2.509
# 226  [{'nbrhd_tuples': 202, 'nbrhd_confs': 11, 'ite...              0.227
# 227  [{'nbrhd_tuples': 163, 'nbrhd_confs': 7, 'iter...              0.258
# 228  [{'nbrhd_tuples': 217, 'nbrhd_confs': 4, 'iter...              0.487
# 229  [{'nbrhd_tuples': 248, 'nbrhd_confs': 42, 'ite...              1.274
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                 3599.798          True        10.786948        3600
# 1                 3599.786          True       359.828161        3600
# 2                 3599.698          True      3613.428668        3600
# 3                 3599.787          True       194.122723        3600
# 4                 3599.747          True        79.593106        3600
# ..                     ...           ...              ...         ...
# 225               3597.491          True       457.258101        3600
# 226               3599.773          True        38.335659        3600
# 227               3599.742          True      3602.234645        3600
# 228               3599.513          True      3616.875958        3600
# 229               3598.726          True       329.659227        3600
#
# [230 rows x 17 columns]

# %%
# calculate the best known lower bound
best_lower_bound = data.groupby(["instance_name"])["lower_bound"].max().reset_index().rename(columns={"lower_bound": "best_lower_bound"})
data = data.merge(best_lower_bound, on="instance_name")

# %%
# calculate the best upper bound
best_upper_bound = data.groupby(["instance_name"])["upper_bound"].min().reset_index().rename(columns={"upper_bound": "best_upper_bound"})
data = data.merge(best_upper_bound, on="instance_name")

# %%
best_bounds = best_lower_bound.merge(best_upper_bound, on=['instance_name'])
best_bounds["note"] = "60min runtime, 60s iterations"
best_bounds.to_csv("./out/06_best_bounds.csv", index=False)
pd.read_csv("./out/06_best_bounds.csv")
# Out:
#                   instance_name  best_lower_bound  best_upper_bound  \
# 0                           APL                 7                 7
# 1                     APL-Model                 8                 8
# 2               BankingSoftware                28                29
# 3                 BattleofTanks               256               313
# 4                    ChatClient                 7                 7
# 5                          DMIE                16                16
# 6                        E-Shop                 8                12
# 7                    EMBToolkit              1872              1872
# 8                        FameDB                 8                 8
# 9                    FeatureIDE                 7                 8
# 10                FreeBSD-8_0_0                30                54
# 11                          PPU                12                12
# 12                     SafeBali                11                11
# 13                  SortingLine                 9                 9
# 14                     TightVNC                 8                 8
# 15                       Violet                15                17
# 16            WaterlooGenerated                82                82
# 17                     XSEngine                32                40
# 18                     aaed2000                51                57
# 19                     am31_sim                28                38
# 20             atlas_mips32_4kc                33                40
# 21                        axTLS                10                11
# 22                  berkeleyDB1                15                15
# 23                  berkeleyDB2                11                12
# 24               busybox-1_18_0                12                18
# 25               busybox-1_29_2                19                23
# 26  busybox_2007-01-24_09-14-09                21                21
# 27  busybox_2020-12-16_21-53-05                18                22
# 28                    calculate                 5                 5
# 29                          car                 5                 5
# 30                         dell                31                31
# 31              eCos-3-0_i386pc                33                48
# 32                       ea2468                31                42
# 33                        email                 6                 6
# 34   fiasco_2017-09-26_11-30-56               225               225
# 35   fiasco_2020-12-01_14-09-14               196               196
# 36           financial_services              4304              4363
# 37                fs_2017-05-22               396               396
# 38                          gpl                16                16
# 39              integrator_arm7                32                40
# 40                          lcm                 6                 6
# 41  soletta_2015-06-26_18-38-56                24                24
# 42   toybox_2006-10-31_23-30-06                 8                 8
# 43   toybox_2020-12-06_00-02-46                 7                13
# 44   uclibc_2008-06-05_13-46-47               505               505
# 45   uclibc_2020-12-24_11-54-53               365               365
#
#                              note
# 0   60min runtime, 60s iterations
# 1   60min runtime, 60s iterations
# 2   60min runtime, 60s iterations
# 3   60min runtime, 60s iterations
# 4   60min runtime, 60s iterations
# 5   60min runtime, 60s iterations
# 6   60min runtime, 60s iterations
# 7   60min runtime, 60s iterations
# 8   60min runtime, 60s iterations
# 9   60min runtime, 60s iterations
# 10  60min runtime, 60s iterations
# 11  60min runtime, 60s iterations
# 12  60min runtime, 60s iterations
# 13  60min runtime, 60s iterations
# 14  60min runtime, 60s iterations
# 15  60min runtime, 60s iterations
# 16  60min runtime, 60s iterations
# 17  60min runtime, 60s iterations
# 18  60min runtime, 60s iterations
# 19  60min runtime, 60s iterations
# 20  60min runtime, 60s iterations
# 21  60min runtime, 60s iterations
# 22  60min runtime, 60s iterations
# 23  60min runtime, 60s iterations
# 24  60min runtime, 60s iterations
# 25  60min runtime, 60s iterations
# 26  60min runtime, 60s iterations
# 27  60min runtime, 60s iterations
# 28  60min runtime, 60s iterations
# 29  60min runtime, 60s iterations
# 30  60min runtime, 60s iterations
# 31  60min runtime, 60s iterations
# 32  60min runtime, 60s iterations
# 33  60min runtime, 60s iterations
# 34  60min runtime, 60s iterations
# 35  60min runtime, 60s iterations
# 36  60min runtime, 60s iterations
# 37  60min runtime, 60s iterations
# 38  60min runtime, 60s iterations
# 39  60min runtime, 60s iterations
# 40  60min runtime, 60s iterations
# 41  60min runtime, 60s iterations
# 42  60min runtime, 60s iterations
# 43  60min runtime, 60s iterations
# 44  60min runtime, 60s iterations
# 45  60min runtime, 60s iterations

# %%
# calculate best baseline algorithm sample
baseline_data = pd.read_json("./00_simple_baseline_data.json.zip")
best_baseline = baseline_data.groupby(["instance_name"])[["sample_size"]].min().reset_index().rename(columns={"sample_size": "best_baseline_sample_size"})
data = data.merge(best_baseline, on="instance_name", how="left")

# %%
t = data.groupby("instance_name")[["num_vars", "num_clauses", "best_baseline_sample_size", "baseline_sample_size", "upper_bound", "lower_bound", "best_upper_bound", "best_lower_bound"]].mean()
t.sort_values(["num_vars", "num_clauses"], inplace=True)
# checking consistency is important.
assert (t["best_lower_bound"]<=t["best_baseline_sample_size"]).all()
assert (t["best_upper_bound"]>=t["best_lower_bound"]).all()
t
# Out:
#                              num_vars  num_clauses  best_baseline_sample_size  \
# instance_name
# calculate                         9.0         15.0                        9.0
# lcm                               9.0         16.0                        8.0
# email                            10.0         17.0                        6.0
# ChatClient                       14.0         20.0                        8.0
# toybox_2006-10-31_23-30-06       16.0         13.0                        9.0
# car                              16.0         33.0                        6.0
# FeatureIDE                       19.0         27.0                       11.0
# FameDB                           22.0         40.0                        8.0
# APL                              23.0         35.0                        9.0
# SafeBali                         24.0         45.0                       11.0
# TightVNC                         28.0         39.0                       10.0
# APL-Model                        28.0         40.0                       10.0
# gpl                              38.0         99.0                       18.0
# SortingLine                      39.0         77.0                       12.0
# dell                             46.0        244.0                       34.0
# PPU                              52.0        109.0                       12.0
# berkeleyDB1                      76.0        147.0                       19.0
# axTLS                            96.0        183.0                       16.0
# Violet                          101.0        203.0                       23.0
# berkeleyDB2                     119.0        346.0                       21.0
# soletta_2015-06-26_18-38-56     129.0        192.0                       30.0
# BattleofTanks                   144.0        769.0                      444.0
# BankingSoftware                 176.0        280.0                       40.0
# fiasco_2017-09-26_11-30-56      230.0       1181.0                      237.0
# fiasco_2020-12-01_14-09-14      258.0       1542.0                      213.0
# uclibc_2008-06-05_13-46-47      263.0       1699.0                      506.0
# uclibc_2020-12-24_11-54-53      272.0       1670.0                      365.0
# E-Shop                          326.0        499.0                       20.0
# toybox_2020-12-06_00-02-46      334.0         92.0                       18.0
# DMIE                            366.0        627.0                       25.0
# busybox_2007-01-24_09-14-09     540.0        429.0                       35.0
# fs_2017-05-22                   557.0       4992.0                      398.0
# WaterlooGenerated               580.0        879.0                      144.0
# financial_services              771.0       7238.0                     4396.0
# busybox-1_18_0                  854.0       1164.0                       29.0
# busybox-1_29_2                 1018.0        997.0                       37.0
# busybox_2020-12-16_21-53-05    1050.0        996.0                       34.0
# am31_sim                       1178.0       2747.0                       61.0
# EMBToolkit                     1179.0       5414.0                     1883.0
# atlas_mips32_4kc               1229.0       2875.0                       66.0
# eCos-3-0_i386pc                1245.0       3723.0                       66.0
# integrator_arm7                1272.0       2980.0                       66.0
# XSEngine                       1273.0       2942.0                       63.0
# aaed2000                       1298.0       3036.0                       89.0
# FreeBSD-8_0_0                  1397.0      15692.0                       76.0
# ea2468                         1408.0       3319.0                       65.0
#
#                              baseline_sample_size  upper_bound  lower_bound  \
# instance_name
# calculate                                    10.0          5.0          5.0
# lcm                                           8.0          6.0          6.0
# email                                         7.0          6.0          6.0
# ChatClient                                    8.0          7.0          7.0
# toybox_2006-10-31_23-30-06                   10.0          8.0          8.0
# car                                           7.0          5.0          5.0
# FeatureIDE                                   12.0          8.0          7.0
# FameDB                                        8.0          8.0          8.0
# APL                                          10.0          7.0          7.0
# SafeBali                                     11.0         11.0         10.4
# TightVNC                                     12.0          8.0          8.0
# APL-Model                                    15.0          8.0          8.0
# gpl                                          22.0         16.0         15.8
# SortingLine                                  17.0          9.0          9.0
# dell                                         38.0         31.0         31.0
# PPU                                          16.0         12.0         12.0
# berkeleyDB1                                  23.0         15.0         15.0
# axTLS                                        17.0         11.0         10.0
# Violet                                       27.0         17.0         15.0
# berkeleyDB2                                  22.0         12.0         11.0
# soletta_2015-06-26_18-38-56                  32.0         24.0         24.0
# BattleofTanks                               454.0        315.6        256.0
# BankingSoftware                              43.0         29.0         28.0
# fiasco_2017-09-26_11-30-56                  246.0        225.4        224.0
# fiasco_2020-12-01_14-09-14                  224.0        196.0        196.0
# uclibc_2008-06-05_13-46-47                  510.0        505.0        505.0
# uclibc_2020-12-24_11-54-53                  369.0        365.0        365.0
# E-Shop                                       22.0         12.0          8.0
# toybox_2020-12-06_00-02-46                   20.0         13.2          7.0
# DMIE                                         27.0         16.0         16.0
# busybox_2007-01-24_09-14-09                  39.0         21.0         21.0
# fs_2017-05-22                               398.0        396.0        396.0
# WaterlooGenerated                           149.0         82.0         82.0
# financial_services                         4417.0       4368.2       4271.6
# busybox-1_18_0                               30.0         18.0         12.0
# busybox-1_29_2                               44.0         23.4         17.4
# busybox_2020-12-16_21-53-05                  39.0         22.4         18.0
# am31_sim                                     65.0         38.0         25.0
# EMBToolkit                                 1883.0       1872.0       1860.0
# atlas_mips32_4kc                             77.0         41.0         31.0
# eCos-3-0_i386pc                              70.0         49.2         28.0
# integrator_arm7                              71.0         41.0         30.4
# XSEngine                                     69.0         41.0         31.4
# aaed2000                                     95.0         58.2         49.8
# FreeBSD-8_0_0                                81.0         55.8         28.0
# ea2468                                       72.0         42.2         29.0
#
#                              best_upper_bound  best_lower_bound
# instance_name
# calculate                                 5.0               5.0
# lcm                                       6.0               6.0
# email                                     6.0               6.0
# ChatClient                                7.0               7.0
# toybox_2006-10-31_23-30-06                8.0               8.0
# car                                       5.0               5.0
# FeatureIDE                                8.0               7.0
# FameDB                                    8.0               8.0
# APL                                       7.0               7.0
# SafeBali                                 11.0              11.0
# TightVNC                                  8.0               8.0
# APL-Model                                 8.0               8.0
# gpl                                      16.0              16.0
# SortingLine                               9.0               9.0
# dell                                     31.0              31.0
# PPU                                      12.0              12.0
# berkeleyDB1                              15.0              15.0
# axTLS                                    11.0              10.0
# Violet                                   17.0              15.0
# berkeleyDB2                              12.0              11.0
# soletta_2015-06-26_18-38-56              24.0              24.0
# BattleofTanks                           313.0             256.0
# BankingSoftware                          29.0              28.0
# fiasco_2017-09-26_11-30-56              225.0             225.0
# fiasco_2020-12-01_14-09-14              196.0             196.0
# uclibc_2008-06-05_13-46-47              505.0             505.0
# uclibc_2020-12-24_11-54-53              365.0             365.0
# E-Shop                                   12.0               8.0
# toybox_2020-12-06_00-02-46               13.0               7.0
# DMIE                                     16.0              16.0
# busybox_2007-01-24_09-14-09              21.0              21.0
# fs_2017-05-22                           396.0             396.0
# WaterlooGenerated                        82.0              82.0
# financial_services                     4363.0            4304.0
# busybox-1_18_0                           18.0              12.0
# busybox-1_29_2                           23.0              19.0
# busybox_2020-12-16_21-53-05              22.0              18.0
# am31_sim                                 38.0              28.0
# EMBToolkit                             1872.0            1872.0
# atlas_mips32_4kc                         40.0              33.0
# eCos-3-0_i386pc                          48.0              33.0
# integrator_arm7                          40.0              32.0
# XSEngine                                 40.0              32.0
# aaed2000                                 57.0              51.0
# FreeBSD-8_0_0                            54.0              30.0
# ea2468                                   42.0              31.0

# %%
data[["instance_name", "best_lower_bound", "best_upper_bound"]]
# Out:
#                   instance_name  best_lower_bound  best_upper_bound
# 0    toybox_2006-10-31_23-30-06                 8                 8
# 1    toybox_2006-10-31_23-30-06                 8                 8
# 2    toybox_2006-10-31_23-30-06                 8                 8
# 3    toybox_2006-10-31_23-30-06                 8                 8
# 4    toybox_2006-10-31_23-30-06                 8                 8
# ..                          ...               ...               ...
# 225                       email                 6                 6
# 226                       email                 6                 6
# 227                       email                 6                 6
# 228                       email                 6                 6
# 229                       email                 6                 6
#
# [230 rows x 3 columns]
