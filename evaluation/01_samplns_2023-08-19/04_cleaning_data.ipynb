# %% [markdown]
# # Cleaning the data and providing a small and easily parsable database.
#
# The database with the full logs is too huge to work on. Most of the data would only be needed for debugging but not for evaluation.
# Thus, we create a clean and small database for the further evaluation.

# %%
import pandas as pd
from _conf import (
    RESULT_FOLDER,EXTENDED_BASELINE_DATA
)
from algbench import read_as_pandas

# %%
# Read the baseline results for comparison. They also already contain instance data (num_clauses and num_features).
baseline_data = pd.read_json(EXTENDED_BASELINE_DATA)
baseline_data.rename(columns={"sample_size": "baseline_sample_size"}, inplace=True)
baseline_data
# Out:
#                    instance_name  num_vars  num_clauses  baseline_alg  \
# 0                      calculate         9           15  ACTS-IPOG-FT
# 1                            lcm         9           16  ACTS-IPOG-FT
# 2                          email        10           17  ACTS-IPOG-FT
# 3                     ChatClient        14           20  ACTS-IPOG-FT
# 4     toybox_2006-10-31_23-30-06        16           13  ACTS-IPOG-FT
# ...                          ...       ...          ...           ...
# 1945                      freetz     31012       102705     FIDE-YASA
# 1946                      freetz     31012       102705     FIDE-YASA
# 1947                      freetz     31012       102705     FIDE-YASA
# 1948                      freetz     31012       102705     FIDE-YASA
# 1949                      freetz     31012       102705     FIDE-YASA
#
#      baseline_alg_conf  runtime  baseline_sample_size  \
# 0                   t2     1620                   9.0
# 1                   t2      485                   9.0
# 2                   t2      514                   8.0
# 3                   t2      538                  10.0
# 4                   t2      485                  13.0
# ...                ...      ...                   ...
# 1945       t2_m10_null   900009                   NaN
# 1946       t2_m10_null   900008                   NaN
# 1947       t2_m10_null   900008                   NaN
# 1948       t2_m10_null   900008                   NaN
# 1949       t2_m10_null   900008                   NaN
#
#                                 path_to_baseline_sample  \
# 0     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 1     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 2     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 3     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 4     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# ...                                                 ...
# 1945                                               None
# 1946                                               None
# 1947                                               None
# 1948                                               None
# 1949                                               None
#
#                                archive_path
# 0             ./EXTERNAL_INPUT/baseline.zip
# 1             ./EXTERNAL_INPUT/baseline.zip
# 2             ./EXTERNAL_INPUT/baseline.zip
# 3             ./EXTERNAL_INPUT/baseline.zip
# 4             ./EXTERNAL_INPUT/baseline.zip
# ...                                     ...
# 1945  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1946  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1947  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1948  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1949  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
# [1950 rows x 9 columns]

# %%
# Get the data from the result folder
samplns_data = read_as_pandas(
    RESULT_FOLDER,
    lambda result: {
        "parameters": result["parameters"],
        "initial_sample_path": result["parameters"]["args"]["initial_sample_path"],
        "instance_name": result["parameters"]["args"]["instance_name"],
        "lower_bound": result["result"]["lower_bound"],
        "upper_bound": len(result["result"]["solution"]),
        "iteration_info": result["result"]["iteration_info"],
        "time_used_by_yasa": result["result"]["time_used_by_yasa"],
        "timelimit_for_samplns": result["result"]["timelimit_for_samplns"],
        "samplns_used": result["result"]["samplns_used"],
        "runtime": result["runtime"],
        "time_limit": result["parameters"]["args"]["time_limit"],
    }
    if result.get("result", None) and result.get("result", {}).get("solution", None)
    else None,
)
samplns_data.drop_duplicates(subset=["initial_sample_path"], inplace=True)
samplns_data
# Out:
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                          initial_sample_path               instance_name  \
# 0    2023-03-01_13-51-03/36_1_3_2_sample.csv              busybox-1_18_0
# 1    2023-03-01_13-51-03/12_1_3_4_sample.csv                   APL-Model
# 2    2023-03-01_13-51-03/29_1_3_4_sample.csv  toybox_2020-12-06_00-02-46
# 3    2023-03-01_13-51-03/28_1_3_1_sample.csv                      E-Shop
# 4    2023-03-01_13-51-03/28_1_3_3_sample.csv                      E-Shop
# ..                                       ...                         ...
# 225   2023-03-01_13-51-03/9_1_3_5_sample.csv                         APL
# 226  2023-03-01_13-51-03/46_1_3_1_sample.csv               FreeBSD-8_0_0
# 227  2023-03-01_13-51-03/42_1_3_4_sample.csv             eCos-3-0_i386pc
# 228  2023-03-01_13-51-03/33_1_3_1_sample.csv               fs_2017-05-22
# 229  2023-03-01_13-51-03/46_1_3_3_sample.csv               FreeBSD-8_0_0
#
#      lower_bound  upper_bound  \
# 0           12.0           18
# 1            8.0            8
# 2            7.0           14
# 3            8.0           12
# 4            8.0           12
# ..           ...          ...
# 225          7.0            7
# 226         25.0           63
# 227         26.0           53
# 228        396.0          396
# 229         28.0           68
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 141, 'nbrhd_confs': 1, 'iter...              2.639
# 1    [{'nbrhd_tuples': 204, 'nbrhd_confs': 11, 'ite...              0.312
# 2    [{'nbrhd_tuples': 171, 'nbrhd_confs': 1, 'iter...              0.741
# 3    [{'nbrhd_tuples': 48, 'nbrhd_confs': 2, 'itera...              0.736
# 4    [{'nbrhd_tuples': 131, 'nbrhd_confs': 4, 'iter...              0.737
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 207, 'nbrhd_confs': 10, 'ite...              0.300
# 226  [{'nbrhd_tuples': 240, 'nbrhd_confs': 6, 'iter...             14.082
# 227  [{'nbrhd_tuples': 211, 'nbrhd_confs': 3, 'iter...              4.817
# 228  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...              2.124
# 229  [{'nbrhd_tuples': 107, 'nbrhd_confs': 2, 'iter...             14.061
#
#      timelimit_for_samplns  samplns_used     runtime  time_limit
# 0                  897.361          True  916.832970         900
# 1                  899.688          True  145.871509         900
# 2                  899.259          True  902.233030         900
# 3                  899.264          True  924.385270         900
# 4                  899.263          True  928.903876         900
# ..                     ...           ...         ...         ...
# 225                899.700          True    8.232830         900
# 226                885.918          True  911.483217         900
# 227                895.183          True  897.367976         900
# 228                897.876          True  420.326800         900
# 229                885.939          True  894.766397         900
#
# [230 rows x 11 columns]

# %%
# Pull the baseline info into the data frame
samplns_data_with_baseline_infos = baseline_data.merge(
    right=samplns_data,
    left_on="path_to_baseline_sample",
    right_on="initial_sample_path",
    how="right",
    suffixes=("_baseline", "_samplns"),
)
samplns_data_with_baseline_infos.drop(
    columns=["instance_name_baseline", "initial_sample_path"], inplace=True
)
samplns_data_with_baseline_infos.rename(
    columns={"instance_name_samplns": "instance_name"}, inplace=True
)
samplns_data_with_baseline_infos
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0         854         1164    FIDE-YASA        t2_m1_null              2639
# 1          28           40    FIDE-YASA        t2_m1_null               312
# 2         334           92    FIDE-YASA        t2_m1_null               741
# 3         326          499    FIDE-YASA        t2_m1_null               736
# 4         326          499    FIDE-YASA        t2_m1_null               737
# ..        ...          ...          ...               ...               ...
# 225        23           35    FIDE-YASA        t2_m1_null               300
# 226      1397        15692    FIDE-YASA        t2_m1_null             14082
# 227      1245         3723    FIDE-YASA        t2_m1_null              4817
# 228       557         4992    FIDE-YASA        t2_m1_null              2124
# 229      1397        15692    FIDE-YASA        t2_m1_null             14061
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                    30.0  2023-03-01_13-51-03/36_1_3_2_sample.csv
# 1                    15.0  2023-03-01_13-51-03/12_1_3_4_sample.csv
# 2                    19.0  2023-03-01_13-51-03/29_1_3_4_sample.csv
# 3                    22.0  2023-03-01_13-51-03/28_1_3_1_sample.csv
# 4                    22.0  2023-03-01_13-51-03/28_1_3_3_sample.csv
# ..                    ...                                      ...
# 225                  11.0   2023-03-01_13-51-03/9_1_3_5_sample.csv
# 226                  91.0  2023-03-01_13-51-03/46_1_3_1_sample.csv
# 227                  77.0  2023-03-01_13-51-03/42_1_3_4_sample.csv
# 228                 400.0  2023-03-01_13-51-03/33_1_3_1_sample.csv
# 229                  91.0  2023-03-01_13-51-03/46_1_3_3_sample.csv
#
#                               archive_path  \
# 0    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 3    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 4    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# ..                                     ...
# 225  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 226  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 227  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 228  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 229  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                   instance_name  lower_bound  upper_bound  \
# 0                busybox-1_18_0         12.0           18
# 1                     APL-Model          8.0            8
# 2    toybox_2020-12-06_00-02-46          7.0           14
# 3                        E-Shop          8.0           12
# 4                        E-Shop          8.0           12
# ..                          ...          ...          ...
# 225                         APL          7.0            7
# 226               FreeBSD-8_0_0         25.0           63
# 227             eCos-3-0_i386pc         26.0           53
# 228               fs_2017-05-22        396.0          396
# 229               FreeBSD-8_0_0         28.0           68
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 141, 'nbrhd_confs': 1, 'iter...              2.639
# 1    [{'nbrhd_tuples': 204, 'nbrhd_confs': 11, 'ite...              0.312
# 2    [{'nbrhd_tuples': 171, 'nbrhd_confs': 1, 'iter...              0.741
# 3    [{'nbrhd_tuples': 48, 'nbrhd_confs': 2, 'itera...              0.736
# 4    [{'nbrhd_tuples': 131, 'nbrhd_confs': 4, 'iter...              0.737
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 207, 'nbrhd_confs': 10, 'ite...              0.300
# 226  [{'nbrhd_tuples': 240, 'nbrhd_confs': 6, 'iter...             14.082
# 227  [{'nbrhd_tuples': 211, 'nbrhd_confs': 3, 'iter...              4.817
# 228  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...              2.124
# 229  [{'nbrhd_tuples': 107, 'nbrhd_confs': 2, 'iter...             14.061
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                  897.361          True       916.832970         900
# 1                  899.688          True       145.871509         900
# 2                  899.259          True       902.233030         900
# 3                  899.264          True       924.385270         900
# 4                  899.263          True       928.903876         900
# ..                     ...           ...              ...         ...
# 225                899.700          True         8.232830         900
# 226                885.918          True       911.483217         900
# 227                895.183          True       897.367976         900
# 228                897.876          True       420.326800         900
# 229                885.939          True       894.766397         900
#
# [230 rows x 18 columns]

# %%
# Check that we have all results.
samplns_data_with_baseline_infos.groupby(["instance_name"]).size()
# Out:
# instance_name
# APL                            5
# APL-Model                      5
# BankingSoftware                5
# BattleofTanks                  5
# ChatClient                     5
# DMIE                           5
# E-Shop                         5
# EMBToolkit                     5
# FameDB                         5
# FeatureIDE                     5
# FreeBSD-8_0_0                  5
# PPU                            5
# SafeBali                       5
# SortingLine                    5
# TightVNC                       5
# Violet                         5
# WaterlooGenerated              5
# XSEngine                       5
# aaed2000                       5
# am31_sim                       5
# atlas_mips32_4kc               5
# axTLS                          5
# berkeleyDB1                    5
# berkeleyDB2                    5
# busybox-1_18_0                 5
# busybox-1_29_2                 5
# busybox_2007-01-24_09-14-09    5
# busybox_2020-12-16_21-53-05    5
# calculate                      5
# car                            5
# dell                           5
# eCos-3-0_i386pc                5
# ea2468                         5
# email                          5
# fiasco_2017-09-26_11-30-56     5
# fiasco_2020-12-01_14-09-14     5
# financial_services             5
# fs_2017-05-22                  5
# gpl                            5
# integrator_arm7                5
# lcm                            5
# soletta_2015-06-26_18-38-56    5
# toybox_2006-10-31_23-30-06     5
# toybox_2020-12-06_00-02-46     5
# uclibc_2008-06-05_13-46-47     5
# uclibc_2020-12-24_11-54-53     5
# dtype: int64

# %%
# Will stop the notebook if the data is bad
assert samplns_data_with_baseline_infos.groupby(["instance_name"]).size().min() == 5
assert samplns_data_with_baseline_infos.groupby(["instance_name"]).size().max() == 5

# %%
# Save the cleaned data to a json file
samplns_data_with_baseline_infos.to_json("./05_clean_data.json.zip")

# %%
# This just for looking into one instance.
t = read_as_pandas(
    RESULT_FOLDER,
    lambda result: {
        "parameters": result["parameters"],
        "initial_sample_path": result["parameters"]["args"]["initial_sample_path"],
        "instance_name": result["parameters"]["args"]["instance_name"],
        "lower_bound": result["result"]["lower_bound"],
        "upper_bound": len(result["result"]["solution"]),
        "iteration_info": result["result"]["iteration_info"],
        "time_used_by_yasa": result["result"]["time_used_by_yasa"],
        "timelimit_for_samplns": result["result"]["timelimit_for_samplns"],
        "samplns_used": result["result"]["samplns_used"],
        "instance": result["parameters"]["args"]["instance_name"],
        "logging": result["logging"],
    }
    if result.get("result", None) and result.get("result", {}).get("solution", None)
    else None,
)
t = t[t["instance_name"] == "toybox_2020-12-06_00-02-46"]
for e in t.iloc[0]["logging"]:
    print(e["message"])
# Out:
# Parsed instance 'models/toybox_2020-12-06_00-02-46' with 334 features and 92 rules.
# Preprocessing instance (Instance[models/toybox_2020-12-06_00-02-46]<334 features, 92 rules>).
# Converting instance to CNF (Instance[models/toybox_2020-12-06_00-02-46|EQ]<334 features, 92 rules>).
# Finished converting instance to CNF (Instance[models/toybox_2020-12-06_00-02-46|EQ|CNF]<334 features, 92 rules>).
# Finnished preprocessing (Instance[models/toybox_2020-12-06_00-02-46|EQ|CNF]<334 features, 92 rules>).
# Setting up random neighborhood selector.
# Computing feasible tuples...
# Converted sample to list representation.
# Instance has 206665 feasible tuples.
# Neighborhood selector is ready.
# Building transaction graph for models/toybox_2020-12-06_00-02-46|EQ|CNF with 334 concrete features!
# All valid configurations were added to the transaction graph.
# Setting up random neighborhood selector.
# Computing feasible tuples...
# Converted sample to list representation.
# Instance has 206665 feasible tuples.
# Neighborhood selector is ready.
# Beginning optimization with the following parameters: iterations=10000, iteration_timelimit=60.000000, timelimit=899.259000
# Async Solver started with iteration timelimit 60
# Beginning iteration 0.
# Selected neighborhood, removing 1 configurations, leaving 171 tuples uncovered.
# Optimized neighborhood, lb=1, ub=1.
# Increasing neighborhood size to 312 tuples.
# Beginning iteration 1.
# Selected neighborhood, removing 1 configurations, leaving 229 tuples uncovered.
# Optimized neighborhood, lb=1, ub=1.
# Increasing neighborhood size to 390 tuples.
# Beginning iteration 2.
# Selected neighborhood, removing 1 configurations, leaving 217 tuples uncovered.
# Optimized neighborhood, lb=1, ub=1.
# Increased lower bound to 7 (from 0).
# Increasing neighborhood size to 488 tuples.
# Beginning iteration 3.
# Selected neighborhood, removing 2 configurations, leaving 242 tuples uncovered.
# [Symmetry Breaking]: (5.922157s left) Independent tuple set with size 2 was found!
# [Symmetry Breaking]: Optimal solution found (2)!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increasing neighborhood size to 610 tuples.
# Beginning iteration 4.
# Selected neighborhood, removing 2 configurations, leaving 335 tuples uncovered.
# [Symmetry Breaking]: (5.853271s left) Independent tuple set with size 2 was found!
# [Symmetry Breaking]: Optimal solution found (2)!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increasing neighborhood size to 762 tuples.
# Beginning iteration 5.
# Selected neighborhood, removing 4 configurations, leaving 274 tuples uncovered.
# [Symmetry Breaking]: (5.436452s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: Optimal solution found (4)!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 4 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 953 tuples.
# Beginning iteration 6.
# Selected neighborhood, removing 3 configurations, leaving 893 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 3.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 1192 tuples.
# Beginning iteration 7.
# Selected neighborhood, removing 5 configurations, leaving 660 tuples uncovered.
# [Symmetry Breaking]: (1.716231s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 1490 tuples.
# Beginning iteration 8.
# Selected neighborhood, removing 5 configurations, leaving 488 tuples uncovered.
# [Symmetry Breaking]: (2.322185s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 1862 tuples.
# Beginning iteration 9.
# Selected neighborhood, removing 4 configurations, leaving 1782 tuples uncovered.
# [Symmetry Breaking]: (-0.048484s left) Independent tuple set with size 2 was found!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 2328 tuples.
# Beginning iteration 10.
# Selected neighborhood, removing 5 configurations, leaving 1559 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 2910 tuples.
# Beginning iteration 11.
# Selected neighborhood, removing 6 configurations, leaving 2089 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 3637 tuples.
# Beginning iteration 12.
# Selected neighborhood, removing 5 configurations, leaving 3326 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 4547 tuples.
# Beginning iteration 13.
# Selected neighborhood, removing 4 configurations, leaving 2875 tuples uncovered.
# [Symmetry Breaking]: (5.941799s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 5684 tuples.
# Beginning iteration 14.
# Selected neighborhood, removing 4 configurations, leaving 3155 tuples uncovered.
# [Symmetry Breaking]: (5.603442s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 7105 tuples.
# Beginning iteration 15.
# Selected neighborhood, removing 6 configurations, leaving 6560 tuples uncovered.
# [Symmetry Breaking]: (5.904184s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (5.084277s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 8881 tuples.
# Beginning iteration 16.
# Selected neighborhood, removing 6 configurations, leaving 8447 tuples uncovered.
# [Symmetry Breaking]: (0.263948s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 11102 tuples.
# Beginning iteration 17.
# Selected neighborhood, removing 6 configurations, leaving 9439 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 13877 tuples.
# Beginning iteration 18.
# Selected neighborhood, removing 6 configurations, leaving 12638 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 17347 tuples.
# Beginning iteration 19.
# Selected neighborhood, removing 7 configurations, leaving 14705 tuples uncovered.
# [Symmetry Breaking]: (5.826892s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (5.656600s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (4.406958s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 13010 tuples.
# Beginning iteration 20.
# Selected neighborhood, removing 7 configurations, leaving 11796 tuples uncovered.
# [Symmetry Breaking]: (5.844451s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (4.068507s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 16263 tuples.
# Beginning iteration 21.
# Selected neighborhood, removing 6 configurations, leaving 11252 tuples uncovered.
# [Symmetry Breaking]: (5.847162s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (5.541993s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (5.478664s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 20328 tuples.
# Beginning iteration 22.
# Selected neighborhood, removing 7 configurations, leaving 18570 tuples uncovered.
# [Symmetry Breaking]: (5.774670s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (3.492052s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 15246 tuples.
# Beginning iteration 23.
# Selected neighborhood, removing 6 configurations, leaving 9591 tuples uncovered.
# [Symmetry Breaking]: (5.836719s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 19058 tuples.
# Beginning iteration 24.
# Selected neighborhood, removing 7 configurations, leaving 17497 tuples uncovered.
# [Symmetry Breaking]: (5.614568s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (5.165324s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 14293 tuples.
# Beginning iteration 25.
# Selected neighborhood, removing 6 configurations, leaving 11562 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 17867 tuples.
# Beginning iteration 26.
# Selected neighborhood, removing 7 configurations, leaving 16475 tuples uncovered.
# [Symmetry Breaking]: (5.800397s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 13400 tuples.
# Beginning iteration 27.
# Selected neighborhood, removing 5 configurations, leaving 10277 tuples uncovered.
# [Symmetry Breaking]: (5.858950s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (5.757057s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 16750 tuples.
# Beginning iteration 28.
# Selected neighborhood, removing 6 configurations, leaving 12316 tuples uncovered.
# [Symmetry Breaking]: (5.840914s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (5.677499s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (1.326057s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 20938 tuples.
# Beginning iteration 29.
# Selected neighborhood, removing 7 configurations, leaving 16987 tuples uncovered.
# [Symmetry Breaking]: (5.787308s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (5.731618s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 15703 tuples.
# Beginning iteration 30.
# Selected neighborhood, removing 6 configurations, leaving 11494 tuples uncovered.
# [Symmetry Breaking]: (5.824127s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=6.
# Decreasing neighborhood size to 11777 tuples.
# Beginning iteration 31.
# Selected neighborhood, removing 6 configurations, leaving 11190 tuples uncovered.
# [Symmetry Breaking]: (5.816205s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 14722 tuples.
# Beginning iteration 32.
# Selected neighborhood, removing 6 configurations, leaving 12586 tuples uncovered.
# [Symmetry Breaking]: (5.822755s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 18402 tuples.
# Beginning iteration 33.
# Selected neighborhood, removing 7 configurations, leaving 13993 tuples uncovered.
# [Symmetry Breaking]: (5.821112s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (-0.050569s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 23003 tuples.
# Beginning iteration 34.
# Selected neighborhood, removing 7 configurations, leaving 13605 tuples uncovered.
# [Symmetry Breaking]: (5.694667s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 17252 tuples.
# Beginning iteration 35.
# Selected neighborhood, removing 6 configurations, leaving 14571 tuples uncovered.
# [Symmetry Breaking]: (5.779734s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 21565 tuples.
# Beginning iteration 36.
# Selected neighborhood, removing 7 configurations, leaving 14799 tuples uncovered.
# [Symmetry Breaking]: (4.578819s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (2.902253s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (1.083941s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 16174 tuples.
# Optimization reached time limit.
# Async Solver stopped

# %%
# Check that we can read the data
data = pd.read_json("./05_clean_data.json.zip")
data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0         854         1164    FIDE-YASA        t2_m1_null              2639
# 1          28           40    FIDE-YASA        t2_m1_null               312
# 2         334           92    FIDE-YASA        t2_m1_null               741
# 3         326          499    FIDE-YASA        t2_m1_null               736
# 4         326          499    FIDE-YASA        t2_m1_null               737
# ..        ...          ...          ...               ...               ...
# 225        23           35    FIDE-YASA        t2_m1_null               300
# 226      1397        15692    FIDE-YASA        t2_m1_null             14082
# 227      1245         3723    FIDE-YASA        t2_m1_null              4817
# 228       557         4992    FIDE-YASA        t2_m1_null              2124
# 229      1397        15692    FIDE-YASA        t2_m1_null             14061
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      30  2023-03-01_13-51-03/36_1_3_2_sample.csv
# 1                      15  2023-03-01_13-51-03/12_1_3_4_sample.csv
# 2                      19  2023-03-01_13-51-03/29_1_3_4_sample.csv
# 3                      22  2023-03-01_13-51-03/28_1_3_1_sample.csv
# 4                      22  2023-03-01_13-51-03/28_1_3_3_sample.csv
# ..                    ...                                      ...
# 225                    11   2023-03-01_13-51-03/9_1_3_5_sample.csv
# 226                    91  2023-03-01_13-51-03/46_1_3_1_sample.csv
# 227                    77  2023-03-01_13-51-03/42_1_3_4_sample.csv
# 228                   400  2023-03-01_13-51-03/33_1_3_1_sample.csv
# 229                    91  2023-03-01_13-51-03/46_1_3_3_sample.csv
#
#                               archive_path  \
# 0    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 3    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 4    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# ..                                     ...
# 225  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 226  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 227  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 228  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 229  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                   instance_name  lower_bound  upper_bound  \
# 0                busybox-1_18_0           12           18
# 1                     APL-Model            8            8
# 2    toybox_2020-12-06_00-02-46            7           14
# 3                        E-Shop            8           12
# 4                        E-Shop            8           12
# ..                          ...          ...          ...
# 225                         APL            7            7
# 226               FreeBSD-8_0_0           25           63
# 227             eCos-3-0_i386pc           26           53
# 228               fs_2017-05-22          396          396
# 229               FreeBSD-8_0_0           28           68
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 141, 'nbrhd_confs': 1, 'iter...              2.639
# 1    [{'nbrhd_tuples': 204, 'nbrhd_confs': 11, 'ite...              0.312
# 2    [{'nbrhd_tuples': 171, 'nbrhd_confs': 1, 'iter...              0.741
# 3    [{'nbrhd_tuples': 48, 'nbrhd_confs': 2, 'itera...              0.736
# 4    [{'nbrhd_tuples': 131, 'nbrhd_confs': 4, 'iter...              0.737
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 207, 'nbrhd_confs': 10, 'ite...              0.300
# 226  [{'nbrhd_tuples': 240, 'nbrhd_confs': 6, 'iter...             14.082
# 227  [{'nbrhd_tuples': 211, 'nbrhd_confs': 3, 'iter...              4.817
# 228  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...              2.124
# 229  [{'nbrhd_tuples': 107, 'nbrhd_confs': 2, 'iter...             14.061
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                  897.361          True       916.832970         900
# 1                  899.688          True       145.871509         900
# 2                  899.259          True       902.233030         900
# 3                  899.264          True       924.385270         900
# 4                  899.263          True       928.903876         900
# ..                     ...           ...              ...         ...
# 225                899.700          True         8.232830         900
# 226                885.918          True       911.483217         900
# 227                895.183          True       897.367976         900
# 228                897.876          True       420.326800         900
# 229                885.939          True       894.766397         900
#
# [230 rows x 18 columns]

# %% [markdown]
# * `instance_name`: The instance name.
# * `num_vars`: The number of variables in the instance.
# * `num_clauses`: The number of clauses in the instance.
# * `baseline_alg`: The baseline algorithm that created the sample
# * `baseline_alg_conf`: The configuration of the baseline algorithm that created the sample.
# * `runtime_baseline`: The runtime of the baseline algorithm that created the sample.
# * `baseline_sample_size`: The size of the sample created by the baseline algorithm.
# * `path_to_baseline_sample`: The path to the sample created by the baseline algorithm.
# * `parameters` The parameters used to run samplns.
# * `lower_bound` The lower bound computed by SampLNS.
# * `upper_bound` The upper bound computed by SampLNS.
# * `iteration_info` Info the extract the progress of SampLNS. The time do not include the baseline algorithm.
# * `time_used_by_yasa` The time used by the baseline algorithm.
# * `timelimit_for_samplns` The time limit for SampLNS. Check also `parameters` for the full timelimit.
# * `runtime_samplns` The runtime of SampLNS without the baseline.
# * `time_limit` The overall timelimit.
