# %%
import pandas as pd

samplns_data = pd.read_json("./05_clean_data.json.zip")
samplns_data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0        1272         2980         YASA        t2_m1_null             3.389
# 1          96          183         YASA        t2_m1_null             0.252
# 2           9           16         YASA        t2_m1_null             0.202
# 3         230         1181         YASA        t2_m1_null             0.982
# 4         263         1699         YASA        t2_m1_null             1.483
# ..        ...          ...          ...               ...               ...
# 225        16           33         YASA        t2_m1_null             0.205
# 226        10           17         YASA        t2_m1_null             0.202
# 227       334           92         YASA        t2_m1_null             0.478
# 228      1229         2875         YASA        t2_m1_null             3.433
# 229       580          879         YASA        t2_m1_null             1.432
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      71  2023-03-01_13-51-03/43_1_7_2_sample.csv
# 1                      17  2023-03-01_13-51-03/18_1_7_2_sample.csv
# 2                       8   2023-03-01_13-51-03/2_1_7_3_sample.csv
# 3                     246  2023-03-01_13-51-03/24_1_7_5_sample.csv
# 4                     510  2023-03-01_13-51-03/26_1_7_3_sample.csv
# ..                    ...                                      ...
# 225                     7   2023-03-01_13-51-03/6_1_7_4_sample.csv
# 226                     7   2023-03-01_13-51-03/3_1_7_4_sample.csv
# 227                    20  2023-03-01_13-51-03/29_1_7_2_sample.csv
# 228                    77  2023-03-01_13-51-03/41_1_7_2_sample.csv
# 229                   149  2023-03-01_13-51-03/34_1_7_2_sample.csv
#
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                   instance_name  lower_bound  upper_bound  \
# 0               integrator_arm7           27           47
# 1                         axTLS           10           11
# 2                           lcm            6            6
# 3    fiasco_2017-09-26_11-30-56          223          225
# 4    uclibc_2008-06-05_13-46-47          505          505
# ..                          ...          ...          ...
# 225                         car            5            5
# 226                       email            6            6
# 227  toybox_2020-12-06_00-02-46            7           14
# 228            atlas_mips32_4kc           32           45
# 229           WaterlooGenerated           82           82
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 92, 'nbrhd_confs': 4, 'itera...              3.389
# 1    [{'nbrhd_tuples': 208, 'nbrhd_confs': 7, 'iter...              0.252
# 2    [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...              0.202
# 3    [{'nbrhd_tuples': 224, 'nbrhd_confs': 20, 'ite...              0.982
# 4    [{'nbrhd_tuples': 248, 'nbrhd_confs': 49, 'ite...              1.483
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 77, 'nbrhd_confs': 7, 'itera...              0.205
# 226  [{'nbrhd_tuples': 70, 'nbrhd_confs': 7, 'itera...              0.202
# 227  [{'nbrhd_tuples': 139, 'nbrhd_confs': 2, 'iter...              0.478
# 228  [{'nbrhd_tuples': 229, 'nbrhd_confs': 11, 'ite...              3.433
# 229  [{'nbrhd_tuples': 247, 'nbrhd_confs': 31, 'ite...              1.432
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                  896.611          True       901.019550         900
# 1                  899.748          True       924.424374         900
# 2                  899.798          True         0.104894         900
# 3                  899.018          True       928.357737         900
# 4                  898.517          True       847.626329         900
# ..                     ...           ...              ...         ...
# 225                899.795          True         0.065082         900
# 226                899.798          True         0.197271         900
# 227                899.522          True       920.295881         900
# 228                896.567          True       926.051666         900
# 229                898.568          True       840.673600         900
#
# [230 rows x 17 columns]

# %%
best_lower_bound = (
    samplns_data.groupby(["instance_name"])["lower_bound"]
    .max()
    .reset_index()
    .rename(columns={"lower_bound": "best_lower_bound"})
)
best_lower_bound.to_json("./out/07_best_lower_bounds.json.zip")
best_lower_bound
best_lower_bound["internal_best_lower_bound"] = best_lower_bound["best_lower_bound"]
from _conf import EXTERNAL_BOUNDS

external_best_lb = (
    pd.concat([pd.read_csv(p) for p in EXTERNAL_BOUNDS])
    .groupby(["instance_name"])["best_lower_bound"]
    .max()
    .reset_index()
)
best_lower_bound = (
    pd.concat([best_lower_bound, external_best_lb])
    .groupby(["instance_name"])[["best_lower_bound", "internal_best_lower_bound"]]
    .max()
    .reset_index()
)
best_lower_bound
# Out:
#                   instance_name  best_lower_bound  internal_best_lower_bound
# 0                           APL                 7                        7.0
# 1                     APL-Model                 8                        8.0
# 2               BankingSoftware                28                       28.0
# 3                 BattleofTanks               256                      256.0
# 4                    ChatClient                 7                        7.0
# 5                          DMIE                16                       16.0
# 6                        E-Shop                10                        8.0
# 7                    EMBToolkit              1872                     1841.0
# 8                        FameDB                 8                        8.0
# 9                    FeatureIDE                 7                        7.0
# 10                FreeBSD-8_0_0                30                       30.0
# 11                          PPU                12                       12.0
# 12                     SafeBali                11                       11.0
# 13                  SortingLine                 9                        9.0
# 14                     TightVNC                 8                        8.0
# 15                       Violet                15                       15.0
# 16            WaterlooGenerated                82                       82.0
# 17                     XSEngine                32                       31.0
# 18                     aaed2000                51                       51.0
# 19                     am31_sim                28                       27.0
# 20             atlas_mips32_4kc                33                       32.0
# 21                        axTLS                10                       10.0
# 22                  berkeleyDB1                15                       15.0
# 23                  berkeleyDB2                12                       11.0
# 24               busybox-1_18_0                13                       13.0
# 25               busybox-1_29_2                21                       21.0
# 26  busybox_2007-01-24_09-14-09                21                       21.0
# 27  busybox_2020-12-16_21-53-05                19                       17.0
# 28                    calculate                 5                        5.0
# 29                          car                 5                        5.0
# 30                         dell                31                       31.0
# 31              eCos-3-0_i386pc                34                       30.0
# 32                       ea2468                31                       31.0
# 33                        email                 6                        6.0
# 34   fiasco_2017-09-26_11-30-56               225                      224.0
# 35   fiasco_2020-12-01_14-09-14               196                      196.0
# 36           financial_services              4304                     4164.0
# 37                fs_2017-05-22               396                      396.0
# 38                          gpl                16                       16.0
# 39              integrator_arm7                33                       32.0
# 40                          lcm                 6                        6.0
# 41  soletta_2015-06-26_18-38-56                24                       24.0
# 42   toybox_2006-10-31_23-30-06                 8                        8.0
# 43   toybox_2020-12-06_00-02-46                 8                        7.0
# 44   uclibc_2008-06-05_13-46-47               505                      505.0
# 45   uclibc_2020-12-24_11-54-53               365                      365.0

# %%
best_upper_bound = (
    samplns_data.groupby(["instance_name"])["upper_bound"]
    .min()
    .reset_index()
    .rename(columns={"upper_bound": "best_upper_bound"})
)
best_upper_bound["internal_best_upper_bound"] = best_upper_bound["best_upper_bound"]
from _conf import EXTERNAL_BOUNDS

external_best_ub = (
    pd.concat([pd.read_csv(p) for p in EXTERNAL_BOUNDS])
    .groupby(["instance_name"])["best_upper_bound"]
    .min()
    .reset_index()
)
best_upper_bound = (
    pd.concat([best_upper_bound, external_best_ub])
    .groupby(["instance_name"])[["best_upper_bound", "internal_best_upper_bound"]]
    .min()
    .reset_index()
)
best_upper_bound
# Out:
#                   instance_name  best_upper_bound  internal_best_upper_bound
# 0                           APL                 7                        7.0
# 1                     APL-Model                 8                        8.0
# 2               BankingSoftware                29                       29.0
# 3                 BattleofTanks               313                      338.0
# 4                    ChatClient                 7                        7.0
# 5                          DMIE                16                       16.0
# 6                        E-Shop                12                       12.0
# 7                    EMBToolkit              1872                     1876.0
# 8                        FameDB                 8                        8.0
# 9                    FeatureIDE                 8                        8.0
# 10                FreeBSD-8_0_0                50                       63.0
# 11                          PPU                12                       12.0
# 12                     SafeBali                11                       11.0
# 13                  SortingLine                 9                        9.0
# 14                     TightVNC                 8                        8.0
# 15                       Violet                17                       17.0
# 16            WaterlooGenerated                82                       82.0
# 17                     XSEngine                38                       43.0
# 18                     aaed2000                54                       64.0
# 19                     am31_sim                36                       40.0
# 20             atlas_mips32_4kc                39                       44.0
# 21                        axTLS                11                       11.0
# 22                  berkeleyDB1                15                       15.0
# 23                  berkeleyDB2                12                       12.0
# 24               busybox-1_18_0                17                       18.0
# 25               busybox-1_29_2                23                       24.0
# 26  busybox_2007-01-24_09-14-09                21                       21.0
# 27  busybox_2020-12-16_21-53-05                21                       22.0
# 28                    calculate                 5                        5.0
# 29                          car                 5                        5.0
# 30                         dell                31                       31.0
# 31              eCos-3-0_i386pc                44                       52.0
# 32                       ea2468                39                       44.0
# 33                        email                 6                        6.0
# 34   fiasco_2017-09-26_11-30-56               225                      225.0
# 35   fiasco_2020-12-01_14-09-14               196                      196.0
# 36           financial_services              4356                     4391.0
# 37                fs_2017-05-22               396                      396.0
# 38                          gpl                16                       16.0
# 39              integrator_arm7                39                       43.0
# 40                          lcm                 6                        6.0
# 41  soletta_2015-06-26_18-38-56                24                       24.0
# 42   toybox_2006-10-31_23-30-06                 8                        8.0
# 43   toybox_2020-12-06_00-02-46                13                       13.0
# 44   uclibc_2008-06-05_13-46-47               505                      505.0
# 45   uclibc_2020-12-24_11-54-53               365                      365.0

# %%
# calculate the best known lower bound
# best_lower_bound = samplns_data.groupby(["instance_name"])["lower_bound"].max().reset_index().rename(columns={"lower_bound": "best_lower_bound"})
samplns_data = samplns_data.merge(best_lower_bound, on="instance_name")

# %%
# calculate the best upper bound
# best_upper_bound = samplns_data.groupby(["instance_name"])["upper_bound"].min().reset_index().rename(columns={"upper_bound": "best_upper_bound"})
samplns_data = samplns_data.merge(best_upper_bound, on="instance_name")

# %%
# calculate best baseline algorithm sample
baseline_data = pd.read_json("./00_simple_baseline_data.json.zip")
from _conf import EXTENDED_BASELINE_DATA

extended_baseline_data = pd.read_json(EXTENDED_BASELINE_DATA)
extended_baseline_data = pd.concat([baseline_data, extended_baseline_data])
baseline_data = extended_baseline_data
best_baseline = (
    baseline_data.groupby(["instance_name"])[["sample_size"]]
    .min()
    .reset_index()
    .rename(columns={"sample_size": "best_baseline_sample_size"})
)
samplns_data = samplns_data.merge(best_baseline, on="instance_name", how="left")

# %%
performance_table = samplns_data.groupby("instance_name")[
    [
        "num_vars",
        "num_clauses",
        "best_baseline_sample_size",
        "baseline_sample_size",
        "upper_bound",
        "lower_bound",
        "best_upper_bound",
        "internal_best_upper_bound",
        "best_lower_bound",
        "internal_best_lower_bound",
    ]
].mean()
performance_table.sort_values(["num_vars", "num_clauses"], inplace=True)
performance_table["Improvement"] = 100 * (
    1
    - (
        performance_table["upper_bound"]
        / performance_table["best_baseline_sample_size"]
    )
)
# checking consistency is important.
assert (
    performance_table["best_lower_bound"]
    <= performance_table["best_baseline_sample_size"]
).all()
assert (
    performance_table["best_upper_bound"] >= performance_table["best_lower_bound"]
).all()
performance_table
# Out:
#                              num_vars  num_clauses  best_baseline_sample_size  \
# instance_name
# calculate                         9.0         15.0                        9.0
# lcm                               9.0         16.0                        8.0
# email                            10.0         17.0                        6.0
# ChatClient                       14.0         20.0                        8.0
# toybox_2006-10-31_23-30-06       16.0         13.0                        9.0
# car                              16.0         33.0                        6.0
# FeatureIDE                       19.0         27.0                       11.0
# FameDB                           22.0         40.0                        8.0
# APL                              23.0         35.0                        9.0
# SafeBali                         24.0         45.0                       11.0
# TightVNC                         28.0         39.0                       10.0
# APL-Model                        28.0         40.0                       10.0
# gpl                              38.0         99.0                       18.0
# SortingLine                      39.0         77.0                       12.0
# dell                             46.0        244.0                       34.0
# PPU                              52.0        109.0                       12.0
# berkeleyDB1                      76.0        147.0                       19.0
# axTLS                            96.0        183.0                       16.0
# Violet                          101.0        203.0                       23.0
# berkeleyDB2                     119.0        346.0                       21.0
# soletta_2015-06-26_18-38-56     129.0        192.0                       30.0
# BattleofTanks                   144.0        769.0                      444.0
# BankingSoftware                 176.0        280.0                       40.0
# fiasco_2017-09-26_11-30-56      230.0       1181.0                      237.0
# fiasco_2020-12-01_14-09-14      258.0       1542.0                      213.0
# uclibc_2008-06-05_13-46-47      263.0       1699.0                      506.0
# uclibc_2020-12-24_11-54-53      272.0       1670.0                      365.0
# E-Shop                          326.0        499.0                       20.0
# toybox_2020-12-06_00-02-46      334.0         92.0                       18.0
# DMIE                            366.0        627.0                       25.0
# busybox_2007-01-24_09-14-09     540.0        429.0                       35.0
# fs_2017-05-22                   557.0       4992.0                      398.0
# WaterlooGenerated               580.0        879.0                      144.0
# financial_services              771.0       7238.0                     4396.0
# busybox-1_18_0                  854.0       1164.0                       29.0
# busybox-1_29_2                 1018.0        997.0                       37.0
# busybox_2020-12-16_21-53-05    1050.0        996.0                       34.0
# am31_sim                       1178.0       2747.0                       61.0
# EMBToolkit                     1179.0       5414.0                     1883.0
# atlas_mips32_4kc               1229.0       2875.0                       66.0
# eCos-3-0_i386pc                1245.0       3723.0                       66.0
# integrator_arm7                1272.0       2980.0                       66.0
# XSEngine                       1273.0       2942.0                       63.0
# aaed2000                       1298.0       3036.0                       89.0
# FreeBSD-8_0_0                  1397.0      15692.0                       76.0
# ea2468                         1408.0       3319.0                       65.0
#
#                              baseline_sample_size  upper_bound  lower_bound  \
# instance_name
# calculate                                    10.0          5.0          5.0
# lcm                                           8.0          6.0          6.0
# email                                         7.0          6.0          6.0
# ChatClient                                    8.0          7.0          7.0
# toybox_2006-10-31_23-30-06                   10.0          8.0          8.0
# car                                           7.0          5.0          5.0
# FeatureIDE                                   12.0          8.0          7.0
# FameDB                                        8.0          8.0          8.0
# APL                                          10.0          7.0          7.0
# SafeBali                                     11.0         11.0         10.2
# TightVNC                                     12.0          8.0          8.0
# APL-Model                                    15.0          8.0          8.0
# gpl                                          22.0         16.0         16.0
# SortingLine                                  17.0          9.0          9.0
# dell                                         38.0         31.0         31.0
# PPU                                          16.0         12.0         11.4
# berkeleyDB1                                  23.0         15.0         15.0
# axTLS                                        17.0         11.0         10.0
# Violet                                       27.0         17.0         14.2
# berkeleyDB2                                  22.0         12.0         10.8
# soletta_2015-06-26_18-38-56                  32.0         24.0         24.0
# BattleofTanks                               454.0        341.6        256.0
# BankingSoftware                              43.0         29.0         28.0
# fiasco_2017-09-26_11-30-56                  246.0        225.4        223.0
# fiasco_2020-12-01_14-09-14                  224.0        197.2        196.0
# uclibc_2008-06-05_13-46-47                  510.0        505.0        505.0
# uclibc_2020-12-24_11-54-53                  369.0        365.0        365.0
# E-Shop                                       22.0         12.2          7.8
# toybox_2020-12-06_00-02-46                   20.0         13.8          7.0
# DMIE                                         27.0         16.0         15.8
# busybox_2007-01-24_09-14-09                  39.0         22.0         21.0
# fs_2017-05-22                               398.0        396.0        396.0
# WaterlooGenerated                           149.0         82.4         82.0
# financial_services                         4417.0       4395.6       4132.0
# busybox-1_18_0                               30.0         18.0         11.8
# busybox-1_29_2                               44.0         24.6         17.4
# busybox_2020-12-16_21-53-05                  39.0         23.2         13.6
# am31_sim                                     65.0         41.2         24.2
# EMBToolkit                                 1883.0       1877.2       1746.0
# atlas_mips32_4kc                             77.0         44.8         30.0
# eCos-3-0_i386pc                              70.0         53.0         25.4
# integrator_arm7                              71.0         45.4         28.0
# XSEngine                                     69.0         44.2         28.8
# aaed2000                                     95.0         66.6         47.0
# FreeBSD-8_0_0                                81.0         64.4         28.0
# ea2468                                       72.0         45.4         26.4
#
#                              best_upper_bound  internal_best_upper_bound  \
# instance_name
# calculate                                 5.0                        5.0
# lcm                                       6.0                        6.0
# email                                     6.0                        6.0
# ChatClient                                7.0                        7.0
# toybox_2006-10-31_23-30-06                8.0                        8.0
# car                                       5.0                        5.0
# FeatureIDE                                8.0                        8.0
# FameDB                                    8.0                        8.0
# APL                                       7.0                        7.0
# SafeBali                                 11.0                       11.0
# TightVNC                                  8.0                        8.0
# APL-Model                                 8.0                        8.0
# gpl                                      16.0                       16.0
# SortingLine                               9.0                        9.0
# dell                                     31.0                       31.0
# PPU                                      12.0                       12.0
# berkeleyDB1                              15.0                       15.0
# axTLS                                    11.0                       11.0
# Violet                                   17.0                       17.0
# berkeleyDB2                              12.0                       12.0
# soletta_2015-06-26_18-38-56              24.0                       24.0
# BattleofTanks                           313.0                      338.0
# BankingSoftware                          29.0                       29.0
# fiasco_2017-09-26_11-30-56              225.0                      225.0
# fiasco_2020-12-01_14-09-14              196.0                      196.0
# uclibc_2008-06-05_13-46-47              505.0                      505.0
# uclibc_2020-12-24_11-54-53              365.0                      365.0
# E-Shop                                   12.0                       12.0
# toybox_2020-12-06_00-02-46               13.0                       13.0
# DMIE                                     16.0                       16.0
# busybox_2007-01-24_09-14-09              21.0                       21.0
# fs_2017-05-22                           396.0                      396.0
# WaterlooGenerated                        82.0                       82.0
# financial_services                     4356.0                     4391.0
# busybox-1_18_0                           17.0                       18.0
# busybox-1_29_2                           23.0                       24.0
# busybox_2020-12-16_21-53-05              21.0                       22.0
# am31_sim                                 36.0                       40.0
# EMBToolkit                             1872.0                     1876.0
# atlas_mips32_4kc                         39.0                       44.0
# eCos-3-0_i386pc                          44.0                       52.0
# integrator_arm7                          39.0                       43.0
# XSEngine                                 38.0                       43.0
# aaed2000                                 54.0                       64.0
# FreeBSD-8_0_0                            50.0                       63.0
# ea2468                                   39.0                       44.0
#
#                              best_lower_bound  internal_best_lower_bound  \
# instance_name
# calculate                                 5.0                        5.0
# lcm                                       6.0                        6.0
# email                                     6.0                        6.0
# ChatClient                                7.0                        7.0
# toybox_2006-10-31_23-30-06                8.0                        8.0
# car                                       5.0                        5.0
# FeatureIDE                                7.0                        7.0
# FameDB                                    8.0                        8.0
# APL                                       7.0                        7.0
# SafeBali                                 11.0                       11.0
# TightVNC                                  8.0                        8.0
# APL-Model                                 8.0                        8.0
# gpl                                      16.0                       16.0
# SortingLine                               9.0                        9.0
# dell                                     31.0                       31.0
# PPU                                      12.0                       12.0
# berkeleyDB1                              15.0                       15.0
# axTLS                                    10.0                       10.0
# Violet                                   15.0                       15.0
# berkeleyDB2                              12.0                       11.0
# soletta_2015-06-26_18-38-56              24.0                       24.0
# BattleofTanks                           256.0                      256.0
# BankingSoftware                          28.0                       28.0
# fiasco_2017-09-26_11-30-56              225.0                      224.0
# fiasco_2020-12-01_14-09-14              196.0                      196.0
# uclibc_2008-06-05_13-46-47              505.0                      505.0
# uclibc_2020-12-24_11-54-53              365.0                      365.0
# E-Shop                                   10.0                        8.0
# toybox_2020-12-06_00-02-46                8.0                        7.0
# DMIE                                     16.0                       16.0
# busybox_2007-01-24_09-14-09              21.0                       21.0
# fs_2017-05-22                           396.0                      396.0
# WaterlooGenerated                        82.0                       82.0
# financial_services                     4304.0                     4164.0
# busybox-1_18_0                           13.0                       13.0
# busybox-1_29_2                           21.0                       21.0
# busybox_2020-12-16_21-53-05              19.0                       17.0
# am31_sim                                 28.0                       27.0
# EMBToolkit                             1872.0                     1841.0
# atlas_mips32_4kc                         33.0                       32.0
# eCos-3-0_i386pc                          34.0                       30.0
# integrator_arm7                          33.0                       32.0
# XSEngine                                 32.0                       31.0
# aaed2000                                 51.0                       51.0
# FreeBSD-8_0_0                            30.0                       30.0
# ea2468                                   31.0                       31.0
#
#                              Improvement
# instance_name
# calculate                      44.444444
# lcm                            25.000000
# email                           0.000000
# ChatClient                     12.500000
# toybox_2006-10-31_23-30-06     11.111111
# car                            16.666667
# FeatureIDE                     27.272727
# FameDB                          0.000000
# APL                            22.222222
# SafeBali                        0.000000
# TightVNC                       20.000000
# APL-Model                      20.000000
# gpl                            11.111111
# SortingLine                    25.000000
# dell                            8.823529
# PPU                             0.000000
# berkeleyDB1                    21.052632
# axTLS                          31.250000
# Violet                         26.086957
# berkeleyDB2                    42.857143
# soletta_2015-06-26_18-38-56    20.000000
# BattleofTanks                  23.063063
# BankingSoftware                27.500000
# fiasco_2017-09-26_11-30-56      4.894515
# fiasco_2020-12-01_14-09-14      7.417840
# uclibc_2008-06-05_13-46-47      0.197628
# uclibc_2020-12-24_11-54-53      0.000000
# E-Shop                         39.000000
# toybox_2020-12-06_00-02-46     23.333333
# DMIE                           36.000000
# busybox_2007-01-24_09-14-09    37.142857
# fs_2017-05-22                   0.502513
# WaterlooGenerated              42.777778
# financial_services              0.009099
# busybox-1_18_0                 37.931034
# busybox-1_29_2                 33.513514
# busybox_2020-12-16_21-53-05    31.764706
# am31_sim                       32.459016
# EMBToolkit                      0.308019
# atlas_mips32_4kc               32.121212
# eCos-3-0_i386pc                19.696970
# integrator_arm7                31.212121
# XSEngine                       29.841270
# aaed2000                       25.168539
# FreeBSD-8_0_0                  15.263158
# ea2468                         30.153846

# %%
# Code to query the time of the last change in lower or upper bound.


# Collect the data from the iteration_info events.
class EventCollector:
    def __init__(self):
        self.events = {
            "time": [],
            "val": [],
            "type": [],
            "instance": [],
            "path": [],
            # "alg": [],
            "initial_sample_size": [],
            "y": [],
            "final": [],
        }

    def __call__(self, row):
        it_data = row["iteration_info"]

        def add(val, lbub, time, final=False):
            if time > 900:
                return
            self.events["time"].append((time + row["time_used_by_yasa"]) / 60)
            self.events["val"].append(val)
            self.events["type"].append(lbub)
            self.events["instance"].append(row["instance_name"])
            # self.events["alg"].append(row["baseline_alg"])
            self.events["path"].append(row["path_to_baseline_sample"])
            self.events["initial_sample_size"].append(row["baseline_sample_size"])
            self.events["y"].append(100 * (val / row["best_lower_bound"]))
            self.events["final"].append(final)

        # add a zero entry
        add(0, "Lower", 0)
        add(row["baseline_sample_size"], "Upper", 0)
        for event in it_data:
            add(
                event["lb"],
                "Lower",
                event["time"],
                final=event["lb"] == row["lower_bound"],
            )
            add(
                event["ub"],
                "Upper",
                event["time"],
                final=event["ub"] == row["upper_bound"],
            )


ec = EventCollector()
samplns_data.apply(ec, axis=1)
t_events = pd.DataFrame(ec.events)
t_ = t_events.groupby(["instance", "path"])["time"].max().reset_index()


time_until_last_change = (
    t_events[t_events["final"]]
    .groupby(["instance", "path", "type"])[["time"]]
    .min()
    .reset_index()
    .groupby(["instance", "type"])[["time"]]
    .mean()
)

unsolved_symbol = "$*$"


def get_time_info(instance):
    d = time_until_last_change.groupby("instance")["time"].max().to_dict()
    if instance not in d:
        return unsolved_symbol
    else:
        secs = round(d[instance] * 60)
        if secs == 0:
            return "$<\\SI{1}{\\second}$"
        return "\\SI{" + str(secs) + "}{\\second}"


time_until_last_change

performance_table = performance_table.merge(
    time_until_last_change.groupby("instance")["time"].max(),
    left_index=True,
    right_index=True,
)

performance_table["latex_time"] = performance_table.index.to_series().apply(
    get_time_info
)
# performance_table

# %%
t = performance_table.copy()
t["best"] = t["best_baseline_sample_size"]
t["lb"] = t.apply(
    lambda row: f"{row['lower_bound']} ({int(row['best_lower_bound'])})", axis=1
)
t["ub"] = t.apply(
    lambda row: f"{row['upper_bound']} ({int(row['best_upper_bound'])})", axis=1
)
t["opt"] = t["upper_bound"] == t["best_lower_bound"]
t["baseline_opt"] = t["best"] == t["best_lower_bound"]
t["opt_proven_longtime"] = t["best_upper_bound"] == t["best_lower_bound"]
t["opt_proved"] = t["upper_bound"] == t["lower_bound"]
t["Improvement"] = 100 * (1 - (t["upper_bound"] / t["best"]))
prepared_latex_table = t[
    [
        "num_vars",
        "num_clauses",
        "best",
        "baseline_opt",
        "ub",
        "lb",
        "Improvement",
        "opt_proven_longtime",
        "opt",
        "opt_proved",
        "time",
        "latex_time",
    ]
].copy()
prepared_latex_table
# Out:
#                              num_vars  num_clauses    best  baseline_opt  \
# calculate                         9.0         15.0     9.0         False
# lcm                               9.0         16.0     8.0         False
# email                            10.0         17.0     6.0          True
# ChatClient                       14.0         20.0     8.0         False
# toybox_2006-10-31_23-30-06       16.0         13.0     9.0         False
# car                              16.0         33.0     6.0         False
# FeatureIDE                       19.0         27.0    11.0         False
# FameDB                           22.0         40.0     8.0          True
# APL                              23.0         35.0     9.0         False
# SafeBali                         24.0         45.0    11.0          True
# TightVNC                         28.0         39.0    10.0         False
# APL-Model                        28.0         40.0    10.0         False
# gpl                              38.0         99.0    18.0         False
# SortingLine                      39.0         77.0    12.0         False
# dell                             46.0        244.0    34.0         False
# PPU                              52.0        109.0    12.0          True
# berkeleyDB1                      76.0        147.0    19.0         False
# axTLS                            96.0        183.0    16.0         False
# Violet                          101.0        203.0    23.0         False
# berkeleyDB2                     119.0        346.0    21.0         False
# soletta_2015-06-26_18-38-56     129.0        192.0    30.0         False
# BattleofTanks                   144.0        769.0   444.0         False
# BankingSoftware                 176.0        280.0    40.0         False
# fiasco_2017-09-26_11-30-56      230.0       1181.0   237.0         False
# fiasco_2020-12-01_14-09-14      258.0       1542.0   213.0         False
# uclibc_2008-06-05_13-46-47      263.0       1699.0   506.0         False
# uclibc_2020-12-24_11-54-53      272.0       1670.0   365.0          True
# E-Shop                          326.0        499.0    20.0         False
# toybox_2020-12-06_00-02-46      334.0         92.0    18.0         False
# DMIE                            366.0        627.0    25.0         False
# busybox_2007-01-24_09-14-09     540.0        429.0    35.0         False
# fs_2017-05-22                   557.0       4992.0   398.0         False
# WaterlooGenerated               580.0        879.0   144.0         False
# financial_services              771.0       7238.0  4396.0         False
# busybox-1_18_0                  854.0       1164.0    29.0         False
# busybox-1_29_2                 1018.0        997.0    37.0         False
# busybox_2020-12-16_21-53-05    1050.0        996.0    34.0         False
# am31_sim                       1178.0       2747.0    61.0         False
# EMBToolkit                     1179.0       5414.0  1883.0         False
# atlas_mips32_4kc               1229.0       2875.0    66.0         False
# eCos-3-0_i386pc                1245.0       3723.0    66.0         False
# integrator_arm7                1272.0       2980.0    66.0         False
# XSEngine                       1273.0       2942.0    63.0         False
# aaed2000                       1298.0       3036.0    89.0         False
# FreeBSD-8_0_0                  1397.0      15692.0    76.0         False
# ea2468                         1408.0       3319.0    65.0         False
#
#                                         ub             lb  Improvement  \
# calculate                          5.0 (5)        5.0 (5)    44.444444
# lcm                                6.0 (6)        6.0 (6)    25.000000
# email                              6.0 (6)        6.0 (6)     0.000000
# ChatClient                         7.0 (7)        7.0 (7)    12.500000
# toybox_2006-10-31_23-30-06         8.0 (8)        8.0 (8)    11.111111
# car                                5.0 (5)        5.0 (5)    16.666667
# FeatureIDE                         8.0 (8)        7.0 (7)    27.272727
# FameDB                             8.0 (8)        8.0 (8)     0.000000
# APL                                7.0 (7)        7.0 (7)    22.222222
# SafeBali                         11.0 (11)      10.2 (11)     0.000000
# TightVNC                           8.0 (8)        8.0 (8)    20.000000
# APL-Model                          8.0 (8)        8.0 (8)    20.000000
# gpl                              16.0 (16)      16.0 (16)    11.111111
# SortingLine                        9.0 (9)        9.0 (9)    25.000000
# dell                             31.0 (31)      31.0 (31)     8.823529
# PPU                              12.0 (12)      11.4 (12)     0.000000
# berkeleyDB1                      15.0 (15)      15.0 (15)    21.052632
# axTLS                            11.0 (11)      10.0 (10)    31.250000
# Violet                           17.0 (17)      14.2 (15)    26.086957
# berkeleyDB2                      12.0 (12)      10.8 (12)    42.857143
# soletta_2015-06-26_18-38-56      24.0 (24)      24.0 (24)    20.000000
# BattleofTanks                  341.6 (313)    256.0 (256)    23.063063
# BankingSoftware                  29.0 (29)      28.0 (28)    27.500000
# fiasco_2017-09-26_11-30-56     225.4 (225)    223.0 (225)     4.894515
# fiasco_2020-12-01_14-09-14     197.2 (196)    196.0 (196)     7.417840
# uclibc_2008-06-05_13-46-47     505.0 (505)    505.0 (505)     0.197628
# uclibc_2020-12-24_11-54-53     365.0 (365)    365.0 (365)     0.000000
# E-Shop                           12.2 (12)       7.8 (10)    39.000000
# toybox_2020-12-06_00-02-46       13.8 (13)        7.0 (8)    23.333333
# DMIE                             16.0 (16)      15.8 (16)    36.000000
# busybox_2007-01-24_09-14-09      22.0 (21)      21.0 (21)    37.142857
# fs_2017-05-22                  396.0 (396)    396.0 (396)     0.502513
# WaterlooGenerated                82.4 (82)      82.0 (82)    42.777778
# financial_services           4395.6 (4356)  4132.0 (4304)     0.009099
# busybox-1_18_0                   18.0 (17)      11.8 (13)    37.931034
# busybox-1_29_2                   24.6 (23)      17.4 (21)    33.513514
# busybox_2020-12-16_21-53-05      23.2 (21)      13.6 (19)    31.764706
# am31_sim                         41.2 (36)      24.2 (28)    32.459016
# EMBToolkit                   1877.2 (1872)  1746.0 (1872)     0.308019
# atlas_mips32_4kc                 44.8 (39)      30.0 (33)    32.121212
# eCos-3-0_i386pc                  53.0 (44)      25.4 (34)    19.696970
# integrator_arm7                  45.4 (39)      28.0 (33)    31.212121
# XSEngine                         44.2 (38)      28.8 (32)    29.841270
# aaed2000                         66.6 (54)      47.0 (51)    25.168539
# FreeBSD-8_0_0                    64.4 (50)      28.0 (30)    15.263158
# ea2468                           45.4 (39)      26.4 (31)    30.153846
#
#                              opt_proven_longtime    opt  opt_proved  \
# calculate                                   True   True        True
# lcm                                         True   True        True
# email                                       True   True        True
# ChatClient                                  True   True        True
# toybox_2006-10-31_23-30-06                  True   True        True
# car                                         True   True        True
# FeatureIDE                                 False  False       False
# FameDB                                      True   True        True
# APL                                         True   True        True
# SafeBali                                    True   True       False
# TightVNC                                    True   True        True
# APL-Model                                   True   True        True
# gpl                                         True   True        True
# SortingLine                                 True   True        True
# dell                                        True   True        True
# PPU                                         True   True       False
# berkeleyDB1                                 True   True        True
# axTLS                                      False  False       False
# Violet                                     False  False       False
# berkeleyDB2                                 True   True       False
# soletta_2015-06-26_18-38-56                 True   True        True
# BattleofTanks                              False  False       False
# BankingSoftware                            False  False       False
# fiasco_2017-09-26_11-30-56                  True  False       False
# fiasco_2020-12-01_14-09-14                  True  False       False
# uclibc_2008-06-05_13-46-47                  True   True        True
# uclibc_2020-12-24_11-54-53                  True   True        True
# E-Shop                                     False  False       False
# toybox_2020-12-06_00-02-46                 False  False       False
# DMIE                                        True   True       False
# busybox_2007-01-24_09-14-09                 True  False       False
# fs_2017-05-22                               True   True        True
# WaterlooGenerated                           True  False       False
# financial_services                         False  False       False
# busybox-1_18_0                             False  False       False
# busybox-1_29_2                             False  False       False
# busybox_2020-12-16_21-53-05                False  False       False
# am31_sim                                   False  False       False
# EMBToolkit                                  True  False       False
# atlas_mips32_4kc                           False  False       False
# eCos-3-0_i386pc                            False  False       False
# integrator_arm7                            False  False       False
# XSEngine                                   False  False       False
# aaed2000                                   False  False       False
# FreeBSD-8_0_0                              False  False       False
# ea2468                                     False  False       False
#
#                                   time          latex_time
# calculate                     0.004542  $<\SI{1}{\second}$
# lcm                           0.004025  $<\SI{1}{\second}$
# email                         0.004739  $<\SI{1}{\second}$
# ChatClient                    0.334423    \SI{20}{\second}
# toybox_2006-10-31_23-30-06    0.154727     \SI{9}{\second}
# car                           0.004389  $<\SI{1}{\second}$
# FeatureIDE                    0.362484    \SI{22}{\second}
# FameDB                        0.073418     \SI{4}{\second}
# APL                           0.136439     \SI{8}{\second}
# SafeBali                      0.004444  $<\SI{1}{\second}$
# TightVNC                      3.080768   \SI{185}{\second}
# APL-Model                     1.771934   \SI{106}{\second}
# gpl                           0.299042    \SI{18}{\second}
# SortingLine                   0.611885    \SI{37}{\second}
# dell                          1.209059    \SI{73}{\second}
# PPU                           0.504769    \SI{30}{\second}
# berkeleyDB1                   5.343317   \SI{321}{\second}
# axTLS                         0.755065    \SI{45}{\second}
# Violet                        6.884731   \SI{413}{\second}
# berkeleyDB2                   4.865922   \SI{292}{\second}
# soletta_2015-06-26_18-38-56   1.025021    \SI{62}{\second}
# BattleofTanks                13.854912   \SI{831}{\second}
# BankingSoftware               0.690055    \SI{41}{\second}
# fiasco_2017-09-26_11-30-56    8.351923   \SI{501}{\second}
# fiasco_2020-12-01_14-09-14   12.105096   \SI{726}{\second}
# uclibc_2008-06-05_13-46-47    9.421597   \SI{565}{\second}
# uclibc_2020-12-24_11-54-53    4.801036   \SI{288}{\second}
# E-Shop                        8.735349   \SI{524}{\second}
# toybox_2020-12-06_00-02-46    1.640670    \SI{98}{\second}
# DMIE                          4.942895   \SI{297}{\second}
# busybox_2007-01-24_09-14-09   4.978202   \SI{299}{\second}
# fs_2017-05-22                 7.153978   \SI{429}{\second}
# WaterlooGenerated             6.645738   \SI{399}{\second}
# financial_services           14.796896   \SI{888}{\second}
# busybox-1_18_0                5.639032   \SI{338}{\second}
# busybox-1_29_2                9.611652   \SI{577}{\second}
# busybox_2020-12-16_21-53-05   8.888191   \SI{533}{\second}
# am31_sim                     11.146004   \SI{669}{\second}
# EMBToolkit                   13.564493   \SI{814}{\second}
# atlas_mips32_4kc             13.599739   \SI{816}{\second}
# eCos-3-0_i386pc              12.391446   \SI{743}{\second}
# integrator_arm7              12.340083   \SI{740}{\second}
# XSEngine                     13.174822   \SI{790}{\second}
# aaed2000                     14.147581   \SI{849}{\second}
# FreeBSD-8_0_0                11.718916   \SI{703}{\second}
# ea2468                       14.212323   \SI{853}{\second}

# %%
# proved optimality for n instances
prepared_latex_table["opt_proved"].sum()
# Out:
# 18

# %%
# proved optimality for n instances using more time (1hr)
prepared_latex_table["opt_proven_longtime"].sum()
# Out:
# 27

# %%
prepared_latex_table["Improvement"].mean()
# Out:
# 20.57979511950669

# %%
(prepared_latex_table["Improvement"] > 0).sum()
# Out:
# 41

# %%
def to_latex_table(t: pd.DataFrame, extra=None) -> str:
    """
    Convert a pandas dataframe to a latex table.
    """
    tex_table = "\\begin{tabular}"
    tex_table += "{l " + " ".join(["r"] * (len(t.columns) - 1)) + "}\n"
    tex_table += " & ".join(t.columns) + "\\\\\n"
    tex_table += "\\hline\n"
    for idx in t.index:
        tex_table += f"{' & '.join(str(x) for x in t.loc[idx])}\\\\\n"
    if extra:
        tex_table += "\n"
        tex_table += extra + "\n"
        tex_table += "\n"

    tex_table += "\\end{tabular}"
    return tex_table


def shorten_name(name):
    threshold = 20
    if len(name) > threshold:
        return name[: threshold - 3] + "..."
    return name


def si_num(num):
    return "\\num[text-series-to-math=true]{" + str(int(num)) + "}"


performance_table.sort_values(by=["num_vars", "num_clauses"], inplace=True)

data = {
    "Feature Model": [],
    "$|\\features|$": [],
    "$|\\clauses|$": [],
    "Best": [],
    "SampLNS": [],
    "LB": [],
    "Savings": [],
    "Time": [],
}
t = performance_table
num_opt_baseline = 0
num_potential_opt_baseline = 0
num_opt_samplns = 0
num_savings = 0

for idx in t.index:
    data["Feature Model"].append(shorten_name(idx.replace("_", "\\_")))
    data["$|\\features|$"].append(si_num(int(t["num_vars"][idx])))
    data["$|\\clauses|$"].append(si_num(int(t["num_clauses"][idx])))
    best_baseline = int(t["best_baseline_sample_size"][idx])
    best_lb = t["best_lower_bound"][idx]
    if best_baseline == best_lb:
        data["Best"].append("\\textbf{" + si_num(best_baseline) + "}")
        num_opt_baseline += 1
    else:
        data["Best"].append(si_num(best_baseline))
    if best_baseline <= t["best_upper_bound"][idx]:
        num_potential_opt_baseline += 1
    samplns = int(round(t["upper_bound"][idx]))
    if samplns == best_lb:
        num_opt_samplns += 1
        data["SampLNS"].append(
            "\\textbf{"
            + si_num(samplns)
            + "} ("
            + si_num(int(t["best_upper_bound"][idx]))
            + ")"
        )
    else:
        data["SampLNS"].append(
            si_num(samplns) + " (" + si_num(int(t["best_upper_bound"][idx])) + ")"
        )
    data["LB"].append(
        si_num(int(round(t["lower_bound"][idx])))
        + " ("
        + si_num(int(t["best_lower_bound"][idx]))
        + ")"
    )
    if t["Improvement"][idx] > 0:
        num_savings += 1
    data["Savings"].append(
        "\\SI{" + f"{round(t['Improvement'][idx], 2):.2g}" + "}{\\percent}"
    )
    data["Time"].append(t["latex_time"][idx])

percentage_opt_baseline = (
    "\\SI{" + str(round(100 * num_opt_baseline / len(t))) + "}{\\percent}"
)
percentage_opt_samplns = (
    "\\SI{" + str(round(100 * num_opt_samplns / len(t))) + "}{\\percent}"
)
percentage_improved = "\\SI{" + str(round(100 * num_savings / len(t))) + "}{\\percent}"

extra = (
    "\\hline \n \\ \\\\ \n \\textbf{optimality} & & & "
    + str(num_opt_baseline)
    + " & $\\geq "
    + str(num_opt_samplns)
    + "$ & & \\\\ & & & ("
    + percentage_opt_baseline
    + ") &("
    + percentage_opt_samplns
    + ") & & \\\\ \n \\textbf{improvements} & & & & &\\multicolumn{2}{r}{"
    + si_num(num_savings)
    + " ("
    + percentage_improved
    + ")} \\\\ \\ \\\\ \\ \\\\"
)

print(to_latex_table(pd.DataFrame(data=data), extra))
# Out:
# \begin{tabular}{l r r r r r r r}
# Feature Model & $|\features|$ & $|\clauses|$ & Best & SampLNS & LB & Savings & Time\\
# \hline
# calculate & \num[text-series-to-math=true]{9} & \num[text-series-to-math=true]{15} & \num[text-series-to-math=true]{9} & \textbf{\num[text-series-to-math=true]{5}} (\num[text-series-to-math=true]{5}) & \num[text-series-to-math=true]{5} (\num[text-series-to-math=true]{5}) & \SI{44}{\percent} & $<\SI{1}{\second}$\\
# lcm & \num[text-series-to-math=true]{9} & \num[text-series-to-math=true]{16} & \num[text-series-to-math=true]{8} & \textbf{\num[text-series-to-math=true]{6}} (\num[text-series-to-math=true]{6}) & \num[text-series-to-math=true]{6} (\num[text-series-to-math=true]{6}) & \SI{25}{\percent} & $<\SI{1}{\second}$\\
# email & \num[text-series-to-math=true]{10} & \num[text-series-to-math=true]{17} & \textbf{\num[text-series-to-math=true]{6}} & \textbf{\num[text-series-to-math=true]{6}} (\num[text-series-to-math=true]{6}) & \num[text-series-to-math=true]{6} (\num[text-series-to-math=true]{6}) & \SI{0}{\percent} & $<\SI{1}{\second}$\\
# ChatClient & \num[text-series-to-math=true]{14} & \num[text-series-to-math=true]{20} & \num[text-series-to-math=true]{8} & \textbf{\num[text-series-to-math=true]{7}} (\num[text-series-to-math=true]{7}) & \num[text-series-to-math=true]{7} (\num[text-series-to-math=true]{7}) & \SI{12}{\percent} & \SI{20}{\second}\\
# toybox\_2006-10-3... & \num[text-series-to-math=true]{16} & \num[text-series-to-math=true]{13} & \num[text-series-to-math=true]{9} & \textbf{\num[text-series-to-math=true]{8}} (\num[text-series-to-math=true]{8}) & \num[text-series-to-math=true]{8} (\num[text-series-to-math=true]{8}) & \SI{11}{\percent} & \SI{9}{\second}\\
# car & \num[text-series-to-math=true]{16} & \num[text-series-to-math=true]{33} & \num[text-series-to-math=true]{6} & \textbf{\num[text-series-to-math=true]{5}} (\num[text-series-to-math=true]{5}) & \num[text-series-to-math=true]{5} (\num[text-series-to-math=true]{5}) & \SI{17}{\percent} & $<\SI{1}{\second}$\\
# FeatureIDE & \num[text-series-to-math=true]{19} & \num[text-series-to-math=true]{27} & \num[text-series-to-math=true]{11} & \num[text-series-to-math=true]{8} (\num[text-series-to-math=true]{8}) & \num[text-series-to-math=true]{7} (\num[text-series-to-math=true]{7}) & \SI{27}{\percent} & \SI{22}{\second}\\
# FameDB & \num[text-series-to-math=true]{22} & \num[text-series-to-math=true]{40} & \textbf{\num[text-series-to-math=true]{8}} & \textbf{\num[text-series-to-math=true]{8}} (\num[text-series-to-math=true]{8}) & \num[text-series-to-math=true]{8} (\num[text-series-to-math=true]{8}) & \SI{0}{\percent} & \SI{4}{\second}\\
# APL & \num[text-series-to-math=true]{23} & \num[text-series-to-math=true]{35} & \num[text-series-to-math=true]{9} & \textbf{\num[text-series-to-math=true]{7}} (\num[text-series-to-math=true]{7}) & \num[text-series-to-math=true]{7} (\num[text-series-to-math=true]{7}) & \SI{22}{\percent} & \SI{8}{\second}\\
# SafeBali & \num[text-series-to-math=true]{24} & \num[text-series-to-math=true]{45} & \textbf{\num[text-series-to-math=true]{11}} & \textbf{\num[text-series-to-math=true]{11}} (\num[text-series-to-math=true]{11}) & \num[text-series-to-math=true]{10} (\num[text-series-to-math=true]{11}) & \SI{0}{\percent} & $<\SI{1}{\second}$\\
# TightVNC & \num[text-series-to-math=true]{28} & \num[text-series-to-math=true]{39} & \num[text-series-to-math=true]{10} & \textbf{\num[text-series-to-math=true]{8}} (\num[text-series-to-math=true]{8}) & \num[text-series-to-math=true]{8} (\num[text-series-to-math=true]{8}) & \SI{20}{\percent} & \SI{185}{\second}\\
# APL-Model & \num[text-series-to-math=true]{28} & \num[text-series-to-math=true]{40} & \num[text-series-to-math=true]{10} & \textbf{\num[text-series-to-math=true]{8}} (\num[text-series-to-math=true]{8}) & \num[text-series-to-math=true]{8} (\num[text-series-to-math=true]{8}) & \SI{20}{\percent} & \SI{106}{\second}\\
# gpl & \num[text-series-to-math=true]{38} & \num[text-series-to-math=true]{99} & \num[text-series-to-math=true]{18} & \textbf{\num[text-series-to-math=true]{16}} (\num[text-series-to-math=true]{16}) & \num[text-series-to-math=true]{16} (\num[text-series-to-math=true]{16}) & \SI{11}{\percent} & \SI{18}{\second}\\
# SortingLine & \num[text-series-to-math=true]{39} & \num[text-series-to-math=true]{77} & \num[text-series-to-math=true]{12} & \textbf{\num[text-series-to-math=true]{9}} (\num[text-series-to-math=true]{9}) & \num[text-series-to-math=true]{9} (\num[text-series-to-math=true]{9}) & \SI{25}{\percent} & \SI{37}{\second}\\
# dell & \num[text-series-to-math=true]{46} & \num[text-series-to-math=true]{244} & \num[text-series-to-math=true]{34} & \textbf{\num[text-series-to-math=true]{31}} (\num[text-series-to-math=true]{31}) & \num[text-series-to-math=true]{31} (\num[text-series-to-math=true]{31}) & \SI{8.8}{\percent} & \SI{73}{\second}\\
# PPU & \num[text-series-to-math=true]{52} & \num[text-series-to-math=true]{109} & \textbf{\num[text-series-to-math=true]{12}} & \textbf{\num[text-series-to-math=true]{12}} (\num[text-series-to-math=true]{12}) & \num[text-series-to-math=true]{11} (\num[text-series-to-math=true]{12}) & \SI{0}{\percent} & \SI{30}{\second}\\
# berkeleyDB1 & \num[text-series-to-math=true]{76} & \num[text-series-to-math=true]{147} & \num[text-series-to-math=true]{19} & \textbf{\num[text-series-to-math=true]{15}} (\num[text-series-to-math=true]{15}) & \num[text-series-to-math=true]{15} (\num[text-series-to-math=true]{15}) & \SI{21}{\percent} & \SI{321}{\second}\\
# axTLS & \num[text-series-to-math=true]{96} & \num[text-series-to-math=true]{183} & \num[text-series-to-math=true]{16} & \num[text-series-to-math=true]{11} (\num[text-series-to-math=true]{11}) & \num[text-series-to-math=true]{10} (\num[text-series-to-math=true]{10}) & \SI{31}{\percent} & \SI{45}{\second}\\
# Violet & \num[text-series-to-math=true]{101} & \num[text-series-to-math=true]{203} & \num[text-series-to-math=true]{23} & \num[text-series-to-math=true]{17} (\num[text-series-to-math=true]{17}) & \num[text-series-to-math=true]{14} (\num[text-series-to-math=true]{15}) & \SI{26}{\percent} & \SI{413}{\second}\\
# berkeleyDB2 & \num[text-series-to-math=true]{119} & \num[text-series-to-math=true]{346} & \num[text-series-to-math=true]{21} & \textbf{\num[text-series-to-math=true]{12}} (\num[text-series-to-math=true]{12}) & \num[text-series-to-math=true]{11} (\num[text-series-to-math=true]{12}) & \SI{43}{\percent} & \SI{292}{\second}\\
# soletta\_2015-06-... & \num[text-series-to-math=true]{129} & \num[text-series-to-math=true]{192} & \num[text-series-to-math=true]{30} & \textbf{\num[text-series-to-math=true]{24}} (\num[text-series-to-math=true]{24}) & \num[text-series-to-math=true]{24} (\num[text-series-to-math=true]{24}) & \SI{20}{\percent} & \SI{62}{\second}\\
# BattleofTanks & \num[text-series-to-math=true]{144} & \num[text-series-to-math=true]{769} & \num[text-series-to-math=true]{444} & \num[text-series-to-math=true]{342} (\num[text-series-to-math=true]{313}) & \num[text-series-to-math=true]{256} (\num[text-series-to-math=true]{256}) & \SI{23}{\percent} & \SI{831}{\second}\\
# BankingSoftware & \num[text-series-to-math=true]{176} & \num[text-series-to-math=true]{280} & \num[text-series-to-math=true]{40} & \num[text-series-to-math=true]{29} (\num[text-series-to-math=true]{29}) & \num[text-series-to-math=true]{28} (\num[text-series-to-math=true]{28}) & \SI{28}{\percent} & \SI{41}{\second}\\
# fiasco\_2017-09-2... & \num[text-series-to-math=true]{230} & \num[text-series-to-math=true]{1181} & \num[text-series-to-math=true]{237} & \textbf{\num[text-series-to-math=true]{225}} (\num[text-series-to-math=true]{225}) & \num[text-series-to-math=true]{223} (\num[text-series-to-math=true]{225}) & \SI{4.9}{\percent} & \SI{501}{\second}\\
# fiasco\_2020-12-0... & \num[text-series-to-math=true]{258} & \num[text-series-to-math=true]{1542} & \num[text-series-to-math=true]{213} & \num[text-series-to-math=true]{197} (\num[text-series-to-math=true]{196}) & \num[text-series-to-math=true]{196} (\num[text-series-to-math=true]{196}) & \SI{7.4}{\percent} & \SI{726}{\second}\\
# uclibc\_2008-06-0... & \num[text-series-to-math=true]{263} & \num[text-series-to-math=true]{1699} & \num[text-series-to-math=true]{506} & \textbf{\num[text-series-to-math=true]{505}} (\num[text-series-to-math=true]{505}) & \num[text-series-to-math=true]{505} (\num[text-series-to-math=true]{505}) & \SI{0.2}{\percent} & \SI{565}{\second}\\
# uclibc\_2020-12-2... & \num[text-series-to-math=true]{272} & \num[text-series-to-math=true]{1670} & \textbf{\num[text-series-to-math=true]{365}} & \textbf{\num[text-series-to-math=true]{365}} (\num[text-series-to-math=true]{365}) & \num[text-series-to-math=true]{365} (\num[text-series-to-math=true]{365}) & \SI{0}{\percent} & \SI{288}{\second}\\
# E-Shop & \num[text-series-to-math=true]{326} & \num[text-series-to-math=true]{499} & \num[text-series-to-math=true]{20} & \num[text-series-to-math=true]{12} (\num[text-series-to-math=true]{12}) & \num[text-series-to-math=true]{8} (\num[text-series-to-math=true]{10}) & \SI{39}{\percent} & \SI{524}{\second}\\
# toybox\_2020-12-0... & \num[text-series-to-math=true]{334} & \num[text-series-to-math=true]{92} & \num[text-series-to-math=true]{18} & \num[text-series-to-math=true]{14} (\num[text-series-to-math=true]{13}) & \num[text-series-to-math=true]{7} (\num[text-series-to-math=true]{8}) & \SI{23}{\percent} & \SI{98}{\second}\\
# DMIE & \num[text-series-to-math=true]{366} & \num[text-series-to-math=true]{627} & \num[text-series-to-math=true]{25} & \textbf{\num[text-series-to-math=true]{16}} (\num[text-series-to-math=true]{16}) & \num[text-series-to-math=true]{16} (\num[text-series-to-math=true]{16}) & \SI{36}{\percent} & \SI{297}{\second}\\
# busybox\_2007-01-... & \num[text-series-to-math=true]{540} & \num[text-series-to-math=true]{429} & \num[text-series-to-math=true]{35} & \num[text-series-to-math=true]{22} (\num[text-series-to-math=true]{21}) & \num[text-series-to-math=true]{21} (\num[text-series-to-math=true]{21}) & \SI{37}{\percent} & \SI{299}{\second}\\
# fs\_2017-05-22 & \num[text-series-to-math=true]{557} & \num[text-series-to-math=true]{4992} & \num[text-series-to-math=true]{398} & \textbf{\num[text-series-to-math=true]{396}} (\num[text-series-to-math=true]{396}) & \num[text-series-to-math=true]{396} (\num[text-series-to-math=true]{396}) & \SI{0.5}{\percent} & \SI{429}{\second}\\
# WaterlooGenerated & \num[text-series-to-math=true]{580} & \num[text-series-to-math=true]{879} & \num[text-series-to-math=true]{144} & \textbf{\num[text-series-to-math=true]{82}} (\num[text-series-to-math=true]{82}) & \num[text-series-to-math=true]{82} (\num[text-series-to-math=true]{82}) & \SI{43}{\percent} & \SI{399}{\second}\\
# financial\_services & \num[text-series-to-math=true]{771} & \num[text-series-to-math=true]{7238} & \num[text-series-to-math=true]{4396} & \num[text-series-to-math=true]{4396} (\num[text-series-to-math=true]{4356}) & \num[text-series-to-math=true]{4132} (\num[text-series-to-math=true]{4304}) & \SI{0.01}{\percent} & \SI{888}{\second}\\
# busybox-1\_18\_0 & \num[text-series-to-math=true]{854} & \num[text-series-to-math=true]{1164} & \num[text-series-to-math=true]{29} & \num[text-series-to-math=true]{18} (\num[text-series-to-math=true]{17}) & \num[text-series-to-math=true]{12} (\num[text-series-to-math=true]{13}) & \SI{38}{\percent} & \SI{338}{\second}\\
# busybox-1\_29\_2 & \num[text-series-to-math=true]{1018} & \num[text-series-to-math=true]{997} & \num[text-series-to-math=true]{37} & \num[text-series-to-math=true]{25} (\num[text-series-to-math=true]{23}) & \num[text-series-to-math=true]{17} (\num[text-series-to-math=true]{21}) & \SI{34}{\percent} & \SI{577}{\second}\\
# busybox\_2020-12-... & \num[text-series-to-math=true]{1050} & \num[text-series-to-math=true]{996} & \num[text-series-to-math=true]{34} & \num[text-series-to-math=true]{23} (\num[text-series-to-math=true]{21}) & \num[text-series-to-math=true]{14} (\num[text-series-to-math=true]{19}) & \SI{32}{\percent} & \SI{533}{\second}\\
# am31\_sim & \num[text-series-to-math=true]{1178} & \num[text-series-to-math=true]{2747} & \num[text-series-to-math=true]{61} & \num[text-series-to-math=true]{41} (\num[text-series-to-math=true]{36}) & \num[text-series-to-math=true]{24} (\num[text-series-to-math=true]{28}) & \SI{32}{\percent} & \SI{669}{\second}\\
# EMBToolkit & \num[text-series-to-math=true]{1179} & \num[text-series-to-math=true]{5414} & \num[text-series-to-math=true]{1883} & \num[text-series-to-math=true]{1877} (\num[text-series-to-math=true]{1872}) & \num[text-series-to-math=true]{1746} (\num[text-series-to-math=true]{1872}) & \SI{0.31}{\percent} & \SI{814}{\second}\\
# atlas\_mips32\_4kc & \num[text-series-to-math=true]{1229} & \num[text-series-to-math=true]{2875} & \num[text-series-to-math=true]{66} & \num[text-series-to-math=true]{45} (\num[text-series-to-math=true]{39}) & \num[text-series-to-math=true]{30} (\num[text-series-to-math=true]{33}) & \SI{32}{\percent} & \SI{816}{\second}\\
# eCos-3-0\_i386pc & \num[text-series-to-math=true]{1245} & \num[text-series-to-math=true]{3723} & \num[text-series-to-math=true]{66} & \num[text-series-to-math=true]{53} (\num[text-series-to-math=true]{44}) & \num[text-series-to-math=true]{25} (\num[text-series-to-math=true]{34}) & \SI{20}{\percent} & \SI{743}{\second}\\
# integrator\_arm7 & \num[text-series-to-math=true]{1272} & \num[text-series-to-math=true]{2980} & \num[text-series-to-math=true]{66} & \num[text-series-to-math=true]{45} (\num[text-series-to-math=true]{39}) & \num[text-series-to-math=true]{28} (\num[text-series-to-math=true]{33}) & \SI{31}{\percent} & \SI{740}{\second}\\
# XSEngine & \num[text-series-to-math=true]{1273} & \num[text-series-to-math=true]{2942} & \num[text-series-to-math=true]{63} & \num[text-series-to-math=true]{44} (\num[text-series-to-math=true]{38}) & \num[text-series-to-math=true]{29} (\num[text-series-to-math=true]{32}) & \SI{30}{\percent} & \SI{790}{\second}\\
# aaed2000 & \num[text-series-to-math=true]{1298} & \num[text-series-to-math=true]{3036} & \num[text-series-to-math=true]{89} & \num[text-series-to-math=true]{67} (\num[text-series-to-math=true]{54}) & \num[text-series-to-math=true]{47} (\num[text-series-to-math=true]{51}) & \SI{25}{\percent} & \SI{849}{\second}\\
# FreeBSD-8\_0\_0 & \num[text-series-to-math=true]{1397} & \num[text-series-to-math=true]{15692} & \num[text-series-to-math=true]{76} & \num[text-series-to-math=true]{64} (\num[text-series-to-math=true]{50}) & \num[text-series-to-math=true]{28} (\num[text-series-to-math=true]{30}) & \SI{15}{\percent} & \SI{703}{\second}\\
# ea2468 & \num[text-series-to-math=true]{1408} & \num[text-series-to-math=true]{3319} & \num[text-series-to-math=true]{65} & \num[text-series-to-math=true]{45} (\num[text-series-to-math=true]{39}) & \num[text-series-to-math=true]{26} (\num[text-series-to-math=true]{31}) & \SI{30}{\percent} & \SI{853}{\second}\\
#
# \hline
#  \ \\
#  \textbf{optimality} & & & 5 & $\geq 24$ & & \\ & & & (\SI{11}{\percent}) &(\SI{52}{\percent}) & & \\
#  \textbf{improvements} & & & & &\multicolumn{2}{r}{\num[text-series-to-math=true]{41} (\SI{89}{\percent})} \\ \ \\ \ \\
#
# \end{tabular}
