# %% [markdown]
# # Check Data
#
# This file is just for quickly checking the input data.

# %%
import pandas as pd
from _conf import BASELINE_ARCHIVES
from _utils import parse_solution_overview

baseline_data = pd.concat([parse_solution_overview(p) for p in BASELINE_ARCHIVES])
# Set non available sample sizes to None instead of 0 (which would harm the mean values)
baseline_data.loc[baseline_data["Path"].isna(), "SampleSize"] = None
baseline_data
# Out:
# Found the data folders: {'QuBRA/FeatJAR/evaluation-sampling-algorithms/results/2023-08-18_16-43-25/'}
# Found the data folders: {'2023-03-01_13-51-03/'}
#       ModelID  AlgorithmID  SystemIteration  AlgorithmIteration  InTime  \
# 0           1            0                1                   1    True
# 1           2            0                1                   1    True
# 2           3            0                1                   1    True
# 3           4            0                1                   1    True
# 4           5            0                1                   1    True
# ...       ...          ...              ...                 ...     ...
# 2745       50           10                1                   1   False
# 2746       50           10                1                   2   False
# 2747       50           10                1                   3   False
# 2748       50           10                1                   4   False
# 2749       50           10                1                   5   False
#
#       Success    Time  SampleSize                    Instance  #Variables  \
# 0        True    1620         9.0                   calculate           9
# 1        True     485         9.0                         lcm           9
# 2        True     514         8.0                       email          10
# 3        True     538        10.0                  ChatClient          14
# 4        True     485        13.0  toybox_2006-10-31_23-30-06          16
# ...       ...     ...         ...                         ...         ...
# 2745     True  900008         NaN                      freetz       31012
# 2746     True  900008         NaN                      freetz       31012
# 2747     True  900010         NaN                      freetz       31012
# 2748     True  900009         NaN                      freetz       31012
# 2749     True  900008         NaN                      freetz       31012
#
#       #Clauses     Algorithm     Settings  \
# 0           15  ACTS-IPOG-FT           t2
# 1           16  ACTS-IPOG-FT           t2
# 2           17  ACTS-IPOG-FT           t2
# 3           20  ACTS-IPOG-FT           t2
# 4           13  ACTS-IPOG-FT           t2
# ...        ...           ...          ...
# 2745    102705          YASA  t2_m10_null
# 2746    102705          YASA  t2_m10_null
# 2747    102705          YASA  t2_m10_null
# 2748    102705          YASA  t2_m10_null
# 2749    102705          YASA  t2_m10_null
#
#                                                    Path  \
# 0     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 1     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 2     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 3     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# 4     QuBRA/FeatJAR/evaluation-sampling-algorithms/r...
# ...                                                 ...
# 2745                                               None
# 2746                                               None
# 2747                                               None
# 2748                                               None
# 2749                                               None
#
#                                 ArchivePath
# 0             ./EXTERNAL_INPUT/baseline.zip
# 1             ./EXTERNAL_INPUT/baseline.zip
# 2             ./EXTERNAL_INPUT/baseline.zip
# 3             ./EXTERNAL_INPUT/baseline.zip
# 4             ./EXTERNAL_INPUT/baseline.zip
# ...                                     ...
# 2745  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2746  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2747  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2748  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2749  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
# [2950 rows x 15 columns]

# %%
# Try parsing all instances
from _conf import BASELINE_ARCHIVES, INSTANCE_ARCHIVE
from _utils import get_instance, parse_solution_overview

instances_with_spaces = {}

for instance_name in baseline_data["Instance"].unique().tolist():
    instance = get_instance(instance_name, INSTANCE_ARCHIVE)
    if any(" " in f for f in instance.features):
        print(instance_name, "has a feature with spaces in it")
        print([f for f in instance.features if " " in f])
        instances_with_spaces[instance_name] = [
            f for f in instance.features if " " in f
        ]
print(instances_with_spaces)
# Out:
# Removing ALT-Feature Type with only one element.
# Removing ALT-Feature VncViewer with only one element.
# Removing ALT-Feature HiddenWgt with only one element.
# Removing ALT-Feature GPL with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature FLogging with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature FPersistency with only one element.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature FStatistics with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature FEvictor with only one element.
# Removing ALT-Feature FBtree with only one element.
# Removing ALT-Feature BerkeleyDb with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Removing ALT-Feature Violet with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature SPL with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature UserType with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature UserType_1 with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# PPU has a feature with spaces in it
# ['Vendor 1', 'Vendor 2']
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing DIMACS
# Parsing DIMACS
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_GCC_VERSION_4_1_2_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LIBXRANDR_VERSION_1_3_0_alt with only one element.
# Removing ALT-Feature EMBTK_XCMISCPROTO_VERSION_1_2_0_alt with only one element.
# Removing ALT-Feature EMBTK_IMLIB2_VERSION_1_4_4_alt with only one element.
# Removing ALT-Feature EMBTK_LIBPTHREADSTUBS_VERSION_0_3_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FONTSPROTO_VERSION_2_1_0_alt with only one element.
# Removing ALT-Feature EMBTK_MTDUTILS_VERSION_1_3_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FONTCONFIG_VERSION_2_8_0_alt with only one element.
# Removing ALT-Feature EMBTK_LIBXCOMPOSITE_VERSION_0_4_2_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_RANDRPROTO_VERSION_1_3_1_alt with only one element.
# Removing ALT-Feature EMBTK_XF86VIDEOFBDEV_VERSION_0_4_2_alt with only one element.
# Removing ALT-Feature EMBTK_RESOURCEPROTO_VERSION_1_1_0_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_XKBCOMP_VERSION_1_1_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_BIGREQSPROTO_VERSION_1_1_0_alt with only one element.
# Removing ALT-Feature EMBTK_MICROPERL_VERSION_5_10_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LIBTIFF_VERSION_3_9_2_alt with only one element.
# Removing ALT-Feature EMBTK_XCBPROTO_VERSION_1_6_alt with only one element.
# Removing ALT-Feature EMBTK_COMPOSITEPROTO_VERSION_0_4_1_alt with only one element.
# Removing ALT-Feature EMBTK_XKEYBOARDCONFIG_VERSION_1_8_alt with only one element.
# Removing ALT-Feature EMBTK_NCURSES_VERSION_5_7_alt with only one element.
# Removing ALT-Feature EMBTK_ZLIB_VERSION_1_2_5_alt with only one element.
# Removing ALT-Feature EMBTK_TSLIB_VERSION_1_0_alt with only one element.
# Removing ALT-Feature EMBTK_UTILLINUXNG_VERSION_2_18_alt with only one element.
# Removing ALT-Feature EMBTK_LIBXFT_VERSION_2_1_14_alt with only one element.
# Removing ALT-Feature EMBTK_LIBXFIXES_VERSION_4_0_5_alt with only one element.
# Removing ALT-Feature EMBTK_LIBFONTENC_VERSION_1_0_5_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LIBXKBFILE_VERSION_1_0_6_alt with only one element.
# Removing ALT-Feature EMBTK_DAMAGEPROTO_VERSION_1_2_0_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_XTRANS_VERSION_1_2_5_alt with only one element.
# Removing ALT-Feature EMBTK_LIBELF_VERSION_0_8_13_alt with only one element.
# Removing ALT-Feature EMBTK_RECORDPROTO_VERSION_1_14_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LUA_VERSION_5_1_alt with only one element.
# Removing ALT-Feature EMBTK_EXPAT_VERSION_2_0_1_alt with only one element.
# Removing ALT-Feature EMBTK_XCBUTIL_VERSION_0_3_6_alt with only one element.
# Removing ALT-Feature EMBTK_DBUS_VERSION_1_2_24_alt with only one element.
# Removing ALT-Feature EMBTK_INPUTPROTO_VERSION_2_0_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FIXESPROTO_VERSION_4_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FREEFONT_TTF_VERSION_20090104_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_GCC_VERSION_4_2_4_alt with only one element.
# Removing ALT-Feature EMBTK_ARCH_ARM_ABI_EABI_alt with only one element.
# Removing ALT-Feature EMBTK_MPC_HOST_VERSION_0_8_1_alt with only one element.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Removing ALT-Feature N_100300__F_100325_xor with only one element.
# Removing ALT-Feature N_100300__F_100330 with only one element.
# Removing ALT-Feature N_100000__I_101285_i_F_101295 with only one element.
# Removing ALT-Feature N_100000__I_101285_i_F_101310 with only one element.
# Removing ALT-Feature N_100000__I_101405_i_F_101415 with only one element.
# Removing ALT-Feature N_100000__I_101405_i_F_101430 with only one element.
# Removing ALT-Feature N_100000__I_101525_i_F_101535 with only one element.
# Removing ALT-Feature N_100000__I_101525_i_F_101550 with only one element.
# Removing ALT-Feature N_100000__I_101645_i_F_101655 with only one element.
# Removing ALT-Feature N_100000__I_101645_i_F_101670 with only one element.
# Removing ALT-Feature N_101764__F_101784_xor with only one element.
# Removing ALT-Feature N_101764__F_101808 with only one element.
# Removing ALT-Feature N_101906__F_101927 with only one element.
# Removing ALT-Feature N_101932__F_101952 with only one element.
# Removing ALT-Feature N_102004__F_102014 with only one element.
# Removing ALT-Feature N_102004__F_102013 with only one element.
# Removing ALT-Feature N_102004__F_102016 with only one element.
# Removing ALT-Feature N_102004__F_102019 with only one element.
# Removing ALT-Feature N_102004__F_102018 with only one element.
# Removing ALT-Feature N_102383__I_102808_i_F_102845_xor with only one element.
# Removing ALT-Feature N_102383__I_102808_i_F_102806_xor with only one element.
# Removing ALT-Feature N_102383__I_103054_i_F_103091_xor with only one element.
# Removing ALT-Feature N_102383__I_103054_i_F_103052_xor with only one element.
# Removing ALT-Feature N_102383__I_103300_i_F_103532 with only one element.
# Removing ALT-Feature N_102383__I_103300_i_F_103538 with only one element.
# Removing ALT-Feature N_102383__I_103546_i_F_103778 with only one element.
# Removing ALT-Feature N_102383__I_103546_i_F_103784 with only one element.
# Removing ALT-Feature N_102383__I_103792_i_F_104024 with only one element.
# Removing ALT-Feature N_102383__I_103792_i_F_104030 with only one element.
# Removing ALT-Feature N_102383__I_104038_i_F_104270 with only one element.
# Removing ALT-Feature N_102383__I_104038_i_F_104276 with only one element.
# Removing ALT-Feature N_104284__F_104292 with only one element.
# Removing ALT-Feature N_104700__F_104725 with only one element.
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# {'PPU': ['Vendor 1', 'Vendor 2']}

# %%
baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size()
# Out:
# Algorithm      Settings    Instance
# ACTS-IPOF-CSP  t2          APL                            1
#                            APL-Model                      1
#                            Automotive01                   1
#                            BankingSoftware                1
#                            BattleofTanks                  1
#                                                          ..
# YASA           t2_m5_null  soletta_2017-03-09_21-02-40    5
#                            toybox_2006-10-31_23-30-06     5
#                            toybox_2020-12-06_00-02-46     5
#                            uclibc_2008-06-05_13-46-47     5
#                            uclibc_2020-12-24_11-54-53     5
# Length: 750, dtype: int64

# %%
# Make sure, we have the same amount of samples for each algorithm and instance
assert (
    baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().min()
    == baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().max()
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Make sure, we have the same amount of samples for each algorithm and instance
# ----> 2 assert baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().min() == baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().max()
#
# AssertionError:

# %%
# Make sure, every algorithm has run on the same number of instances
assert (
    baseline_data.groupby(["Algorithm", "Settings"]).size().max()
    == baseline_data.groupby(["Algorithm", "Settings"]).size().min()
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Make sure, every algorithm has run on the same number of instances
# ----> 2 assert baseline_data.groupby(["Algorithm", "Settings"]).size().max() == baseline_data.groupby(["Algorithm", "Settings"]).size().min()
#
# AssertionError:

# %%
baseline_data[["Algorithm", "Settings", "Instance"]].nunique()
# Out:
# Algorithm     9
# Settings      5
# Instance     50
# dtype: int64

# %%
# show full dataframe
import pandas as pd

pd.set_option("display.max_rows", None)

print(
    baseline_data.groupby(["Instance"])[["#Variables", "#Clauses", "SampleSize"]]
    .mean()
    .sort_values(by="#Variables", ascending=True)
)
# Out:
#                              #Variables  #Clauses   SampleSize
# Instance
# calculate                           9.0      15.0     9.203390
# lcm                                 9.0      16.0     8.186441
# email                              10.0      17.0     7.033898
# ChatClient                         14.0      20.0     9.118644
# toybox_2006-10-31_23-30-06         16.0      13.0    11.169492
# car                                16.0      33.0     6.152542
# FeatureIDE                         19.0      27.0    12.474576
# FameDB                             22.0      40.0     9.355932
# APL                                23.0      35.0    10.203390
# SafeBali                           24.0      45.0    11.363636
# APL-Model                          28.0      40.0    12.610169
# TightVNC                           28.0      39.0    12.881356
# gpl                                38.0      99.0    20.745763
# SortingLine                        39.0      77.0    15.525424
# dell                               46.0     244.0    37.898305
# PPU                                52.0     109.0    14.181818
# berkeleyDB1                        76.0     147.0    21.818182
# axTLS                              96.0     183.0    17.728814
# Violet                            101.0     203.0    26.169492
# berkeleyDB2                       119.0     346.0    22.824561
# soletta_2015-06-26_18-38-56       129.0     192.0    33.728814
# BattleofTanks                     144.0     769.0   478.385965
# BankingSoftware                   176.0     280.0    44.362069
# fiasco_2017-09-26_11-30-56        230.0    1181.0   258.090909
# fiasco_2020-12-01_14-09-14        258.0    1542.0   236.090909
# uclibc_2008-06-05_13-46-47        263.0    1699.0   533.363636
# uclibc_2020-12-24_11-54-53        272.0    1670.0   386.818182
# E-Shop                            326.0     499.0    22.181818
# toybox_2020-12-06_00-02-46        334.0      92.0    23.728814
# DMIE                              366.0     627.0    29.181818
# soletta_2017-03-09_21-02-40       458.0    1862.0    61.454545
# busybox_2007-01-24_09-14-09       540.0     429.0    41.542373
# fs_2017-05-22                     557.0    4992.0   401.400000
# WaterlooGenerated                 580.0     879.0   160.333333
# financial_services                771.0    7238.0  4402.750000
# busybox-1_18_0                    854.0    1164.0    34.636364
# busybox-1_29_2                   1018.0     997.0    44.727273
# busybox_2020-12-16_21-53-05      1050.0     996.0    43.101695
# am31_sim                         1178.0    2747.0    65.545455
# EMBToolkit                       1179.0    5414.0  1928.900000
# atlas_mips32_4kc                 1229.0    2875.0    72.019608
# eCos-3-0_i386pc                  1245.0    3723.0    71.100000
# integrator_arm7                  1272.0    2980.0    71.800000
# XSEngine                         1273.0    2942.0    68.600000
# aaed2000                         1298.0    3036.0    99.600000
# FreeBSD-8_0_0                    1397.0   15692.0    82.100000
# ea2468                           1408.0    3319.0    72.000000
# Automotive01                     2513.0   10311.0   951.500000
# main_light                       3296.0    8004.0  1047.875000
# freetz                          31012.0  102705.0          NaN

# %%
baseline_data["Instance"].unique()
# Out:
# array(['calculate', 'lcm', 'email', 'ChatClient', 'car', 'FeatureIDE',
#        'FameDB2', 'FameDB', 'APL', 'SafeBali', 'APL-Model', 'gpl', 'dell',
#        'PPU', 'fiasco', 'berkeleyDB1', 'axTLS', 'berkeleyDB2',
#        'BattleofTanks', 'BankingSoftware', 'eShopSplot', 'E-Shop',
#        'eShopFIDE', 'DMIE', 'fs_2017-05-22', 'financial_services',
#        'busybox-1_18_0', 'busybox-1_23_1', 'busybox-1_29_2', 'am31_sim',
#        'EMBToolkit', 'calm16_ceb', 'calm32_ceb', 'psim', 'h8300h_sim',
#        'h8s_sim', 'fads', 'ceb_v850', 'edosk2674', 'jmr3904', 'h8max',
#        'cma28x', 'aki3068net', 'atlas_mips64_5kc', 'cma230', 'mpc50',
#        'gps4020', 'aeb', 'atlas_mips32_4kc', 'ref4955', 'brutus',
#        'sa1100mm', 'prpmc1100', 'pid', 'mb93093', 'asb',
#        'malta_mips64_5kc', 'malta_mips32_4kc', 'eCos-3-0_i386pc',
#        'csb281', 'eb42', 'mac7100evb', 'mace1', 'excalibur_arm9',
#        'frv400', 'cq7708', 'eb40', 'grg', 'eb40a', 'jtst', 'asb2305',
#        'ebsa285', 'edb7xxx', 'ixdp425', 'pati', 'picasso', 'lpcmt',
#        'p2106', 'mcb2100', 'mb93091', 'dreamcast', 'sh7708', 'pc_vmWare',
#        'iq80321', 'innovator', 'pc_rltk8139', 'iq80310', 'npwr', 'ipaq',
#        'pc_i82544', 'pc_i82559', 'integrator_arm7', 'sh4_202_md',
#        'olpch2294', 'refidt334', 'aim711', 'nano', 'flexanet', 'ocelot',
#        'cme555', 'assabet', 'e7t', 'ec555', 'cq7750', 'integrator_arm9',
#        'eb55', 'adder', 'olpcl2294', 'phycore', 'olpce2294', 'cerf',
#        'adderII', 'moab', 'pc_usb_d12', 'aaed2000', 'cerfpda', 'mbx',
#        'se7751', 'at91sam7sek', 'hs7729pci', 'rattler', 'at91sam7xek',
#        'se77x9', 'm5272c3', 'sam7ex256', 'phycore229x', 'FreeBSD-8_0_0',
#        'ea2468', 'toybox_2006-10-31_23-30-06', 'TightVNC', 'SortingLine',
#        'Violet', 'soletta_2015-06-26_18-38-56',
#        'fiasco_2017-09-26_11-30-56', 'fiasco_2020-12-01_14-09-14',
#        'uclibc_2008-06-05_13-46-47', 'uclibc_2020-12-24_11-54-53',
#        'toybox_2020-12-06_00-02-46', 'soletta_2017-03-09_21-02-40',
#        'busybox_2007-01-24_09-14-09', 'WaterlooGenerated',
#        'busybox_2020-12-16_21-53-05', 'XSEngine', 'Automotive01',
#        'main_light', 'freetz'], dtype=object)
