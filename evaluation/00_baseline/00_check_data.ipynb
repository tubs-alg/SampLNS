# %% [markdown]
# # Check Data
#
# This file is just for quickly checking the input data.

# %%
import pandas as pd
from _conf import BASELINE_ARCHIVES
from _utils import parse_solution_overview

baseline_data = pd.concat([parse_solution_overview(p) for p in BASELINE_ARCHIVES])
# Set non available sample sizes to None instead of 0 (which would harm the mean values)
baseline_data.loc[baseline_data["Path"].isna(), "SampleSize"] = None
baseline_data
# Out:
# Found the data folders: {'2024-02-20_15-34-55/', '2024-02-23_21-52-36/', '2024-02-23_21-52-42/', '2024-02-20_15-35-55/', '2024-02-23_21-52-24/', '2024-02-23_21-52-29/'}
#       ModelID  AlgorithmID  SystemIteration  AlgorithmIteration  InTime  \
# 0           1            0                1                   1    True
# 1           1            0                2                   1    True
# 2           1            0                3                   1    True
# 3           1            0                4                   1    True
# 4           1            0                5                   1    True
# ...       ...          ...              ...                 ...     ...
# 2580        6           10                1                   1   False
# 2581        6           10                2                   1   False
# 2582        6           10                3                   1   False
# 2583        6           10                4                   1   False
# 2584        6           10                5                   1   False
#
#       Success    Time  SampleSize                     Instance  #Variables  \
# 0        True    4167        60.0  soletta_2017-03-09_21-02-40         458
# 1        True    4100        64.0  soletta_2017-03-09_21-02-40         458
# 2        True    4192        67.0  soletta_2017-03-09_21-02-40         458
# 3        True    4186        61.0  soletta_2017-03-09_21-02-40         458
# 4        True    4228        61.0  soletta_2017-03-09_21-02-40         458
# ...       ...     ...         ...                          ...         ...
# 2580     True  900009         NaN                     XSEngine        1273
# 2581     True  900009         NaN                     XSEngine        1273
# 2582     True  900008         NaN                     XSEngine        1273
# 2583     True  900009         NaN                     XSEngine        1273
# 2584     True  900008         NaN                     XSEngine        1273
#
#       #Clauses      Algorithm Settings  \
# 0         1862      FIDE-ICPL       t2
# 1         1862      FIDE-ICPL       t2
# 2         1862      FIDE-ICPL       t2
# 3         1862      FIDE-ICPL       t2
# 4         1862      FIDE-ICPL       t2
# ...        ...            ...      ...
# 2580      2942  ACTS-IPOF-CSP       t2
# 2581      2942  ACTS-IPOF-CSP       t2
# 2582      2942  ACTS-IPOF-CSP       t2
# 2583      2942  ACTS-IPOF-CSP       t2
# 2584      2942  ACTS-IPOF-CSP       t2
#
#                                         Path                    ArchivePath
# 0     2024-02-20_15-34-55/1_1_0_1_sample.csv  ./EXTERNAL_INPUT/baseline.zip
# 1     2024-02-20_15-34-55/1_2_0_1_sample.csv  ./EXTERNAL_INPUT/baseline.zip
# 2     2024-02-20_15-34-55/1_3_0_1_sample.csv  ./EXTERNAL_INPUT/baseline.zip
# 3     2024-02-20_15-34-55/1_4_0_1_sample.csv  ./EXTERNAL_INPUT/baseline.zip
# 4     2024-02-20_15-34-55/1_5_0_1_sample.csv  ./EXTERNAL_INPUT/baseline.zip
# ...                                      ...                            ...
# 2580                                    None  ./EXTERNAL_INPUT/baseline.zip
# 2581                                    None  ./EXTERNAL_INPUT/baseline.zip
# 2582                                    None  ./EXTERNAL_INPUT/baseline.zip
# 2583                                    None  ./EXTERNAL_INPUT/baseline.zip
# 2584                                    None  ./EXTERNAL_INPUT/baseline.zip
#
# [2585 rows x 15 columns]

# %%
# Try parsing all instances
from _conf import BASELINE_ARCHIVES, INSTANCE_ARCHIVE
from _utils import get_instance, parse_solution_overview

instances_with_spaces = {}

for instance_name in baseline_data["Instance"].unique().tolist():
    instance = get_instance(instance_name, INSTANCE_ARCHIVE)
    if any(" " in f for f in instance.features):
        print(instance_name, "has a feature with spaces in it")
        print([f for f in instance.features if " " in f])
        instances_with_spaces[instance_name] = [
            f for f in instance.features if " " in f
        ]
print(instances_with_spaces)
# Out:
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Parsing DIMACS
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_GCC_VERSION_4_1_2_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LIBXRANDR_VERSION_1_3_0_alt with only one element.
# Removing ALT-Feature EMBTK_XCMISCPROTO_VERSION_1_2_0_alt with only one element.
# Removing ALT-Feature EMBTK_IMLIB2_VERSION_1_4_4_alt with only one element.
# Removing ALT-Feature EMBTK_LIBPTHREADSTUBS_VERSION_0_3_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FONTSPROTO_VERSION_2_1_0_alt with only one element.
# Removing ALT-Feature EMBTK_MTDUTILS_VERSION_1_3_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FONTCONFIG_VERSION_2_8_0_alt with only one element.
# Removing ALT-Feature EMBTK_LIBXCOMPOSITE_VERSION_0_4_2_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_RANDRPROTO_VERSION_1_3_1_alt with only one element.
# Removing ALT-Feature EMBTK_XF86VIDEOFBDEV_VERSION_0_4_2_alt with only one element.
# Removing ALT-Feature EMBTK_RESOURCEPROTO_VERSION_1_1_0_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_XKBCOMP_VERSION_1_1_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_BIGREQSPROTO_VERSION_1_1_0_alt with only one element.
# Removing ALT-Feature EMBTK_MICROPERL_VERSION_5_10_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LIBTIFF_VERSION_3_9_2_alt with only one element.
# Removing ALT-Feature EMBTK_XCBPROTO_VERSION_1_6_alt with only one element.
# Removing ALT-Feature EMBTK_COMPOSITEPROTO_VERSION_0_4_1_alt with only one element.
# Removing ALT-Feature EMBTK_XKEYBOARDCONFIG_VERSION_1_8_alt with only one element.
# Removing ALT-Feature EMBTK_NCURSES_VERSION_5_7_alt with only one element.
# Removing ALT-Feature EMBTK_ZLIB_VERSION_1_2_5_alt with only one element.
# Removing ALT-Feature EMBTK_TSLIB_VERSION_1_0_alt with only one element.
# Removing ALT-Feature EMBTK_UTILLINUXNG_VERSION_2_18_alt with only one element.
# Removing ALT-Feature EMBTK_LIBXFT_VERSION_2_1_14_alt with only one element.
# Removing ALT-Feature EMBTK_LIBXFIXES_VERSION_4_0_5_alt with only one element.
# Removing ALT-Feature EMBTK_LIBFONTENC_VERSION_1_0_5_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LIBXKBFILE_VERSION_1_0_6_alt with only one element.
# Removing ALT-Feature EMBTK_DAMAGEPROTO_VERSION_1_2_0_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_XTRANS_VERSION_1_2_5_alt with only one element.
# Removing ALT-Feature EMBTK_LIBELF_VERSION_0_8_13_alt with only one element.
# Removing ALT-Feature EMBTK_RECORDPROTO_VERSION_1_14_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_LUA_VERSION_5_1_alt with only one element.
# Removing ALT-Feature EMBTK_EXPAT_VERSION_2_0_1_alt with only one element.
# Removing ALT-Feature EMBTK_XCBUTIL_VERSION_0_3_6_alt with only one element.
# Removing ALT-Feature EMBTK_DBUS_VERSION_1_2_24_alt with only one element.
# Removing ALT-Feature EMBTK_INPUTPROTO_VERSION_2_0_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FIXESPROTO_VERSION_4_1_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_FREEFONT_TTF_VERSION_20090104_alt with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature EMBTK_GCC_VERSION_4_2_4_alt with only one element.
# Removing ALT-Feature EMBTK_ARCH_ARM_ABI_EABI_alt with only one element.
# Removing ALT-Feature EMBTK_MPC_HOST_VERSION_0_8_1_alt with only one element.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Conjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Parsing FeatureIDE
# Parsing FeatureIDE
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Removing ALT-Feature Violet with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature SPL with only one element.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Removing ALT-Feature Type with only one element.
# Removing ALT-Feature VncViewer with only one element.
# Removing ALT-Feature HiddenWgt with only one element.
# Removing ALT-Feature GPL with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature FLogging with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature FPersistency with only one element.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature FStatistics with only one element.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature FEvictor with only one element.
# Removing ALT-Feature FBtree with only one element.
# Removing ALT-Feature BerkeleyDb with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Disjunction with only one literal removed.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Removing ALT-Feature UserType with only one element.
# Making mandatory elements of ALT non-mandatory.
# Removing ALT-Feature UserType_1 with only one element.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of ALT non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Making mandatory elements of OR non-mandatory.
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# PPU has a feature with spaces in it
# ['Vendor 1', 'Vendor 2']
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# Parsing DIMACS
# Parsing DIMACS
# Parsing DIMACS
# Parsing DIMACS
# Parsing FeatureIDE
# Parsing FeatureIDE
# {'PPU': ['Vendor 1', 'Vendor 2']}

# %%
baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size()
# Out:
# Algorithm      Settings  Instance
# ACTS-IPOF-CSP  t2        APL                            5
#                          APL-Model                      5
#                          BankingSoftware                5
#                          BattleofTanks                  5
#                          ChatClient                     5
#                                                        ..
# Incling        t2        soletta_2017-03-09_21-02-40    5
#                          toybox_2006-10-31_23-30-06     5
#                          toybox_2020-12-06_00-02-46     5
#                          uclibc_2008-06-05_13-46-47     5
#                          uclibc_2020-12-24_11-54-53     5
# Length: 517, dtype: int64

# %%
# Check that sample sizes are actually different in the runs.
baseline_data.groupby(["Algorithm", "Settings", "Instance"])["SampleSize"].nunique()
# Out:
# Algorithm      Settings  Instance
# ACTS-IPOF-CSP  t2        APL                            2
#                          APL-Model                      3
#                          BankingSoftware                1
#                          BattleofTanks                  0
#                          ChatClient                     2
#                                                        ..
# Incling        t2        soletta_2017-03-09_21-02-40    5
#                          toybox_2006-10-31_23-30-06     2
#                          toybox_2020-12-06_00-02-46     3
#                          uclibc_2008-06-05_13-46-47     3
#                          uclibc_2020-12-24_11-54-53     5
# Name: SampleSize, Length: 517, dtype: int64

# %%
# Check that all instances are present in the baseline
assert len(set(["calculate", "lcm", "email", "ChatClient", "toybox_2006-10-31_23-30-06", "car", "FeatureIDE", "FameDB", "APL", "SafeBali", "TightVNC", "APL-Model", "gpl", "SortingLine", "dell", "soletta_2017-03-09_21-02-40", "busybox_2007-01-24_09-14-09", "fs_2017-05-22", "WaterlooGenerated", "financial_services", "busybox-1_18_0", "busybox-1_29_2", "busybox_2020-12-16_21-53-05", "am31_sim", "EMBToolkit", "PPU", "berkeleyDB1", "axTLS", "Violet", "berkeleyDB2", "soletta_2015-06-26_18-38-56", "BattleofTanks", "BankingSoftware", "fiasco_2017-09-26_11-30-56", "fiasco_2020-12-01_14-09-14", "uclibc_2008-06-05_13-46-47", "uclibc_2020-12-24_11-54-53", "E-Shop", "toybox_2020-12-06_00-02-46", "DMIE", "atlas_mips32_4kc", "eCos-3-0_i386pc", "integrator_arm7", "XSEngine", "aaed2000", "FreeBSD-8_0_0", "ea2468"])-
        set(baseline_data["Instance"].unique())) == 0

# %%
# Make sure, we have the same amount of samples for each algorithm and instance
assert (
    baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().min()
    == baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().max()
), f'{baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().min()} {baseline_data.groupby(["Algorithm", "Settings", "Instance"]).size().max()}'

# %%
# Make sure, every algorithm has run on the same number of instances
assert (
    baseline_data.groupby(["Algorithm", "Settings"]).size().max()
    == baseline_data.groupby(["Algorithm", "Settings"]).size().min()
)

# %%
baseline_data[["Algorithm", "Settings", "Instance"]].nunique()
# Out:
# Algorithm     8
# Settings      5
# Instance     47
# dtype: int64

# %%
# show full dataframe
import pandas as pd

pd.set_option("display.max_rows", None)

print(
    baseline_data.groupby(["Instance"])[["#Variables", "#Clauses", "SampleSize"]]
    .mean()
    .sort_values(by="#Variables", ascending=True)
)
# Out:
#                              #Variables  #Clauses   SampleSize
# Instance
# calculate                           9.0      15.0     9.381818
# lcm                                 9.0      16.0     8.654545
# email                              10.0      17.0     7.272727
# ChatClient                         14.0      20.0     9.254545
# toybox_2006-10-31_23-30-06         16.0      13.0    11.963636
# car                                16.0      33.0     6.454545
# FeatureIDE                         19.0      27.0    12.545455
# FameDB                             22.0      40.0     9.600000
# APL                                23.0      35.0    10.945455
# SafeBali                           24.0      45.0    11.257143
# TightVNC                           28.0      39.0    13.400000
# APL-Model                          28.0      40.0    13.309091
# gpl                                38.0      99.0    20.727273
# SortingLine                        39.0      77.0    15.981818
# dell                               46.0     244.0    38.472727
# PPU                                52.0     109.0    14.571429
# berkeleyDB1                        76.0     147.0    22.971429
# axTLS                              96.0     183.0    18.090909
# Violet                            101.0     203.0    28.109091
# berkeleyDB2                       119.0     346.0    23.733333
# soletta_2015-06-26_18-38-56       129.0     192.0    34.163636
# BattleofTanks                     144.0     769.0   512.688889
# BankingSoftware                   176.0     280.0    46.880000
# fiasco_2017-09-26_11-30-56        230.0    1181.0   267.971429
# fiasco_2020-12-01_14-09-14        258.0    1542.0   245.457143
# uclibc_2008-06-05_13-46-47        263.0    1699.0   547.742857
# uclibc_2020-12-24_11-54-53        272.0    1670.0   398.542857
# E-Shop                            326.0     499.0    22.914286
# toybox_2020-12-06_00-02-46        334.0      92.0    24.163636
# DMIE                              366.0     627.0    30.756098
# soletta_2017-03-09_21-02-40       458.0    1862.0    64.057143
# busybox_2007-01-24_09-14-09       540.0     429.0    43.672727
# fs_2017-05-22                     557.0    4992.0   402.333333
# WaterlooGenerated                 580.0     879.0   172.555556
# financial_services                771.0    7238.0  4399.600000
# busybox-1_18_0                    854.0    1164.0    37.085714
# busybox-1_29_2                   1018.0     997.0    47.171429
# busybox_2020-12-16_21-53-05      1050.0     996.0    47.148936
# am31_sim                         1178.0    2747.0    66.857143
# EMBToolkit                       1179.0    5414.0  1963.300000
# atlas_mips32_4kc                 1229.0    2875.0    73.114286
# eCos-3-0_i386pc                  1245.0    3723.0    73.485714
# integrator_arm7                  1272.0    2980.0    73.939394
# XSEngine                         1273.0    2942.0    72.264706
# aaed2000                         1298.0    3036.0   104.233333
# FreeBSD-8_0_0                    1397.0   15692.0    86.600000
# ea2468                           1408.0    3319.0    73.666667

# %%
baseline_data["Instance"].unique()
# Out:
# array(['soletta_2017-03-09_21-02-40', 'busybox_2007-01-24_09-14-09',
#        'fs_2017-05-22', 'WaterlooGenerated', 'financial_services',
#        'busybox-1_18_0', 'busybox-1_29_2', 'busybox_2020-12-16_21-53-05',
#        'am31_sim', 'EMBToolkit', 'aaed2000', 'FreeBSD-8_0_0', 'ea2468',
#        'Violet', 'berkeleyDB2', 'soletta_2015-06-26_18-38-56',
#        'eCos-3-0_i386pc', 'calculate', 'lcm', 'email', 'ChatClient',
#        'toybox_2006-10-31_23-30-06', 'car', 'FeatureIDE', 'FameDB', 'APL',
#        'SafeBali', 'TightVNC', 'APL-Model', 'gpl', 'SortingLine', 'dell',
#        'PPU', 'berkeleyDB1', 'axTLS', 'BattleofTanks', 'BankingSoftware',
#        'E-Shop', 'toybox_2020-12-06_00-02-46', 'DMIE', 'atlas_mips32_4kc',
#        'fiasco_2017-09-26_11-30-56', 'fiasco_2020-12-01_14-09-14',
#        'uclibc_2008-06-05_13-46-47', 'uclibc_2020-12-24_11-54-53',
#        'integrator_arm7', 'XSEngine'], dtype=object)
