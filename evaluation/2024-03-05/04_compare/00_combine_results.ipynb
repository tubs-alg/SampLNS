# %%
from pathlib import Path
import tomllib
import pandas as pd

with (Path().cwd()/".."/"config.toml").open("rb") as f:
    config = tomllib.load(f)
    config_exp = config[Path().cwd().name]
    config_input = config_exp["input"]

# %%
instance_infos = pd.read_json(Path("..")/config_input["baseline_algs"])[["Instance", "#Variables", "#Clauses"]].rename(columns={"#Variables": "n", "#Clauses": "m", "Instance": "instance"}).groupby("instance").mean()
instance_infos.to_json(config["04_compare"]["output"]["instance_infos"])
instance_infos
# Out:
#                                   n        m
# instance
# APL                            23.0     35.0
# APL-Model                      28.0     40.0
# BankingSoftware               176.0    280.0
# BattleofTanks                 144.0    769.0
# ChatClient                     14.0     20.0
# DMIE                          366.0    627.0
# E-Shop                        326.0    499.0
# EMBToolkit                   1179.0   5414.0
# FameDB                         22.0     40.0
# FeatureIDE                     19.0     27.0
# FreeBSD-8_0_0                1397.0  15692.0
# PPU                            52.0    109.0
# SafeBali                       24.0     45.0
# SortingLine                    39.0     77.0
# TightVNC                       28.0     39.0
# Violet                        101.0    203.0
# WaterlooGenerated             580.0    879.0
# XSEngine                     1273.0   2942.0
# aaed2000                     1298.0   3036.0
# am31_sim                     1178.0   2747.0
# atlas_mips32_4kc             1229.0   2875.0
# axTLS                          96.0    183.0
# berkeleyDB1                    76.0    147.0
# berkeleyDB2                   119.0    346.0
# busybox-1_18_0                854.0   1164.0
# busybox-1_29_2               1018.0    997.0
# busybox_2007-01-24_09-14-09   540.0    429.0
# busybox_2020-12-16_21-53-05  1050.0    996.0
# calculate                       9.0     15.0
# car                            16.0     33.0
# dell                           46.0    244.0
# eCos-3-0_i386pc              1245.0   3723.0
# ea2468                       1408.0   3319.0
# email                          10.0     17.0
# fiasco_2017-09-26_11-30-56    230.0   1181.0
# fiasco_2020-12-01_14-09-14    258.0   1542.0
# financial_services            771.0   7238.0
# fs_2017-05-22                 557.0   4992.0
# gpl                            38.0     99.0
# integrator_arm7              1272.0   2980.0
# lcm                             9.0     16.0
# soletta_2015-06-26_18-38-56   129.0    192.0
# soletta_2017-03-09_21-02-40   458.0   1862.0
# toybox_2006-10-31_23-30-06     16.0     13.0
# toybox_2020-12-06_00-02-46    334.0     92.0
# uclibc_2008-06-05_13-46-47    263.0   1699.0
# uclibc_2020-12-24_11-54-53    272.0   1670.0

# %%
baseline_data = pd.read_json(Path("..")/config_input["baseline_algs"])
baseline_data.rename(columns={"Instance": "instance", "SampleSize": "upper_bound"}, inplace=True)
def name_algorithms(row):
    if "YASA" in row["Algorithm"]:
        m = row["Settings"].split("_")[1][1:]
        return f"YASA (m={m})"
    else:
        return row["Algorithm"].replace("FIDE-","")
baseline_data["algorithm"] = baseline_data.apply(name_algorithms, axis=1)
print(baseline_data["algorithm"].unique())
baseline_data["runtime"] = baseline_data["Time"]/1000
baseline_data = baseline_data[['instance', 'algorithm', 'upper_bound', "runtime"]]
baseline_data
# Out:
# ['ICPL' 'Chvatal' 'Incling' 'YASA (m=1)' 'YASA (m=3)' 'YASA (m=5)'
#  'YASA (m=10)' 'ACTS-IPOG-FT' 'ACTS-IPOG-CSP' 'ACTS-IPOF-FT'
#  'ACTS-IPOF-CSP']
#              instance      algorithm  upper_bound  runtime
# 0                 PPU           ICPL         15.0    1.706
# 1                 PPU        Chvatal         15.0    1.455
# 2                 PPU        Incling         17.0    0.171
# 3                 PPU     YASA (m=1)         13.0    0.266
# 4                 PPU     YASA (m=3)         12.0    0.290
# ...               ...            ...          ...      ...
# 2580  eCos-3-0_i386pc    YASA (m=10)         68.0   24.011
# 2581  eCos-3-0_i386pc   ACTS-IPOG-FT          NaN  900.001
# 2582  eCos-3-0_i386pc  ACTS-IPOG-CSP          NaN  900.008
# 2583  eCos-3-0_i386pc   ACTS-IPOF-FT          NaN  900.008
# 2584  eCos-3-0_i386pc  ACTS-IPOF-CSP          NaN  900.009
#
# [2585 rows x 4 columns]

# %%
yasa_15min_data = pd.read_json(Path("..")/config_input["yasa_15min"]).drop(columns=["path"])
yasa_15min_data["algorithm"] = "YASA (15min)"
yasa_15min_data["runtime"] = 900.0
yasa_15min_data.rename(columns={"sample_size": "upper_bound"}, inplace=True)
yasa_15min_data
# Out:
#                         instance  upper_bound     algorithm  runtime
# 0    soletta_2017-03-09_21-02-40           63  YASA (15min)    900.0
# 1    soletta_2017-03-09_21-02-40           64  YASA (15min)    900.0
# 2    soletta_2017-03-09_21-02-40           62  YASA (15min)    900.0
# 3    soletta_2017-03-09_21-02-40           63  YASA (15min)    900.0
# 4    soletta_2017-03-09_21-02-40           63  YASA (15min)    900.0
# ..                           ...          ...           ...      ...
# 230                     am31_sim           69  YASA (15min)    900.0
# 231                     am31_sim           72  YASA (15min)    900.0
# 232                     am31_sim           70  YASA (15min)    900.0
# 233                     am31_sim           72  YASA (15min)    900.0
# 234                     am31_sim           72  YASA (15min)    900.0
#
# [235 rows x 4 columns]

# %%
baseline_df = pd.concat([baseline_data, yasa_15min_data], ignore_index=True)
baseline_df
# Out:
#       instance     algorithm  upper_bound  runtime
# 0          PPU          ICPL         15.0    1.706
# 1          PPU       Chvatal         15.0    1.455
# 2          PPU       Incling         17.0    0.171
# 3          PPU    YASA (m=1)         13.0    0.266
# 4          PPU    YASA (m=3)         12.0    0.290
# ...        ...           ...          ...      ...
# 2815  am31_sim  YASA (15min)         69.0  900.000
# 2816  am31_sim  YASA (15min)         72.0  900.000
# 2817  am31_sim  YASA (15min)         70.0  900.000
# 2818  am31_sim  YASA (15min)         72.0  900.000
# 2819  am31_sim  YASA (15min)         72.0  900.000
#
# [2820 rows x 4 columns]

# %%
path = Path(config["04_compare"]["output"]["baseline_data"])
path.parent.mkdir(parents=True, exist_ok=True)
baseline_df.to_json(path)
baseline_df
# Out:
#       instance     algorithm  upper_bound  runtime
# 0          PPU          ICPL         15.0    1.706
# 1          PPU       Chvatal         15.0    1.455
# 2          PPU       Incling         17.0    0.171
# 3          PPU    YASA (m=1)         13.0    0.266
# 4          PPU    YASA (m=3)         12.0    0.290
# ...        ...           ...          ...      ...
# 2815  am31_sim  YASA (15min)         69.0  900.000
# 2816  am31_sim  YASA (15min)         72.0  900.000
# 2817  am31_sim  YASA (15min)         70.0  900.000
# 2818  am31_sim  YASA (15min)         72.0  900.000
# 2819  am31_sim  YASA (15min)         72.0  900.000
#
# [2820 rows x 4 columns]

# %%
best_upper_bound_by_baseline = baseline_df.groupby(["instance"])["upper_bound"].min().reset_index()
best_upper_bound_by_baseline
# Out:
#                        instance  upper_bound
# 0                           APL          9.0
# 1                     APL-Model         10.0
# 2               BankingSoftware         40.0
# 3                 BattleofTanks        451.0
# 4                    ChatClient          7.0
# 5                          DMIE         26.0
# 6                        E-Shop         19.0
# 7                    EMBToolkit       1881.0
# 8                        FameDB          8.0
# 9                    FeatureIDE          9.0
# 10                FreeBSD-8_0_0         76.0
# 11                          PPU         12.0
# 12                     SafeBali         11.0
# 13                  SortingLine         12.0
# 14                     TightVNC         11.0
# 15                       Violet         23.0
# 16            WaterlooGenerated        144.0
# 17                     XSEngine         63.0
# 18                     aaed2000         87.0
# 19                     am31_sim         60.0
# 20             atlas_mips32_4kc         66.0
# 21                        axTLS         16.0
# 22                  berkeleyDB1         19.0
# 23                  berkeleyDB2         20.0
# 24               busybox-1_18_0         26.0
# 25               busybox-1_29_2         36.0
# 26  busybox_2007-01-24_09-14-09         34.0
# 27  busybox_2020-12-16_21-53-05         33.0
# 28                    calculate          9.0
# 29                          car          6.0
# 30                         dell         32.0
# 31              eCos-3-0_i386pc         64.0
# 32                       ea2468         65.0
# 33                        email          6.0
# 34   fiasco_2017-09-26_11-30-56        234.0
# 35   fiasco_2020-12-01_14-09-14        209.0
# 36           financial_services       4384.0
# 37                fs_2017-05-22        398.0
# 38                          gpl         17.0
# 39              integrator_arm7         66.0
# 40                          lcm          8.0
# 41  soletta_2015-06-26_18-38-56         30.0
# 42  soletta_2017-03-09_21-02-40         56.0
# 43   toybox_2006-10-31_23-30-06          9.0
# 44   toybox_2020-12-06_00-02-46         18.0
# 45   uclibc_2008-06-05_13-46-47        505.0
# 46   uclibc_2020-12-24_11-54-53        365.0

# %%
samplns_15min = pd.read_json(Path("..")/config_input["samplns_15min"])
samplns_15min["algorithm"] = "SampLNS (15min)"
samplns_15min
# Out:
#                   instance_name   lb   ub  iteration     runtime  \
# 0                   berkeleyDB1   15   15          1  127.061744
# 1                 BattleofTanks  256  324          2  905.864063
# 2    uclibc_2008-06-05_13-46-47  505  505          4  112.978185
# 3                           APL    7    7          0    1.150905
# 4                    ChatClient    7    7          0    2.577169
# ..                          ...  ...  ...        ...         ...
# 235               FreeBSD-8_0_0   29   47          0  917.751250
# 236                         lcm    6    6          2    0.314571
# 237             integrator_arm7   28   40          2  939.704633
# 238  fiasco_2017-09-26_11-30-56  225  226          1  905.998053
# 239                  ChatClient    7    7          1    0.908417
#
#                   timestamp hostname  time_used_by_yasa  time_of_last_update  \
# 0   2024-02-29 22:34:46.548  algra02           0.444649            70.800291
# 1   2024-02-29 23:48:03.136  algra06           0.757872           899.401329
# 2   2024-03-01 01:59:14.695  algra04           1.563936           109.876549
# 3   2024-02-29 21:35:43.570  algra03           0.364628             0.782022
# 4   2024-02-29 21:35:41.952  algra05           0.565027             2.004380
# ..                      ...      ...                ...                  ...
# 235 2024-02-29 22:23:02.911  algra03          11.911315           809.872718
# 236 2024-02-29 23:36:06.011  algra03           0.273436             0.037731
# 237 2024-03-01 00:22:24.083  algra02           3.890440           738.614761
# 238 2024-02-29 22:45:22.583  algra06           1.046048           256.179602
# 239 2024-02-29 22:31:55.149  algra04           0.328528             0.575585
#
#            algorithm
# 0    SampLNS (15min)
# 1    SampLNS (15min)
# 2    SampLNS (15min)
# 3    SampLNS (15min)
# 4    SampLNS (15min)
# ..               ...
# 235  SampLNS (15min)
# 236  SampLNS (15min)
# 237  SampLNS (15min)
# 238  SampLNS (15min)
# 239  SampLNS (15min)
#
# [240 rows x 10 columns]

# %%
samplns_3h = pd.read_json(Path("..")/config_input["samplns_3h"])
samplns_3h["algorithm"] = "SampLNS (3h)"
samplns_3h
# Out:
#                    instance_name   lb   ub  iteration       runtime  \
# 0                           DMIE   16   16          2     84.251726
# 1                       XSEngine   32   37          2  10835.245833
# 2    busybox_2020-12-16_21-53-05   19   20          2  10812.507526
# 3                           dell   31   31          1     45.378754
# 4                       aaed2000   51   52          0  10958.007358
# ..                           ...  ...  ...        ...           ...
# 230                          PPU   12   12          2      4.602942
# 231   fiasco_2017-09-26_11-30-56  225  225          4    323.909784
# 232                       ea2468   32   37          1  10894.844934
# 233                       E-Shop   10   12          3  10841.477915
# 234                       E-Shop   10   12          4  10826.492279
#
#                   timestamp hostname  time_used_by_yasa  time_of_last_update  \
# 0   2024-03-03 13:52:56.774  algra05           1.151671            82.275646
# 1   2024-03-03 19:04:44.852  algra02           3.947085           861.827745
# 2   2024-03-03 16:21:47.983  algra01           3.722179          1315.498623
# 3   2024-03-03 03:18:58.480  algra04           0.430485            44.940805
# 4   2024-03-03 00:52:45.945  algra02           4.545260          5245.348895
# ..                      ...      ...                ...                  ...
# 230 2024-03-03 11:44:34.043  algra03           0.406477             0.836773
# 231 2024-03-04 06:45:12.567  algra04           1.074143           280.138028
# 232 2024-03-03 10:51:18.668  algra05           4.102623          2573.002214
# 233 2024-03-04 17:32:52.372  algra03           1.290838          2133.181815
# 234 2024-03-04 17:32:56.526  algra04           1.101863          6748.320928
#
#         algorithm
# 0    SampLNS (3h)
# 1    SampLNS (3h)
# 2    SampLNS (3h)
# 3    SampLNS (3h)
# 4    SampLNS (3h)
# ..            ...
# 230  SampLNS (3h)
# 231  SampLNS (3h)
# 232  SampLNS (3h)
# 233  SampLNS (3h)
# 234  SampLNS (3h)
#
# [235 rows x 10 columns]

# %%
best_ub = samplns_3h.groupby(["instance_name"])["ub"].min()
best_lb = samplns_3h.groupby(["instance_name"])["lb"].max()
time_last_update_3h = samplns_3h.groupby(["instance_name"])["time_of_last_update"].mean()
samplns_lb = samplns_15min.groupby(["instance_name"])["lb"].mean()
samplns_ub = samplns_15min.groupby(["instance_name"])["ub"].mean()
time_last_update_15min = samplns_15min.groupby(["instance_name"])["time_of_last_update"].mean()
time_initial_solution = samplns_15min.groupby(["instance_name"])["time_used_by_yasa"].mean()
baseline_ub = best_upper_bound_by_baseline.groupby(["instance"])["upper_bound"].min()
# combine to columns
df = pd.DataFrame()
df['num_vars'] = instance_infos["n"]
df['num_clauses'] = instance_infos["m"]
df["best_ub"] = best_ub
df["best_lb"] = best_lb
df["samplns_ub"] = samplns_ub
df["samplns_lb"] = samplns_lb
df["baseline_ub"] = baseline_ub
df["time_initial_solution"] = time_initial_solution
df["time_last_update_15min"] = time_initial_solution+time_last_update_15min
df["time_last_update_3h"] = time_initial_solution+time_last_update_3h
df.sort_values(by=["num_vars", "num_clauses"], inplace=True)
df.to_json(config["04_compare"]["output"]["aggregated_table"])
df
# Out:
#                              num_vars  num_clauses  best_ub  best_lb  \
# instance
# calculate                         9.0         15.0        5        5
# lcm                               9.0         16.0        6        6
# email                            10.0         17.0        6        6
# ChatClient                       14.0         20.0        7        7
# toybox_2006-10-31_23-30-06       16.0         13.0        8        8
# car                              16.0         33.0        5        5
# FeatureIDE                       19.0         27.0        8        8
# FameDB                           22.0         40.0        8        8
# APL                              23.0         35.0        7        7
# SafeBali                         24.0         45.0       11       11
# TightVNC                         28.0         39.0        8        8
# APL-Model                        28.0         40.0        8        8
# gpl                              38.0         99.0       16       16
# SortingLine                      39.0         77.0        9        9
# dell                             46.0        244.0       31       31
# PPU                              52.0        109.0       12       12
# berkeleyDB1                      76.0        147.0       15       15
# axTLS                            96.0        183.0       11       10
# Violet                          101.0        203.0       17       16
# berkeleyDB2                     119.0        346.0       12       12
# soletta_2015-06-26_18-38-56     129.0        192.0       24       24
# BattleofTanks                   144.0        769.0      295      256
# BankingSoftware                 176.0        280.0       29       29
# fiasco_2017-09-26_11-30-56      230.0       1181.0      225      225
# fiasco_2020-12-01_14-09-14      258.0       1542.0      196      196
# uclibc_2008-06-05_13-46-47      263.0       1699.0      505      505
# uclibc_2020-12-24_11-54-53      272.0       1670.0      365      365
# E-Shop                          326.0        499.0       12       10
# toybox_2020-12-06_00-02-46      334.0         92.0       13        8
# DMIE                            366.0        627.0       16       16
# soletta_2017-03-09_21-02-40     458.0       1862.0       37       37
# busybox_2007-01-24_09-14-09     540.0        429.0       21       21
# fs_2017-05-22                   557.0       4992.0      396      396
# WaterlooGenerated               580.0        879.0       82       82
# financial_services              771.0       7238.0     4340     4336
# busybox-1_18_0                  854.0       1164.0       16       13
# busybox-1_29_2                 1018.0        997.0       22       21
# busybox_2020-12-16_21-53-05    1050.0        996.0       20       19
# am31_sim                       1178.0       2747.0       33       29
# EMBToolkit                     1179.0       5414.0     1872     1872
# atlas_mips32_4kc               1229.0       2875.0       36       33
# eCos-3-0_i386pc                1245.0       3723.0       39       36
# integrator_arm7                1272.0       2980.0       36       33
# XSEngine                       1273.0       2942.0       36       32
# aaed2000                       1298.0       3036.0       52       51
# FreeBSD-8_0_0                  1397.0      15692.0       41       30
# ea2468                         1408.0       3319.0       36       32
#
#                              samplns_ub  samplns_lb  baseline_ub  \
# instance
# calculate                           5.0         5.0          9.0
# lcm                                 6.0         6.0          8.0
# email                               6.0         6.0          6.0
# ChatClient                          7.0         7.0          7.0
# toybox_2006-10-31_23-30-06          8.0         8.0          9.0
# car                                 5.0         5.0          6.0
# FeatureIDE                          8.0         8.0          9.0
# FameDB                              8.0         8.0          8.0
# APL                                 7.0         7.0          9.0
# SafeBali                           11.0        11.0         11.0
# TightVNC                            8.0         8.0         11.0
# APL-Model                           8.0         8.0         10.0
# gpl                                16.0        16.0         17.0
# SortingLine                         9.0         9.0         12.0
# dell                               31.0        31.0         32.0
# PPU                                12.0        12.0         12.0
# berkeleyDB1                        15.0        15.0         19.0
# axTLS                              11.0        10.0         16.0
# Violet                             17.0        16.0         23.0
# berkeleyDB2                        12.0        12.0         20.0
# soletta_2015-06-26_18-38-56        24.0        24.0         30.0
# BattleofTanks                     320.8       256.0        451.0
# BankingSoftware                    29.0        29.0         40.0
# fiasco_2017-09-26_11-30-56        225.2       225.0        234.0
# fiasco_2020-12-01_14-09-14        196.2       196.0        209.0
# uclibc_2008-06-05_13-46-47        505.0       505.0        505.0
# uclibc_2020-12-24_11-54-53        365.0       365.0        365.0
# E-Shop                             12.0         9.2         19.0
# toybox_2020-12-06_00-02-46         13.0         7.6         18.0
# DMIE                               16.0        16.0         26.0
# soletta_2017-03-09_21-02-40        37.0        31.8         56.0
# busybox_2007-01-24_09-14-09        21.0        21.0         34.0
# fs_2017-05-22                     396.0       396.0        398.0
# WaterlooGenerated                  82.0        82.0        144.0
# financial_services               4368.0      4274.0       4384.0
# busybox-1_18_0                     16.8        11.0         26.0
# busybox-1_29_2                     22.2        17.6         36.0
# busybox_2020-12-16_21-53-05        21.0        17.6         33.0
# am31_sim                           36.4        26.8         60.0
# EMBToolkit                       1879.2      1821.4       1881.0
# atlas_mips32_4kc                   38.8        31.8         66.0
# eCos-3-0_i386pc                    43.8        31.8         64.0
# integrator_arm7                    38.8        30.4         66.0
# XSEngine                           38.6        31.4         63.0
# aaed2000                           55.4        51.0         87.0
# FreeBSD-8_0_0                      47.4        27.6         76.0
# ea2468                             38.6        31.2         65.0
#
#                              time_initial_solution  time_last_update_15min  \
# instance
# calculate                                 0.349753                0.409805
# lcm                                       0.320516                0.362959
# email                                     0.320861                0.390224
# ChatClient                                0.370952                1.386273
# toybox_2006-10-31_23-30-06                0.392972                1.462752
# car                                       0.285722                0.350269
# FeatureIDE                                0.372879              270.834257
# FameDB                                    0.325365                1.142090
# APL                                       0.376910                1.216988
# SafeBali                                  0.289868                0.348789
# TightVNC                                  0.379794               16.321072
# APL-Model                                 0.382902               14.253435
# gpl                                       0.404755                3.285951
# SortingLine                               0.396580                8.398344
# dell                                      0.428439               29.103761
# PPU                                       0.413108                2.022978
# berkeleyDB1                               0.447414               76.986518
# axTLS                                     0.471843               20.057263
# Violet                                    0.497060              475.952112
# berkeleyDB2                               0.593849              162.070655
# soletta_2015-06-26_18-38-56               0.495447               20.888723
# BattleofTanks                             0.752472              886.609187
# BankingSoftware                           0.596430              305.780550
# fiasco_2017-09-26_11-30-56                1.030443              381.747905
# fiasco_2020-12-01_14-09-14                1.170880              437.769211
# uclibc_2008-06-05_13-46-47                1.541881              103.955548
# uclibc_2020-12-24_11-54-53                1.424021              107.898085
# E-Shop                                    0.807115              268.359209
# toybox_2020-12-06_00-02-46                0.809139              531.706355
# DMIE                                      1.060736              103.905248
# soletta_2017-03-09_21-02-40               1.046823              386.850711
# busybox_2007-01-24_09-14-09               1.375954              164.416598
# fs_2017-05-22                             1.925099              478.438463
# WaterlooGenerated                         2.027764              222.937937
# financial_services                       26.242545              861.969250
# busybox-1_18_0                            2.356051              232.805142
# busybox-1_29_2                            3.399958              465.459174
# busybox_2020-12-16_21-53-05               3.638184              406.848358
# am31_sim                                  3.492027              698.574993
# EMBToolkit                               20.140515              862.746574
# atlas_mips32_4kc                          3.924828              548.494868
# eCos-3-0_i386pc                           3.964060              621.041021
# integrator_arm7                           3.930661              680.972956
# XSEngine                                  4.044927              571.596174
# aaed2000                                  4.360600              707.188756
# FreeBSD-8_0_0                            12.530583              830.542454
# ea2468                                    4.172094              720.562702
#
#                              time_last_update_3h
# instance
# calculate                               0.509709
# lcm                                     0.459972
# email                                   0.476566
# ChatClient                              1.897152
# toybox_2006-10-31_23-30-06              1.492623
# car                                     0.417284
# FeatureIDE                            127.857561
# FameDB                                  1.180048
# APL                                     1.243059
# SafeBali                                0.371186
# TightVNC                               20.813122
# APL-Model                              14.685163
# gpl                                     2.740578
# SortingLine                             8.667998
# dell                                   44.733151
# PPU                                     1.956019
# berkeleyDB1                           137.398030
# axTLS                                  20.153662
# Violet                                655.975868
# berkeleyDB2                           282.009782
# soletta_2015-06-26_18-38-56            59.986393
# BattleofTanks                        9571.552268
# BankingSoftware                       428.732166
# fiasco_2017-09-26_11-30-56            579.469621
# fiasco_2020-12-01_14-09-14            477.510403
# uclibc_2008-06-05_13-46-47             66.753174
# uclibc_2020-12-24_11-54-53            111.682079
# E-Shop                               3862.019537
# toybox_2020-12-06_00-02-46           2076.582480
# DMIE                                  135.478084
# soletta_2017-03-09_21-02-40          1450.197826
# busybox_2007-01-24_09-14-09           236.739674
# fs_2017-05-22                         575.460746
# WaterlooGenerated                     309.563807
# financial_services                   6092.808977
# busybox-1_18_0                       3512.875040
# busybox-1_29_2                       3625.282573
# busybox_2020-12-16_21-53-05          1047.812506
# am31_sim                             4634.816347
# EMBToolkit                           2830.647929
# atlas_mips32_4kc                     2970.620116
# eCos-3-0_i386pc                      8747.147056
# integrator_arm7                      4906.030064
# XSEngine                             3100.504590
# aaed2000                             4501.787760
# FreeBSD-8_0_0                        7212.430580
# ea2468                               4013.670933

# %%
num_instance_with_opt_solution = (df["best_lb"]==df["best_ub"]).sum()
num_instance_with_opt_solution
# Out:
# 30

# %%
num_instance_with_opt_solution/len(df)
# Out:
# 0.6382978723404256

# %%
(df["samplns_lb"].round()==df["samplns_ub"].round()).sum()
# Out:
# 28
