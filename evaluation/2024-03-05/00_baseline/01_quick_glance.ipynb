# %%
from pathlib import Path

import pandas as pd
import tomllib

with (Path().cwd() / ".." / "config.toml").open("rb") as f:
    config = tomllib.load(f)
    config_exp = config[Path().cwd().name]
df = pd.read_json(config_exp["baseline_table"])
df
# Out:
#       ModelID  AlgorithmID  SystemIteration  AlgorithmIteration  InTime  \
# 0           1            0                1                   1    True
# 1           1            1                1                   1    True
# 2           1            2                1                   1    True
# 3           1            3                1                   1    True
# 4           1            4                1                   1    True
# ...       ...          ...              ...                 ...     ...
# 2580        4            6                5                   1    True
# 2581        4            7                5                   1   False
# 2582        4            8                5                   1   False
# 2583        4            9                5                   1   False
# 2584        4           10                5                   1   False
#
#       Success    Time  SampleSize         Instance  #Variables  #Clauses  \
# 0        True    1706        15.0              PPU          52       109
# 1        True    1455        15.0              PPU          52       109
# 2        True     171        17.0              PPU          52       109
# 3        True     266        13.0              PPU          52       109
# 4        True     290        12.0              PPU          52       109
# ...       ...     ...         ...              ...         ...       ...
# 2580     True   24011        68.0  eCos-3-0_i386pc        1245      3723
# 2581     True  900001         NaN  eCos-3-0_i386pc        1245      3723
# 2582     True  900008         NaN  eCos-3-0_i386pc        1245      3723
# 2583     True  900008         NaN  eCos-3-0_i386pc        1245      3723
# 2584     True  900009         NaN  eCos-3-0_i386pc        1245      3723
#
#           Algorithm     Settings                                    Path  \
# 0         FIDE-ICPL           t2  2024-02-23_21-52-24/1_1_0_1_sample.csv
# 1      FIDE-Chvatal           t2  2024-02-23_21-52-24/1_1_1_1_sample.csv
# 2           Incling           t2  2024-02-23_21-52-24/1_1_2_1_sample.csv
# 3         FIDE-YASA   t2_m1_null  2024-02-23_21-52-24/1_1_3_1_sample.csv
# 4         FIDE-YASA   t2_m3_null  2024-02-23_21-52-24/1_1_4_1_sample.csv
# ...             ...          ...                                     ...
# 2580      FIDE-YASA  t2_m10_null  2024-02-23_21-52-42/4_5_6_1_sample.csv
# 2581   ACTS-IPOG-FT           t2                                    None
# 2582  ACTS-IPOG-CSP           t2                                    None
# 2583   ACTS-IPOF-FT           t2                                    None
# 2584  ACTS-IPOF-CSP           t2                                    None
#
#              ArchivePath
# 0     INPUT/baseline.zip
# 1     INPUT/baseline.zip
# 2     INPUT/baseline.zip
# 3     INPUT/baseline.zip
# 4     INPUT/baseline.zip
# ...                  ...
# 2580  INPUT/baseline.zip
# 2581  INPUT/baseline.zip
# 2582  INPUT/baseline.zip
# 2583  INPUT/baseline.zip
# 2584  INPUT/baseline.zip
#
# [2585 rows x 15 columns]
