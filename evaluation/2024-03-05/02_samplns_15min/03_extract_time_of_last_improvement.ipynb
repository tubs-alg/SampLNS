# %%
import tomllib
from pathlib import Path

with Path("../config.toml").open("rb") as f:
    config = tomllib.load(f)

config
# Out:
# {'benchmark': {'instance_names': ['calculate',
#    'lcm',
#    'email',
#    'ChatClient',
#    'toybox_2006-10-31_23-30-06',
#    'car',
#    'FeatureIDE',
#    'FameDB',
#    'APL',
#    'SafeBali',
#    'TightVNC',
#    'APL-Model',
#    'gpl',
#    'SortingLine',
#    'dell',
#    'PPU',
#    'berkeleyDB1',
#    'axTLS',
#    'Violet',
#    'berkeleyDB2',
#    'soletta_2015-06-26_18-38-56',
#    'BattleofTanks',
#    'BankingSoftware',
#    'fiasco_2017-09-26_11-30-56',
#    'fiasco_2020-12-01_14-09-14',
#    'uclibc_2008-06-05_13-46-47',
#    'uclibc_2020-12-24_11-54-53',
#    'E-Shop',
#    'toybox_2020-12-06_00-02-46',
#    'DMIE',
#    'soletta_2017-03-09_21-02-40',
#    'busybox_2007-01-24_09-14-09',
#    'fs_2017-05-22',
#    'WaterlooGenerated',
#    'financial_services',
#    'busybox-1_18_0',
#    'busybox-1_29_2',
#    'busybox_2020-12-16_21-53-05',
#    'am31_sim',
#    'EMBToolkit',
#    'atlas_mips32_4kc',
#    'eCos-3-0_i386pc',
#    'integrator_arm7',
#    'XSEngine',
#    'aaed2000',
#    'FreeBSD-8_0_0',
#    'ea2468'],
#   'instance_archive': './benchmark_models.zip',
#   'workstation_generation': 'alggen05'},
#  'baseline': {'subfolder': './00_baseline'},
#  'yasa_15min': {'subfolder': './01_yasa_15min'},
#  'samplns_15min': {'subfolder': './02_samplns_15min',
#   'iterations': 10000,
#   'iteration_time_limit': 60.0,
#   'time_limit': 900,
#   'algbench_results': 'DATA/algbench',
#   'result_table': 'OUTPUT/results.json.xz',
#   'iteration_info': 'OUTPUT/results_with_iteration_infos.json.xz',
#   'result_table_with_last_update': 'OUTPUT/result_with_last_update_time.json.xz'},
#  'long_runtime': {'subfolder': './03_samplns_3h'}}

# %%
import pandas as pd

EXPERIMENT = "samplns_15min"
df = pd.read_json(config[EXPERIMENT]["iteration_info"])
df
# Out:
#                   instance_name   lb   ub  iteration     runtime  \
# 0                   berkeleyDB1   15   15          1  127.061744
# 1                 BattleofTanks  256  324          2  905.864063
# 2    uclibc_2008-06-05_13-46-47  505  505          4  112.978185
# 3                           APL    7    7          0    1.150905
# 4                    ChatClient    7    7          0    2.577169
# ..                          ...  ...  ...        ...         ...
# 235               FreeBSD-8_0_0   29   47          0  917.751250
# 236                         lcm    6    6          2    0.314571
# 237             integrator_arm7   28   40          2  939.704633
# 238  fiasco_2017-09-26_11-30-56  225  226          1  905.998053
# 239                  ChatClient    7    7          1    0.908417
#
#                      timestamp hostname  \
# 0   2024-02-29 22:34:46.548635  algra02
# 1   2024-02-29 23:48:03.136810  algra06
# 2   2024-03-01 01:59:14.695447  algra04
# 3   2024-02-29 21:35:43.570688  algra03
# 4   2024-02-29 21:35:41.952781  algra05
# ..                         ...      ...
# 235 2024-02-29 22:23:02.911481  algra03
# 236 2024-02-29 23:36:06.011318  algra03
# 237 2024-03-01 00:22:24.083679  algra02
# 238 2024-02-29 22:45:22.583912  algra06
# 239 2024-02-29 22:31:55.149952  algra04
#
#                                                 sample  time_used_by_yasa  \
# 0    [{'featureLoggingSevere': False, 'featureCriti...           0.444649
# 1    [{'Feature_53': False, 'Feature_148': False, '...           0.757872
# 2    [{'CONFIG_UCLIBC_HAS_SSP': False, 'CONFIG_CONF...           1.563936
# 3    [{'Xml': False, 'drc': True, 'me': True, 'xc':...           0.364628
# 4    [{'ChatLogs': False, 'UnreadMessageCounter': F...           0.565027
# ..                                                 ...                ...
# 235  [{'blank_saver': True, 'at91_cfata': False, 'I...          11.911315
# 236  [{'__SELECTED_FEATURE_mutant_1': True, '__SELE...           0.273436
# 237  [{'CYGBLD_ISO_NAME_MAX_HEADER': True, 'CYGBLD_...           3.890440
# 238  [{'CONFIG_SCHED_HPET': False, 'CONFIG_PPC32_60...           1.046048
# 239  [{'TextFormatting': False, 'ChatLogs': True, '...           0.328528
#
#                                         iteration_info
# 0    [{'nbrhd_tuples': 181, 'nbrhd_confs': 7, 'iter...
# 1    [{'nbrhd_tuples': 249, 'nbrhd_confs': 67, 'ite...
# 2    [{'nbrhd_tuples': 248, 'nbrhd_confs': 44, 'ite...
# 3    [{'nbrhd_tuples': 207, 'nbrhd_confs': 9, 'iter...
# 4    [{'nbrhd_tuples': 176, 'nbrhd_confs': 9, 'iter...
# ..                                                 ...
# 235  [{'nbrhd_tuples': 69, 'nbrhd_confs': 2, 'itera...
# 236  [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...
# 237  [{'nbrhd_tuples': 200, 'nbrhd_confs': 4, 'iter...
# 238  [{'nbrhd_tuples': 249, 'nbrhd_confs': 18, 'ite...
# 239  [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...
#
# [240 rows x 10 columns]

# %%
df.groupby("instance_name")["iteration"].count()
# Out:
# instance_name
# APL                            5
# APL-Model                      5
# BankingSoftware                5
# BattleofTanks                  5
# ChatClient                     5
# DMIE                           5
# E-Shop                         5
# EMBToolkit                     5
# FameDB                         5
# FeatureIDE                     5
# FreeBSD-8_0_0                  5
# PPU                            5
# SafeBali                       5
# SortingLine                    5
# TightVNC                       5
# Violet                         5
# WaterlooGenerated              5
# XSEngine                       5
# aaed2000                       5
# am31_sim                       5
# atlas_mips32_4kc               5
# axTLS                          5
# berkeleyDB1                    5
# berkeleyDB2                    5
# busybox-1_18_0                 5
# busybox-1_29_2                 5
# busybox_2007-01-24_09-14-09    5
# busybox_2020-12-16_21-53-05    5
# calculate                      5
# car                            5
# dell                           5
# eCos-3-0_i386pc                5
# ea2468                         5
# email                          5
# fiasco_2017-09-26_11-30-56     5
# fiasco_2020-12-01_14-09-14     5
# financial_services             5
# fs_2017-05-22                  5
# gpl                            5
# integrator_arm7                5
# lcm                            5
# main_light                     5
# soletta_2015-06-26_18-38-56    5
# soletta_2017-03-09_21-02-40    5
# toybox_2006-10-31_23-30-06     5
# toybox_2020-12-06_00-02-46     5
# uclibc_2008-06-05_13-46-47     5
# uclibc_2020-12-24_11-54-53     5
# Name: iteration, dtype: int64

# %%
df.loc[0, "iteration_info"]
# Out:
# [{'nbrhd_tuples': 181,
#   'nbrhd_confs': 7,
#   'iteration': 0,
#   'lb': 11,
#   'ub': 23,
#   'time': 0.17917609210000002,
#   'iteration_time': 0.17569637300000002,
#   'events': [[0.00026226040000000003, 'neighborhood_selected'],
#    [0.1238534451, 'local_cds_computed'],
#    [0.1544742584, 'model_built'],
#    [0.1747338772, 'model_optimized'],
#    [0.1756186485, 'neighborhood_optimized'],
#    [0.1756961346, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 272,
#   'nbrhd_confs': 13,
#   'iteration': 1,
#   'lb': 11,
#   'ub': 19,
#   'time': 0.533741951,
#   'iteration_time': 0.35452508930000004,
#   'events': [[0.0001928806, 'neighborhood_selected'],
#    [0.2056603432, 'local_cds_computed'],
#    [0.2871832848, 'model_built'],
#    [0.3532378674, 'model_optimized'],
#    [0.3544383049, 'neighborhood_optimized'],
#    [0.35452437400000003, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 285,
#   'nbrhd_confs': 7,
#   'iteration': 2,
#   'lb': 11,
#   'ub': 19,
#   'time': 1.0298318863,
#   'iteration_time': 0.4960381985,
#   'events': [[0.00019550320000000002, 'neighborhood_selected'],
#    [0.4005777836, 'local_cds_computed'],
#    [0.4509763718, 'model_built'],
#    [0.49498534200000005, 'model_optimized'],
#    [0.4959528446, 'neighborhood_optimized'],
#    [0.4960379601, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 460,
#   'nbrhd_confs': 9,
#   'iteration': 3,
#   'lb': 11,
#   'ub': 18,
#   'time': 1.7762153149,
#   'iteration_time': 0.7463347912,
#   'events': [[0.00020837780000000002, 'neighborhood_selected'],
#    [0.5483868122000001, 'local_cds_computed'],
#    [0.6467506886000001, 'model_built'],
#    [0.7450892925, 'model_optimized'],
#    [0.7462463379000001, 'neighborhood_optimized'],
#    [0.7463343143000001, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 427,
#   'nbrhd_confs': 11,
#   'iteration': 4,
#   'lb': 11,
#   'ub': 17,
#   'time': 2.7509827614,
#   'iteration_time': 0.9747140408,
#   'events': [[0.0001749992, 'neighborhood_selected'],
#    [0.7462844849, 'local_cds_computed'],
#    [0.8714210987000001, 'model_built'],
#    [0.9731345177, 'model_optimized'],
#    [0.9746215343, 'neighborhood_optimized'],
#    [0.9747135639000001, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 488,
#   'nbrhd_confs': 8,
#   'iteration': 5,
#   'lb': 12,
#   'ub': 17,
#   'time': 3.5993235111,
#   'iteration_time': 0.8482897282,
#   'events': [[0.00026106830000000004, 'neighborhood_selected'],
#    [0.6661577225, 'local_cds_computed'],
#    [0.7591681480000001, 'model_built'],
#    [0.8469316959000001, 'model_optimized'],
#    [0.8481750488, 'neighborhood_optimized'],
#    [0.8482892513, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 645,
#   'nbrhd_confs': 11,
#   'iteration': 6,
#   'lb': 12,
#   'ub': 16,
#   'time': 5.0299224854,
#   'iteration_time': 1.4305508137,
#   'events': [[0.00018835070000000002, 'neighborhood_selected'],
#    [1.1041648388, 'local_cds_computed'],
#    [1.2698905468000001, 'model_built'],
#    [1.4289085865, 'model_optimized'],
#    [1.4304571152, 'neighborhood_optimized'],
#    [1.4305500984, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 1000,
#   'nbrhd_confs': 10,
#   'iteration': 7,
#   'lb': 12,
#   'ub': 16,
#   'time': 7.3188149929,
#   'iteration_time': 2.2888400555,
#   'events': [[0.0002965927, 'neighborhood_selected'],
#    [1.9249503613, 'local_cds_computed'],
#    [2.1601936817, 'model_built'],
#    [2.2871687412, 'model_optimized'],
#    [2.2887494564, 'neighborhood_optimized'],
#    [2.288839817, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 1346,
#   'nbrhd_confs': 11,
#   'iteration': 8,
#   'lb': 12,
#   'ub': 15,
#   'time': 14.7088875771,
#   'iteration_time': 7.3900198936,
#   'events': [[0.0003173351, 'neighborhood_selected'],
#    [6.2568149566999995, 'local_cds_computed'],
#    [6.60216856, 'model_built'],
#    [7.3882648945, 'model_optimized'],
#    [7.3899271488, 'neighborhood_optimized'],
#    [7.3900194168, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 1355,
#   'nbrhd_confs': 11,
#   'iteration': 9,
#   'lb': 12,
#   'ub': 15,
#   'time': 21.6852118969,
#   'iteration_time': 6.9762711525,
#   'events': [[0.000316143, 'neighborhood_selected'],
#    [6.1344678402, 'local_cds_computed'],
#    [6.4651737213, 'model_built'],
#    [6.9743232727, 'model_optimized'],
#    [6.976174593, 'neighborhood_optimized'],
#    [6.9762709141, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 2032,
#   'nbrhd_confs': 12,
#   'iteration': 10,
#   'lb': 12,
#   'ub': 15,
#   'time': 29.1312627792,
#   'iteration_time': 7.445997715,
#   'events': [[0.00045180320000000004, 'neighborhood_selected'],
#    [6.0460867882, 'local_cds_computed'],
#    [6.6104142666, 'model_built'],
#    [7.4437322617, 'model_optimized'],
#    [7.4459028244, 'neighborhood_optimized'],
#    [7.445997715, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 2142,
#   'nbrhd_confs': 12,
#   'iteration': 11,
#   'lb': 12,
#   'ub': 15,
#   'time': 36.6530983448,
#   'iteration_time': 7.5217852592,
#   'events': [[0.0010194778, 'neighborhood_selected'],
#    [6.0467991829, 'local_cds_computed'],
#    [6.6409797668, 'model_built'],
#    [7.5194735527, 'model_optimized'],
#    [7.5216906071, 'neighborhood_optimized'],
#    [7.5217847824, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 2995,
#   'nbrhd_confs': 13,
#   'iteration': 12,
#   'lb': 13.0,
#   'ub': 15,
#   'time': 49.1169044971,
#   'iteration_time': 12.4637539387,
#   'events': [[0.0005667210000000001, 'neighborhood_selected'],
#    [6.1050448418, 'local_cds_computed'],
#    [6.9806828499, 'model_built'],
#    [12.461133480099999, 'model_optimized'],
#    [12.4636583328, 'neighborhood_optimized'],
#    [12.4637537003, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 3670,
#   'nbrhd_confs': 14,
#   'iteration': 13,
#   'lb': 14.0,
#   'ub': 15,
#   'time': 58.9631781578,
#   'iteration_time': 9.8462240696,
#   'events': [[0.0007619858, 'neighborhood_selected'],
#    [6.0753834248, 'local_cds_computed'],
#    [7.2396962643, 'model_built'],
#    [9.8432955742, 'model_optimized'],
#    [9.8461277485, 'neighborhood_optimized'],
#    [9.8462238312, 'global_lb_iteration_finished']]},
#  {'nbrhd_tuples': 5048,
#   'nbrhd_confs': 15,
#   'iteration': 14,
#   'lb': 15.0,
#   'ub': 15,
#   'time': 70.8002912998,
#   'iteration_time': 11.8370599747,
#   'events': [[0.0009365082, 'neighborhood_selected'],
#    [6.0283594131, 'local_cds_computed'],
#    [7.6817319393, 'model_built'],
#    [11.8336279392, 'model_optimized'],
#    [11.8369657993, 'neighborhood_optimized'],
#    [11.8370597363, 'global_lb_iteration_finished']]}]

# %%
def time_of_last_update(iterations: list):
    end_lb = iterations[-1]["lb"]
    end_ub = iterations[-1]["ub"]
    for iteration in iterations:
        if iteration["lb"] == end_lb and iteration["ub"] == end_ub:
            return iteration["time"]
    return None

# %%
df["time_of_last_update"] = df["iteration_info"].apply(time_of_last_update)
df
# Out:
#                   instance_name   lb   ub  iteration     runtime  \
# 0                   berkeleyDB1   15   15          1  127.061744
# 1                 BattleofTanks  256  324          2  905.864063
# 2    uclibc_2008-06-05_13-46-47  505  505          4  112.978185
# 3                           APL    7    7          0    1.150905
# 4                    ChatClient    7    7          0    2.577169
# ..                          ...  ...  ...        ...         ...
# 235               FreeBSD-8_0_0   29   47          0  917.751250
# 236                         lcm    6    6          2    0.314571
# 237             integrator_arm7   28   40          2  939.704633
# 238  fiasco_2017-09-26_11-30-56  225  226          1  905.998053
# 239                  ChatClient    7    7          1    0.908417
#
#                      timestamp hostname  \
# 0   2024-02-29 22:34:46.548635  algra02
# 1   2024-02-29 23:48:03.136810  algra06
# 2   2024-03-01 01:59:14.695447  algra04
# 3   2024-02-29 21:35:43.570688  algra03
# 4   2024-02-29 21:35:41.952781  algra05
# ..                         ...      ...
# 235 2024-02-29 22:23:02.911481  algra03
# 236 2024-02-29 23:36:06.011318  algra03
# 237 2024-03-01 00:22:24.083679  algra02
# 238 2024-02-29 22:45:22.583912  algra06
# 239 2024-02-29 22:31:55.149952  algra04
#
#                                                 sample  time_used_by_yasa  \
# 0    [{'featureLoggingSevere': False, 'featureCriti...           0.444649
# 1    [{'Feature_53': False, 'Feature_148': False, '...           0.757872
# 2    [{'CONFIG_UCLIBC_HAS_SSP': False, 'CONFIG_CONF...           1.563936
# 3    [{'Xml': False, 'drc': True, 'me': True, 'xc':...           0.364628
# 4    [{'ChatLogs': False, 'UnreadMessageCounter': F...           0.565027
# ..                                                 ...                ...
# 235  [{'blank_saver': True, 'at91_cfata': False, 'I...          11.911315
# 236  [{'__SELECTED_FEATURE_mutant_1': True, '__SELE...           0.273436
# 237  [{'CYGBLD_ISO_NAME_MAX_HEADER': True, 'CYGBLD_...           3.890440
# 238  [{'CONFIG_SCHED_HPET': False, 'CONFIG_PPC32_60...           1.046048
# 239  [{'TextFormatting': False, 'ChatLogs': True, '...           0.328528
#
#                                         iteration_info  time_of_last_update
# 0    [{'nbrhd_tuples': 181, 'nbrhd_confs': 7, 'iter...            70.800291
# 1    [{'nbrhd_tuples': 249, 'nbrhd_confs': 67, 'ite...           899.401329
# 2    [{'nbrhd_tuples': 248, 'nbrhd_confs': 44, 'ite...           109.876549
# 3    [{'nbrhd_tuples': 207, 'nbrhd_confs': 9, 'iter...             0.782022
# 4    [{'nbrhd_tuples': 176, 'nbrhd_confs': 9, 'iter...             2.004380
# ..                                                 ...                  ...
# 235  [{'nbrhd_tuples': 69, 'nbrhd_confs': 2, 'itera...           809.872718
# 236  [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...             0.037731
# 237  [{'nbrhd_tuples': 200, 'nbrhd_confs': 4, 'iter...           738.614761
# 238  [{'nbrhd_tuples': 249, 'nbrhd_confs': 18, 'ite...           256.179602
# 239  [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...             0.575585
#
# [240 rows x 11 columns]

# %%
assert (df["time_of_last_update"]<= df["runtime"]).all(), "Some time_of_last_update is greater than runtime, which cannot be"

# %%
df.drop(columns=["sample", "iteration_info"]).to_json(config[EXPERIMENT]["result_table_with_last_update"])

# %%
del df  # free the memory. This is a big dataframe
