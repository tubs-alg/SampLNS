# %% [markdown]
# # Cleaning the data and providing a small and easily parsable database.
#
# The database with the full logs is too huge to work on. Most of the data would only be needed for debugging but not for evaluation.
# Thus, we create a clean and small database for the further evaluation.

# %%
from _conf import ITERATIONS, ITERATION_TIME_LIMIT, TIME_LIMIT, BASE, RESULT_FOLDER, INPUT_SAMPLE_ARCHIVE, INSTANCE_ARCHIVE

import pandas as pd
from algbench import read_as_pandas, Benchmark
from _utils import parse_solution_overview

# %%
# Read the baseline results for comparison. They also already contain instance data (num_clauses and num_features).
baseline_data = pd.read_json("./00_simple_baseline_data.json.zip")
baseline_data.rename(columns={"sample_size": "baseline_sample_size"}, inplace=True)
baseline_data
# Out:
#      instance_name  num_vars  num_clauses baseline_alg baseline_alg_conf  \
# 0        calculate         9           15    FIDE-ICPL                t2
# 1        calculate         9           15    FIDE-ICPL                t2
# 2        calculate         9           15    FIDE-ICPL                t2
# 3        calculate         9           15    FIDE-ICPL                t2
# 4        calculate         9           15    FIDE-ICPL                t2
# ...            ...       ...          ...          ...               ...
# 2745        freetz     31012       102705         YASA       t2_m10_null
# 2746        freetz     31012       102705         YASA       t2_m10_null
# 2747        freetz     31012       102705         YASA       t2_m10_null
# 2748        freetz     31012       102705         YASA       t2_m10_null
# 2749        freetz     31012       102705         YASA       t2_m10_null
#
#       runtime  baseline_sample_size                 path_to_baseline_sample
# 0       1.484                   9.0  2023-03-01_13-51-03/1_1_0_1_sample.csv
# 1       1.280                   9.0  2023-03-01_13-51-03/1_1_0_2_sample.csv
# 2       1.289                   9.0  2023-03-01_13-51-03/1_1_0_3_sample.csv
# 3       1.274                   9.0  2023-03-01_13-51-03/1_1_0_4_sample.csv
# 4       1.277                   9.0  2023-03-01_13-51-03/1_1_0_5_sample.csv
# ...       ...                   ...                                     ...
# 2745  900.008                   NaN                                    None
# 2746  900.008                   NaN                                    None
# 2747  900.010                   NaN                                    None
# 2748  900.009                   NaN                                    None
# 2749  900.008                   NaN                                    None
#
# [2750 rows x 8 columns]

# %%
# Get the data from the result folder
samplns_data = read_as_pandas(
        RESULT_FOLDER,
        lambda result: {
            "parameters": result["parameters"],
            "initial_sample_path": result["parameters"]["args"]["initial_sample_path"],
            "instance_name": result["parameters"]["args"]["instance_name"],
            "lower_bound": result["result"]["lower_bound"],
            "upper_bound": len(result["result"]["solution"]),
            "iteration_info": result["result"]["iteration_info"],
            "time_used_by_yasa": result["result"]["time_used_by_yasa"],
            "timelimit_for_samplns": result["result"]["timelimit_for_samplns"],
            "samplns_used": result["result"]["samplns_used"],
            "runtime": result["runtime"],
            "time_limit": result["parameters"]["args"]["time_limit"],
        } if result.get("result", None) and  result.get("result", dict()).get("solution", None) else None,
    )
samplns_data.drop_duplicates(subset=["initial_sample_path"], inplace=True)
samplns_data
# Out:
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                          initial_sample_path               instance_name  \
# 0    2023-03-01_13-51-03/44_1_7_1_sample.csv                    XSEngine
# 1     2023-03-01_13-51-03/4_1_7_2_sample.csv                  ChatClient
# 2    2023-03-01_13-51-03/47_1_7_2_sample.csv                      ea2468
# 3    2023-03-01_13-51-03/15_1_7_2_sample.csv                        dell
# 4    2023-03-01_13-51-03/25_1_7_5_sample.csv  fiasco_2020-12-01_14-09-14
# ..                                       ...                         ...
# 225  2023-03-01_13-51-03/12_1_7_2_sample.csv                   APL-Model
# 226  2023-03-01_13-51-03/26_1_7_1_sample.csv  uclibc_2008-06-05_13-46-47
# 227  2023-03-01_13-51-03/24_1_7_4_sample.csv  fiasco_2017-09-26_11-30-56
# 228   2023-03-01_13-51-03/2_1_7_3_sample.csv                         lcm
# 229   2023-03-01_13-51-03/3_1_7_3_sample.csv                       email
#
#      lower_bound  upper_bound  \
# 0           32.0           40
# 1            7.0            7
# 2           24.0           40
# 3           31.0           31
# 4          196.0          196
# ..           ...          ...
# 225          8.0            8
# 226        505.0          505
# 227        224.0          225
# 228          6.0            6
# 229          6.0            6
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 210, 'nbrhd_confs': 9, 'iter...              3.395
# 1    [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...              0.183
# 2    [{'nbrhd_tuples': 207, 'nbrhd_confs': 5, 'iter...              3.594
# 3    [{'nbrhd_tuples': 249, 'nbrhd_confs': 25, 'ite...              0.257
# 4    [{'nbrhd_tuples': 235, 'nbrhd_confs': 15, 'ite...              1.176
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 249, 'nbrhd_confs': 12, 'ite...              0.192
# 226  [{'nbrhd_tuples': 243, 'nbrhd_confs': 44, 'ite...              1.492
# 227  [{'nbrhd_tuples': 234, 'nbrhd_confs': 22, 'ite...              0.990
# 228  [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...              0.202
# 229  [{'nbrhd_tuples': 70, 'nbrhd_confs': 7, 'itera...              0.200
#
#      timelimit_for_samplns  samplns_used      runtime  time_limit
# 0                 3596.605          True  3708.056571        3600
# 1                 3599.817          True    15.838238        3600
# 2                 3596.406          True  3614.455043        3600
# 3                 3599.743          True   117.523291        3600
# 4                 3598.824          True  2319.812010        3600
# ..                     ...           ...          ...         ...
# 225               3599.808          True    93.377796        3600
# 226               3598.508          True   726.094270        3600
# 227               3599.010          True  3655.331330        3600
# 228               3599.798          True     0.076086        3600
# 229               3599.800          True     0.056341        3600
#
# [230 rows x 11 columns]

# %%
# Pull the baseline info into the data frame
samplns_data_with_baseline_infos = baseline_data.merge(right=samplns_data, left_on="path_to_baseline_sample", right_on="initial_sample_path", how="right", suffixes=("_baseline", "_samplns"))
samplns_data_with_baseline_infos.drop(columns=["instance_name_baseline", "initial_sample_path"], inplace=True)
samplns_data_with_baseline_infos.rename(columns={"instance_name_samplns": "instance_name"}, inplace=True)
samplns_data_with_baseline_infos
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0        1273         2942         YASA        t2_m1_null             3.395
# 1          14           20         YASA        t2_m1_null             0.183
# 2        1408         3319         YASA        t2_m1_null             3.594
# 3          46          244         YASA        t2_m1_null             0.257
# 4         258         1542         YASA        t2_m1_null             1.176
# ..        ...          ...          ...               ...               ...
# 225        28           40         YASA        t2_m1_null             0.192
# 226       263         1699         YASA        t2_m1_null             1.492
# 227       230         1181         YASA        t2_m1_null             0.990
# 228         9           16         YASA        t2_m1_null             0.202
# 229        10           17         YASA        t2_m1_null             0.200
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                    69.0  2023-03-01_13-51-03/44_1_7_1_sample.csv
# 1                     8.0   2023-03-01_13-51-03/4_1_7_2_sample.csv
# 2                    72.0  2023-03-01_13-51-03/47_1_7_2_sample.csv
# 3                    38.0  2023-03-01_13-51-03/15_1_7_2_sample.csv
# 4                   224.0  2023-03-01_13-51-03/25_1_7_5_sample.csv
# ..                    ...                                      ...
# 225                  15.0  2023-03-01_13-51-03/12_1_7_2_sample.csv
# 226                 510.0  2023-03-01_13-51-03/26_1_7_1_sample.csv
# 227                 246.0  2023-03-01_13-51-03/24_1_7_4_sample.csv
# 228                   8.0   2023-03-01_13-51-03/2_1_7_3_sample.csv
# 229                   7.0   2023-03-01_13-51-03/3_1_7_3_sample.csv
#
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                   instance_name  lower_bound  upper_bound  \
# 0                      XSEngine         32.0           40
# 1                    ChatClient          7.0            7
# 2                        ea2468         24.0           40
# 3                          dell         31.0           31
# 4    fiasco_2020-12-01_14-09-14        196.0          196
# ..                          ...          ...          ...
# 225                   APL-Model          8.0            8
# 226  uclibc_2008-06-05_13-46-47        505.0          505
# 227  fiasco_2017-09-26_11-30-56        224.0          225
# 228                         lcm          6.0            6
# 229                       email          6.0            6
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 210, 'nbrhd_confs': 9, 'iter...              3.395
# 1    [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...              0.183
# 2    [{'nbrhd_tuples': 207, 'nbrhd_confs': 5, 'iter...              3.594
# 3    [{'nbrhd_tuples': 249, 'nbrhd_confs': 25, 'ite...              0.257
# 4    [{'nbrhd_tuples': 235, 'nbrhd_confs': 15, 'ite...              1.176
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 249, 'nbrhd_confs': 12, 'ite...              0.192
# 226  [{'nbrhd_tuples': 243, 'nbrhd_confs': 44, 'ite...              1.492
# 227  [{'nbrhd_tuples': 234, 'nbrhd_confs': 22, 'ite...              0.990
# 228  [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...              0.202
# 229  [{'nbrhd_tuples': 70, 'nbrhd_confs': 7, 'itera...              0.200
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                 3596.605          True      3708.056571        3600
# 1                 3599.817          True        15.838238        3600
# 2                 3596.406          True      3614.455043        3600
# 3                 3599.743          True       117.523291        3600
# 4                 3598.824          True      2319.812010        3600
# ..                     ...           ...              ...         ...
# 225               3599.808          True        93.377796        3600
# 226               3598.508          True       726.094270        3600
# 227               3599.010          True      3655.331330        3600
# 228               3599.798          True         0.076086        3600
# 229               3599.800          True         0.056341        3600
#
# [230 rows x 17 columns]

# %%
# Check that we have all results.
samplns_data_with_baseline_infos.groupby(['instance_name']).size()
# Out:
# instance_name
# APL                            5
# APL-Model                      5
# BankingSoftware                5
# BattleofTanks                  5
# ChatClient                     5
# DMIE                           5
# E-Shop                         5
# EMBToolkit                     5
# FameDB                         5
# FeatureIDE                     5
# FreeBSD-8_0_0                  5
# PPU                            5
# SafeBali                       5
# SortingLine                    5
# TightVNC                       5
# Violet                         5
# WaterlooGenerated              5
# XSEngine                       5
# aaed2000                       5
# am31_sim                       5
# atlas_mips32_4kc               5
# axTLS                          5
# berkeleyDB1                    5
# berkeleyDB2                    5
# busybox-1_18_0                 5
# busybox-1_29_2                 5
# busybox_2007-01-24_09-14-09    5
# busybox_2020-12-16_21-53-05    5
# calculate                      5
# car                            5
# dell                           5
# eCos-3-0_i386pc                5
# ea2468                         5
# email                          5
# fiasco_2017-09-26_11-30-56     5
# fiasco_2020-12-01_14-09-14     5
# financial_services             5
# fs_2017-05-22                  5
# gpl                            5
# integrator_arm7                5
# lcm                            5
# soletta_2015-06-26_18-38-56    5
# toybox_2006-10-31_23-30-06     5
# toybox_2020-12-06_00-02-46     5
# uclibc_2008-06-05_13-46-47     5
# uclibc_2020-12-24_11-54-53     5
# dtype: int64

# %%
# Will stop the notebook if the data is bad
assert samplns_data_with_baseline_infos.groupby(['instance_name']).size().min() == 5
assert samplns_data_with_baseline_infos.groupby(['instance_name']).size().max() == 5

# %%
# Save the cleaned data to a json file
samplns_data_with_baseline_infos.to_json("./05_clean_data.json.zip")

# %%
# This just for looking into one instance.
t = read_as_pandas(
        RESULT_FOLDER,
        lambda result: {
            "parameters": result["parameters"],
            "initial_sample_path": result["parameters"]["args"]["initial_sample_path"],
            "instance_name": result["parameters"]["args"]["instance_name"],
            "lower_bound": result["result"]["lower_bound"],
            "upper_bound": len(result["result"]["solution"]),
            "iteration_info": result["result"]["iteration_info"],
            "time_used_by_yasa": result["result"]["time_used_by_yasa"],
            "timelimit_for_samplns": result["result"]["timelimit_for_samplns"],
            "samplns_used": result["result"]["samplns_used"],
            "instance": result["parameters"]["args"]["instance_name"],
            "logging": result["logging"],
        } if result.get("result", None) and  result.get("result", dict()).get("solution", None) else None,
    )
t = t[t["instance_name"] == "toybox_2020-12-06_00-02-46"]
for e in t.iloc[0]["logging"]:
    print(e["message"])
# Out:
# Parsed instance 'models/toybox_2020-12-06_00-02-46' with 334 features and 92 rules.
# Preprocessing instance (Instance[models/toybox_2020-12-06_00-02-46]<334 features, 92 rules>).
# Converting instance to CNF (Instance[models/toybox_2020-12-06_00-02-46|EQ]<334 features, 92 rules>).
# Finished converting instance to CNF (Instance[models/toybox_2020-12-06_00-02-46|EQ|CNF]<334 features, 92 rules>).
# Finnished preprocessing (Instance[models/toybox_2020-12-06_00-02-46|EQ|CNF]<334 features, 92 rules>).
# Setting up random neighborhood selector.
# Computing feasible tuples...
# Converted sample to list representation.
# Instance has 206665 feasible tuples.
# Neighborhood selector is ready.
# Building transaction graph for models/toybox_2020-12-06_00-02-46|EQ|CNF with 334 concrete features!
# All valid configurations were added to the transaction graph.
# Setting up random neighborhood selector.
# Computing feasible tuples...
# Converted sample to list representation.
# Instance has 206665 feasible tuples.
# Neighborhood selector is ready.
# Beginning optimization with the following parameters: iterations=10000, iteration_timelimit=120.000000, timelimit=3599.526000
# Async Solver started with iteration timelimit 120
# Beginning iteration 0.
# Selected neighborhood, removing 3 configurations, leaving 171 tuples uncovered.
# [Symmetry Breaking]: (11.947428s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: Optimal solution found (3)!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 3 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=3, ub=3.
# Increased lower bound to 5 (from 0).
# Increasing neighborhood size to 312 tuples.
# Beginning iteration 1.
# Selected neighborhood, removing 2 configurations, leaving 158 tuples uncovered.
# [Symmetry Breaking]: (11.960257s left) Independent tuple set with size 2 was found!
# [Symmetry Breaking]: Optimal solution found (2)!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increasing neighborhood size to 390 tuples.
# Beginning iteration 2.
# Selected neighborhood, removing 4 configurations, leaving 290 tuples uncovered.
# [Symmetry Breaking]: (11.850594s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 488 tuples.
# Beginning iteration 3.
# Selected neighborhood, removing 4 configurations, leaving 462 tuples uncovered.
# [Symmetry Breaking]: (9.270004s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 610 tuples.
# Beginning iteration 4.
# Selected neighborhood, removing 2 configurations, leaving 473 tuples uncovered.
# [Symmetry Breaking]: (10.589746s left) Independent tuple set with size 2 was found!
# [Symmetry Breaking]: Optimal solution found (2)!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increasing neighborhood size to 762 tuples.
# Beginning iteration 5.
# Selected neighborhood, removing 4 configurations, leaving 576 tuples uncovered.
# [Symmetry Breaking]: (8.408562s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increased lower bound to 6 (from 5).
# Increasing neighborhood size to 953 tuples.
# Beginning iteration 6.
# Selected neighborhood, removing 4 configurations, leaving 743 tuples uncovered.
# [Symmetry Breaking]: Optimal solution found (4)!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 4 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 1192 tuples.
# Beginning iteration 7.
# Selected neighborhood, removing 3 configurations, leaving 814 tuples uncovered.
# [Symmetry Breaking]: (0.105660s left) Independent tuple set with size 2 was found!
# [Symmetry Breaking]: The greedy solver found 1 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 3.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 1490 tuples.
# Beginning iteration 8.
# Selected neighborhood, removing 5 configurations, leaving 1182 tuples uncovered.
# [Symmetry Breaking]: (11.948557s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increased lower bound to 7 (from 6).
# Increasing neighborhood size to 1862 tuples.
# Beginning iteration 9.
# Selected neighborhood, removing 3 configurations, leaving 1490 tuples uncovered.
# [Symmetry Breaking]: Optimal solution found (3)!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 2328 tuples.
# Beginning iteration 10.
# Selected neighborhood, removing 4 configurations, leaving 1386 tuples uncovered.
# [Symmetry Breaking]: (11.980911s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 2910 tuples.
# Beginning iteration 11.
# Selected neighborhood, removing 6 configurations, leaving 2738 tuples uncovered.
# [Symmetry Breaking]: (11.964689s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 3637 tuples.
# Beginning iteration 12.
# Selected neighborhood, removing 4 configurations, leaving 3144 tuples uncovered.
# [Symmetry Breaking]: (11.938286s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 4547 tuples.
# Beginning iteration 13.
# Selected neighborhood, removing 4 configurations, leaving 2951 tuples uncovered.
# [Symmetry Breaking]: (11.941624s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.885887s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: Optimal solution found (4)!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 5684 tuples.
# Beginning iteration 14.
# Selected neighborhood, removing 5 configurations, leaving 5235 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 7105 tuples.
# Beginning iteration 15.
# Selected neighborhood, removing 4 configurations, leaving 3673 tuples uncovered.
# [Symmetry Breaking]: (11.822354s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 8881 tuples.
# Beginning iteration 16.
# Selected neighborhood, removing 5 configurations, leaving 8083 tuples uncovered.
# [Symmetry Breaking]: (11.618403s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: Optimal solution found (5)!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 5 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 11102 tuples.
# Beginning iteration 17.
# Selected neighborhood, removing 5 configurations, leaving 6913 tuples uncovered.
# [Symmetry Breaking]: (11.798960s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 13877 tuples.
# Beginning iteration 18.
# Selected neighborhood, removing 6 configurations, leaving 11249 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=6.
# Decreasing neighborhood size to 10408 tuples.
# Beginning iteration 19.
# Selected neighborhood, removing 5 configurations, leaving 7740 tuples uncovered.
# [Symmetry Breaking]: (11.769164s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (7.744801s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: Optimal solution found (5)!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 5 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 13010 tuples.
# Beginning iteration 20.
# Selected neighborhood, removing 6 configurations, leaving 9704 tuples uncovered.
# [Symmetry Breaking]: (-5.420495s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 16263 tuples.
# Beginning iteration 21.
# Selected neighborhood, removing 6 configurations, leaving 11869 tuples uncovered.
# [Symmetry Breaking]: (11.845916s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.013237s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (7.171333s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 20328 tuples.
# Beginning iteration 22.
# Selected neighborhood, removing 7 configurations, leaving 18233 tuples uncovered.
# [Symmetry Breaking]: (11.645780s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (-3.319171s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 25410 tuples.
# Beginning iteration 23.
# Selected neighborhood, removing 7 configurations, leaving 23832 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 31763 tuples.
# Beginning iteration 24.
# Selected neighborhood, removing 7 configurations, leaving 25619 tuples uncovered.
# [Symmetry Breaking]: (11.350443s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (10.470564s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 39704 tuples.
# Beginning iteration 25.
# Selected neighborhood, removing 7 configurations, leaving 23898 tuples uncovered.
# [Symmetry Breaking]: (11.671388s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.539042s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 29778 tuples.
# Beginning iteration 26.
# Selected neighborhood, removing 7 configurations, leaving 25737 tuples uncovered.
# [Symmetry Breaking]: (11.592502s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.183554s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (9.514643s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 37223 tuples.
# Beginning iteration 27.
# Selected neighborhood, removing 7 configurations, leaving 25953 tuples uncovered.
# [Symmetry Breaking]: (11.446521s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 46528 tuples.
# Beginning iteration 28.
# Selected neighborhood, removing 8 configurations, leaving 40468 tuples uncovered.
# [Symmetry Breaking]: (4.081586s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (3.145324s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (1.415075s left) Independent tuple set with size 7 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 7 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 7 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 34896 tuples.
# Beginning iteration 29.
# Selected neighborhood, removing 7 configurations, leaving 26655 tuples uncovered.
# [Symmetry Breaking]: (11.558870s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 43620 tuples.
# Beginning iteration 30.
# Selected neighborhood, removing 8 configurations, leaving 38706 tuples uncovered.
# [Symmetry Breaking]: (11.548970s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.539200s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (10.946874s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 32715 tuples.
# Beginning iteration 31.
# Selected neighborhood, removing 7 configurations, leaving 23838 tuples uncovered.
# [Symmetry Breaking]: (11.582056s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=7.
# Decreasing neighborhood size to 24536 tuples.
# Beginning iteration 32.
# Selected neighborhood, removing 6 configurations, leaving 18809 tuples uncovered.
# [Symmetry Breaking]: (11.735743s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.538790s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (10.823060s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: Optimal solution found (6)!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 30670 tuples.
# Beginning iteration 33.
# Selected neighborhood, removing 7 configurations, leaving 24060 tuples uncovered.
# [Symmetry Breaking]: (11.643693s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 23003 tuples.
# Beginning iteration 34.
# Selected neighborhood, removing 6 configurations, leaving 16846 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 28753 tuples.
# Beginning iteration 35.
# Selected neighborhood, removing 7 configurations, leaving 22713 tuples uncovered.
# [Symmetry Breaking]: (11.647190s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 21565 tuples.
# Beginning iteration 36.
# Selected neighborhood, removing 6 configurations, leaving 16857 tuples uncovered.
# [Symmetry Breaking]: (11.780108s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (3.077795s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 26956 tuples.
# Beginning iteration 37.
# Selected neighborhood, removing 6 configurations, leaving 17394 tuples uncovered.
# [Symmetry Breaking]: (9.529413s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (9.106579s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: Optimal solution found (6)!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 33696 tuples.
# Beginning iteration 38.
# Selected neighborhood, removing 7 configurations, leaving 27970 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 25272 tuples.
# Beginning iteration 39.
# Selected neighborhood, removing 7 configurations, leaving 23249 tuples uncovered.
# [Symmetry Breaking]: (9.828538s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 5 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 31590 tuples.
# Beginning iteration 40.
# Selected neighborhood, removing 7 configurations, leaving 23033 tuples uncovered.
# [Symmetry Breaking]: (11.300785s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (9.872008s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (9.644032s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 39487 tuples.
# Beginning iteration 41.
# Selected neighborhood, removing 8 configurations, leaving 38074 tuples uncovered.
# [Symmetry Breaking]: (9.196057s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (8.620991s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Increased lower bound to 8 (from 7).
# Optimized neighborhood, lb=8, ub=8.
# Increasing neighborhood size to 49359 tuples.
# Beginning iteration 42.
# Selected neighborhood, removing 8 configurations, leaving 40691 tuples uncovered.
# [Symmetry Breaking]: (9.014848s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 37019 tuples.
# Beginning iteration 43.
# Selected neighborhood, removing 8 configurations, leaving 35643 tuples uncovered.
# [Symmetry Breaking]: (11.528390s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (11.338076s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (-0.719020s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 27764 tuples.
# Beginning iteration 44.
# Selected neighborhood, removing 7 configurations, leaving 26560 tuples uncovered.
# [Symmetry Breaking]: (11.651342s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (-2.834692s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 34705 tuples.
# Beginning iteration 45.
# Selected neighborhood, removing 7 configurations, leaving 29614 tuples uncovered.
# [Symmetry Breaking]: (11.504577s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (6.613027s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 43382 tuples.
# Beginning iteration 46.
# Selected neighborhood, removing 8 configurations, leaving 40066 tuples uncovered.
# [Symmetry Breaking]: (11.388538s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (11.093984s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 32536 tuples.
# Beginning iteration 47.
# Selected neighborhood, removing 7 configurations, leaving 26969 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 24402 tuples.
# Beginning iteration 48.
# Selected neighborhood, removing 6 configurations, leaving 17370 tuples uncovered.
# [Symmetry Breaking]: (10.595843s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 30503 tuples.
# Beginning iteration 49.
# Selected neighborhood, removing 7 configurations, leaving 27873 tuples uncovered.
# [Symmetry Breaking]: (11.656995s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 38129 tuples.
# Beginning iteration 50.
# Selected neighborhood, removing 7 configurations, leaving 24617 tuples uncovered.
# [Symmetry Breaking]: (6.530719s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 4 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 47661 tuples.
# Beginning iteration 51.
# Selected neighborhood, removing 8 configurations, leaving 39569 tuples uncovered.
# [Symmetry Breaking]: (11.440361s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 35745 tuples.
# Beginning iteration 52.
# Selected neighborhood, removing 7 configurations, leaving 25863 tuples uncovered.
# [Symmetry Breaking]: (11.692964s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (10.087497s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: (3.900135s left) Independent tuple set with size 5 was found!
# [Symmetry Breaking]: (3.616395s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 44682 tuples.
# Beginning iteration 53.
# Selected neighborhood, removing 8 configurations, leaving 38554 tuples uncovered.
# [Symmetry Breaking]: (11.342793s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (4.602144s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: (3.460081s left) Independent tuple set with size 7 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 7 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 7 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=8, ub=8.
# Increasing neighborhood size to 55853 tuples.
# Beginning iteration 54.
# Selected neighborhood, removing 9 configurations, leaving 54808 tuples uncovered.
# [Symmetry Breaking]: (11.336924s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (4.836563s left) Independent tuple set with size 7 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 7 tuples!
# Building model for neighborhood of size 9.
# Using 15 threads for search.
# Using 7 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=9.
# Decreasing neighborhood size to 41889 tuples.
# Beginning iteration 55.
# Selected neighborhood, removing 8 configurations, leaving 37659 tuples uncovered.
# [Symmetry Breaking]: (8.585375s left) Independent tuple set with size 6 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 8.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=8.
# Decreasing neighborhood size to 31417 tuples.
# Beginning iteration 56.
# Selected neighborhood, removing 7 configurations, leaving 24341 tuples uncovered.
# [Symmetry Breaking]: (11.631446s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: (4.362248s left) Independent tuple set with size 4 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 23563 tuples.
# Beginning iteration 57.
# Selected neighborhood, removing 6 configurations, leaving 16653 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 29453 tuples.
# Beginning iteration 58.
# Selected neighborhood, removing 7 configurations, leaving 23356 tuples uncovered.
# [Symmetry Breaking]: The greedy solver found 5 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=7, ub=7.
# Increasing neighborhood size to 36817 tuples.
# Beginning iteration 59.
# Selected neighborhood, removing 7 configurations, leaving 26221 tuples uncovered.
# [Symmetry Breaking]: (0.152743s left) Independent tuple set with size 3 was found!
# [Symmetry Breaking]: The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Timeout in iteration.
# Optimized neighborhood, lb=1, ub=7.
# Decreasing neighborhood size to 27612 tuples.
# Optimization reached time limit.
# Async Solver stopped

# %%
# Check that we can read the data
data = pd.read_json("./05_clean_data.json.zip")
data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0        1273         2942         YASA        t2_m1_null             3.395
# 1          14           20         YASA        t2_m1_null             0.183
# 2        1408         3319         YASA        t2_m1_null             3.594
# 3          46          244         YASA        t2_m1_null             0.257
# 4         258         1542         YASA        t2_m1_null             1.176
# ..        ...          ...          ...               ...               ...
# 225        28           40         YASA        t2_m1_null             0.192
# 226       263         1699         YASA        t2_m1_null             1.492
# 227       230         1181         YASA        t2_m1_null             0.990
# 228         9           16         YASA        t2_m1_null             0.202
# 229        10           17         YASA        t2_m1_null             0.200
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      69  2023-03-01_13-51-03/44_1_7_1_sample.csv
# 1                       8   2023-03-01_13-51-03/4_1_7_2_sample.csv
# 2                      72  2023-03-01_13-51-03/47_1_7_2_sample.csv
# 3                      38  2023-03-01_13-51-03/15_1_7_2_sample.csv
# 4                     224  2023-03-01_13-51-03/25_1_7_5_sample.csv
# ..                    ...                                      ...
# 225                    15  2023-03-01_13-51-03/12_1_7_2_sample.csv
# 226                   510  2023-03-01_13-51-03/26_1_7_1_sample.csv
# 227                   246  2023-03-01_13-51-03/24_1_7_4_sample.csv
# 228                     8   2023-03-01_13-51-03/2_1_7_3_sample.csv
# 229                     7   2023-03-01_13-51-03/3_1_7_3_sample.csv
#
#                                             parameters  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...
# 1    {'func': 'run_samplns', 'args': {'instance_nam...
# 2    {'func': 'run_samplns', 'args': {'instance_nam...
# 3    {'func': 'run_samplns', 'args': {'instance_nam...
# 4    {'func': 'run_samplns', 'args': {'instance_nam...
# ..                                                 ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...
# 226  {'func': 'run_samplns', 'args': {'instance_nam...
# 227  {'func': 'run_samplns', 'args': {'instance_nam...
# 228  {'func': 'run_samplns', 'args': {'instance_nam...
# 229  {'func': 'run_samplns', 'args': {'instance_nam...
#
#                   instance_name  lower_bound  upper_bound  \
# 0                      XSEngine           32           40
# 1                    ChatClient            7            7
# 2                        ea2468           24           40
# 3                          dell           31           31
# 4    fiasco_2020-12-01_14-09-14          196          196
# ..                          ...          ...          ...
# 225                   APL-Model            8            8
# 226  uclibc_2008-06-05_13-46-47          505          505
# 227  fiasco_2017-09-26_11-30-56          224          225
# 228                         lcm            6            6
# 229                       email            6            6
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 210, 'nbrhd_confs': 9, 'iter...              3.395
# 1    [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...              0.183
# 2    [{'nbrhd_tuples': 207, 'nbrhd_confs': 5, 'iter...              3.594
# 3    [{'nbrhd_tuples': 249, 'nbrhd_confs': 25, 'ite...              0.257
# 4    [{'nbrhd_tuples': 235, 'nbrhd_confs': 15, 'ite...              1.176
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 249, 'nbrhd_confs': 12, 'ite...              0.192
# 226  [{'nbrhd_tuples': 243, 'nbrhd_confs': 44, 'ite...              1.492
# 227  [{'nbrhd_tuples': 234, 'nbrhd_confs': 22, 'ite...              0.990
# 228  [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...              0.202
# 229  [{'nbrhd_tuples': 70, 'nbrhd_confs': 7, 'itera...              0.200
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                 3596.605          True      3708.056571        3600
# 1                 3599.817          True        15.838238        3600
# 2                 3596.406          True      3614.455043        3600
# 3                 3599.743          True       117.523291        3600
# 4                 3598.824          True      2319.812010        3600
# ..                     ...           ...              ...         ...
# 225               3599.808          True        93.377796        3600
# 226               3598.508          True       726.094270        3600
# 227               3599.010          True      3655.331330        3600
# 228               3599.798          True         0.076086        3600
# 229               3599.800          True         0.056341        3600
#
# [230 rows x 17 columns]

# %% [markdown]
# * `instance_name`: The instance name.
# * `num_vars`: The number of variables in the instance.
# * `num_clauses`: The number of clauses in the instance.
# * `baseline_alg`: The baseline algorithm that created the sample
# * `baseline_alg_conf`: The configuration of the baseline algorithm that created the sample.
# * `runtime_baseline`: The runtime of the baseline algorithm that created the sample.
# * `baseline_sample_size`: The size of the sample created by the baseline algorithm.
# * `path_to_baseline_sample`: The path to the sample created by the baseline algorithm.
# * `parameters` The parameters used to run samplns.
# * `lower_bound` The lower bound computed by SampLNS.
# * `upper_bound` The upper bound computed by SampLNS.
# * `iteration_info` Info the extract the progress of SampLNS. The time do not include the baseline algorithm.
# * `time_used_by_yasa` The time used by the baseline algorithm.
# * `timelimit_for_samplns` The time limit for SampLNS. Check also `parameters` for the full timelimit.
# * `runtime_samplns` The runtime of SampLNS without the baseline.
# * `time_limit` The overall timelimit.
