# %%
import pandas as pd

data = pd.read_json("./05_clean_data.json.zip")

# %%
# Find the best values for each instance as reference.
best_solutions = data[["instance", "initial_sample_size", "optimized_sample_size"]].groupby("instance").min().reset_index().rename(columns={"initial_sample_size": "best_baseline", "optimized_sample_size": "best_lns_ub"})
best_lb = data[["instance", "lower_bound"]].groupby("instance").max().reset_index().rename(columns={"lower_bound": "best_lb"})
mean_ub = data[["instance", "optimized_sample_size"]].groupby("instance").mean().reset_index().rename(columns={"optimized_sample_size": "mean_lns_ub"})
best_values = best_solutions.merge(best_lb, left_on="instance", right_on="instance")
best_values = best_values.merge(mean_ub, left_on="instance", right_on="instance")

# %%
samplns_yasa = data[data["baseline_alg"] == "YASA(m=1)"][["instance", "optimized_sample_size"]].groupby("instance").mean().reset_index().rename(columns={"optimized_sample_size": "samplns_yasa"})
best_values = best_values.merge(samplns_yasa, left_on="instance", right_on="instance")
best_values
# Out:
#                        instance  best_baseline  best_lns_ub  best_lb  \
# 0                           APL              9            7        7
# 1                     APL-Model             10            8        8
# 2               BankingSoftware             40           29       28
# 3                 BattleofTanks            444          322      256
# 4                    ChatClient              8            7        7
# 5                          DMIE             25           16       16
# 6                        E-Shop             20           12       10
# 7                    EMBToolkit           1883         1883     1872
# 8                        FameDB              8            8        8
# 9                    FeatureIDE             11            8        8
# 10                FreeBSD-8_0_0             76           55       30
# 11                          PPU             12           12       12
# 12                     SafeBali             11           11       11
# 13                  SortingLine             12            9        9
# 14                     TightVNC             10            8        8
# 15                       Violet             23           17       16
# 16            WaterlooGenerated            144           82       82
# 17                     XSEngine             63           38       33
# 18                     aaed2000             89           55       51
# 19                     am31_sim             61           36       29
# 20             atlas_mips32_4kc             66           38       33
# 21                        axTLS             16           11       10
# 22                  berkeleyDB1             19           15       15
# 23                  berkeleyDB2             21           12       12
# 24               busybox-1_18_0             29           17       13
# 25  busybox_2007-01-24_09-14-09             35           21       21
# 26  busybox_2020-12-16_21-53-05             34           21       20
# 27                    calculate              9            5        5
# 28                          car              6            5        5
# 29                         dell             34           31       31
# 30              eCos-3-0_i386pc             66           45       33
# 31                       ea2468             65           40       33
# 32                        email              6            6        6
# 33   fiasco_2017-09-26_11-30-56            237          225      225
# 34   fiasco_2020-12-01_14-09-14            213          196      196
# 35           financial_services           4396         4396     2731
# 36                fs_2017-05-22            398          396      396
# 37                          gpl             18           16       16
# 38              integrator_arm7             66           39       33
# 39                          lcm              8            6        6
# 40  soletta_2015-06-26_18-38-56             30           24       24
# 41  soletta_2017-03-09_21-02-40             57           37       37
# 42   toybox_2006-10-31_23-30-06              9            8        8
# 43   toybox_2020-12-06_00-02-46             18           11       10
#
#     mean_lns_ub  samplns_yasa
# 0      7.000000           7.0
# 1      8.000000           8.0
# 2     29.000000          29.0
# 3    331.763636         330.4
# 4      7.000000           7.0
# 5     16.000000          16.0
# 6     12.000000          12.0
# 7   1928.900000        1883.0
# 8      8.000000           8.0
# 9      8.000000           8.0
# 10    59.555556          59.0
# 11    12.000000          12.0
# 12    11.000000          11.0
# 13     9.000000           9.0
# 14     8.000000           8.0
# 15    17.000000          17.0
# 16    82.000000          82.0
# 17    40.040000          39.4
# 18    58.680000          58.8
# 19    37.400000          37.2
# 20    40.137255          40.4
# 21    11.000000          11.0
# 22    15.000000          15.0
# 23    12.000000          12.0
# 24    17.090909          17.2
# 25    21.054545          21.0
# 26    21.163636          21.4
# 27     5.000000           5.0
# 28     5.000000           5.0
# 29    31.000000          31.0
# 30    48.740000          47.6
# 31    41.020000          41.4
# 32     6.000000           6.0
# 33   225.127273         225.0
# 34   196.345455         196.2
# 35  4402.750000        4417.0
# 36   397.660000         396.6
# 37    16.000000          16.0
# 38    40.420000          40.2
# 39     6.000000           6.0
# 40    24.000000          24.0
# 41    37.000000          37.0
# 42     8.000000           8.0
# 43    11.000000          11.0

# %%
data = data.merge(best_values, left_on="instance", right_on="instance")

# %%
t = data[data["initial_sample_size"]==data["best_baseline"]].drop_duplicates(subset=["instance"], keep="last")

# %%
t
# Out:
#                          instance  #Variables  #Clauses  \
# 45                  BattleofTanks         144       769
# 103                      XSEngine        1273      2942
# 151    toybox_2006-10-31_23-30-06          16        13
# 214                           APL          23        35
# 259                      aaed2000        1298      3036
# 311               integrator_arm7        1272      2980
# 356   busybox_2007-01-24_09-14-09         540       429
# 418    fiasco_2020-12-01_14-09-14         258      1542
# 474                 fs_2017-05-22         557      4992
# 510            financial_services         771      7238
# 569                           lcm           9        16
# 618                   SortingLine          39        77
# 679                     calculate           9        15
# 727                    EMBToolkit        1179      5414
# 782                   berkeleyDB2         119       346
# 837                        FameDB          22        40
# 894                busybox-1_18_0         854      1164
# 949                      SafeBali          24        45
# 1004                          PPU          52       109
# 1050  soletta_2015-06-26_18-38-56         129       192
# 1111                          gpl          38        99
# 1169  busybox_2020-12-16_21-53-05        1050       996
# 1221                     am31_sim        1178      2747
# 1275              BankingSoftware         176       280
# 1331                        axTLS          96       183
# 1374                    APL-Model          28        40
# 1443                   ChatClient          14        20
# 1499                          car          16        33
# 1540   toybox_2020-12-06_00-02-46         334        92
# 1602             atlas_mips32_4kc        1229      2875
# 1660  soletta_2017-03-09_21-02-40         458      1862
# 1713                       E-Shop         326       499
# 1767                       Violet         101       203
# 1824                         dell          46       244
# 1875                       ea2468        1408      3319
# 1930                        email          10        17
# 1979                     TightVNC          28        39
# 2030                FreeBSD-8_0_0        1397     15692
# 2082   fiasco_2017-09-26_11-30-56         230      1181
# 2137            WaterlooGenerated         580       879
# 2195                   FeatureIDE          19        27
# 2249                         DMIE         366       627
# 2298                  berkeleyDB1          76       147
# 2355              eCos-3-0_i386pc        1245      3723
#
#                                          iteration_info     baseline_alg  \
# 45    [{'nbrhd_tuples': 248, 'nbrhd_confs': 74, 'ite...       YASA(m=10)
# 103   [{'nbrhd_tuples': 247, 'nbrhd_confs': 3, 'iter...        YASA(m=5)
# 151   [{'nbrhd_tuples': 202, 'nbrhd_confs': 7, 'iter...        YASA(m=3)
# 214   [{'nbrhd_tuples': 207, 'nbrhd_confs': 8, 'iter...       YASA(m=10)
# 259   [{'nbrhd_tuples': 168, 'nbrhd_confs': 1, 'iter...  FIDE-YASA(m=10)
# 311   [{'nbrhd_tuples': 166, 'nbrhd_confs': 2, 'iter...   FIDE-YASA(m=5)
# 356   [{'nbrhd_tuples': 207, 'nbrhd_confs': 5, 'iter...       YASA(m=10)
# 418   [{'nbrhd_tuples': 246, 'nbrhd_confs': 15, 'ite...       YASA(m=10)
# 474   [{'nbrhd_tuples': 1, 'nbrhd_confs': 1, 'iterat...       YASA(m=10)
# 510   [{'nbrhd_tuples': 247, 'nbrhd_confs': 172, 'it...  FIDE-YASA(m=10)
# 569   [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...        YASA(m=3)
# 618   [{'nbrhd_tuples': 220, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 679   [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...   FIDE-YASA(m=3)
# 727   [{'nbrhd_tuples': 249, 'nbrhd_confs': 107, 'it...        YASA(m=1)
# 782   [{'nbrhd_tuples': 247, 'nbrhd_confs': 5, 'iter...   FIDE-YASA(m=5)
# 837   [{'nbrhd_tuples': 224, 'nbrhd_confs': 7, 'iter...        YASA(m=1)
# 894   [{'nbrhd_tuples': 234, 'nbrhd_confs': 3, 'iter...       YASA(m=10)
# 949   [{'nbrhd_tuples': 141, 'nbrhd_confs': 11, 'ite...   FIDE-YASA(m=3)
# 1004  [{'nbrhd_tuples': 225, 'nbrhd_confs': 7, 'iter...   FIDE-YASA(m=3)
# 1050  [{'nbrhd_tuples': 211, 'nbrhd_confs': 9, 'iter...  FIDE-YASA(m=10)
# 1111  [{'nbrhd_tuples': 214, 'nbrhd_confs': 12, 'ite...       YASA(m=10)
# 1169  [{'nbrhd_tuples': 116, 'nbrhd_confs': 2, 'iter...  FIDE-YASA(m=10)
# 1221  [{'nbrhd_tuples': 179, 'nbrhd_confs': 3, 'iter...        YASA(m=5)
# 1275  [{'nbrhd_tuples': 228, 'nbrhd_confs': 12, 'ite...       YASA(m=10)
# 1331  [{'nbrhd_tuples': 202, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 1374  [{'nbrhd_tuples': 191, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 1443  [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...       YASA(m=10)
# 1499  [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...   FIDE-YASA(m=5)
# 1540  [{'nbrhd_tuples': 193, 'nbrhd_confs': 5, 'iter...  FIDE-YASA(m=10)
# 1602  [{'nbrhd_tuples': 135, 'nbrhd_confs': 5, 'iter...   FIDE-YASA(m=3)
# 1660  [{'nbrhd_tuples': 219, 'nbrhd_confs': 9, 'iter...   FIDE-YASA(m=5)
# 1713  [{'nbrhd_tuples': 112, 'nbrhd_confs': 2, 'iter...   FIDE-YASA(m=5)
# 1767  [{'nbrhd_tuples': 227, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 1824  [{'nbrhd_tuples': 196, 'nbrhd_confs': 20, 'ite...       YASA(m=10)
# 1875  [{'nbrhd_tuples': 134, 'nbrhd_confs': 4, 'iter...       YASA(m=10)
# 1930  [{'nbrhd_tuples': 70, 'nbrhd_confs': 6, 'itera...   FIDE-YASA(m=3)
# 1979  [{'nbrhd_tuples': 177, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 2030  [{'nbrhd_tuples': 80, 'nbrhd_confs': 4, 'itera...   FIDE-YASA(m=5)
# 2082  [{'nbrhd_tuples': 246, 'nbrhd_confs': 30, 'ite...        YASA(m=5)
# 2137  [{'nbrhd_tuples': 222, 'nbrhd_confs': 14, 'ite...  FIDE-YASA(m=10)
# 2195  [{'nbrhd_tuples': 204, 'nbrhd_confs': 8, 'iter...        YASA(m=5)
# 2249  [{'nbrhd_tuples': 213, 'nbrhd_confs': 4, 'iter...       YASA(m=10)
# 2298  [{'nbrhd_tuples': 236, 'nbrhd_confs': 7, 'iter...       YASA(m=10)
# 2355  [{'nbrhd_tuples': 229, 'nbrhd_confs': 2, 'iter...       YASA(m=10)
#
#                            initial_sample_path  initial_sample_size  \
# 45    2023-03-01_13-51-03/22_1_10_1_sample.csv                  444
# 103    2023-03-01_13-51-03/44_1_9_1_sample.csv                   63
# 151     2023-03-01_13-51-03/5_1_8_4_sample.csv                    9
# 214    2023-03-01_13-51-03/9_1_10_1_sample.csv                    9
# 259    2023-03-01_13-51-03/45_1_6_1_sample.csv                   89
# 311    2023-03-01_13-51-03/43_1_5_2_sample.csv                   66
# 356   2023-03-01_13-51-03/32_1_10_4_sample.csv                   35
# 418   2023-03-01_13-51-03/25_1_10_4_sample.csv                  213
# 474   2023-03-01_13-51-03/33_1_10_4_sample.csv                  398
# 510    2023-03-01_13-51-03/35_1_6_2_sample.csv                 4396
# 569     2023-03-01_13-51-03/2_1_8_2_sample.csv                    8
# 618    2023-03-01_13-51-03/14_1_6_4_sample.csv                   12
# 679     2023-03-01_13-51-03/1_1_4_5_sample.csv                    9
# 727    2023-03-01_13-51-03/40_1_7_5_sample.csv                 1883
# 782    2023-03-01_13-51-03/20_1_5_5_sample.csv                   21
# 837     2023-03-01_13-51-03/8_1_7_3_sample.csv                    8
# 894   2023-03-01_13-51-03/36_1_10_4_sample.csv                   29
# 949    2023-03-01_13-51-03/10_1_4_2_sample.csv                   11
# 1004   2023-03-01_13-51-03/16_1_4_4_sample.csv                   12
# 1050   2023-03-01_13-51-03/21_1_6_2_sample.csv                   30
# 1111  2023-03-01_13-51-03/13_1_10_2_sample.csv                   18
# 1169   2023-03-01_13-51-03/38_1_6_5_sample.csv                   34
# 1221   2023-03-01_13-51-03/39_1_9_1_sample.csv                   61
# 1275  2023-03-01_13-51-03/23_1_10_1_sample.csv                   40
# 1331  2023-03-01_13-51-03/18_1_10_4_sample.csv                   16
# 1374  2023-03-01_13-51-03/12_1_10_2_sample.csv                   10
# 1443   2023-03-01_13-51-03/4_1_10_1_sample.csv                    8
# 1499    2023-03-01_13-51-03/6_1_5_3_sample.csv                    6
# 1540   2023-03-01_13-51-03/29_1_6_1_sample.csv                   18
# 1602   2023-03-01_13-51-03/41_1_4_5_sample.csv                   66
# 1660   2023-03-01_13-51-03/31_1_5_4_sample.csv                   57
# 1713   2023-03-01_13-51-03/28_1_5_3_sample.csv                   20
# 1767   2023-03-01_13-51-03/19_1_6_2_sample.csv                   23
# 1824  2023-03-01_13-51-03/15_1_10_4_sample.csv                   34
# 1875  2023-03-01_13-51-03/47_1_10_2_sample.csv                   65
# 1930    2023-03-01_13-51-03/3_1_4_4_sample.csv                    6
# 1979  2023-03-01_13-51-03/11_1_10_2_sample.csv                   10
# 2030   2023-03-01_13-51-03/46_1_5_4_sample.csv                   76
# 2082   2023-03-01_13-51-03/24_1_9_3_sample.csv                  237
# 2137   2023-03-01_13-51-03/34_1_6_4_sample.csv                  144
# 2195    2023-03-01_13-51-03/7_1_9_3_sample.csv                   11
# 2249  2023-03-01_13-51-03/30_1_10_2_sample.csv                   25
# 2298  2023-03-01_13-51-03/17_1_10_3_sample.csv                   19
# 2355  2023-03-01_13-51-03/42_1_10_3_sample.csv                   66
#
#       lower_bound  optimized_sample_size  best_baseline  best_lns_ub  best_lb  \
# 45            242                    334            444          322      256
# 103            30                     41             63           38       33
# 151             8                      8              9            8        8
# 214             7                      7              9            7        7
# 259            51                     58             89           55       51
# 311            31                     40             66           39       33
# 356            21                     21             35           21       21
# 418           145                    197            213          196      196
# 474           396                    396            398          396      396
# 510          1191                   4396           4396         4396     2731
# 569             6                      6              8            6        6
# 618             9                      9             12            9        9
# 679             5                      5              9            5        5
# 727          1776                   1883           1883         1883     1872
# 782            12                     12             21           12       12
# 837             8                      8              8            8        8
# 894            12                     17             29           17       13
# 949            11                     11             11           11       11
# 1004           12                     12             12           12       12
# 1050           24                     24             30           24       24
# 1111           16                     16             18           16       16
# 1169           14                     22             34           21       20
# 1221           21                     38             61           36       29
# 1275           28                     29             40           29       28
# 1331           10                     11             16           11       10
# 1374            8                      8             10            8        8
# 1443            7                      7              8            7        7
# 1499            5                      5              6            5        5
# 1540           10                     11             18           11       10
# 1602           19                     40             66           38       33
# 1660           37                     37             57           37       37
# 1713            9                     12             20           12       10
# 1767           15                     17             23           17       16
# 1824           31                     31             34           31       31
# 1875           29                     40             65           40       33
# 1930            6                      6              6            6        6
# 1979            8                      8             10            8        8
# 2030           26                     59             76           55       30
# 2082          224                    225            237          225      225
# 2137           82                     82            144           82       82
# 2195            8                      8             11            8        8
# 2249           16                     16             25           16       16
# 2298           15                     15             19           15       15
# 2355           25                     47             66           45       33
#
#       mean_lns_ub  samplns_yasa
# 45     331.763636         330.4
# 103     40.040000          39.4
# 151      8.000000           8.0
# 214      7.000000           7.0
# 259     58.680000          58.8
# 311     40.420000          40.2
# 356     21.054545          21.0
# 418    196.345455         196.2
# 474    397.660000         396.6
# 510   4402.750000        4417.0
# 569      6.000000           6.0
# 618      9.000000           9.0
# 679      5.000000           5.0
# 727   1928.900000        1883.0
# 782     12.000000          12.0
# 837      8.000000           8.0
# 894     17.090909          17.2
# 949     11.000000          11.0
# 1004    12.000000          12.0
# 1050    24.000000          24.0
# 1111    16.000000          16.0
# 1169    21.163636          21.4
# 1221    37.400000          37.2
# 1275    29.000000          29.0
# 1331    11.000000          11.0
# 1374     8.000000           8.0
# 1443     7.000000           7.0
# 1499     5.000000           5.0
# 1540    11.000000          11.0
# 1602    40.137255          40.4
# 1660    37.000000          37.0
# 1713    12.000000          12.0
# 1767    17.000000          17.0
# 1824    31.000000          31.0
# 1875    41.020000          41.4
# 1930     6.000000           6.0
# 1979     8.000000           8.0
# 2030    59.555556          59.0
# 2082   225.127273         225.0
# 2137    82.000000          82.0
# 2195     8.000000           8.0
# 2249    16.000000          16.0
# 2298    15.000000          15.0
# 2355    48.740000          47.6

# %%
t["baseline"] = t.apply((lambda row: f"{row['initial_sample_size']}/{row['baseline_alg']}"), axis=1)
t["sampLNS"] = t.apply((lambda row: f"{row['best_lns_ub']} (\\O {int(round(row['mean_lns_ub']))})"), axis=1)
def shorten(s):
    if len(s)>23:
        return s[:20]+"..."
    return s
#t["instance_details"] = t.apply((lambda row: f"{shorten(row['instance'])} ({row['#Variables']}/{row['#Clauses']})"), axis=1)
t["instance_details"] = t.apply((lambda row: f"{shorten(row['instance'])}"), axis=1)
t["reduction"] = 100*(1-t["samplns_yasa"]/t["best_baseline"])
t["rel_size_after_samplns"] =100*(t["samplns_yasa"]/t["best_baseline"])
t["savings"] = 100*(1-t["samplns_yasa"]/t["best_baseline"])
t["opt_1"] =t["best_baseline"] == t["best_lb"]
t["opt_2"] =t["samplns_yasa"].apply(lambda x: round(x)) == t["best_lb"]
t
# Out:
#                          instance  #Variables  #Clauses  \
# 45                  BattleofTanks         144       769
# 103                      XSEngine        1273      2942
# 151    toybox_2006-10-31_23-30-06          16        13
# 214                           APL          23        35
# 259                      aaed2000        1298      3036
# 311               integrator_arm7        1272      2980
# 356   busybox_2007-01-24_09-14-09         540       429
# 418    fiasco_2020-12-01_14-09-14         258      1542
# 474                 fs_2017-05-22         557      4992
# 510            financial_services         771      7238
# 569                           lcm           9        16
# 618                   SortingLine          39        77
# 679                     calculate           9        15
# 727                    EMBToolkit        1179      5414
# 782                   berkeleyDB2         119       346
# 837                        FameDB          22        40
# 894                busybox-1_18_0         854      1164
# 949                      SafeBali          24        45
# 1004                          PPU          52       109
# 1050  soletta_2015-06-26_18-38-56         129       192
# 1111                          gpl          38        99
# 1169  busybox_2020-12-16_21-53-05        1050       996
# 1221                     am31_sim        1178      2747
# 1275              BankingSoftware         176       280
# 1331                        axTLS          96       183
# 1374                    APL-Model          28        40
# 1443                   ChatClient          14        20
# 1499                          car          16        33
# 1540   toybox_2020-12-06_00-02-46         334        92
# 1602             atlas_mips32_4kc        1229      2875
# 1660  soletta_2017-03-09_21-02-40         458      1862
# 1713                       E-Shop         326       499
# 1767                       Violet         101       203
# 1824                         dell          46       244
# 1875                       ea2468        1408      3319
# 1930                        email          10        17
# 1979                     TightVNC          28        39
# 2030                FreeBSD-8_0_0        1397     15692
# 2082   fiasco_2017-09-26_11-30-56         230      1181
# 2137            WaterlooGenerated         580       879
# 2195                   FeatureIDE          19        27
# 2249                         DMIE         366       627
# 2298                  berkeleyDB1          76       147
# 2355              eCos-3-0_i386pc        1245      3723
#
#                                          iteration_info     baseline_alg  \
# 45    [{'nbrhd_tuples': 248, 'nbrhd_confs': 74, 'ite...       YASA(m=10)
# 103   [{'nbrhd_tuples': 247, 'nbrhd_confs': 3, 'iter...        YASA(m=5)
# 151   [{'nbrhd_tuples': 202, 'nbrhd_confs': 7, 'iter...        YASA(m=3)
# 214   [{'nbrhd_tuples': 207, 'nbrhd_confs': 8, 'iter...       YASA(m=10)
# 259   [{'nbrhd_tuples': 168, 'nbrhd_confs': 1, 'iter...  FIDE-YASA(m=10)
# 311   [{'nbrhd_tuples': 166, 'nbrhd_confs': 2, 'iter...   FIDE-YASA(m=5)
# 356   [{'nbrhd_tuples': 207, 'nbrhd_confs': 5, 'iter...       YASA(m=10)
# 418   [{'nbrhd_tuples': 246, 'nbrhd_confs': 15, 'ite...       YASA(m=10)
# 474   [{'nbrhd_tuples': 1, 'nbrhd_confs': 1, 'iterat...       YASA(m=10)
# 510   [{'nbrhd_tuples': 247, 'nbrhd_confs': 172, 'it...  FIDE-YASA(m=10)
# 569   [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...        YASA(m=3)
# 618   [{'nbrhd_tuples': 220, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 679   [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...   FIDE-YASA(m=3)
# 727   [{'nbrhd_tuples': 249, 'nbrhd_confs': 107, 'it...        YASA(m=1)
# 782   [{'nbrhd_tuples': 247, 'nbrhd_confs': 5, 'iter...   FIDE-YASA(m=5)
# 837   [{'nbrhd_tuples': 224, 'nbrhd_confs': 7, 'iter...        YASA(m=1)
# 894   [{'nbrhd_tuples': 234, 'nbrhd_confs': 3, 'iter...       YASA(m=10)
# 949   [{'nbrhd_tuples': 141, 'nbrhd_confs': 11, 'ite...   FIDE-YASA(m=3)
# 1004  [{'nbrhd_tuples': 225, 'nbrhd_confs': 7, 'iter...   FIDE-YASA(m=3)
# 1050  [{'nbrhd_tuples': 211, 'nbrhd_confs': 9, 'iter...  FIDE-YASA(m=10)
# 1111  [{'nbrhd_tuples': 214, 'nbrhd_confs': 12, 'ite...       YASA(m=10)
# 1169  [{'nbrhd_tuples': 116, 'nbrhd_confs': 2, 'iter...  FIDE-YASA(m=10)
# 1221  [{'nbrhd_tuples': 179, 'nbrhd_confs': 3, 'iter...        YASA(m=5)
# 1275  [{'nbrhd_tuples': 228, 'nbrhd_confs': 12, 'ite...       YASA(m=10)
# 1331  [{'nbrhd_tuples': 202, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 1374  [{'nbrhd_tuples': 191, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 1443  [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...       YASA(m=10)
# 1499  [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...   FIDE-YASA(m=5)
# 1540  [{'nbrhd_tuples': 193, 'nbrhd_confs': 5, 'iter...  FIDE-YASA(m=10)
# 1602  [{'nbrhd_tuples': 135, 'nbrhd_confs': 5, 'iter...   FIDE-YASA(m=3)
# 1660  [{'nbrhd_tuples': 219, 'nbrhd_confs': 9, 'iter...   FIDE-YASA(m=5)
# 1713  [{'nbrhd_tuples': 112, 'nbrhd_confs': 2, 'iter...   FIDE-YASA(m=5)
# 1767  [{'nbrhd_tuples': 227, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 1824  [{'nbrhd_tuples': 196, 'nbrhd_confs': 20, 'ite...       YASA(m=10)
# 1875  [{'nbrhd_tuples': 134, 'nbrhd_confs': 4, 'iter...       YASA(m=10)
# 1930  [{'nbrhd_tuples': 70, 'nbrhd_confs': 6, 'itera...   FIDE-YASA(m=3)
# 1979  [{'nbrhd_tuples': 177, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 2030  [{'nbrhd_tuples': 80, 'nbrhd_confs': 4, 'itera...   FIDE-YASA(m=5)
# 2082  [{'nbrhd_tuples': 246, 'nbrhd_confs': 30, 'ite...        YASA(m=5)
# 2137  [{'nbrhd_tuples': 222, 'nbrhd_confs': 14, 'ite...  FIDE-YASA(m=10)
# 2195  [{'nbrhd_tuples': 204, 'nbrhd_confs': 8, 'iter...        YASA(m=5)
# 2249  [{'nbrhd_tuples': 213, 'nbrhd_confs': 4, 'iter...       YASA(m=10)
# 2298  [{'nbrhd_tuples': 236, 'nbrhd_confs': 7, 'iter...       YASA(m=10)
# 2355  [{'nbrhd_tuples': 229, 'nbrhd_confs': 2, 'iter...       YASA(m=10)
#
#                            initial_sample_path  initial_sample_size  \
# 45    2023-03-01_13-51-03/22_1_10_1_sample.csv                  444
# 103    2023-03-01_13-51-03/44_1_9_1_sample.csv                   63
# 151     2023-03-01_13-51-03/5_1_8_4_sample.csv                    9
# 214    2023-03-01_13-51-03/9_1_10_1_sample.csv                    9
# 259    2023-03-01_13-51-03/45_1_6_1_sample.csv                   89
# 311    2023-03-01_13-51-03/43_1_5_2_sample.csv                   66
# 356   2023-03-01_13-51-03/32_1_10_4_sample.csv                   35
# 418   2023-03-01_13-51-03/25_1_10_4_sample.csv                  213
# 474   2023-03-01_13-51-03/33_1_10_4_sample.csv                  398
# 510    2023-03-01_13-51-03/35_1_6_2_sample.csv                 4396
# 569     2023-03-01_13-51-03/2_1_8_2_sample.csv                    8
# 618    2023-03-01_13-51-03/14_1_6_4_sample.csv                   12
# 679     2023-03-01_13-51-03/1_1_4_5_sample.csv                    9
# 727    2023-03-01_13-51-03/40_1_7_5_sample.csv                 1883
# 782    2023-03-01_13-51-03/20_1_5_5_sample.csv                   21
# 837     2023-03-01_13-51-03/8_1_7_3_sample.csv                    8
# 894   2023-03-01_13-51-03/36_1_10_4_sample.csv                   29
# 949    2023-03-01_13-51-03/10_1_4_2_sample.csv                   11
# 1004   2023-03-01_13-51-03/16_1_4_4_sample.csv                   12
# 1050   2023-03-01_13-51-03/21_1_6_2_sample.csv                   30
# 1111  2023-03-01_13-51-03/13_1_10_2_sample.csv                   18
# 1169   2023-03-01_13-51-03/38_1_6_5_sample.csv                   34
# 1221   2023-03-01_13-51-03/39_1_9_1_sample.csv                   61
# 1275  2023-03-01_13-51-03/23_1_10_1_sample.csv                   40
# 1331  2023-03-01_13-51-03/18_1_10_4_sample.csv                   16
# 1374  2023-03-01_13-51-03/12_1_10_2_sample.csv                   10
# 1443   2023-03-01_13-51-03/4_1_10_1_sample.csv                    8
# 1499    2023-03-01_13-51-03/6_1_5_3_sample.csv                    6
# 1540   2023-03-01_13-51-03/29_1_6_1_sample.csv                   18
# 1602   2023-03-01_13-51-03/41_1_4_5_sample.csv                   66
# 1660   2023-03-01_13-51-03/31_1_5_4_sample.csv                   57
# 1713   2023-03-01_13-51-03/28_1_5_3_sample.csv                   20
# 1767   2023-03-01_13-51-03/19_1_6_2_sample.csv                   23
# 1824  2023-03-01_13-51-03/15_1_10_4_sample.csv                   34
# 1875  2023-03-01_13-51-03/47_1_10_2_sample.csv                   65
# 1930    2023-03-01_13-51-03/3_1_4_4_sample.csv                    6
# 1979  2023-03-01_13-51-03/11_1_10_2_sample.csv                   10
# 2030   2023-03-01_13-51-03/46_1_5_4_sample.csv                   76
# 2082   2023-03-01_13-51-03/24_1_9_3_sample.csv                  237
# 2137   2023-03-01_13-51-03/34_1_6_4_sample.csv                  144
# 2195    2023-03-01_13-51-03/7_1_9_3_sample.csv                   11
# 2249  2023-03-01_13-51-03/30_1_10_2_sample.csv                   25
# 2298  2023-03-01_13-51-03/17_1_10_3_sample.csv                   19
# 2355  2023-03-01_13-51-03/42_1_10_3_sample.csv                   66
#
#       lower_bound  optimized_sample_size  best_baseline  ...  mean_lns_ub  \
# 45            242                    334            444  ...   331.763636
# 103            30                     41             63  ...    40.040000
# 151             8                      8              9  ...     8.000000
# 214             7                      7              9  ...     7.000000
# 259            51                     58             89  ...    58.680000
# 311            31                     40             66  ...    40.420000
# 356            21                     21             35  ...    21.054545
# 418           145                    197            213  ...   196.345455
# 474           396                    396            398  ...   397.660000
# 510          1191                   4396           4396  ...  4402.750000
# 569             6                      6              8  ...     6.000000
# 618             9                      9             12  ...     9.000000
# 679             5                      5              9  ...     5.000000
# 727          1776                   1883           1883  ...  1928.900000
# 782            12                     12             21  ...    12.000000
# 837             8                      8              8  ...     8.000000
# 894            12                     17             29  ...    17.090909
# 949            11                     11             11  ...    11.000000
# 1004           12                     12             12  ...    12.000000
# 1050           24                     24             30  ...    24.000000
# 1111           16                     16             18  ...    16.000000
# 1169           14                     22             34  ...    21.163636
# 1221           21                     38             61  ...    37.400000
# 1275           28                     29             40  ...    29.000000
# 1331           10                     11             16  ...    11.000000
# 1374            8                      8             10  ...     8.000000
# 1443            7                      7              8  ...     7.000000
# 1499            5                      5              6  ...     5.000000
# 1540           10                     11             18  ...    11.000000
# 1602           19                     40             66  ...    40.137255
# 1660           37                     37             57  ...    37.000000
# 1713            9                     12             20  ...    12.000000
# 1767           15                     17             23  ...    17.000000
# 1824           31                     31             34  ...    31.000000
# 1875           29                     40             65  ...    41.020000
# 1930            6                      6              6  ...     6.000000
# 1979            8                      8             10  ...     8.000000
# 2030           26                     59             76  ...    59.555556
# 2082          224                    225            237  ...   225.127273
# 2137           82                     82            144  ...    82.000000
# 2195            8                      8             11  ...     8.000000
# 2249           16                     16             25  ...    16.000000
# 2298           15                     15             19  ...    15.000000
# 2355           25                     47             66  ...    48.740000
#
#       samplns_yasa              baseline         sampLNS  \
# 45           330.4        444/YASA(m=10)    322 (\O 332)
# 103           39.4          63/YASA(m=5)      38 (\O 40)
# 151            8.0           9/YASA(m=3)        8 (\O 8)
# 214            7.0          9/YASA(m=10)        7 (\O 7)
# 259           58.8    89/FIDE-YASA(m=10)      55 (\O 59)
# 311           40.2     66/FIDE-YASA(m=5)      39 (\O 40)
# 356           21.0         35/YASA(m=10)      21 (\O 21)
# 418          196.2        213/YASA(m=10)    196 (\O 196)
# 474          396.6        398/YASA(m=10)    396 (\O 398)
# 510         4417.0  4396/FIDE-YASA(m=10)  4396 (\O 4403)
# 569            6.0           8/YASA(m=3)        6 (\O 6)
# 618            9.0    12/FIDE-YASA(m=10)        9 (\O 9)
# 679            5.0      9/FIDE-YASA(m=3)        5 (\O 5)
# 727         1883.0        1883/YASA(m=1)  1883 (\O 1929)
# 782           12.0     21/FIDE-YASA(m=5)      12 (\O 12)
# 837            8.0           8/YASA(m=1)        8 (\O 8)
# 894           17.2         29/YASA(m=10)      17 (\O 17)
# 949           11.0     11/FIDE-YASA(m=3)      11 (\O 11)
# 1004          12.0     12/FIDE-YASA(m=3)      12 (\O 12)
# 1050          24.0    30/FIDE-YASA(m=10)      24 (\O 24)
# 1111          16.0         18/YASA(m=10)      16 (\O 16)
# 1169          21.4    34/FIDE-YASA(m=10)      21 (\O 21)
# 1221          37.2          61/YASA(m=5)      36 (\O 37)
# 1275          29.0         40/YASA(m=10)      29 (\O 29)
# 1331          11.0         16/YASA(m=10)      11 (\O 11)
# 1374           8.0         10/YASA(m=10)        8 (\O 8)
# 1443           7.0          8/YASA(m=10)        7 (\O 7)
# 1499           5.0      6/FIDE-YASA(m=5)        5 (\O 5)
# 1540          11.0    18/FIDE-YASA(m=10)      11 (\O 11)
# 1602          40.4     66/FIDE-YASA(m=3)      38 (\O 40)
# 1660          37.0     57/FIDE-YASA(m=5)      37 (\O 37)
# 1713          12.0     20/FIDE-YASA(m=5)      12 (\O 12)
# 1767          17.0    23/FIDE-YASA(m=10)      17 (\O 17)
# 1824          31.0         34/YASA(m=10)      31 (\O 31)
# 1875          41.4         65/YASA(m=10)      40 (\O 41)
# 1930           6.0      6/FIDE-YASA(m=3)        6 (\O 6)
# 1979           8.0         10/YASA(m=10)        8 (\O 8)
# 2030          59.0     76/FIDE-YASA(m=5)      55 (\O 60)
# 2082         225.0         237/YASA(m=5)    225 (\O 225)
# 2137          82.0   144/FIDE-YASA(m=10)      82 (\O 82)
# 2195           8.0          11/YASA(m=5)        8 (\O 8)
# 2249          16.0         25/YASA(m=10)      16 (\O 16)
# 2298          15.0         19/YASA(m=10)      15 (\O 15)
# 2355          47.6         66/YASA(m=10)      45 (\O 49)
#
#              instance_details  reduction rel_size_after_samplns    savings  \
# 45              BattleofTanks  25.585586              74.414414  25.585586
# 103                  XSEngine  37.460317              62.539683  37.460317
# 151   toybox_2006-10-31_23...  11.111111              88.888889  11.111111
# 214                       APL  22.222222              77.777778  22.222222
# 259                  aaed2000  33.932584              66.067416  33.932584
# 311           integrator_arm7  39.090909              60.909091  39.090909
# 356   busybox_2007-01-24_0...  40.000000              60.000000  40.000000
# 418   fiasco_2020-12-01_14...   7.887324              92.112676   7.887324
# 474             fs_2017-05-22   0.351759              99.648241   0.351759
# 510        financial_services  -0.477707             100.477707  -0.477707
# 569                       lcm  25.000000              75.000000  25.000000
# 618               SortingLine  25.000000              75.000000  25.000000
# 679                 calculate  44.444444              55.555556  44.444444
# 727                EMBToolkit   0.000000             100.000000   0.000000
# 782               berkeleyDB2  42.857143              57.142857  42.857143
# 837                    FameDB   0.000000             100.000000   0.000000
# 894            busybox-1_18_0  40.689655              59.310345  40.689655
# 949                  SafeBali   0.000000             100.000000   0.000000
# 1004                      PPU   0.000000             100.000000   0.000000
# 1050  soletta_2015-06-26_1...  20.000000              80.000000  20.000000
# 1111                      gpl  11.111111              88.888889  11.111111
# 1169  busybox_2020-12-16_2...  37.058824              62.941176  37.058824
# 1221                 am31_sim  39.016393              60.983607  39.016393
# 1275          BankingSoftware  27.500000              72.500000  27.500000
# 1331                    axTLS  31.250000              68.750000  31.250000
# 1374                APL-Model  20.000000              80.000000  20.000000
# 1443               ChatClient  12.500000              87.500000  12.500000
# 1499                      car  16.666667              83.333333  16.666667
# 1540  toybox_2020-12-06_00...  38.888889              61.111111  38.888889
# 1602         atlas_mips32_4kc  38.787879              61.212121  38.787879
# 1660  soletta_2017-03-09_2...  35.087719              64.912281  35.087719
# 1713                   E-Shop  40.000000              60.000000  40.000000
# 1767                   Violet  26.086957              73.913043  26.086957
# 1824                     dell   8.823529              91.176471   8.823529
# 1875                   ea2468  36.307692              63.692308  36.307692
# 1930                    email   0.000000             100.000000   0.000000
# 1979                 TightVNC  20.000000              80.000000  20.000000
# 2030            FreeBSD-8_0_0  22.368421              77.631579  22.368421
# 2082  fiasco_2017-09-26_11...   5.063291              94.936709   5.063291
# 2137        WaterlooGenerated  43.055556              56.944444  43.055556
# 2195               FeatureIDE  27.272727              72.727273  27.272727
# 2249                     DMIE  36.000000              64.000000  36.000000
# 2298              berkeleyDB1  21.052632              78.947368  21.052632
# 2355          eCos-3-0_i386pc  27.878788              72.121212  27.878788
#
#       opt_1  opt_2
# 45    False  False
# 103   False  False
# 151   False   True
# 214   False   True
# 259   False  False
# 311   False  False
# 356   False   True
# 418   False   True
# 474   False  False
# 510   False  False
# 569   False   True
# 618   False   True
# 679   False   True
# 727   False  False
# 782   False   True
# 837    True   True
# 894   False  False
# 949    True   True
# 1004   True   True
# 1050  False   True
# 1111  False   True
# 1169  False  False
# 1221  False  False
# 1275  False  False
# 1331  False  False
# 1374  False   True
# 1443  False   True
# 1499  False   True
# 1540  False  False
# 1602  False  False
# 1660  False   True
# 1713  False  False
# 1767  False  False
# 1824  False   True
# 1875  False  False
# 1930   True   True
# 1979  False   True
# 2030  False  False
# 2082  False   True
# 2137  False   True
# 2195  False   True
# 2249  False   True
# 2298  False   True
# 2355  False  False
#
# [44 rows x 22 columns]

# %%
# Code to query the time of the last change in lower or upper bound.

# Collect the data from the iteration_info events.
class EventCollector:
    def __init__(self):
        self.events = {
            "time": [],
            "val": [],
            "type": [],
            "instance": [],
            "path": [],
            "alg": [],
            "initial_sample_size": [],
            "y": [],
            "final": [],
        }

    def __call__(self, row):
        it_data = row["iteration_info"]

        def add(val, lbub, time, final=False):
            if time > 900:
                return
            self.events["time"].append(time / 60)
            self.events["val"].append(val)
            self.events["type"].append(lbub)
            self.events["instance"].append(row["instance"])
            self.events["alg"].append(row["baseline_alg"])
            self.events["path"].append(row["initial_sample_path"])
            self.events["initial_sample_size"].append(row["initial_sample_size"])
            self.events["y"].append(100 * (val / row["best_lb"]))
            self.events["final"].append(final)

        # add a zero entry
        add(0, "Lower", 0)
        add(row["initial_sample_size"], "Upper", 0)
        for event in it_data:
            add(event["lb"], "Lower", event["time"], final=event["lb"]==row["lower_bound"])
            add(event["ub"], "Upper", event["time"], final=event["ub"]==row["optimized_sample_size"])

instance_infos = data[
    ["instance", "#Variables", "#Clauses"]].drop_duplicates().sort_values(
    by=["#Variables", "#Clauses"])

ec = EventCollector()
data[data["baseline_alg"] == "FIDE-YASA(m=1)"].sort_values(
    by=["#Variables", "#Clauses"]).apply(ec, axis=1)
t_events = pd.DataFrame(ec.events)
t_ = t_events.groupby(["instance", "path"])["time"].max().reset_index()
unsolved_instances = t_[t_["time"] == 0]["instance"].unique().tolist()
solved_instances = [x for x in instance_infos["instance"].tolist() if
                    x not in unsolved_instances]

time_until_last_change = t_events[t_events["final"] & (t_events["instance"].isin(solved_instances))].groupby(["instance", "path", "type"])[["time"]].min().reset_index().groupby(["instance", "type"])[["time"]].mean()

unsolved_symbol = "$*$"
def get_time_info(instance):
    d = time_until_last_change.groupby("instance")["time"].max().to_dict()
    if instance not in d:
        return unsolved_symbol
    else:
        secs =  round(d[instance]*60)
        if secs == 0:
            return "$<\\SI{1}{\\second}$"
        return "\\SI{"+str(secs)+"}{\\second}"

# %%
tex_table = ""
def append(*args):
    global tex_table
    tex_table += f"{' '.join(str(x) for x in args)}\n"
t.sort_values(by=["#Variables", "#Clauses"], inplace=True)
for idx in t.index:
    unsolved = t["instance"][idx] in unsolved_instances
    append(t["instance_details"][idx].replace('_', '\\_'), "& \\num{", t["#Variables"][idx], "} & \\num{", t["#Clauses"][idx], "} &", ("\\textbf{" if t["opt_1"][idx] else "{")+"\\num[text-series-to-math=true]{", t["best_baseline"][idx], " }} &", unsolved_symbol if unsolved else (("\\textbf{" if t["opt_2"][idx] else "{")+"\\num[text-series-to-math=true]{"+ str( int(round(t["samplns_yasa"][idx])))+ "}}")," & \\num{", round(t["best_lb"][idx]), "} &", unsolved_symbol if unsolved else "\\SI{"+f"{round(t['savings'][idx], 2):.2g}"+"}{\\percent}", "&", get_time_info(t["instance"][idx]), "\\\\")

print(tex_table)
# Out:
# \begin{center}
# \begin{tabular}{ l c c c}
# Instance & $|\features|/|\clauses|$ & Baseline & SampLNS & Lower bound & Relative size\\
# \hline
# calculate & \num{ 9 } & \num{ 15 } & {\num[text-series-to-math=true]{ 9  }} & \textbf{\num[text-series-to-math=true]{5}}  & \num{ 5 } & \SI{44}{\percent} & $<\SI{1}{\second}$ \\
# lcm & \num{ 9 } & \num{ 16 } & {\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{6}}  & \num{ 6 } & \SI{25}{\percent} & $<\SI{1}{\second}$ \\
# email & \num{ 10 } & \num{ 17 } & \textbf{\num[text-series-to-math=true]{ 6  }} & \textbf{\num[text-series-to-math=true]{6}}  & \num{ 6 } & \SI{0}{\percent} & $<\SI{1}{\second}$ \\
# ChatClient & \num{ 14 } & \num{ 20 } & {\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{7}}  & \num{ 7 } & \SI{12}{\percent} & \SI{1}{\second} \\
# toybox\_2006-10-31\_23... & \num{ 16 } & \num{ 13 } & {\num[text-series-to-math=true]{ 9  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{11}{\percent} & \SI{2}{\second} \\
# car & \num{ 16 } & \num{ 33 } & {\num[text-series-to-math=true]{ 6  }} & \textbf{\num[text-series-to-math=true]{5}}  & \num{ 5 } & \SI{17}{\percent} & $<\SI{1}{\second}$ \\
# FeatureIDE & \num{ 19 } & \num{ 27 } & {\num[text-series-to-math=true]{ 11  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{27}{\percent} & \SI{114}{\second} \\
# FameDB & \num{ 22 } & \num{ 40 } & \textbf{\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{0}{\percent} & \SI{1}{\second} \\
# APL & \num{ 23 } & \num{ 35 } & {\num[text-series-to-math=true]{ 9  }} & \textbf{\num[text-series-to-math=true]{7}}  & \num{ 7 } & \SI{22}{\percent} & \SI{2}{\second} \\
# SafeBali & \num{ 24 } & \num{ 45 } & \textbf{\num[text-series-to-math=true]{ 11  }} & \textbf{\num[text-series-to-math=true]{11}}  & \num{ 11 } & \SI{0}{\percent} & $<\SI{1}{\second}$ \\
# TightVNC & \num{ 28 } & \num{ 39 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{20}{\percent} & \SI{42}{\second} \\
# APL-Model & \num{ 28 } & \num{ 40 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{20}{\percent} & \SI{28}{\second} \\
# gpl & \num{ 38 } & \num{ 99 } & {\num[text-series-to-math=true]{ 18  }} & \textbf{\num[text-series-to-math=true]{16}}  & \num{ 16 } & \SI{11}{\percent} & \SI{10}{\second} \\
# SortingLine & \num{ 39 } & \num{ 77 } & {\num[text-series-to-math=true]{ 12  }} & \textbf{\num[text-series-to-math=true]{9}}  & \num{ 9 } & \SI{25}{\percent} & \SI{24}{\second} \\
# dell & \num{ 46 } & \num{ 244 } & {\num[text-series-to-math=true]{ 34  }} & \textbf{\num[text-series-to-math=true]{31}}  & \num{ 31 } & \SI{8.8}{\percent} & \SI{58}{\second} \\
# PPU & \num{ 52 } & \num{ 109 } & \textbf{\num[text-series-to-math=true]{ 12  }} & \textbf{\num[text-series-to-math=true]{12}}  & \num{ 12 } & \SI{0}{\percent} & \SI{7}{\second} \\
# berkeleyDB1 & \num{ 76 } & \num{ 147 } & {\num[text-series-to-math=true]{ 19  }} & \textbf{\num[text-series-to-math=true]{15}}  & \num{ 15 } & \SI{21}{\percent} & \SI{192}{\second} \\
# axTLS & \num{ 96 } & \num{ 183 } & {\num[text-series-to-math=true]{ 16  }} & {\num[text-series-to-math=true]{11}}  & \num{ 10 } & \SI{31}{\percent} & \SI{40}{\second} \\
# Violet & \num{ 101 } & \num{ 203 } & {\num[text-series-to-math=true]{ 23  }} & {\num[text-series-to-math=true]{17}}  & \num{ 16 } & \SI{26}{\percent} & \SI{270}{\second} \\
# berkeleyDB2 & \num{ 119 } & \num{ 346 } & {\num[text-series-to-math=true]{ 21  }} & \textbf{\num[text-series-to-math=true]{12}}  & \num{ 12 } & \SI{43}{\percent} & \SI{265}{\second} \\
# soletta\_2015-06-26\_1... & \num{ 129 } & \num{ 192 } & {\num[text-series-to-math=true]{ 30  }} & \textbf{\num[text-series-to-math=true]{24}}  & \num{ 24 } & \SI{20}{\percent} & \SI{52}{\second} \\
# BattleofTanks & \num{ 144 } & \num{ 769 } & {\num[text-series-to-math=true]{ 444  }} & {\num[text-series-to-math=true]{330}}  & \num{ 256 } & \SI{26}{\percent} & \SI{871}{\second} \\
# BankingSoftware & \num{ 176 } & \num{ 280 } & {\num[text-series-to-math=true]{ 40  }} & {\num[text-series-to-math=true]{29}}  & \num{ 28 } & \SI{28}{\percent} & \SI{54}{\second} \\
# fiasco\_2017-09-26\_11... & \num{ 230 } & \num{ 1181 } & {\num[text-series-to-math=true]{ 237  }} & \textbf{\num[text-series-to-math=true]{225}}  & \num{ 225 } & \SI{5.1}{\percent} & \SI{550}{\second} \\
# fiasco\_2020-12-01\_14... & \num{ 258 } & \num{ 1542 } & {\num[text-series-to-math=true]{ 213  }} & \textbf{\num[text-series-to-math=true]{196}}  & \num{ 196 } & \SI{7.9}{\percent} & \SI{301}{\second} \\
# E-Shop & \num{ 326 } & \num{ 499 } & {\num[text-series-to-math=true]{ 20  }} & {\num[text-series-to-math=true]{12}}  & \num{ 10 } & \SI{40}{\percent} & \SI{496}{\second} \\
# toybox\_2020-12-06\_00... & \num{ 334 } & \num{ 92 } & {\num[text-series-to-math=true]{ 18  }} & {\num[text-series-to-math=true]{11}}  & \num{ 10 } & \SI{39}{\percent} & \SI{133}{\second} \\
# DMIE & \num{ 366 } & \num{ 627 } & {\num[text-series-to-math=true]{ 25  }} & \textbf{\num[text-series-to-math=true]{16}}  & \num{ 16 } & \SI{36}{\percent} & \SI{164}{\second} \\
# soletta\_2017-03-09\_2... & \num{ 458 } & \num{ 1862 } & {\num[text-series-to-math=true]{ 57  }} & \textbf{\num[text-series-to-math=true]{37}}  & \num{ 37 } & \SI{35}{\percent} & \SI{338}{\second} \\
# busybox\_2007-01-24\_0... & \num{ 540 } & \num{ 429 } & {\num[text-series-to-math=true]{ 35  }} & \textbf{\num[text-series-to-math=true]{21}}  & \num{ 21 } & \SI{40}{\percent} & \SI{292}{\second} \\
# fs\_2017-05-22 & \num{ 557 } & \num{ 4992 } & {\num[text-series-to-math=true]{ 398  }} & {\num[text-series-to-math=true]{397}}  & \num{ 396 } & \SI{0.35}{\percent} & \SI{717}{\second} \\
# WaterlooGenerated & \num{ 580 } & \num{ 879 } & {\num[text-series-to-math=true]{ 144  }} & \textbf{\num[text-series-to-math=true]{82}}  & \num{ 82 } & \SI{43}{\percent} & \SI{396}{\second} \\
# financial\_services & \num{ 771 } & \num{ 7238 } & {\num[text-series-to-math=true]{ 4396  }} & $*$  & \num{ 2731 } & $*$ & $*$ \\
# busybox-1\_18\_0 & \num{ 854 } & \num{ 1164 } & {\num[text-series-to-math=true]{ 29  }} & {\num[text-series-to-math=true]{17}}  & \num{ 13 } & \SI{41}{\percent} & \SI{327}{\second} \\
# busybox\_2020-12-16\_2... & \num{ 1050 } & \num{ 996 } & {\num[text-series-to-math=true]{ 34  }} & {\num[text-series-to-math=true]{21}}  & \num{ 20 } & \SI{37}{\percent} & \SI{617}{\second} \\
# am31\_sim & \num{ 1178 } & \num{ 2747 } & {\num[text-series-to-math=true]{ 61  }} & {\num[text-series-to-math=true]{37}}  & \num{ 29 } & \SI{39}{\percent} & \SI{587}{\second} \\
# EMBToolkit & \num{ 1179 } & \num{ 5414 } & {\num[text-series-to-math=true]{ 1883  }} & $*$  & \num{ 1872 } & $*$ & $*$ \\
# atlas\_mips32\_4kc & \num{ 1229 } & \num{ 2875 } & {\num[text-series-to-math=true]{ 66  }} & {\num[text-series-to-math=true]{40}}  & \num{ 33 } & \SI{39}{\percent} & \SI{714}{\second} \\
# eCos-3-0\_i386pc & \num{ 1245 } & \num{ 3723 } & {\num[text-series-to-math=true]{ 66  }} & {\num[text-series-to-math=true]{48}}  & \num{ 33 } & \SI{28}{\percent} & \SI{836}{\second} \\
# integrator\_arm7 & \num{ 1272 } & \num{ 2980 } & {\num[text-series-to-math=true]{ 66  }} & {\num[text-series-to-math=true]{40}}  & \num{ 33 } & \SI{39}{\percent} & \SI{684}{\second} \\
# XSEngine & \num{ 1273 } & \num{ 2942 } & {\num[text-series-to-math=true]{ 63  }} & {\num[text-series-to-math=true]{39}}  & \num{ 33 } & \SI{37}{\percent} & \SI{671}{\second} \\
# aaed2000 & \num{ 1298 } & \num{ 3036 } & {\num[text-series-to-math=true]{ 89  }} & {\num[text-series-to-math=true]{59}}  & \num{ 51 } & \SI{34}{\percent} & \SI{854}{\second} \\
# FreeBSD-8\_0\_0 & \num{ 1397 } & \num{ 15692 } & {\num[text-series-to-math=true]{ 76  }} & {\num[text-series-to-math=true]{59}}  & \num{ 30 } & \SI{22}{\percent} & \SI{867}{\second} \\
# ea2468 & \num{ 1408 } & \num{ 3319 } & {\num[text-series-to-math=true]{ 65  }} & {\num[text-series-to-math=true]{41}}  & \num{ 33 } & \SI{36}{\percent} & \SI{665}{\second} \\
# \end{tabular}
# \end{center}

# %%
len(t[t["best_baseline"]/t["best_lb"]<=1.1])
# Out:
# 9
