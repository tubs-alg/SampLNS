# %%
import pandas as pd

data = pd.read_json("./05_clean_data.json.zip")

# %%
# Find the best values for each instance as reference.
best_solutions = (
    data[["instance", "initial_sample_size", "optimized_sample_size"]]
    .groupby("instance")
    .min()
    .reset_index()
    .rename(
        columns={
            "initial_sample_size": "best_baseline",
            #"optimized_sample_size": "best_lns_ub",
        }
    )
)
best_lb = (
    data[["instance", "lower_bound"]]
    .groupby("instance")
    .max()
    .reset_index()
    .rename(columns={"lower_bound": "best_lb"})
)
mean_ub = (
    data[["instance", "optimized_sample_size"]]
    .groupby("instance")
    .mean()
    .reset_index()
    .rename(columns={"optimized_sample_size": "mean_lns_ub"})
)
mean_lb = (
    data[["instance", "lower_bound"]]
    .groupby("instance")
    .mean()
    .reset_index()
    .rename(columns={"lower_bound": "mean_lns_lb"})
)
best_values = best_solutions.merge(best_lb, left_on="instance", right_on="instance")
best_values = best_values.merge(mean_ub, left_on="instance", right_on="instance")
best_values = best_values.merge(mean_lb, left_on="instance", right_on="instance")

# %%
#samplns_yasa = (
#    data[data["baseline_alg"] == "YASA(m=1)"][["instance", "optimized_sample_size"]]
#    .groupby("instance")
#    .mean()
#    .reset_index()
   # .rename(columns={"optimized_sample_size": "samplns_yasa"})
#)
#best_values = best_values.merge(samplns_yasa, left_on="instance", right_on="instance")
best_values
# Out:
#                        instance  best_baseline  optimized_sample_size  \
# 0                           APL             10                      7
# 1                     APL-Model             15                      8
# 2               BankingSoftware             43                     29
# 3                 BattleofTanks            454                    340
# 4                    ChatClient              8                      7
# 5                          DMIE             27                     16
# 6                        E-Shop             22                     12
# 7                    EMBToolkit           1883                   1877
# 8                        FameDB              8                      8
# 9                    FeatureIDE             12                      8
# 10                FreeBSD-8_0_0             81                     61
# 11                          PPU             16                     12
# 12                     SafeBali             11                     11
# 13                  SortingLine             17                      9
# 14                     TightVNC             12                      8
# 15                       Violet             27                     17
# 16            WaterlooGenerated            149                     82
# 17                     XSEngine             69                     43
# 18                     aaed2000             95                     65
# 19                     am31_sim             65                     40
# 20             atlas_mips32_4kc             77                     43
# 21                        axTLS             17                     11
# 22                  berkeleyDB1             23                     15
# 23                  berkeleyDB2             22                     12
# 24               busybox-1_18_0             30                     18
# 25               busybox-1_29_2             44                     24
# 26  busybox_2007-01-24_09-14-09             39                     22
# 27  busybox_2020-12-16_21-53-05             39                     23
# 28                    calculate             10                      5
# 29                          car              7                      5
# 30                         dell             38                     31
# 31              eCos-3-0_i386pc             70                     51
# 32                       ea2468             72                     44
# 33                        email              7                      6
# 34   fiasco_2017-09-26_11-30-56            246                    225
# 35   fiasco_2020-12-01_14-09-14            224                    196
# 36           financial_services           4417                   4396
# 37                fs_2017-05-22            398                    396
# 38                          gpl             22                     16
# 39              integrator_arm7             71                     42
# 40                          lcm              8                      6
# 41  soletta_2015-06-26_18-38-56             32                     24
# 42   toybox_2006-10-31_23-30-06             10                      8
# 43   toybox_2020-12-06_00-02-46             20                     13
# 44   uclibc_2008-06-05_13-46-47            510                    505
# 45   uclibc_2020-12-24_11-54-53            369                    365
#
#     best_lb  mean_lns_ub  mean_lns_lb
# 0         7          7.0          7.0
# 1         7          8.0          7.0
# 2        28         29.0         28.0
# 3       256        345.6        256.0
# 4         7          7.0          7.0
# 5        16         16.2         15.6
# 6         8         12.6          8.0
# 7      1851       1877.6       1789.8
# 8         8          8.0          8.0
# 9         7          8.0          7.0
# 10       29         65.0         25.0
# 11       12         12.0         12.0
# 12       11         11.0          8.6
# 13        9          9.0          9.0
# 14        8          8.0          8.0
# 15       15         17.0         14.2
# 16       82         82.6         82.0
# 17       32         44.6         29.8
# 18       51         67.4         50.6
# 19       28         41.0         23.8
# 20       31         44.6         29.8
# 21       10         11.0         10.0
# 22       15         15.0         15.0
# 23       11         12.0         11.0
# 24       12         18.0         11.8
# 25       18         24.6         15.2
# 26       21         22.0         21.0
# 27       18         23.4         15.0
# 28        5          5.0          5.0
# 29        5          5.0          5.0
# 30       31         31.0         31.0
# 31       33         54.2         27.2
# 32       31         45.6         29.2
# 33        6          6.0          6.0
# 34      225        226.2        223.8
# 35      196        197.8        196.0
# 36     4201       4398.2       4110.6
# 37      396        396.0        396.0
# 38       16         16.0         16.0
# 39       33         44.8         30.4
# 40        6          6.0          6.0
# 41       24         24.0         23.8
# 42        8          8.0          8.0
# 43        7         13.8          7.0
# 44      505        505.0        505.0
# 45      365        365.0        365.0

# %%
data = data.merge(best_values, left_on="instance", right_on="instance")

# %%
t = data[data["initial_sample_size"] == data["best_baseline"]].drop_duplicates(
    subset=["instance"], keep="last"
)

# %%
t
# Out:
#                         instance  #Variables  #Clauses  \
# 4    busybox_2020-12-16_21-53-05        1050       996
# 9                          email          10        17
# 14             WaterlooGenerated         580       879
# 19                    FeatureIDE          19        27
# 24                      TightVNC          28        39
# 29                           car          16        33
# 34            financial_services         771      7238
# 39                busybox-1_29_2        1018       997
# 44                    ChatClient          14        20
# 49                     APL-Model          28        40
# 54    toybox_2020-12-06_00-02-46         334        92
# 59                    EMBToolkit        1179      5414
# 64   soletta_2015-06-26_18-38-56         129       192
# 69                      aaed2000        1298      3036
# 74                           gpl          38        99
# 79               eCos-3-0_i386pc        1245      3723
# 84                   berkeleyDB2         119       346
# 89   busybox_2007-01-24_09-14-09         540       429
# 94               BankingSoftware         176       280
# 99                      XSEngine        1273      2942
# 104                         DMIE         366       627
# 109                     SafeBali          24        45
# 114                          PPU          52       109
# 119                       ea2468        1408      3319
# 124   toybox_2006-10-31_23-30-06          16        13
# 129                FreeBSD-8_0_0        1397     15692
# 134               busybox-1_18_0         854      1164
# 139                       FameDB          22        40
# 144   fiasco_2017-09-26_11-30-56         230      1181
# 149                    calculate           9        15
# 154                       Violet         101       203
# 159                        axTLS          96       183
# 164                BattleofTanks         144       769
# 169   uclibc_2020-12-24_11-54-53         272      1670
# 174   uclibc_2008-06-05_13-46-47         263      1699
# 179                fs_2017-05-22         557      4992
# 184                     am31_sim        1178      2747
# 189                       E-Shop         326       499
# 194                  berkeleyDB1          76       147
# 199             atlas_mips32_4kc        1229      2875
# 204                          lcm           9        16
# 209                         dell          46       244
# 214                  SortingLine          39        77
# 219                          APL          23        35
# 224   fiasco_2020-12-01_14-09-14         258      1542
# 229              integrator_arm7        1272      2980
#
#                                         iteration_info baseline_alg  \
# 4    [{'nbrhd_tuples': 216, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 9    [{'nbrhd_tuples': 70, 'nbrhd_confs': 7, 'itera...    YASA(m=1)
# 14   [{'nbrhd_tuples': 237, 'nbrhd_confs': 31, 'ite...    YASA(m=1)
# 19   [{'nbrhd_tuples': 231, 'nbrhd_confs': 9, 'iter...    YASA(m=1)
# 24   [{'nbrhd_tuples': 230, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 29   [{'nbrhd_tuples': 77, 'nbrhd_confs': 7, 'itera...    YASA(m=1)
# 34   [{'nbrhd_tuples': 249, 'nbrhd_confs': 159, 'it...    YASA(m=1)
# 39   [{'nbrhd_tuples': 184, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 44   [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 49   [{'nbrhd_tuples': 171, 'nbrhd_confs': 11, 'ite...    YASA(m=1)
# 54   [{'nbrhd_tuples': 228, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 59   [{'nbrhd_tuples': 246, 'nbrhd_confs': 102, 'it...    YASA(m=1)
# 64   [{'nbrhd_tuples': 228, 'nbrhd_confs': 13, 'ite...    YASA(m=1)
# 69   [{'nbrhd_tuples': 219, 'nbrhd_confs': 4, 'iter...    YASA(m=1)
# 74   [{'nbrhd_tuples': 224, 'nbrhd_confs': 17, 'ite...    YASA(m=1)
# 79   [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...    YASA(m=1)
# 84   [{'nbrhd_tuples': 232, 'nbrhd_confs': 4, 'iter...    YASA(m=1)
# 89   [{'nbrhd_tuples': 237, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 94   [{'nbrhd_tuples': 229, 'nbrhd_confs': 14, 'ite...    YASA(m=1)
# 99   [{'nbrhd_tuples': 232, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 104  [{'nbrhd_tuples': 241, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 109  [{'nbrhd_tuples': 141, 'nbrhd_confs': 11, 'ite...    YASA(m=1)
# 114  [{'nbrhd_tuples': 234, 'nbrhd_confs': 10, 'ite...    YASA(m=1)
# 119  [{'nbrhd_tuples': 123, 'nbrhd_confs': 6, 'iter...    YASA(m=1)
# 124  [{'nbrhd_tuples': 245, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 129  [{'nbrhd_tuples': 234, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 134  [{'nbrhd_tuples': 79, 'nbrhd_confs': 2, 'itera...    YASA(m=1)
# 139  [{'nbrhd_tuples': 224, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 144  [{'nbrhd_tuples': 241, 'nbrhd_confs': 21, 'ite...    YASA(m=1)
# 149  [{'nbrhd_tuples': 38, 'nbrhd_confs': 10, 'iter...    YASA(m=1)
# 154  [{'nbrhd_tuples': 178, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 159  [{'nbrhd_tuples': 179, 'nbrhd_confs': 6, 'iter...    YASA(m=1)
# 164  [{'nbrhd_tuples': 247, 'nbrhd_confs': 80, 'ite...    YASA(m=1)
# 169  [{'nbrhd_tuples': 228, 'nbrhd_confs': 39, 'ite...    YASA(m=1)
# 174  [{'nbrhd_tuples': 247, 'nbrhd_confs': 44, 'ite...    YASA(m=1)
# 179  [{'nbrhd_tuples': 3, 'nbrhd_confs': 1, 'iterat...    YASA(m=1)
# 184  [{'nbrhd_tuples': 61, 'nbrhd_confs': 3, 'itera...    YASA(m=1)
# 189  [{'nbrhd_tuples': 149, 'nbrhd_confs': 4, 'iter...    YASA(m=1)
# 194  [{'nbrhd_tuples': 238, 'nbrhd_confs': 11, 'ite...    YASA(m=1)
# 199  [{'nbrhd_tuples': 215, 'nbrhd_confs': 9, 'iter...    YASA(m=1)
# 204  [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...    YASA(m=1)
# 209  [{'nbrhd_tuples': 248, 'nbrhd_confs': 23, 'ite...    YASA(m=1)
# 214  [{'nbrhd_tuples': 206, 'nbrhd_confs': 12, 'ite...    YASA(m=1)
# 219  [{'nbrhd_tuples': 207, 'nbrhd_confs': 9, 'iter...    YASA(m=1)
# 224  [{'nbrhd_tuples': 236, 'nbrhd_confs': 19, 'ite...    YASA(m=1)
# 229  [{'nbrhd_tuples': 188, 'nbrhd_confs': 6, 'iter...    YASA(m=1)
#
#                          initial_sample_path  initial_sample_size  \
# 4    2023-03-01_13-51-03/38_1_7_1_sample.csv                   39
# 9     2023-03-01_13-51-03/3_1_7_4_sample.csv                    7
# 14   2023-03-01_13-51-03/34_1_7_3_sample.csv                  149
# 19    2023-03-01_13-51-03/7_1_7_1_sample.csv                   12
# 24   2023-03-01_13-51-03/11_1_7_4_sample.csv                   12
# 29    2023-03-01_13-51-03/6_1_7_2_sample.csv                    7
# 34   2023-03-01_13-51-03/35_1_7_5_sample.csv                 4417
# 39   2023-03-01_13-51-03/37_1_7_1_sample.csv                   44
# 44    2023-03-01_13-51-03/4_1_7_5_sample.csv                    8
# 49   2023-03-01_13-51-03/12_1_7_2_sample.csv                   15
# 54   2023-03-01_13-51-03/29_1_7_1_sample.csv                   20
# 59   2023-03-01_13-51-03/40_1_7_1_sample.csv                 1883
# 64   2023-03-01_13-51-03/21_1_7_2_sample.csv                   32
# 69   2023-03-01_13-51-03/45_1_7_1_sample.csv                   95
# 74   2023-03-01_13-51-03/13_1_7_2_sample.csv                   22
# 79   2023-03-01_13-51-03/42_1_7_2_sample.csv                   70
# 84   2023-03-01_13-51-03/20_1_7_5_sample.csv                   22
# 89   2023-03-01_13-51-03/32_1_7_1_sample.csv                   39
# 94   2023-03-01_13-51-03/23_1_7_5_sample.csv                   43
# 99   2023-03-01_13-51-03/44_1_7_5_sample.csv                   69
# 104  2023-03-01_13-51-03/30_1_7_5_sample.csv                   27
# 109  2023-03-01_13-51-03/10_1_7_4_sample.csv                   11
# 114  2023-03-01_13-51-03/16_1_7_1_sample.csv                   16
# 119  2023-03-01_13-51-03/47_1_7_3_sample.csv                   72
# 124   2023-03-01_13-51-03/5_1_7_1_sample.csv                   10
# 129  2023-03-01_13-51-03/46_1_7_4_sample.csv                   81
# 134  2023-03-01_13-51-03/36_1_7_3_sample.csv                   30
# 139   2023-03-01_13-51-03/8_1_7_3_sample.csv                    8
# 144  2023-03-01_13-51-03/24_1_7_1_sample.csv                  246
# 149   2023-03-01_13-51-03/1_1_7_1_sample.csv                   10
# 154  2023-03-01_13-51-03/19_1_7_1_sample.csv                   27
# 159  2023-03-01_13-51-03/18_1_7_4_sample.csv                   17
# 164  2023-03-01_13-51-03/22_1_7_3_sample.csv                  454
# 169  2023-03-01_13-51-03/27_1_7_5_sample.csv                  369
# 174  2023-03-01_13-51-03/26_1_7_3_sample.csv                  510
# 179  2023-03-01_13-51-03/33_1_7_4_sample.csv                  398
# 184  2023-03-01_13-51-03/39_1_7_5_sample.csv                   65
# 189  2023-03-01_13-51-03/28_1_7_3_sample.csv                   22
# 194  2023-03-01_13-51-03/17_1_7_2_sample.csv                   23
# 199  2023-03-01_13-51-03/41_1_7_3_sample.csv                   77
# 204   2023-03-01_13-51-03/2_1_7_2_sample.csv                    8
# 209  2023-03-01_13-51-03/15_1_7_4_sample.csv                   38
# 214  2023-03-01_13-51-03/14_1_7_3_sample.csv                   17
# 219   2023-03-01_13-51-03/9_1_7_2_sample.csv                   10
# 224  2023-03-01_13-51-03/25_1_7_3_sample.csv                  224
# 229  2023-03-01_13-51-03/43_1_7_3_sample.csv                   71
#
#      lower_bound  optimized_sample_size_x  time_used_by_yasa  \
# 4             14                       23              2.273
# 9              6                        6              0.202
# 14            82                       82              1.434
# 19             7                        8              0.234
# 24             8                        8              0.219
# 29             5                        5              0.208
# 34          3904                     4396             45.284
# 39            10                       25              2.305
# 44             7                        7              0.211
# 49             7                        8              0.192
# 54             7                       14              0.462
# 59          1842                     1879             34.135
# 64            24                       24              0.293
# 69            51                       68              3.826
# 74            16                       16              0.252
# 79            29                       58              4.101
# 84            11                       12              0.294
# 89            21                       22              0.897
# 94            28                       29              0.339
# 99            28                       45              3.352
# 104           14                       17              0.597
# 109           11                       11              0.225
# 114           12                       12              0.220
# 119           27                       45              3.615
# 124            8                        8              0.202
# 129           29                       61             11.962
# 134           12                       18              1.283
# 139            8                        8              0.226
# 144          224                      225              0.968
# 149            5                        5              0.214
# 154           14                       17              0.288
# 159           10                       11              0.256
# 164          256                      340              0.635
# 169          365                      365              1.219
# 174          505                      505              1.483
# 179          396                      396              2.575
# 184           21                       44              2.925
# 189            8                       13              0.476
# 194           15                       15              0.276
# 199           30                       45              3.285
# 204            6                        6              0.201
# 209           31                       31              0.250
# 214            9                        9              0.202
# 219            7                        7              0.189
# 224          196                      196              1.152
# 229           33                       42              3.384
#
#      timelimit_for_samplns  samplns_used  best_baseline  \
# 4                  897.727          True             39
# 9                  899.798          True              7
# 14                 898.566          True            149
# 19                 899.766          True             12
# 24                 899.781          True             12
# 29                 899.792          True              7
# 34                 854.716          True           4417
# 39                 897.695          True             44
# 44                 899.789          True              8
# 49                 899.808          True             15
# 54                 899.538          True             20
# 59                 865.865          True           1883
# 64                 899.707          True             32
# 69                 896.174          True             95
# 74                 899.748          True             22
# 79                 895.899          True             70
# 84                 899.706          True             22
# 89                 899.103          True             39
# 94                 899.661          True             43
# 99                 896.648          True             69
# 104                899.403          True             27
# 109                899.775          True             11
# 114                899.780          True             16
# 119                896.385          True             72
# 124                899.798          True             10
# 129                888.038          True             81
# 134                898.717          True             30
# 139                899.774          True              8
# 144                899.032          True            246
# 149                899.786          True             10
# 154                899.712          True             27
# 159                899.744          True             17
# 164                899.365          True            454
# 169                898.781          True            369
# 174                898.517          True            510
# 179                897.425          True            398
# 184                897.075          True             65
# 189                899.524          True             22
# 194                899.724          True             23
# 199                896.715          True             77
# 204                899.799          True              8
# 209                899.750          True             38
# 214                899.798          True             17
# 219                899.811          True             10
# 224                898.848          True            224
# 229                896.616          True             71
#
#      optimized_sample_size_y  best_lb  mean_lns_ub  mean_lns_lb
# 4                         23       18         23.4         15.0
# 9                          6        6          6.0          6.0
# 14                        82       82         82.6         82.0
# 19                         8        7          8.0          7.0
# 24                         8        8          8.0          8.0
# 29                         5        5          5.0          5.0
# 34                      4396     4201       4398.2       4110.6
# 39                        24       18         24.6         15.2
# 44                         7        7          7.0          7.0
# 49                         8        7          8.0          7.0
# 54                        13        7         13.8          7.0
# 59                      1877     1851       1877.6       1789.8
# 64                        24       24         24.0         23.8
# 69                        65       51         67.4         50.6
# 74                        16       16         16.0         16.0
# 79                        51       33         54.2         27.2
# 84                        12       11         12.0         11.0
# 89                        22       21         22.0         21.0
# 94                        29       28         29.0         28.0
# 99                        43       32         44.6         29.8
# 104                       16       16         16.2         15.6
# 109                       11       11         11.0          8.6
# 114                       12       12         12.0         12.0
# 119                       44       31         45.6         29.2
# 124                        8        8          8.0          8.0
# 129                       61       29         65.0         25.0
# 134                       18       12         18.0         11.8
# 139                        8        8          8.0          8.0
# 144                      225      225        226.2        223.8
# 149                        5        5          5.0          5.0
# 154                       17       15         17.0         14.2
# 159                       11       10         11.0         10.0
# 164                      340      256        345.6        256.0
# 169                      365      365        365.0        365.0
# 174                      505      505        505.0        505.0
# 179                      396      396        396.0        396.0
# 184                       40       28         41.0         23.8
# 189                       12        8         12.6          8.0
# 194                       15       15         15.0         15.0
# 199                       43       31         44.6         29.8
# 204                        6        6          6.0          6.0
# 209                       31       31         31.0         31.0
# 214                        9        9          9.0          9.0
# 219                        7        7          7.0          7.0
# 224                      196      196        197.8        196.0
# 229                       42       33         44.8         30.4

# %%
t["baseline"] = t.apply(
    (lambda row: f"{row['initial_sample_size']}/{row['baseline_alg']}"), axis=1
)
t["sampLNS"] = t.apply(
    (lambda row: f"{row['best_lns_ub']} (\\O {int(round(row['mean_lns_ub']))})"), axis=1
)


def shorten(s):
    if len(s) > 23:
        return s[:20] + "..."
    return s


# t["instance_details"] = t.apply((lambda row: f"{shorten(row['instance'])} ({row['#Variables']}/{row['#Clauses']})"), axis=1)
t["instance_details"] = t.apply((lambda row: f"{shorten(row['instance'])}"), axis=1)
t["reduction"] = 100 * (1 - t["samplns_yasa"] / t["best_baseline"])
t["rel_size_after_samplns"] = 100 * (t["samplns_yasa"] / t["best_baseline"])
t["savings"] = 100 * (1 - t["samplns_yasa"] / t["best_baseline"])
t["opt_1"] = t["best_baseline"] == t["best_lb"]
t["opt_2"] = t["samplns_yasa"].apply(lambda x: round(x)) == t["best_lb"]
t
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'best_lns_ub'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 4
#       1 t["baseline"] = t.apply(
#       2     (lambda row: f"{row['initial_sample_size']}/{row['baseline_alg']}"), axis=1
#       3 )
# ----> 4 t["sampLNS"] = t.apply(
#       5     (lambda row: f"{row['best_lns_ub']} (\\O {int(round(row['mean_lns_ub']))})"), axis=1
#       6 )
#       9 def shorten(s):
#      10     if len(s) > 23:
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[49], line 5, in <lambda>(row)
#       1 t["baseline"] = t.apply(
#       2     (lambda row: f"{row['initial_sample_size']}/{row['baseline_alg']}"), axis=1
#       3 )
#       4 t["sampLNS"] = t.apply(
# ----> 5     (lambda row: f"{row['best_lns_ub']} (\\O {int(round(row['mean_lns_ub']))})"), axis=1
#       6 )
#       9 def shorten(s):
#      10     if len(s) > 23:
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/mo310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'best_lns_ub'

# %%
# Code to query the time of the last change in lower or upper bound.


# Collect the data from the iteration_info events.
class EventCollector:
    def __init__(self):
        self.events = {
            "time": [],
            "val": [],
            "type": [],
            "instance": [],
            "path": [],
            "alg": [],
            "initial_sample_size": [],
            "y": [],
            "final": [],
        }

    def __call__(self, row):
        it_data = row["iteration_info"]

        def add(val, lbub, time, final=False):
            if time > 900:
                return
            self.events["time"].append(time / 60)
            self.events["val"].append(val)
            self.events["type"].append(lbub)
            self.events["instance"].append(row["instance"])
            self.events["alg"].append(row["baseline_alg"])
            self.events["path"].append(row["initial_sample_path"])
            self.events["initial_sample_size"].append(row["initial_sample_size"])
            self.events["y"].append(100 * (val / row["best_lb"]))
            self.events["final"].append(final)

        # add a zero entry
        add(0, "Lower", 0)
        add(row["initial_sample_size"], "Upper", 0)
        for event in it_data:
            add(
                event["lb"],
                "Lower",
                event["time"],
                final=event["lb"] == row["lower_bound"],
            )
            add(
                event["ub"],
                "Upper",
                event["time"],
                final=event["ub"] == row["optimized_sample_size"],
            )


instance_infos = (
    data[["instance", "#Variables", "#Clauses"]]
    .drop_duplicates()
    .sort_values(by=["#Variables", "#Clauses"])
)

ec = EventCollector()
data[data["baseline_alg"] == "FIDE-YASA(m=1)"].sort_values(
    by=["#Variables", "#Clauses"]
).apply(ec, axis=1)
t_events = pd.DataFrame(ec.events)
t_ = t_events.groupby(["instance", "path"])["time"].max().reset_index()
unsolved_instances = t_[t_["time"] == 0]["instance"].unique().tolist()
solved_instances = [
    x for x in instance_infos["instance"].tolist() if x not in unsolved_instances
]

time_until_last_change = (
    t_events[t_events["final"] & (t_events["instance"].isin(solved_instances))]
    .groupby(["instance", "path", "type"])[["time"]]
    .min()
    .reset_index()
    .groupby(["instance", "type"])[["time"]]
    .mean()
)

unsolved_symbol = "$*$"


def get_time_info(instance):
    d = time_until_last_change.groupby("instance")["time"].max().to_dict()
    if instance not in d:
        return unsolved_symbol
    else:
        secs = round(d[instance] * 60)
        if secs == 0:
            return "$<\\SI{1}{\\second}$"
        return "\\SI{" + str(secs) + "}{\\second}"

# %%
tex_table = ""


def append(*args):
    global tex_table
    tex_table += f"{' '.join(str(x) for x in args)}\n"


t.sort_values(by=["#Variables", "#Clauses"], inplace=True)
for idx in t.index:
    unsolved = t["instance"][idx] in unsolved_instances
    append(
        t["instance_details"][idx].replace("_", "\\_"),
        "& \\num{",
        t["#Variables"][idx],
        "} & \\num{",
        t["#Clauses"][idx],
        "} &",
        ("\\textbf{" if t["opt_1"][idx] else "{") + "\\num[text-series-to-math=true]{",
        t["best_baseline"][idx],
        " }} &",
        unsolved_symbol
        if unsolved
        else (
            ("\\textbf{" if t["opt_2"][idx] else "{")
            + "\\num[text-series-to-math=true]{"
            + str(int(round(t["samplns_yasa"][idx])))
            + "}}"
        ),
        " & \\num{",
        round(t["best_lb"][idx]),
        "} &",
        unsolved_symbol
        if unsolved
        else "\\SI{" + f"{round(t['savings'][idx], 2):.2g}" + "}{\\percent}",
        "&",
        get_time_info(t["instance"][idx]),
        "\\\\",
    )

print(tex_table)
# Out:
# calculate & \num{ 9 } & \num{ 15 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{5}}  & \num{ 5 } & \SI{50}{\percent} & $*$ \\
# lcm & \num{ 9 } & \num{ 16 } & {\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{6}}  & \num{ 6 } & \SI{25}{\percent} & $*$ \\
# email & \num{ 10 } & \num{ 17 } & {\num[text-series-to-math=true]{ 7  }} & \textbf{\num[text-series-to-math=true]{6}}  & \num{ 6 } & \SI{14}{\percent} & $*$ \\
# ChatClient & \num{ 14 } & \num{ 20 } & {\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{7}}  & \num{ 7 } & \SI{12}{\percent} & $*$ \\
# toybox\_2006-10-31\_23... & \num{ 16 } & \num{ 13 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{20}{\percent} & $*$ \\
# car & \num{ 16 } & \num{ 33 } & {\num[text-series-to-math=true]{ 7  }} & \textbf{\num[text-series-to-math=true]{5}}  & \num{ 5 } & \SI{29}{\percent} & $*$ \\
# FeatureIDE & \num{ 19 } & \num{ 27 } & {\num[text-series-to-math=true]{ 12  }} & {\num[text-series-to-math=true]{8}}  & \num{ 7 } & \SI{33}{\percent} & $*$ \\
# FameDB & \num{ 22 } & \num{ 40 } & \textbf{\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{0}{\percent} & $*$ \\
# APL & \num{ 23 } & \num{ 35 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{7}}  & \num{ 7 } & \SI{30}{\percent} & $*$ \\
# SafeBali & \num{ 24 } & \num{ 45 } & \textbf{\num[text-series-to-math=true]{ 11  }} & \textbf{\num[text-series-to-math=true]{11}}  & \num{ 11 } & \SI{0}{\percent} & $*$ \\
# TightVNC & \num{ 28 } & \num{ 39 } & {\num[text-series-to-math=true]{ 12  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{33}{\percent} & $*$ \\
# APL-Model & \num{ 28 } & \num{ 40 } & {\num[text-series-to-math=true]{ 15  }} & {\num[text-series-to-math=true]{8}}  & \num{ 7 } & \SI{47}{\percent} & $*$ \\
# gpl & \num{ 38 } & \num{ 99 } & {\num[text-series-to-math=true]{ 22  }} & \textbf{\num[text-series-to-math=true]{16}}  & \num{ 16 } & \SI{27}{\percent} & $*$ \\
# SortingLine & \num{ 39 } & \num{ 77 } & {\num[text-series-to-math=true]{ 17  }} & \textbf{\num[text-series-to-math=true]{9}}  & \num{ 9 } & \SI{47}{\percent} & $*$ \\
# dell & \num{ 46 } & \num{ 244 } & {\num[text-series-to-math=true]{ 38  }} & \textbf{\num[text-series-to-math=true]{31}}  & \num{ 31 } & \SI{18}{\percent} & $*$ \\
# PPU & \num{ 52 } & \num{ 109 } & {\num[text-series-to-math=true]{ 16  }} & \textbf{\num[text-series-to-math=true]{12}}  & \num{ 12 } & \SI{25}{\percent} & $*$ \\
# berkeleyDB1 & \num{ 76 } & \num{ 147 } & {\num[text-series-to-math=true]{ 23  }} & \textbf{\num[text-series-to-math=true]{15}}  & \num{ 15 } & \SI{35}{\percent} & $*$ \\
# axTLS & \num{ 96 } & \num{ 183 } & {\num[text-series-to-math=true]{ 17  }} & {\num[text-series-to-math=true]{11}}  & \num{ 10 } & \SI{35}{\percent} & $*$ \\
# Violet & \num{ 101 } & \num{ 203 } & {\num[text-series-to-math=true]{ 27  }} & {\num[text-series-to-math=true]{17}}  & \num{ 15 } & \SI{37}{\percent} & $*$ \\
# berkeleyDB2 & \num{ 119 } & \num{ 346 } & {\num[text-series-to-math=true]{ 22  }} & {\num[text-series-to-math=true]{12}}  & \num{ 11 } & \SI{45}{\percent} & $*$ \\
# soletta\_2015-06-26\_1... & \num{ 129 } & \num{ 192 } & {\num[text-series-to-math=true]{ 32  }} & \textbf{\num[text-series-to-math=true]{24}}  & \num{ 24 } & \SI{25}{\percent} & $*$ \\
# BattleofTanks & \num{ 144 } & \num{ 769 } & {\num[text-series-to-math=true]{ 454  }} & {\num[text-series-to-math=true]{346}}  & \num{ 256 } & \SI{24}{\percent} & $*$ \\
# BankingSoftware & \num{ 176 } & \num{ 280 } & {\num[text-series-to-math=true]{ 43  }} & {\num[text-series-to-math=true]{29}}  & \num{ 28 } & \SI{33}{\percent} & $*$ \\
# fiasco\_2017-09-26\_11... & \num{ 230 } & \num{ 1181 } & {\num[text-series-to-math=true]{ 246  }} & {\num[text-series-to-math=true]{226}}  & \num{ 225 } & \SI{8.1}{\percent} & $*$ \\
# fiasco\_2020-12-01\_14... & \num{ 258 } & \num{ 1542 } & {\num[text-series-to-math=true]{ 224  }} & {\num[text-series-to-math=true]{198}}  & \num{ 196 } & \SI{12}{\percent} & $*$ \\
# uclibc\_2008-06-05\_13... & \num{ 263 } & \num{ 1699 } & {\num[text-series-to-math=true]{ 510  }} & \textbf{\num[text-series-to-math=true]{505}}  & \num{ 505 } & \SI{0.98}{\percent} & $*$ \\
# uclibc\_2020-12-24\_11... & \num{ 272 } & \num{ 1670 } & {\num[text-series-to-math=true]{ 369  }} & \textbf{\num[text-series-to-math=true]{365}}  & \num{ 365 } & \SI{1.1}{\percent} & $*$ \\
# E-Shop & \num{ 326 } & \num{ 499 } & {\num[text-series-to-math=true]{ 22  }} & {\num[text-series-to-math=true]{12}}  & \num{ 8 } & \SI{43}{\percent} & $*$ \\
# toybox\_2020-12-06\_00... & \num{ 334 } & \num{ 92 } & {\num[text-series-to-math=true]{ 20  }} & {\num[text-series-to-math=true]{14}}  & \num{ 7 } & \SI{30}{\percent} & $*$ \\
# DMIE & \num{ 366 } & \num{ 627 } & {\num[text-series-to-math=true]{ 27  }} & \textbf{\num[text-series-to-math=true]{16}}  & \num{ 16 } & \SI{41}{\percent} & $*$ \\
# busybox\_2007-01-24\_0... & \num{ 540 } & \num{ 429 } & {\num[text-series-to-math=true]{ 39  }} & {\num[text-series-to-math=true]{22}}  & \num{ 21 } & \SI{44}{\percent} & $*$ \\
# fs\_2017-05-22 & \num{ 557 } & \num{ 4992 } & {\num[text-series-to-math=true]{ 398  }} & \textbf{\num[text-series-to-math=true]{396}}  & \num{ 396 } & \SI{0.5}{\percent} & $*$ \\
# WaterlooGenerated & \num{ 580 } & \num{ 879 } & {\num[text-series-to-math=true]{ 149  }} & {\num[text-series-to-math=true]{83}}  & \num{ 82 } & \SI{45}{\percent} & $*$ \\
# financial\_services & \num{ 771 } & \num{ 7238 } & {\num[text-series-to-math=true]{ 4417  }} & {\num[text-series-to-math=true]{4399}}  & \num{ 4201 } & \SI{0.41}{\percent} & $*$ \\
# busybox-1\_18\_0 & \num{ 854 } & \num{ 1164 } & {\num[text-series-to-math=true]{ 30  }} & {\num[text-series-to-math=true]{18}}  & \num{ 12 } & \SI{40}{\percent} & $*$ \\
# busybox-1\_29\_2 & \num{ 1018 } & \num{ 997 } & {\num[text-series-to-math=true]{ 44  }} & {\num[text-series-to-math=true]{25}}  & \num{ 18 } & \SI{43}{\percent} & $*$ \\
# busybox\_2020-12-16\_2... & \num{ 1050 } & \num{ 996 } & {\num[text-series-to-math=true]{ 39  }} & {\num[text-series-to-math=true]{23}}  & \num{ 18 } & \SI{40}{\percent} & $*$ \\
# am31\_sim & \num{ 1178 } & \num{ 2747 } & {\num[text-series-to-math=true]{ 65  }} & {\num[text-series-to-math=true]{40}}  & \num{ 28 } & \SI{38}{\percent} & $*$ \\
# EMBToolkit & \num{ 1179 } & \num{ 5414 } & {\num[text-series-to-math=true]{ 1883  }} & {\num[text-series-to-math=true]{1878}}  & \num{ 1851 } & \SI{0.29}{\percent} & $*$ \\
# atlas\_mips32\_4kc & \num{ 1229 } & \num{ 2875 } & {\num[text-series-to-math=true]{ 77  }} & {\num[text-series-to-math=true]{44}}  & \num{ 31 } & \SI{44}{\percent} & $*$ \\
# eCos-3-0\_i386pc & \num{ 1245 } & \num{ 3723 } & {\num[text-series-to-math=true]{ 70  }} & {\num[text-series-to-math=true]{53}}  & \num{ 33 } & \SI{24}{\percent} & $*$ \\
# integrator\_arm7 & \num{ 1272 } & \num{ 2980 } & {\num[text-series-to-math=true]{ 71  }} & {\num[text-series-to-math=true]{46}}  & \num{ 32 } & \SI{36}{\percent} & $*$ \\
# XSEngine & \num{ 1273 } & \num{ 2942 } & {\num[text-series-to-math=true]{ 69  }} & {\num[text-series-to-math=true]{44}}  & \num{ 32 } & \SI{37}{\percent} & $*$ \\
# aaed2000 & \num{ 1298 } & \num{ 3036 } & {\num[text-series-to-math=true]{ 95  }} & {\num[text-series-to-math=true]{67}}  & \num{ 51 } & \SI{29}{\percent} & $*$ \\
# FreeBSD-8\_0\_0 & \num{ 1397 } & \num{ 15692 } & {\num[text-series-to-math=true]{ 81  }} & {\num[text-series-to-math=true]{66}}  & \num{ 26 } & \SI{19}{\percent} & $*$ \\
# ea2468 & \num{ 1408 } & \num{ 3319 } & {\num[text-series-to-math=true]{ 72  }} & {\num[text-series-to-math=true]{46}}  & \num{ 31 } & \SI{37}{\percent} & $*$ \\

# %%
len(t[t["best_baseline"] / t["best_lb"] <= 1.1])
# Out:
# 8
