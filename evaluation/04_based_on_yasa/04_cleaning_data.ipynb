# %% [markdown]
# # Cleaning the data and providing a small and easily parsable database.
#
# The database with the full logs is too huge to work on. Most of the data would only be needed for debugging but not for evaluation.
# Thus, we create a clean and small database for the further evaluation.

# %%
from _conf import ITERATIONS, ITERATION_TIME_LIMIT, TIME_LIMIT, BASE, RESULT_FOLDER, INPUT_SAMPLE_ARCHIVE, INSTANCE_ARCHIVE

# %%
from algbench import read_as_pandas, Benchmark
from _utils import parse_solution_overview, parse_sample


def get_results(input_sample_archive, result_folder, max_vars=1500):
    # Loading the data of the experiment.

    # Merge the new data with the data of the initial samples
    data = read_as_pandas(
        result_folder,
        lambda result: {
            "parameters": result["parameters"],
            "initial_sample_path": result["parameters"]["args"]["initial_sample_path"],
            "instance_name": result["parameters"]["args"]["instance_name"],
            "lower_bound": result["result"]["lower_bound"],
            "upper_bound": len(result["result"]["solution"]),
            "iteration_info": result["result"]["iteration_info"],
            "time_used_by_yasa": result["result"]["time_used_by_yasa"],
            "timelimit_for_samplns": result["result"]["timelimit_for_samplns"],
            "samplns_used": result["result"]["samplns_used"],
            "instance": result["parameters"]["args"]["instance_name"],
        } if result.get("result", None) and  result.get("result", dict()).get("solution", None) else None,
    )

    data_initial = parse_solution_overview(input_sample_archive)
    data = data.merge(data_initial, left_on="initial_sample_path", right_on="Path")

    # add a good name for 00_baseline algorithms including the settings
    def baseline_alg_name(row):
        settings = row["Settings"]
        if "_m" in settings:
            m = settings.split("_m")[-1].split("_")[0]
            return f"{row['Algorithm']}(m={m})"
        return row["Algorithm"]

    data["baseline_alg"] = data.apply(baseline_alg_name, axis=1)
    n = len(data)
    data = data[data["#Variables"] <= max_vars].copy()
    print(f"Removed {n-len(data)} results because of size constraint.")
    return data

# %%
t = read_as_pandas(
        RESULT_FOLDER,
        lambda result: {
            "parameters": result["parameters"],
            "initial_sample_path": result["parameters"]["args"]["initial_sample_path"],
            "instance_name": result["parameters"]["args"]["instance_name"],
            "lower_bound": result["result"]["lower_bound"],
            "upper_bound": len(result["result"]["solution"]),
            "iteration_info": result["result"]["iteration_info"],
            "time_used_by_yasa": result["result"]["time_used_by_yasa"],
            "timelimit_for_samplns": result["result"]["timelimit_for_samplns"],
            "samplns_used": result["result"]["samplns_used"],
            "instance": result["parameters"]["args"]["instance_name"],
            "logging": result["logging"],
        } if result.get("result", None) and  result.get("result", dict()).get("solution", None) else None,
    )
t = t[t["instance_name"] == "toybox_2020-12-06_00-02-46"]
for e in t.iloc[0]["logging"]:
    print(e["message"])
# Out:
# Parsed instance 'toybox_2020-12-06_00-02-46' with 334 features and 92 rules.
# Preprocessing instance (Instance[toybox_2020-12-06_00-02-46]<334 features, 92 rules>).
# Converting instance to CNF (Instance[toybox_2020-12-06_00-02-46|EQ]<334 features, 92 rules>).
# Finished converting instance to CNF (Instance[toybox_2020-12-06_00-02-46|EQ|CNF]<334 features, 92 rules>).
# Finnished preprocessing (Instance[toybox_2020-12-06_00-02-46|EQ|CNF]<334 features, 92 rules>).
# Setting up random neighborhood selector.
# Computing feasible tuples...
# Converted sample to list representation.
# Instance has 206665 feasible tuples.
# Neighborhood selector is ready.
# Building transaction graph for toybox_2020-12-06_00-02-46|EQ|CNF with 334 concrete features!
# All valid configurations were added to the transaction graph.
# Setting up random neighborhood selector.
# Computing feasible tuples...
# Converted sample to list representation.
# Instance has 206665 feasible tuples.
# Neighborhood selector is ready.
# Beginning optimization with the following parameters: iterations=10000, iteration_timelimit=60.000000, timelimit=899.538000
# Async Solver started with iteration timelimit 60
# Beginning iteration 0.
# Selected neighborhood, removing 2 configurations, leaving 142 tuples uncovered.
# The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increased lower bound to 5 (from 0).
# Increasing neighborhood size to 312 tuples.
# Beginning iteration 1.
# Selected neighborhood, removing 4 configurations, leaving 214 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 390 tuples.
# Beginning iteration 2.
# Selected neighborhood, removing 3 configurations, leaving 319 tuples uncovered.
# The greedy solver found 1 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 3.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 488 tuples.
# Beginning iteration 3.
# Selected neighborhood, removing 2 configurations, leaving 283 tuples uncovered.
# The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increasing neighborhood size to 610 tuples.
# Beginning iteration 4.
# Selected neighborhood, removing 4 configurations, leaving 524 tuples uncovered.
# The greedy solver found 1 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increased lower bound to 7 (from 5).
# Increasing neighborhood size to 762 tuples.
# Beginning iteration 5.
# Selected neighborhood, removing 2 configurations, leaving 364 tuples uncovered.
# The greedy solver found 1 tuples, the LNS found 2 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=2, ub=2.
# Increasing neighborhood size to 953 tuples.
# Beginning iteration 6.
# Selected neighborhood, removing 3 configurations, leaving 651 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 1192 tuples.
# Beginning iteration 7.
# Selected neighborhood, removing 4 configurations, leaving 909 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 1490 tuples.
# Beginning iteration 8.
# Selected neighborhood, removing 5 configurations, leaving 1084 tuples uncovered.
# The greedy solver found 4 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 1862 tuples.
# Beginning iteration 9.
# Selected neighborhood, removing 3 configurations, leaving 1616 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 3 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 2328 tuples.
# Beginning iteration 10.
# Selected neighborhood, removing 3 configurations, leaving 1126 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 3.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=3, ub=3.
# Increasing neighborhood size to 2910 tuples.
# Beginning iteration 11.
# Selected neighborhood, removing 4 configurations, leaving 2666 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 4 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 3637 tuples.
# Beginning iteration 12.
# Selected neighborhood, removing 4 configurations, leaving 2136 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 4547 tuples.
# Beginning iteration 13.
# Selected neighborhood, removing 4 configurations, leaving 3813 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 5684 tuples.
# Beginning iteration 14.
# Selected neighborhood, removing 6 configurations, leaving 5090 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 7105 tuples.
# Beginning iteration 15.
# Selected neighborhood, removing 4 configurations, leaving 5052 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 4.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=4, ub=4.
# Increasing neighborhood size to 8881 tuples.
# Beginning iteration 16.
# Selected neighborhood, removing 6 configurations, leaving 7217 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 11102 tuples.
# Beginning iteration 17.
# Selected neighborhood, removing 6 configurations, leaving 10670 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=6.
# Decreasing neighborhood size to 8326 tuples.
# Beginning iteration 18.
# Selected neighborhood, removing 6 configurations, leaving 6973 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 10408 tuples.
# Beginning iteration 19.
# Selected neighborhood, removing 5 configurations, leaving 5464 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 13010 tuples.
# Beginning iteration 20.
# Selected neighborhood, removing 7 configurations, leaving 11488 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 16263 tuples.
# Beginning iteration 21.
# Selected neighborhood, removing 6 configurations, leaving 12236 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 20328 tuples.
# Beginning iteration 22.
# Selected neighborhood, removing 7 configurations, leaving 17227 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 15246 tuples.
# Beginning iteration 23.
# Selected neighborhood, removing 6 configurations, leaving 11824 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 19058 tuples.
# Beginning iteration 24.
# Selected neighborhood, removing 7 configurations, leaving 18923 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 14293 tuples.
# Beginning iteration 25.
# Selected neighborhood, removing 6 configurations, leaving 11555 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 17867 tuples.
# Beginning iteration 26.
# Selected neighborhood, removing 6 configurations, leaving 13124 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 22333 tuples.
# Beginning iteration 27.
# Selected neighborhood, removing 7 configurations, leaving 17638 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 16750 tuples.
# Beginning iteration 28.
# Selected neighborhood, removing 7 configurations, leaving 15974 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 12562 tuples.
# Beginning iteration 29.
# Selected neighborhood, removing 5 configurations, leaving 9984 tuples uncovered.
# The greedy solver found 4 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 15703 tuples.
# Beginning iteration 30.
# Selected neighborhood, removing 6 configurations, leaving 11895 tuples uncovered.
# The greedy solver found 4 tuples, the LNS found 6 tuples!
# No optimization necessary: lower bound fits available solution.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 19629 tuples.
# Beginning iteration 31.
# Selected neighborhood, removing 7 configurations, leaving 15753 tuples uncovered.
# The greedy solver found 5 tuples, the LNS found 6 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 6 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 14722 tuples.
# Beginning iteration 32.
# Selected neighborhood, removing 6 configurations, leaving 12431 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 18402 tuples.
# Beginning iteration 33.
# Selected neighborhood, removing 7 configurations, leaving 16025 tuples uncovered.
# The greedy solver found 4 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 13801 tuples.
# Beginning iteration 34.
# Selected neighborhood, removing 6 configurations, leaving 13264 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 2 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 2 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=6.
# Decreasing neighborhood size to 10351 tuples.
# Beginning iteration 35.
# Selected neighborhood, removing 5 configurations, leaving 6084 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 5.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=5, ub=5.
# Increasing neighborhood size to 12939 tuples.
# Beginning iteration 36.
# Selected neighborhood, removing 6 configurations, leaving 12129 tuples uncovered.
# The greedy solver found 2 tuples, the LNS found 5 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 5 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 16174 tuples.
# Beginning iteration 37.
# Selected neighborhood, removing 6 configurations, leaving 11095 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=6.
# Increasing neighborhood size to 20217 tuples.
# Beginning iteration 38.
# Selected neighborhood, removing 7 configurations, leaving 19228 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 3 tuples!
# Building model for neighborhood of size 7.
# Using 15 threads for search.
# Using 3 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=6, ub=7.
# Decreasing neighborhood size to 15163 tuples.
# Beginning iteration 39.
# Selected neighborhood, removing 6 configurations, leaving 10041 tuples uncovered.
# The greedy solver found 3 tuples, the LNS found 4 tuples!
# Building model for neighborhood of size 6.
# Using 15 threads for search.
# Using 4 tuples to break symmetries.
# Model built.
# Optimized neighborhood, lb=0, ub=6.
# Decreasing neighborhood size to 11372 tuples.
# Optimization reached time limit.
# Async Solver stopped

# %%
import pandas as pd

# Loading the data of the experiment.


# CHECK THAT THESE ARE THE CORRECT PATHS!
TIME_LIMIT = 900

BASE = "900_seconds_5_it"
INPUT_SAMPLE_ARCHIVE = f"../01_ICSE_2024_0/00_baseline/{BASE}.zip"
INSTANCE_ARCHIVE = "../01_ICSE_2024_0//00_benchmark_instances.zip"
RESULT_FOLDER = f"01_results/{BASE}_{TIME_LIMIT}"



def recache_data():
    relevant_columns = [
        "instance",
        "#Variables",
        "#Clauses",
        "iteration_info",
        "baseline_alg",
        "initial_sample_path",
        "SampleSize",
        "lower_bound",
        "upper_bound",
        "time_used_by_yasa",
        "timelimit_for_samplns",
        "samplns_used"
    ]
    data = get_results(
        input_sample_archive=INPUT_SAMPLE_ARCHIVE, result_folder=RESULT_FOLDER
    )[relevant_columns]
    data.rename(
        columns={
            "SampleSize": "initial_sample_size",
            "upper_bound": "optimized_sample_size",
        },
        inplace=True,
    )
    data.drop_duplicates(subset=["initial_sample_path"], inplace=True)
    data.to_json("./05_clean_data.json.zip")
    del data


recache_data()
# Out:
# Found the data folders: {'2023-03-01_13-51-03/'}
# Removed 0 results because of size constraint.

# %%
data = pd.read_json("./05_clean_data.json.zip")
data
# Out:
#                        instance  #Variables  #Clauses  \
# 0    fiasco_2017-09-26_11-30-56         230      1181
# 1   busybox_2020-12-16_21-53-05        1050       996
# 2                busybox-1_29_2        1018       997
# 3    toybox_2020-12-06_00-02-46         334        92
# 4    toybox_2020-12-06_00-02-46         334        92
# 5    fiasco_2017-09-26_11-30-56         230      1181
# 6    fiasco_2020-12-01_14-09-14         258      1542
# 7    fiasco_2017-09-26_11-30-56         230      1181
# 8   soletta_2015-06-26_18-38-56         129       192
# 9    fiasco_2017-09-26_11-30-56         230      1181
# 10  busybox_2020-12-16_21-53-05        1050       996
# 11   toybox_2020-12-06_00-02-46         334        92
# 12   toybox_2006-10-31_23-30-06          16        13
# 13  busybox_2020-12-16_21-53-05        1050       996
# 14   toybox_2020-12-06_00-02-46         334        92
# 15   fiasco_2020-12-01_14-09-14         258      1542
# 16   fiasco_2020-12-01_14-09-14         258      1542
# 17               busybox-1_29_2        1018       997
# 18  busybox_2007-01-24_09-14-09         540       429
# 19   fiasco_2020-12-01_14-09-14         258      1542
# 20   fiasco_2020-12-01_14-09-14         258      1542
# 21  soletta_2015-06-26_18-38-56         129       192
# 22  busybox_2007-01-24_09-14-09         540       429
# 23  busybox_2020-12-16_21-53-05        1050       996
# 24   toybox_2006-10-31_23-30-06          16        13
# 25               busybox-1_29_2        1018       997
# 26               busybox-1_29_2        1018       997
# 27  busybox_2020-12-16_21-53-05        1050       996
# 28   toybox_2006-10-31_23-30-06          16        13
# 29   fiasco_2017-09-26_11-30-56         230      1181
# 30  soletta_2015-06-26_18-38-56         129       192
# 31               busybox-1_29_2        1018       997
# 32   toybox_2006-10-31_23-30-06          16        13
# 33   toybox_2006-10-31_23-30-06          16        13
# 34  busybox_2007-01-24_09-14-09         540       429
# 35  soletta_2015-06-26_18-38-56         129       192
# 36  soletta_2015-06-26_18-38-56         129       192
# 37   toybox_2020-12-06_00-02-46         334        92
# 38  busybox_2007-01-24_09-14-09         540       429
# 39  busybox_2007-01-24_09-14-09         540       429
# 40   uclibc_2008-06-05_13-46-47         263      1699
# 41   uclibc_2008-06-05_13-46-47         263      1699
# 42   uclibc_2020-12-24_11-54-53         272      1670
# 43   uclibc_2020-12-24_11-54-53         272      1670
# 44   uclibc_2020-12-24_11-54-53         272      1670
# 45   uclibc_2020-12-24_11-54-53         272      1670
# 46   uclibc_2008-06-05_13-46-47         263      1699
# 47   uclibc_2020-12-24_11-54-53         272      1670
# 48   uclibc_2008-06-05_13-46-47         263      1699
# 49   uclibc_2008-06-05_13-46-47         263      1699
#
#                                        iteration_info baseline_alg  \
# 0   [{'nbrhd_tuples': 249, 'nbrhd_confs': 25, 'ite...    YASA(m=1)
# 1   [{'nbrhd_tuples': 201, 'nbrhd_confs': 2, 'iter...    YASA(m=1)
# 2   [{'nbrhd_tuples': 229, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 3   [{'nbrhd_tuples': 142, 'nbrhd_confs': 2, 'iter...    YASA(m=1)
# 4   [{'nbrhd_tuples': 180, 'nbrhd_confs': 2, 'iter...    YASA(m=1)
# 5   [{'nbrhd_tuples': 242, 'nbrhd_confs': 26, 'ite...    YASA(m=1)
# 6   [{'nbrhd_tuples': 243, 'nbrhd_confs': 22, 'ite...    YASA(m=1)
# 7   [{'nbrhd_tuples': 230, 'nbrhd_confs': 16, 'ite...    YASA(m=1)
# 8   [{'nbrhd_tuples': 230, 'nbrhd_confs': 13, 'ite...    YASA(m=1)
# 9   [{'nbrhd_tuples': 230, 'nbrhd_confs': 26, 'ite...    YASA(m=1)
# 10  [{'nbrhd_tuples': 186, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 11  [{'nbrhd_tuples': 122, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 12  [{'nbrhd_tuples': 189, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 13  [{'nbrhd_tuples': 205, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 14  [{'nbrhd_tuples': 165, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 15  [{'nbrhd_tuples': 227, 'nbrhd_confs': 19, 'ite...    YASA(m=1)
# 16  [{'nbrhd_tuples': 236, 'nbrhd_confs': 17, 'ite...    YASA(m=1)
# 17  [{'nbrhd_tuples': 219, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 18  [{'nbrhd_tuples': 239, 'nbrhd_confs': 6, 'iter...    YASA(m=1)
# 19  [{'nbrhd_tuples': 218, 'nbrhd_confs': 19, 'ite...    YASA(m=1)
# 20  [{'nbrhd_tuples': 237, 'nbrhd_confs': 21, 'ite...    YASA(m=1)
# 21  [{'nbrhd_tuples': 225, 'nbrhd_confs': 10, 'ite...    YASA(m=1)
# 22  [{'nbrhd_tuples': 232, 'nbrhd_confs': 6, 'iter...    YASA(m=1)
# 23  [{'nbrhd_tuples': 163, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 24  [{'nbrhd_tuples': 199, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 25  [{'nbrhd_tuples': 209, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 26  [{'nbrhd_tuples': 235, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 27  [{'nbrhd_tuples': 165, 'nbrhd_confs': 3, 'iter...    YASA(m=1)
# 28  [{'nbrhd_tuples': 245, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 29  [{'nbrhd_tuples': 245, 'nbrhd_confs': 26, 'ite...    YASA(m=1)
# 30  [{'nbrhd_tuples': 227, 'nbrhd_confs': 11, 'ite...    YASA(m=1)
# 31  [{'nbrhd_tuples': 238, 'nbrhd_confs': 7, 'iter...    YASA(m=1)
# 32  [{'nbrhd_tuples': 245, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 33  [{'nbrhd_tuples': 245, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 34  [{'nbrhd_tuples': 168, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 35  [{'nbrhd_tuples': 233, 'nbrhd_confs': 12, 'ite...    YASA(m=1)
# 36  [{'nbrhd_tuples': 175, 'nbrhd_confs': 11, 'ite...    YASA(m=1)
# 37  [{'nbrhd_tuples': 245, 'nbrhd_confs': 2, 'iter...    YASA(m=1)
# 38  [{'nbrhd_tuples': 192, 'nbrhd_confs': 5, 'iter...    YASA(m=1)
# 39  [{'nbrhd_tuples': 249, 'nbrhd_confs': 8, 'iter...    YASA(m=1)
# 40  [{'nbrhd_tuples': 230, 'nbrhd_confs': 47, 'ite...    YASA(m=1)
# 41  [{'nbrhd_tuples': 243, 'nbrhd_confs': 53, 'ite...    YASA(m=1)
# 42  [{'nbrhd_tuples': 248, 'nbrhd_confs': 42, 'ite...    YASA(m=1)
# 43  [{'nbrhd_tuples': 248, 'nbrhd_confs': 44, 'ite...    YASA(m=1)
# 44  [{'nbrhd_tuples': 248, 'nbrhd_confs': 38, 'ite...    YASA(m=1)
# 45  [{'nbrhd_tuples': 249, 'nbrhd_confs': 39, 'ite...    YASA(m=1)
# 46  [{'nbrhd_tuples': 249, 'nbrhd_confs': 47, 'ite...    YASA(m=1)
# 47  [{'nbrhd_tuples': 247, 'nbrhd_confs': 48, 'ite...    YASA(m=1)
# 48  [{'nbrhd_tuples': 240, 'nbrhd_confs': 42, 'ite...    YASA(m=1)
# 49  [{'nbrhd_tuples': 247, 'nbrhd_confs': 50, 'ite...    YASA(m=1)
#
#                         initial_sample_path  initial_sample_size  lower_bound  \
# 0   2023-03-01_13-51-03/24_1_7_5_sample.csv                  246          225
# 1   2023-03-01_13-51-03/38_1_7_2_sample.csv                   39           15
# 2   2023-03-01_13-51-03/37_1_7_4_sample.csv                   44           18
# 3   2023-03-01_13-51-03/29_1_7_1_sample.csv                   20            7
# 4   2023-03-01_13-51-03/29_1_7_5_sample.csv                   20            7
# 5   2023-03-01_13-51-03/24_1_7_1_sample.csv                  246          222
# 6   2023-03-01_13-51-03/25_1_7_5_sample.csv                  224          195
# 7   2023-03-01_13-51-03/24_1_7_4_sample.csv                  246          225
# 8   2023-03-01_13-51-03/21_1_7_1_sample.csv                   32           24
# 9   2023-03-01_13-51-03/24_1_7_3_sample.csv                  246          224
# 10  2023-03-01_13-51-03/38_1_7_3_sample.csv                   39           18
# 11  2023-03-01_13-51-03/29_1_7_3_sample.csv                   20            7
# 12   2023-03-01_13-51-03/5_1_7_2_sample.csv                   10            8
# 13  2023-03-01_13-51-03/38_1_7_4_sample.csv                   39           14
# 14  2023-03-01_13-51-03/29_1_7_4_sample.csv                   20            7
# 15  2023-03-01_13-51-03/25_1_7_1_sample.csv                  224          196
# 16  2023-03-01_13-51-03/25_1_7_3_sample.csv                  224          195
# 17  2023-03-01_13-51-03/37_1_7_1_sample.csv                   44           18
# 18  2023-03-01_13-51-03/32_1_7_5_sample.csv                   39           21
# 19  2023-03-01_13-51-03/25_1_7_2_sample.csv                  224          196
# 20  2023-03-01_13-51-03/25_1_7_4_sample.csv                  224          196
# 21  2023-03-01_13-51-03/21_1_7_4_sample.csv                   32           24
# 22  2023-03-01_13-51-03/32_1_7_2_sample.csv                   39           21
# 23  2023-03-01_13-51-03/38_1_7_5_sample.csv                   39           18
# 24   2023-03-01_13-51-03/5_1_7_5_sample.csv                   10            8
# 25  2023-03-01_13-51-03/37_1_7_5_sample.csv                   44           14
# 26  2023-03-01_13-51-03/37_1_7_3_sample.csv                   44           18
# 27  2023-03-01_13-51-03/38_1_7_1_sample.csv                   39           15
# 28   2023-03-01_13-51-03/5_1_7_3_sample.csv                   10            8
# 29  2023-03-01_13-51-03/24_1_7_2_sample.csv                  246          223
# 30  2023-03-01_13-51-03/21_1_7_2_sample.csv                   32           24
# 31  2023-03-01_13-51-03/37_1_7_2_sample.csv                   44           17
# 32   2023-03-01_13-51-03/5_1_7_4_sample.csv                   10            8
# 33   2023-03-01_13-51-03/5_1_7_1_sample.csv                   10            8
# 34  2023-03-01_13-51-03/32_1_7_3_sample.csv                   39           21
# 35  2023-03-01_13-51-03/21_1_7_5_sample.csv                   32           24
# 36  2023-03-01_13-51-03/21_1_7_3_sample.csv                   32           24
# 37  2023-03-01_13-51-03/29_1_7_2_sample.csv                   20            7
# 38  2023-03-01_13-51-03/32_1_7_4_sample.csv                   39           21
# 39  2023-03-01_13-51-03/32_1_7_1_sample.csv                   39           19
# 40  2023-03-01_13-51-03/26_1_7_4_sample.csv                  510          505
# 41  2023-03-01_13-51-03/26_1_7_2_sample.csv                  510          505
# 42  2023-03-01_13-51-03/27_1_7_4_sample.csv                  369          365
# 43  2023-03-01_13-51-03/27_1_7_1_sample.csv                  369          365
# 44  2023-03-01_13-51-03/27_1_7_2_sample.csv                  369          365
# 45  2023-03-01_13-51-03/27_1_7_3_sample.csv                  369          365
# 46  2023-03-01_13-51-03/26_1_7_3_sample.csv                  510          505
# 47  2023-03-01_13-51-03/27_1_7_5_sample.csv                  369          365
# 48  2023-03-01_13-51-03/26_1_7_5_sample.csv                  510          505
# 49  2023-03-01_13-51-03/26_1_7_1_sample.csv                  510          505
#
#     optimized_sample_size  time_used_by_yasa  timelimit_for_samplns  \
# 0                     226              0.982                899.018
# 1                      23              2.233                897.767
# 2                      25              2.297                897.703
# 3                      14              0.462                899.538
# 4                      14              0.474                899.526
# 5                     226              0.968                899.032
# 6                     198              1.176                898.824
# 7                     225              0.990                899.010
# 8                      24              0.286                899.714
# 9                     227              0.941                899.059
# 10                     25              2.327                897.673
# 11                     14              0.454                899.546
# 12                      8              0.184                899.816
# 13                     23              2.237                897.763
# 14                     14              0.479                899.521
# 15                    198              1.121                898.879
# 16                    197              1.152                898.848
# 17                     25              2.305                897.695
# 18                     21              0.927                899.073
# 19                    198              1.175                898.825
# 20                    198              1.153                898.847
# 21                     24              0.285                899.715
# 22                     21              0.900                899.100
# 23                     23              2.278                897.722
# 24                      8              0.187                899.813
# 25                     23              2.331                897.669
# 26                     26              2.302                897.698
# 27                     23              2.273                897.727
# 28                      8              0.206                899.794
# 29                    225              0.948                899.052
# 30                     24              0.293                899.707
# 31                     25              2.299                897.701
# 32                      8              0.207                899.793
# 33                      8              0.202                899.798
# 34                     22              0.911                899.089
# 35                     24              0.286                899.714
# 36                     24              0.280                899.720
# 37                     14              0.478                899.522
# 38                     22              0.900                899.100
# 39                     22              0.897                899.103
# 40                    505              1.459                898.541
# 41                    505              1.458                898.542
# 42                    365              1.229                898.771
# 43                    365              1.274                898.726
# 44                    365              1.218                898.782
# 45                    365              1.263                898.737
# 46                    505              1.483                898.517
# 47                    365              1.219                898.781
# 48                    505              1.464                898.536
# 49                    505              1.492                898.508
#
#     samplns_used
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
# 30          True
# 31          True
# 32          True
# 33          True
# 34          True
# 35          True
# 36          True
# 37          True
# 38          True
# 39          True
# 40          True
# 41          True
# 42          True
# 43          True
# 44          True
# 45          True
# 46          True
# 47          True
# 48          True
# 49          True

# %% [markdown]
# * `instance` Unique name of feature model.
# * `#Variables` Number of variables in model.
# * `#Clauses` Number of clauses in model.
# * `iteration_info` Information on the individual iterations (needs some additional processing)
# * `baseline_alg` Name of the algorithm that computed the initial sample.
# * `initial_sample_path` Path to the initial sample in the database (for querying, but it also serves as identifier).
# * `initial_sample_size` Size of the initial sample.
# * `lower_bound` The lower bound computed by SampLNS.
# * `optimized_sample_size` Size of the sample after optimization with SampLNS.
