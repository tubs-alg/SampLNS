# %% [markdown]
# # Cleaning the data and providing a small and easily parsable database.
#
# The database with the full logs is too huge to work on. Most of the data would only be needed for debugging but not for evaluation.
# Thus, we create a clean and small database for the further evaluation.

# %%
from _conf import BASE, RESULT_FOLDER, TIME_LIMIT
from _utils import get_instance, parse_sample
from algbench import read_as_pandas

data = read_as_pandas(
    RESULT_FOLDER,
    lambda result: {
        "parameters": result["parameters"],
        "instance_name": result["parameters"]["args"]["instance_name"],
        "sample_method": result["parameters"]["args"]["sample_method"],
        "lower_bound": result["result"]["lower_bound"],
        "upper_bound": result["result"]["upper_bound"],
        "iteration_info": result["result"]["iteration_info"],
        "instance": result["parameters"]["args"]["instance_name"],
    }
    if result["result"]
    and not result["parameters"]["args"]["sample_method"].endswith("3")
    else None,
)
data
data["original_sample_size"] = data.apply(
    lambda row: len(
        parse_sample(
            get_instance(row["instance"]), row["instance"], row["sample_method"]
        )
    ),
    axis=1,
)
data.sort_values(by=["instance", "sample_method", "original_sample_size"], inplace=True)
data
# Out:
# [{'root': True, 'root_6': True, 'max': False, 'min': True, 'root_7': True, 'memory_based': True, 'value_based': False, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': True, 'root_2': True, 'pollyoptmaxcoefficient_10000': True, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': True, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': False, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': True, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': True, 'polly_delinearize': True, 'polly_no_tiling': False, 'polly_parallel': False, 'root_11': True, 'polly': True, 'none': False, 'parallel_force': False, 'parallel': False}, {'root': True, 'root_6': True, 'max': True, 'min': False, 'root_7': True, 'memory_based': False, 'value_based': True, 'root_1': True, 'pollydefaulttilesize_1024': True, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': True, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': True, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': False, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': True, 'polly_opt_simplify_deps': True, 'polly_delinearize': True, 'polly_no_tiling': False, 'polly_parallel': True, 'root_11': True, 'polly': False, 'none': True, 'parallel_force': True, 'parallel': True}, {'root': True, 'root_6': True, 'max': False, 'min': True, 'root_7': True, 'memory_based': True, 'value_based': False, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': True, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': True, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': True, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': True, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': False, 'polly_delinearize': True, 'polly_no_tiling': True, 'polly_parallel': False, 'root_11': True, 'polly': False, 'none': True, 'parallel_force': False, 'parallel': False}, {'root': True, 'root_6': True, 'max': True, 'min': False, 'root_7': True, 'memory_based': False, 'value_based': True, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': True, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': True, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': True, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': Fa ...
# [{'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': True, 'post_0': True, 'cells_2': False, 'cells_1': True, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': False, 'pre_1': True, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': True, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': True, 'pre_1': True, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': True, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': False, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': False, 'post_2': False, 'post_1': True, 'post_0': True, 'cells_2': False, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': True, 'post_2': False, 'post_1': True, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}]
# [{'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': False, 'pre_1': False, 'pre_0': False, 'post_2': False, 'post_1': False, 'post_0': True, 'cells_2': False, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': True, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': False, 'post_0': True, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': True, 'pre_1': True, 'pre_0': False, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': Fals ...
# [{'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': False, 'pre_1': False, 'pre_0': False, 'post_2': False, 'post_1': False, 'post_0': True, 'cells_2': False, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': True, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': False, 'pre_0': True, 'post_2': True, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': True, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': False, 'post_0': True, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': False, 'SeqSOR': True, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': True, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': True, 'pre_1': True, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': True, 'post_1': False, 'post_0': True, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': True, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': True, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': True, 'pre_0': False, 'post_2': False, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': False, 'LoopSolver': False, 'GradientSolver': True, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': True, 'post_0': False, 'cells_2': True, 'cells_1': False, 'cells_0': True}, {'Precon': True, 'SeqGS': True, 'SeqSOR': False, 'Solver': True, 'CGSolver': False, 'BiCGSTABSolver': True, 'LoopSolver': False, 'GradientSolver': False, 'pre_2': False, 'pre_1': False, 'pre_0': True, 'post_2': False, 'post_1': False, 'post_0': False, 'cells_2': False, 'cells_1': False, 'cells_0': False}, {'Precon': True, 'SeqGS': True, 'SeqSOR': Fal ...
# [{'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': True, 'MicroserviceApplication': True, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': False, 'SpringWebSockets': False, 'Libsass': False, 'ClusteredSession': False, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': False, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': False, 'SQL': False, 'Cassandra': False, 'MongoDB': False, 'Development': False, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': False, 'OAuth2': False, 'Uaa': True, 'JWT': False, 'Protractor': False, 'Gatling': True, 'Cucumber': True, 'Application': False, 'MicroserviceGateway': False, 'Monolithic': False}, {'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': True, 'Database': True, 'SpringWebSockets': True, 'Libsass': True, 'ClusteredSession': True, 'InternationalizationSupport': True, 'Docker': True, 'TestingFrameworks': True, 'Production': False, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': False, 'SQL': False, 'Cassandra': False, 'MongoDB': True, 'Development': False, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': False, 'OAuth2': False, 'Uaa': False, 'JWT': True, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': False, 'Monolithic': True}, {'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': True, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': True, 'Libsass': True, 'ClusteredSession': True, 'InternationalizationSupport': True, 'Docker': True, 'TestingFrameworks': True, 'Production': True, 'MySQL': False, 'MariaDB': True, 'PostgreSQL': False, 'SQL': True, 'Cassandra': False, 'MongoDB': False, 'Development': True, 'H2': True, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': True, 'ElasticSearch': True, 'HTTPSession': False, 'OAuth2': False, 'Uaa': False, 'JWT': True, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': True, 'Monolithic': False}, {'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': False, 'Libsass': False, 'ClusteredSession': False, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': False, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': False, 'SQL': False, 'Cassandra': True, 'MongoDB': False, 'Development': False, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': True, 'OAuth2': False, 'Uaa': False, 'JWT': False, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': False, 'Monolithic': True}, {'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': False, 'EhCache': True, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets' ...
# [{'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': True, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': False, 'Libsass': False, 'ClusteredSession': False, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': True, 'MySQL': False, 'MariaDB': True, 'PostgreSQL': False, 'SQL': True, 'Cassandra': False, 'MongoDB': False, 'Development': True, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': True, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': False, 'OAuth2': False, 'Uaa': True, 'JWT': False, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': True, 'Monolithic': False}, {'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': False, 'EhCache': True, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': True, 'Libsass': True, 'ClusteredSession': True, 'InternationalizationSupport': True, 'Docker': False, 'TestingFrameworks': True, 'Production': True, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': True, 'SQL': True, 'Cassandra': False, 'MongoDB': False, 'Development': True, 'H2': True, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': True, 'ElasticSearch': False, 'HTTPSession': False, 'OAuth2': True, 'Uaa': False, 'JWT': False, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': False, 'Monolithic': True}, {'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': False, 'EhCache': True, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': False, 'Libsass': False, 'ClusteredSession': False, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': True, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': True, 'SQL': True, 'Cassandra': False, 'MongoDB': False, 'Development': True, 'H2': False, 'PostgreSQLDev': True, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': True, 'OAuth2': False, 'Uaa': False, 'JWT': False, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': False, 'Monolithic': True}, {'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': True, 'Libsass': False, 'ClusteredSession': True, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': True, 'MySQL': True, 'MariaDB': False, 'PostgreSQL': False, 'SQL': True, 'Cassandra': False, 'MongoDB': False, 'Development': True, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': True, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': True, 'HTTPSession': False, 'OAuth2': False, 'Uaa': False, 'JWT': True, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': True, 'Monolithic': False}, {'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': True, 'Database': True, 'SpringWebSockets': False, 'Lib ...
# [{'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': True, 'MicroserviceApplication': True, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': False, 'SpringWebSockets': False, 'Libsass': False, 'ClusteredSession': False, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': False, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': False, 'SQL': False, 'Cassandra': False, 'MongoDB': False, 'Development': False, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': False, 'OAuth2': False, 'Uaa': True, 'JWT': False, 'Protractor': False, 'Gatling': True, 'Cucumber': True, 'Application': False, 'MicroserviceGateway': False, 'Monolithic': False}, {'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': True, 'Database': True, 'SpringWebSockets': True, 'Libsass': True, 'ClusteredSession': True, 'InternationalizationSupport': True, 'Docker': True, 'TestingFrameworks': True, 'Production': False, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': False, 'SQL': False, 'Cassandra': False, 'MongoDB': True, 'Development': False, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': False, 'OAuth2': False, 'Uaa': False, 'JWT': True, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': False, 'Monolithic': True}, {'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': True, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': False, 'Maven': True, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': True, 'Libsass': True, 'ClusteredSession': True, 'InternationalizationSupport': True, 'Docker': True, 'TestingFrameworks': True, 'Production': True, 'MySQL': False, 'MariaDB': True, 'PostgreSQL': False, 'SQL': True, 'Cassandra': False, 'MongoDB': False, 'Development': True, 'H2': True, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': True, 'ElasticSearch': True, 'HTTPSession': False, 'OAuth2': False, 'Uaa': True, 'JWT': False, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': True, 'Monolithic': False}, {'JHipster': True, 'Hibernate2ndLvlCache': False, 'HazelCast': False, 'EhCache': False, 'Server': False, 'MicroserviceApplication': False, 'UaaServer': False, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets': False, 'Libsass': False, 'ClusteredSession': False, 'InternationalizationSupport': False, 'Docker': False, 'TestingFrameworks': True, 'Production': False, 'MySQL': False, 'MariaDB': False, 'PostgreSQL': False, 'SQL': False, 'Cassandra': True, 'MongoDB': False, 'Development': False, 'H2': False, 'PostgreSQLDev': False, 'MariaDBDev': False, 'MySQLDev': False, 'DiskBased': False, 'InMemory': False, 'ElasticSearch': False, 'HTTPSession': True, 'OAuth2': False, 'Uaa': False, 'JWT': False, 'Protractor': True, 'Gatling': True, 'Cucumber': True, 'Application': True, 'MicroserviceGateway': False, 'Monolithic': True}, {'JHipster': True, 'Hibernate2ndLvlCache': True, 'HazelCast': False, 'EhCache': True, 'Server': True, 'MicroserviceApplication': False, 'UaaServer': True, 'BackEnd': True, 'Gradle': True, 'Maven': False, 'Generator': True, 'Authentication': True, 'SocialLogin': False, 'Database': True, 'SpringWebSockets':  ...
# [{'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': False, 'lagInFrames_0': True, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': True, 'variableBitrate': False, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': False, 'off': True, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': False, 'TileColumns_0': True, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': True, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': False, 'Threads_4': False, 'Threads_2': True, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': True, 'FrameBoost': False, 'lossless': False, 'AutoAltRef': False, 'root_11': True, 'realtime': True, 'good': False}, {'root': True, 'root_5': True, 'lagInFrames_16': True, 'lagInFrames_8': False, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': True, 'variance': False, 'off': False, 'root_1': True, 'TileColumns_6': True, 'TileColumns_3': False, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': True, 'root_3': True, 'Threads_10': False, 'Threads_8': True, 'Threads_6': False, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': True, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': True, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': True, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': True, 'off': False, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': True, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': True, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': True, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': True, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': False, 'root_11': True, 'realtime': True, 'good': False}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': False, 'lagInFrames_0': True, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': True, 'complexity': False, 'variance': False, 'off': False, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': True, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': True, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': True, 'Threads_8': False, 'Threads_6': False, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': True, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': True, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': True, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': False, 'off': True, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': False, 'TileColumns_0': True, 'root_2': True, 'cpuUsed_8': True, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': False, 'Threads_4': True, 'Threads_2': False, ' ...
# [{'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': True, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': True, 'off': False, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': True, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': True, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': False, 'Threads_4': True, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': True, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': False, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': True, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': True, 'variableBitrate': False, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': True, 'off': False, 'root_1': True, 'TileColumns_6': True, 'TileColumns_3': False, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': True, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': False, 'Threads_4': True, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': True, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': False, 'root_11': True, 'realtime': True, 'good': False}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': False, 'lagInFrames_0': True, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': False, 'off': True, 'root_1': True, 'TileColumns_6': True, 'TileColumns_3': False, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': True, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': True, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': True, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': False, 'lossless': True, 'AutoAltRef': False, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': False, 'lagInFrames_0': True, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': True, 'complexity': False, 'variance': False, 'off': False, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': False, 'TileColumns_0': True, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': True, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': True, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': True, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': True, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': True, 'lagInFrames_8': False, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': True, 'constantBitrate': False, 'variableBitrate': False, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': False, 'off': True, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': False, 'TileColumns_0': True, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': True, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': True, 'Threads_8': False, 'Threads_6': False, 'Threads_4': False, 'Threads_2': False, ' ...
# [{'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': False, 'lagInFrames_0': True, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': True, 'variableBitrate': False, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': False, 'off': True, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': False, 'TileColumns_0': True, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': True, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': False, 'Threads_4': False, 'Threads_2': True, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': True, 'FrameBoost': False, 'lossless': False, 'AutoAltRef': False, 'root_11': True, 'realtime': True, 'good': False}, {'root': True, 'root_5': True, 'lagInFrames_16': True, 'lagInFrames_8': False, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': True, 'variance': False, 'off': False, 'root_1': True, 'TileColumns_6': True, 'TileColumns_3': False, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': True, 'root_3': True, 'Threads_10': False, 'Threads_8': True, 'Threads_6': False, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': True, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': True, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': False, 'lagInFrames_8': True, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': False, 'variableBitrate': True, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': True, 'off': False, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': True, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': True, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': True, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': False, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': True, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': False, 'root_11': True, 'realtime': True, 'good': False}, {'root': True, 'root_5': True, 'lagInFrames_16': True, 'lagInFrames_8': False, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': True, 'constantBitrate': False, 'variableBitrate': False, 'root_9': True, 'cyclicRefresh': True, 'complexity': False, 'variance': False, 'off': False, 'root_1': True, 'TileColumns_6': False, 'TileColumns_3': True, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': False, 'cpuUsed_6': False, 'cpuUsed_4': True, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': True, 'Threads_8': False, 'Threads_6': False, 'Threads_4': False, 'Threads_2': False, 'root_4': True, 'bitRate_1500': True, 'bitRate_1200': False, 'bitRate_900': False, 'bitRate_600': False, 'bitRate_300': False, 'FrameBoost': True, 'lossless': True, 'AutoAltRef': True, 'root_11': True, 'realtime': False, 'good': True}, {'root': True, 'root_5': True, 'lagInFrames_16': True, 'lagInFrames_8': False, 'lagInFrames_0': False, 'root_8': True, 'constrainedQuality': False, 'constantBitrate': True, 'variableBitrate': False, 'root_9': True, 'cyclicRefresh': False, 'complexity': False, 'variance': True, 'off': False, 'root_1': True, 'TileColumns_6': True, 'TileColumns_3': False, 'TileColumns_0': False, 'root_2': True, 'cpuUsed_8': True, 'cpuUsed_6': False, 'cpuUsed_4': False, 'cpuUsed_2': False, 'cpuUsed_0': False, 'root_3': True, 'Threads_10': False, 'Threads_8': False, 'Threads_6': False, 'Threads_4': True, 'Threads_2': False, ' ...
# [{'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': False, '[no_mbtree]': False, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': True, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': False, 'ref_9': True}, {'no_asm': True, '[no_8x8dct]': True, '[no_cabac]': True, '[no_deblock]': True, '[no_fast_pskip]': True, '[no_mbtree]': True, '[no_mixed_refs]': True, '[no_weightb]': True, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': False, 'rc_lookahead_60': True, 'ref_1': True, 'ref_5': False, 'ref_9': False}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': True, '[no_deblock]': True, '[no_fast_pskip]': True, '[no_mbtree]': True, '[no_mixed_refs]': True, '[no_weightb]': True, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': True, 'rc_lookahead_40': False, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': True, 'ref_9': False}, {'no_asm': True, '[no_8x8dct]': True, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': False, '[no_mbtree]': False, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': True, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': False, 'ref_9': True}, {'no_asm': True, '[no_8x8dct]': True, '[no_cabac]': False, '[no_deblock]': True, '[no_fast_pskip]': True, '[no_mbtree]': True, '[no_mixed_refs]': True, '[no_weightb]': True, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': True, 'rc_lookahead_40': False, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': True, 'ref_9': False}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': True, '[no_deblock]': False, '[no_fast_pskip]': False, '[no_mbtree]': False, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': True, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': False, 'ref_9': True}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': True, '[no_fast_pskip]': False, '[no_mbtree]': False, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': True, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': False, 'ref_9': True}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': True, '[no_mbtree]': True, '[no_mixed_refs]': True, '[no_weightb]': True, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': True, 'rc_lookahead_60': False, 'ref_1': True, 'ref_5': False, 'ref_9': False}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': False, '[no_mbtree]': True, '[no_mixed_refs]': True, '[no_weightb]': True, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': True, 'rc_lookahead_40': False, 'rc_lookahead_60': False, 'ref_1': False, 'ref_5': False, 'ref_9': True}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': True, '[no_mbtree]': False, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': False, 'rc_lookahead_60': True, 'ref_1': False, 'ref_5': False, 'ref_9': True}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': False, '[no_mbtree]': False, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': False, 'rc_lookahead_40': False, 'rc_lookahead_60': True, 'ref_1': False, 'ref_5': True, 'ref_9': False}, {'no_asm': True, '[no_8x8dct]': False, '[no_cabac]': False, '[no_deblock]': False, '[no_fast_pskip]': False, '[no_mbtree]': True, '[no_mixed_refs]': False, '[no_weightb]': False, 'rc_lookahead': True, 'ref': True, 'rc_lookahead_20': True, 'rc_lookahead_40': False, 'rc_lookahead_60': False ...
# ...
# [{'root': True, 'root_6': True, 'max': False, 'min': True, 'root_7': True, 'memory_based': False, 'value_based': True, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': True, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': True, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': True, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': True, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': False, 'polly_delinearize': True, 'polly_no_tiling': False, 'polly_parallel': False, 'root_11': True, 'polly': False, 'none': True, 'parallel_force': False, 'parallel': False}, {'root': True, 'root_6': True, 'max': True, 'min': False, 'root_7': True, 'memory_based': True, 'value_based': False, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': True, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': True, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': True, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': False, 'root_4': True, 'pollyrtcmaxparameters_16': True, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': True, 'polly_delinearize': True, 'polly_no_tiling': True, 'polly_parallel': True, 'root_11': True, 'polly': True, 'none': False, 'parallel_force': True, 'parallel': True}, {'root': True, 'root_6': True, 'max': True, 'min': False, 'root_7': True, 'memory_based': False, 'value_based': True, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': True, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': True, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': True, 'pollyoptmaxconstantterm_1': False, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': True, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': True, 'polly_delinearize': True, 'polly_no_tiling': True, 'polly_parallel': True, 'root_11': True, 'polly': True, 'none': False, 'parallel_force': True, 'parallel': True}, {'root': True, 'root_6': True, 'max': False, 'min': True, 'root_7': True, 'memory_based': True, 'value_based': False, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': True, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': True, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': True, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': False, ...
# [{'root': True, 'root_6': True, 'max': False, 'min': True, 'root_7': True, 'memory_based': False, 'value_based': True, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': True, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': True, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': True, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': True, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': False, 'polly_delinearize': True, 'polly_no_tiling': False, 'polly_parallel': False, 'root_11': True, 'polly': False, 'none': True, 'parallel_force': False, 'parallel': False}, {'root': True, 'root_6': True, 'max': True, 'min': False, 'root_7': True, 'memory_based': True, 'value_based': False, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': True, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': True, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': True, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': False, 'root_4': True, 'pollyrtcmaxparameters_16': True, 'pollyrtcmaxparameters_8': False, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': True, 'polly_delinearize': True, 'polly_no_tiling': True, 'polly_parallel': True, 'root_11': True, 'polly': True, 'none': False, 'parallel_force': True, 'parallel': True}, {'root': True, 'root_6': True, 'max': True, 'min': False, 'root_7': True, 'memory_based': False, 'value_based': True, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': True, 'pollydefaulttilesize_64': False, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': True, 'pollyoptmaxcoefficient_100': False, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': False, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': True, 'pollyoptmaxconstantterm_1': False, 'root_4': True, 'pollyrtcmaxparameters_16': False, 'pollyrtcmaxparameters_8': True, 'pollyrtcmaxparameters_4': False, 'pollyrtcmaxparameters_2': False, 'pollyrtcmaxparameters_1': False, 'polly_opt_simplify_deps': True, 'polly_delinearize': True, 'polly_no_tiling': True, 'polly_parallel': True, 'root_11': True, 'polly': True, 'none': False, 'parallel_force': True, 'parallel': True}, {'root': True, 'root_6': True, 'max': False, 'min': True, 'root_7': True, 'memory_based': True, 'value_based': False, 'root_1': True, 'pollydefaulttilesize_1024': False, 'pollydefaulttilesize_256': False, 'pollydefaulttilesize_64': True, 'pollydefaulttilesize_16': False, 'pollydefaulttilesize_4': False, 'root_2': True, 'pollyoptmaxcoefficient_10000': False, 'pollyoptmaxcoefficient_1000': False, 'pollyoptmaxcoefficient_100': True, 'pollyoptmaxcoefficient_10': False, 'pollyoptmaxcoefficient_1': False, 'root_3': True, 'pollyoptmaxconstantterm_10000': True, 'pollyoptmaxconstantterm_1000': False, 'pollyoptmaxconstantterm_100': False, 'pollyoptmaxconstantterm_10': False, 'pollyoptmaxconstantterm_1': False, ...
#                                            parameters instance_name  \
# 19  {'func': 'run_samplns', 'args': {'instance_nam...   BerkeleyDBC
# 22  {'func': 'run_samplns', 'args': {'instance_nam...   BerkeleyDBC
# 21  {'func': 'run_samplns', 'args': {'instance_nam...   BerkeleyDBC
# 20  {'func': 'run_samplns', 'args': {'instance_nam...   BerkeleyDBC
# 3   {'func': 'run_samplns', 'args': {'instance_nam...          Dune
# 2   {'func': 'run_samplns', 'args': {'instance_nam...          Dune
# 1   {'func': 'run_samplns', 'args': {'instance_nam...          Dune
# 4   {'func': 'run_samplns', 'args': {'instance_nam...      JHipster
# 6   {'func': 'run_samplns', 'args': {'instance_nam...      JHipster
# 5   {'func': 'run_samplns', 'args': {'instance_nam...      JHipster
# 17  {'func': 'run_samplns', 'args': {'instance_nam...        JavaGC
# 16  {'func': 'run_samplns', 'args': {'instance_nam...        JavaGC
# 18  {'func': 'run_samplns', 'args': {'instance_nam...        JavaGC
# 23  {'func': 'run_samplns', 'args': {'instance_nam...         Polly
# 24  {'func': 'run_samplns', 'args': {'instance_nam...         Polly
# 0   {'func': 'run_samplns', 'args': {'instance_nam...         Polly
# 7   {'func': 'run_samplns', 'args': {'instance_nam...           VP9
# 9   {'func': 'run_samplns', 'args': {'instance_nam...           VP9
# 8   {'func': 'run_samplns', 'args': {'instance_nam...           VP9
# 10  {'func': 'run_samplns', 'args': {'instance_nam...          X264
# 11  {'func': 'run_samplns', 'args': {'instance_nam...          X264
# 12  {'func': 'run_samplns', 'args': {'instance_nam...          X264
# 13  {'func': 'run_samplns', 'args': {'instance_nam...         lrzip
# 14  {'func': 'run_samplns', 'args': {'instance_nam...         lrzip
# 15  {'func': 'run_samplns', 'args': {'instance_nam...         lrzip
#
#    sample_method  lower_bound  upper_bound  \
# 19     Chvatal_2           20           20
# 22        ICPL_2           20           20
# 21          YASA           20           20
# 20        YASA_2           20           20
# 3      Chvatal_2            9            9
# 2         ICPL_2            9            9
# 1         YASA_2            9            9
# 4      Chvatal_2           37           37
# 6         ICPL_2           37           37
# 5         YASA_2           37           37
# 17     Chvatal_2           42           42
# 16        ICPL_2           42           42
# 18        YASA_2           42           42
# 23     Chvatal_2           25           25
# 24        ICPL_2           25           25
# 0         YASA_2           25           25
# 7      Chvatal_2           25           25
# 9         ICPL_2           25           25
# 8         YASA_2           25           25
# 10     Chvatal_2            9            9
# 11        ICPL_2            9            9
# 12        YASA_2            9            9
# 13     Chvatal_2           18           18
# 14        ICPL_2           18           18
# 15        YASA_2           18           18
#
#                                        iteration_info     instance  \
# 19  [{'nbrhd_tuples': 181, 'nbrhd_confs': 18, 'ite...  BerkeleyDBC
# 22  [{'nbrhd_tuples': 228, 'nbrhd_confs': 18, 'ite...  BerkeleyDBC
# 21  [{'nbrhd_tuples': 224, 'nbrhd_confs': 17, 'ite...  BerkeleyDBC
# 20  [{'nbrhd_tuples': 225, 'nbrhd_confs': 16, 'ite...  BerkeleyDBC
# 3   [{'nbrhd_tuples': 215, 'nbrhd_confs': 11, 'ite...         Dune
# 2   [{'nbrhd_tuples': 228, 'nbrhd_confs': 12, 'ite...         Dune
# 1   [{'nbrhd_tuples': 245, 'nbrhd_confs': 11, 'ite...         Dune
# 4   [{'nbrhd_tuples': 227, 'nbrhd_confs': 22, 'ite...     JHipster
# 6   [{'nbrhd_tuples': 231, 'nbrhd_confs': 25, 'ite...     JHipster
# 5   [{'nbrhd_tuples': 243, 'nbrhd_confs': 22, 'ite...     JHipster
# 17  [{'nbrhd_tuples': 249, 'nbrhd_confs': 36, 'ite...       JavaGC
# 16  [{'nbrhd_tuples': 244, 'nbrhd_confs': 34, 'ite...       JavaGC
# 18  [{'nbrhd_tuples': 241, 'nbrhd_confs': 34, 'ite...       JavaGC
# 23  [{'nbrhd_tuples': 236, 'nbrhd_confs': 24, 'ite...        Polly
# 24  [{'nbrhd_tuples': 243, 'nbrhd_confs': 27, 'ite...        Polly
# 0   [{'nbrhd_tuples': 217, 'nbrhd_confs': 26, 'ite...        Polly
# 7   [{'nbrhd_tuples': 236, 'nbrhd_confs': 26, 'ite...          VP9
# 9   [{'nbrhd_tuples': 199, 'nbrhd_confs': 21, 'ite...          VP9
# 8   [{'nbrhd_tuples': 242, 'nbrhd_confs': 25, 'ite...          VP9
# 10  [{'nbrhd_tuples': 183, 'nbrhd_confs': 13, 'ite...         X264
# 11  [{'nbrhd_tuples': 202, 'nbrhd_confs': 13, 'ite...         X264
# 12  [{'nbrhd_tuples': 192, 'nbrhd_confs': 10, 'ite...         X264
# 13  [{'nbrhd_tuples': 228, 'nbrhd_confs': 19, 'ite...        lrzip
# 14  [{'nbrhd_tuples': 225, 'nbrhd_confs': 19, 'ite...        lrzip
# 15  [{'nbrhd_tuples': 249, 'nbrhd_confs': 16, 'ite...        lrzip
#
#     original_sample_size
# 19                    21
# 22                    21
# 21                    20
# 20                    20
# 3                     14
# 2                     14
# 1                     13
# 4                     38
# 6                     40
# 5                     37
# 17                    52
# 16                    53
# 18                    48
# 23                    39
# 24                    42
# 0                     38
# 7                     41
# 9                     40
# 8                     38
# 10                    15
# 11                    15
# 12                    12
# 13                    22
# 14                    23
# 15                    19

# %%
from _utils import parse_sample, parse_solution_overview
from algbench import read_as_pandas


def get_results(input_sample_archive, result_folder, max_vars=1500):
    # Loading the data of the experiment.

    # Merge the new data with the data of the initial samples
    data = read_as_pandas(
        result_folder,
        lambda result: {
            "parameters": result["parameters"],
            "initial_sample_path": result["parameters"]["args"]["method"],
            "instance_name": result["parameters"]["args"]["instance_name"],
            "lower_bound": result["result"]["lower_bound"],
            "upper_bound": result["result"]["upper_bound"],
            "iteration_info": result["result"]["iteration_info"],
            "instance": result["parameters"]["args"]["instance_name"],
        }
        if result["result"]
        else None,
    )

    data_initial = parse_solution_overview(input_sample_archive)
    data = data.merge(data_initial, left_on="initial_sample_path", right_on="Path")

    # add a good name for 00_baseline algorithms including the settings
    def baseline_alg_name(row):
        settings = row["Settings"]
        if "_m" in settings:
            m = settings.split("_m")[-1].split("_")[0]
            return f"{row['Algorithm']}(m={m})"
        return row["Algorithm"]

    data["baseline_alg"] = data.apply(baseline_alg_name, axis=1)
    n = len(data)
    data = data[data["#Variables"] <= max_vars].copy()
    print(f"Removed {n-len(data)} results because of size constraint.")
    return data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 from algbench import read_as_pandas, Benchmark
# ----> 2 from _utils import parse_solution_overview, parse_sample
#       5 def get_results(input_sample_archive, result_folder, max_vars=1500):
#       6     # Loading the data of the experiment.
#       7
#       8     # Merge the new data with the data of the initial samples
#       9     data = read_as_pandas(
#      10         result_folder,
#      11         lambda result: {
#    (...)
#      19         } if result["result"] else None,
#      20     )
#
# ImportError: cannot import name 'parse_solution_overview' from '_utils' (/home/krupke/Repositories/SampLNS/evaluation/03_reinforcment_learning_comparison/_utils.py)

# %%
import pandas as pd

# Loading the data of the experiment.


# CHECK THAT THESE ARE THE CORRECT PATHS!
TIME_LIMIT = 900

BASE = "900_seconds_5_it"
INPUT_SAMPLE_ARCHIVE = f"../01_ICSE_2024_0/00_baseline/{BASE}.zip"
INSTANCE_ARCHIVE = "../01_ICSE_2024_0//00_benchmark_instances.zip"
RESULT_FOLDER = f"01_results/{BASE}_{TIME_LIMIT}"


def recache_data():
    relevant_columns = [
        "instance",
        "#Variables",
        "#Clauses",
        "iteration_info",
        "baseline_alg",
        "initial_sample_path",
        "SampleSize",
        "lower_bound",
        "upper_bound",
    ]
    data = get_results(
        input_sample_archive=INPUT_SAMPLE_ARCHIVE, result_folder=RESULT_FOLDER
    )[relevant_columns]
    data.rename(
        columns={
            "SampleSize": "initial_sample_size",
            "upper_bound": "optimized_sample_size",
        },
        inplace=True,
    )
    data.drop_duplicates(subset=["initial_sample_path"], inplace=True)
    data.to_json("./05_clean_data.json.zip")
    del data


recache_data()
# Out:
# Found the data folders: {'2023-03-01_13-51-03/'}
# Removed 0 results because of size constraint.

# %%
data = pd.read_json("./05_clean_data.json.zip")
data
# Out:
#                          instance  #Variables  #Clauses  \
# 0                           email          10        17
# 1                      ChatClient          14        20
# 2                      ChatClient          14        20
# 3                      ChatClient          14        20
# 4                      ChatClient          14        20
# ...                           ...         ...       ...
# 1933                  berkeleyDB2         119       346
# 1934  soletta_2015-06-26_18-38-56         129       192
# 1935  soletta_2015-06-26_18-38-56         129       192
# 1936  soletta_2015-06-26_18-38-56         129       192
# 1937  soletta_2015-06-26_18-38-56         129       192
#
#                                          iteration_info    baseline_alg  \
# 0     [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...  FIDE-YASA(m=1)
# 1     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# 2     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# 3     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# 4     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# ...                                                 ...             ...
# 1933  [{'nbrhd_tuples': 198, 'nbrhd_confs': 10, 'ite...         Incling
# 1934  [{'nbrhd_tuples': 223, 'nbrhd_confs': 22, 'ite...         Incling
# 1935  [{'nbrhd_tuples': 227, 'nbrhd_confs': 22, 'ite...         Incling
# 1936  [{'nbrhd_tuples': 193, 'nbrhd_confs': 21, 'ite...         Incling
# 1937  [{'nbrhd_tuples': 247, 'nbrhd_confs': 26, 'ite...         Incling
#
#                           initial_sample_path  initial_sample_size  \
# 0      2023-03-01_13-51-03/3_1_3_5_sample.csv                    8
# 1      2023-03-01_13-51-03/4_1_3_1_sample.csv                   10
# 2      2023-03-01_13-51-03/4_1_3_2_sample.csv                   10
# 3      2023-03-01_13-51-03/4_1_3_3_sample.csv                   10
# 4      2023-03-01_13-51-03/4_1_3_4_sample.csv                   10
# ...                                       ...                  ...
# 1933  2023-03-01_13-51-03/20_1_2_5_sample.csv                   28
# 1934  2023-03-01_13-51-03/21_1_2_1_sample.csv                   44
# 1935  2023-03-01_13-51-03/21_1_2_2_sample.csv                   44
# 1936  2023-03-01_13-51-03/21_1_2_3_sample.csv                   44
# 1937  2023-03-01_13-51-03/21_1_2_4_sample.csv                   44
#
#       lower_bound  optimized_sample_size
# 0               6                      6
# 1               7                      7
# 2               7                      7
# 3               7                      7
# 4               7                      7
# ...           ...                    ...
# 1933           11                     12
# 1934           24                     24
# 1935           24                     24
# 1936           24                     24
# 1937           24                     24
#
# [1938 rows x 9 columns]

# %% [markdown]
# * `instance` Unique name of feature model.
# * `#Variables` Number of variables in model.
# * `#Clauses` Number of clauses in model.
# * `iteration_info` Information on the individual iterations (needs some additional processing)
# * `baseline_alg` Name of the algorithm that computed the initial sample.
# * `initial_sample_path` Path to the initial sample in the database (for querying, but it also serves as identifier).
# * `initial_sample_size` Size of the initial sample.
# * `lower_bound` The lower bound computed by SampLNS.
# * `optimized_sample_size` Size of the sample after optimization with SampLNS.
