# %%
import pandas as pd

data = pd.read_json("./05_clean_data.json.zip")
data
# Out:
#                          instance  #Variables  #Clauses  \
# 0                           email          10        17
# 1                      ChatClient          14        20
# 2                      ChatClient          14        20
# 3                      ChatClient          14        20
# 4                      ChatClient          14        20
# ...                           ...         ...       ...
# 1933                  berkeleyDB2         119       346
# 1934  soletta_2015-06-26_18-38-56         129       192
# 1935  soletta_2015-06-26_18-38-56         129       192
# 1936  soletta_2015-06-26_18-38-56         129       192
# 1937  soletta_2015-06-26_18-38-56         129       192
#
#                                          iteration_info    baseline_alg  \
# 0     [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...  FIDE-YASA(m=1)
# 1     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# 2     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# 3     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# 4     [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=1)
# ...                                                 ...             ...
# 1933  [{'nbrhd_tuples': 198, 'nbrhd_confs': 10, 'ite...         Incling
# 1934  [{'nbrhd_tuples': 223, 'nbrhd_confs': 22, 'ite...         Incling
# 1935  [{'nbrhd_tuples': 227, 'nbrhd_confs': 22, 'ite...         Incling
# 1936  [{'nbrhd_tuples': 193, 'nbrhd_confs': 21, 'ite...         Incling
# 1937  [{'nbrhd_tuples': 247, 'nbrhd_confs': 26, 'ite...         Incling
#
#                           initial_sample_path  initial_sample_size  \
# 0      2023-03-01_13-51-03/3_1_3_5_sample.csv                    8
# 1      2023-03-01_13-51-03/4_1_3_1_sample.csv                   10
# 2      2023-03-01_13-51-03/4_1_3_2_sample.csv                   10
# 3      2023-03-01_13-51-03/4_1_3_3_sample.csv                   10
# 4      2023-03-01_13-51-03/4_1_3_4_sample.csv                   10
# ...                                       ...                  ...
# 1933  2023-03-01_13-51-03/20_1_2_5_sample.csv                   28
# 1934  2023-03-01_13-51-03/21_1_2_1_sample.csv                   44
# 1935  2023-03-01_13-51-03/21_1_2_2_sample.csv                   44
# 1936  2023-03-01_13-51-03/21_1_2_3_sample.csv                   44
# 1937  2023-03-01_13-51-03/21_1_2_4_sample.csv                   44
#
#       lower_bound  optimized_sample_size
# 0               6                      6
# 1               7                      7
# 2               7                      7
# 3               7                      7
# 4               7                      7
# ...           ...                    ...
# 1933           11                     12
# 1934           24                     24
# 1935           24                     24
# 1936           24                     24
# 1937           24                     24
#
# [1938 rows x 9 columns]

# %%
# Find the best values for each instance as reference.
best_solutions = (
    data[["instance", "initial_sample_size", "optimized_sample_size"]]
    .groupby("instance")
    .min()
    .reset_index()
    .rename(
        columns={
            "initial_sample_size": "best_baseline",
            "optimized_sample_size": "best_lns_ub",
        }
    )
)
best_lb = (
    data[["instance", "lower_bound"]]
    .groupby("instance")
    .max()
    .reset_index()
    .rename(columns={"lower_bound": "best_lb"})
)
mean_ub = (
    data[["instance", "optimized_sample_size"]]
    .groupby("instance")
    .mean()
    .reset_index()
    .rename(columns={"optimized_sample_size": "mean_lns_ub"})
)
best_values = best_solutions.merge(best_lb, left_on="instance", right_on="instance")
best_values = best_values.merge(mean_ub, left_on="instance", right_on="instance")

# %%
samplns_yasa = (
    data[data["baseline_alg"] == "YASA(m=1)"][["instance", "optimized_sample_size"]]
    .groupby("instance")
    .mean()
    .reset_index()
    .rename(columns={"optimized_sample_size": "samplns_yasa"})
)
best_values = best_values.merge(samplns_yasa, left_on="instance", right_on="instance")
best_values
# Out:
#                        instance  best_baseline  best_lns_ub  best_lb  \
# 0                           APL              9            7        7
# 1                     APL-Model             10            8        8
# 2               BankingSoftware             40           29       28
# 3                 BattleofTanks            444          331      256
# 4                    ChatClient              8            7        7
# 5                          DMIE             25           16       16
# 6                        E-Shop             20           12        9
# 7                    EMBToolkit           1883         1876     1872
# 8                        FameDB              8            8        8
# 9                    FeatureIDE             11            8        7
# 10                FreeBSD-8_0_0             76           61       29
# 11                          PPU             12           12       12
# 12                     SafeBali             11           11       11
# 13                  SortingLine             12            9        9
# 14                     TightVNC             10            8        8
# 15                       Violet             23           17       15
# 16            WaterlooGenerated            144           82       82
# 17                     XSEngine             63           42       33
# 18                     aaed2000             89           62       51
# 19                     am31_sim             63           40       29
# 20             atlas_mips32_4kc             66           43       33
# 21                        axTLS             16           11       10
# 22                  berkeleyDB1             19           15       15
# 23                  berkeleyDB2             21           12       11
# 24               busybox-1_18_0             29           18       13
# 25  busybox_2007-01-24_09-14-09             36           21       21
# 26  busybox_2020-12-16_21-53-05             34           22       19
# 27                    calculate              9            5        5
# 28                          car              6            5        5
# 29                         dell             34           31       31
# 30              eCos-3-0_i386pc             66           49       35
# 31                       ea2468             67           44       33
# 32                        email              6            6        6
# 33   fiasco_2017-09-26_11-30-56            237          225      225
# 34   fiasco_2020-12-01_14-09-14            214          196      196
# 35           financial_services           4396         4375     4248
# 36                fs_2017-05-22            398          396      396
# 37                          gpl             18           16       16
# 38              integrator_arm7             66           43       32
# 39                          lcm              8            6        6
# 40  soletta_2015-06-26_18-38-56             30           24       24
# 41  soletta_2017-03-09_21-02-40             57           37       37
# 42   toybox_2006-10-31_23-30-06              9            8        8
# 43   toybox_2020-12-06_00-02-46             18           11        9
#
#     mean_lns_ub  samplns_yasa
# 0      7.000000           7.0
# 1      8.000000           8.0
# 2     29.000000          29.0
# 3    344.346939         342.2
# 4      7.000000           7.0
# 5     16.152174          16.2
# 6     12.446809          12.2
# 7   1947.322581        1877.4
# 8      8.000000           8.0
# 9      8.000000           8.0
# 10    67.312500          65.0
# 11    12.000000          12.0
# 12    11.000000          11.0
# 13     9.000000           9.0
# 14     8.000000           8.0
# 15    17.000000          17.0
# 16    82.422222          82.4
# 17    45.000000          44.0
# 18    67.028571          65.2
# 19    41.567568          41.4
# 20    45.181818          47.0
# 21    11.000000          11.0
# 22    15.000000          15.0
# 23    12.022727          12.0
# 24    18.000000          18.0
# 25    21.488889          21.2
# 26    22.488889          22.4
# 27     5.000000           5.0
# 28     5.000000           5.0
# 29    31.000000          31.0
# 30    55.300000          53.6
# 31    46.027778          45.6
# 32     6.000000           6.0
# 33   225.461538         225.4
# 34   197.111111         197.6
# 35  4384.033333        4395.4
# 36   396.523810         396.0
# 37    16.000000          16.0
# 38    45.562500          45.2
# 39     6.000000           6.0
# 40    24.000000          24.0
# 41    37.468085          37.4
# 42     8.000000           8.0
# 43    11.000000          11.0

# %%
data = data.merge(best_values, left_on="instance", right_on="instance")

# %%
t = data[data["initial_sample_size"] == data["best_baseline"]].drop_duplicates(
    subset=["instance"], keep="last"
)

# %%
t
# Out:
#                          instance  #Variables  #Clauses  \
# 52                          email          10        17
# 106                    ChatClient          14        20
# 158    toybox_2006-10-31_23-30-06          16        13
# 194    fiasco_2020-12-01_14-09-14         258      1542
# 250                        E-Shop         326       499
# 303                     calculate           9        15
# 352                   berkeleyDB1          76       147
# 404                           gpl          38        99
# 419                   SortingLine          39        77
# 504                          dell          46       244
# 557                           PPU          52       109
# 576                        Violet         101       203
# 624                      TightVNC          28        39
# 650                         axTLS          96       183
# 686                   berkeleyDB2         119       346
# 724   soletta_2015-06-26_18-38-56         129       192
# 793                           APL          23        35
# 833               BankingSoftware         176       280
# 890    fiasco_2017-09-26_11-30-56         230      1181
# 946                        FameDB          22        40
# 999                           lcm           9        16
# 1019                     aaed2000        1298      3036
# 1065                FreeBSD-8_0_0        1397     15692
# 1097                       ea2468        1408      3319
# 1123                   EMBToolkit        1179      5414
# 1165             atlas_mips32_4kc        1229      2875
# 1202                     XSEngine        1273      2942
# 1247            WaterlooGenerated         580       879
# 1277           financial_services         771      7238
# 1315               busybox-1_18_0         854      1164
# 1335  busybox_2020-12-16_21-53-05        1050       996
# 1399                   FeatureIDE          19        27
# 1454                fs_2017-05-22         557      4992
# 1468                         DMIE         366       627
# 1547  soletta_2017-03-09_21-02-40         458      1862
# 1592   toybox_2020-12-06_00-02-46         334        92
# 1641                     SafeBali          24        45
# 1686  busybox_2007-01-24_09-14-09         540       429
# 1716              eCos-3-0_i386pc        1245      3723
# 1748              integrator_arm7        1272      2980
# 1801                          car          16        33
# 1845                BattleofTanks         144       769
# 1873                     am31_sim        1178      2747
# 1927                    APL-Model          28        40
#
#                                          iteration_info     baseline_alg  \
# 52    [{'nbrhd_tuples': 70, 'nbrhd_confs': 6, 'itera...   FIDE-YASA(m=5)
# 106   [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...  FIDE-YASA(m=10)
# 158   [{'nbrhd_tuples': 208, 'nbrhd_confs': 7, 'iter...       YASA(m=10)
# 194   [{'nbrhd_tuples': 245, 'nbrhd_confs': 25, 'ite...  FIDE-YASA(m=10)
# 250   [{'nbrhd_tuples': 213, 'nbrhd_confs': 3, 'iter...  FIDE-YASA(m=10)
# 303   [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...   FIDE-YASA(m=5)
# 352   [{'nbrhd_tuples': 188, 'nbrhd_confs': 9, 'iter...       YASA(m=10)
# 404   [{'nbrhd_tuples': 240, 'nbrhd_confs': 12, 'ite...       YASA(m=10)
# 419   [{'nbrhd_tuples': 179, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 504   [{'nbrhd_tuples': 238, 'nbrhd_confs': 20, 'ite...       YASA(m=10)
# 557   [{'nbrhd_tuples': 231, 'nbrhd_confs': 8, 'iter...   FIDE-YASA(m=3)
# 576   [{'nbrhd_tuples': 163, 'nbrhd_confs': 3, 'iter...  FIDE-YASA(m=10)
# 624   [{'nbrhd_tuples': 192, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 650   [{'nbrhd_tuples': 126, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 686   [{'nbrhd_tuples': 223, 'nbrhd_confs': 5, 'iter...        YASA(m=5)
# 724   [{'nbrhd_tuples': 241, 'nbrhd_confs': 11, 'ite...  FIDE-YASA(m=10)
# 793   [{'nbrhd_tuples': 207, 'nbrhd_confs': 8, 'iter...        YASA(m=3)
# 833   [{'nbrhd_tuples': 227, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=10)
# 890   [{'nbrhd_tuples': 246, 'nbrhd_confs': 28, 'ite...        YASA(m=5)
# 946   [{'nbrhd_tuples': 224, 'nbrhd_confs': 7, 'iter...       YASA(m=10)
# 999   [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...   FIDE-YASA(m=5)
# 1019  [{'nbrhd_tuples': 246, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 1065  [{'nbrhd_tuples': 96, 'nbrhd_confs': 5, 'itera...        YASA(m=3)
# 1097  [{'nbrhd_tuples': 247, 'nbrhd_confs': 4, 'iter...        YASA(m=5)
# 1123  [{'nbrhd_tuples': 249, 'nbrhd_confs': 108, 'it...        YASA(m=1)
# 1165  [{'nbrhd_tuples': 50, 'nbrhd_confs': 2, 'itera...  FIDE-YASA(m=10)
# 1202  [{'nbrhd_tuples': 115, 'nbrhd_confs': 3, 'iter...  FIDE-YASA(m=10)
# 1247  [{'nbrhd_tuples': 171, 'nbrhd_confs': 11, 'ite...  FIDE-YASA(m=10)
# 1277  [{'nbrhd_tuples': 249, 'nbrhd_confs': 161, 'it...  FIDE-YASA(m=10)
# 1315  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...  FIDE-YASA(m=10)
# 1335  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...  FIDE-YASA(m=10)
# 1399  [{'nbrhd_tuples': 169, 'nbrhd_confs': 8, 'iter...        YASA(m=5)
# 1454  [{'nbrhd_tuples': 3, 'nbrhd_confs': 3, 'iterat...  FIDE-YASA(m=10)
# 1468  [{'nbrhd_tuples': 227, 'nbrhd_confs': 5, 'iter...        YASA(m=5)
# 1547  [{'nbrhd_tuples': 188, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 1592  [{'nbrhd_tuples': 206, 'nbrhd_confs': 5, 'iter...  FIDE-YASA(m=10)
# 1641  [{'nbrhd_tuples': 141, 'nbrhd_confs': 11, 'ite...       YASA(m=10)
# 1686  [{'nbrhd_tuples': 209, 'nbrhd_confs': 2, 'iter...  FIDE-YASA(m=10)
# 1716  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...  FIDE-YASA(m=10)
# 1748  [{'nbrhd_tuples': 52, 'nbrhd_confs': 1, 'itera...  FIDE-YASA(m=10)
# 1801  [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...       YASA(m=10)
# 1845  [{'nbrhd_tuples': 248, 'nbrhd_confs': 74, 'ite...       YASA(m=10)
# 1873  [{'nbrhd_tuples': 222, 'nbrhd_confs': 3, 'iter...        YASA(m=3)
# 1927  [{'nbrhd_tuples': 159, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
#
#                            initial_sample_path  initial_sample_size  \
# 52      2023-03-01_13-51-03/3_1_5_4_sample.csv                    6
# 106     2023-03-01_13-51-03/4_1_6_5_sample.csv                    8
# 158    2023-03-01_13-51-03/5_1_10_5_sample.csv                    9
# 194    2023-03-01_13-51-03/25_1_6_5_sample.csv                  214
# 250    2023-03-01_13-51-03/28_1_6_5_sample.csv                   20
# 303     2023-03-01_13-51-03/1_1_5_5_sample.csv                    9
# 352   2023-03-01_13-51-03/17_1_10_2_sample.csv                   19
# 404   2023-03-01_13-51-03/13_1_10_4_sample.csv                   18
# 419    2023-03-01_13-51-03/14_1_6_5_sample.csv                   12
# 504   2023-03-01_13-51-03/15_1_10_4_sample.csv                   34
# 557    2023-03-01_13-51-03/16_1_4_5_sample.csv                   12
# 576    2023-03-01_13-51-03/19_1_6_4_sample.csv                   23
# 624   2023-03-01_13-51-03/11_1_10_5_sample.csv                   10
# 650   2023-03-01_13-51-03/18_1_10_2_sample.csv                   16
# 686    2023-03-01_13-51-03/20_1_9_3_sample.csv                   21
# 724    2023-03-01_13-51-03/21_1_6_4_sample.csv                   30
# 793     2023-03-01_13-51-03/9_1_8_5_sample.csv                    9
# 833    2023-03-01_13-51-03/23_1_6_5_sample.csv                   40
# 890    2023-03-01_13-51-03/24_1_9_1_sample.csv                  237
# 946    2023-03-01_13-51-03/8_1_10_3_sample.csv                    8
# 999     2023-03-01_13-51-03/2_1_5_5_sample.csv                    8
# 1019   2023-03-01_13-51-03/45_1_6_5_sample.csv                   89
# 1065   2023-03-01_13-51-03/46_1_8_4_sample.csv                   76
# 1097   2023-03-01_13-51-03/47_1_9_2_sample.csv                   67
# 1123   2023-03-01_13-51-03/40_1_7_5_sample.csv                 1883
# 1165   2023-03-01_13-51-03/41_1_6_5_sample.csv                   66
# 1202   2023-03-01_13-51-03/44_1_6_4_sample.csv                   63
# 1247   2023-03-01_13-51-03/34_1_6_5_sample.csv                  144
# 1277   2023-03-01_13-51-03/35_1_6_5_sample.csv                 4396
# 1315   2023-03-01_13-51-03/36_1_6_4_sample.csv                   29
# 1335   2023-03-01_13-51-03/38_1_6_5_sample.csv                   34
# 1399    2023-03-01_13-51-03/7_1_9_4_sample.csv                   11
# 1454   2023-03-01_13-51-03/33_1_6_5_sample.csv                  398
# 1468   2023-03-01_13-51-03/30_1_9_3_sample.csv                   25
# 1547   2023-03-01_13-51-03/31_1_6_5_sample.csv                   57
# 1592   2023-03-01_13-51-03/29_1_6_5_sample.csv                   18
# 1641  2023-03-01_13-51-03/10_1_10_1_sample.csv                   11
# 1686   2023-03-01_13-51-03/32_1_6_5_sample.csv                   36
# 1716   2023-03-01_13-51-03/42_1_6_5_sample.csv                   66
# 1748   2023-03-01_13-51-03/43_1_6_5_sample.csv                   66
# 1801   2023-03-01_13-51-03/6_1_10_1_sample.csv                    6
# 1845  2023-03-01_13-51-03/22_1_10_3_sample.csv                  444
# 1873   2023-03-01_13-51-03/39_1_8_5_sample.csv                   63
# 1927  2023-03-01_13-51-03/12_1_10_2_sample.csv                   10
#
#       lower_bound  optimized_sample_size  best_baseline  best_lns_ub  best_lb  \
# 52              6                      6              6            6        6
# 106             7                      7              8            7        7
# 158             8                      8              9            8        8
# 194           196                    197            214          196      196
# 250             8                     12             20           12        9
# 303             5                      5              9            5        5
# 352            15                     15             19           15       15
# 404            16                     16             18           16       16
# 419             9                      9             12            9        9
# 504            31                     31             34           31       31
# 557            12                     12             12           12       12
# 576            13                     17             23           17       15
# 624             8                      8             10            8        8
# 650            10                     11             16           11       10
# 686            11                     12             21           12       11
# 724            24                     24             30           24       24
# 793             7                      7              9            7        7
# 833            28                     29             40           29       28
# 890           224                    225            237          225      225
# 946             8                      8              8            8        8
# 999             6                      6              8            6        6
# 1019           50                     62             89           62       51
# 1065           23                     63             76           61       29
# 1097           30                     45             67           44       33
# 1123         1818                   1880           1883         1876     1872
# 1165           31                     45             66           43       33
# 1202           28                     45             63           42       33
# 1247           82                     83            144           82       82
# 1277         4144                   4383           4396         4375     4248
# 1315           12                     18             29           18       13
# 1335           16                     22             34           22       19
# 1399            7                      8             11            8        7
# 1454          396                    396            398          396      396
# 1468           16                     17             25           16       16
# 1547           28                     37             57           37       37
# 1592            9                     11             18           11        9
# 1641           11                     11             11           11       11
# 1686           21                     21             36           21       21
# 1716           25                     54             66           49       35
# 1748           25                     45             66           43       32
# 1801            5                      5              6            5        5
# 1845          256                    343            444          331      256
# 1873           22                     42             63           40       29
# 1927            7                      8             10            8        8
#
#       mean_lns_ub  samplns_yasa
# 52       6.000000           6.0
# 106      7.000000           7.0
# 158      8.000000           8.0
# 194    197.111111         197.6
# 250     12.446809          12.2
# 303      5.000000           5.0
# 352     15.000000          15.0
# 404     16.000000          16.0
# 419      9.000000           9.0
# 504     31.000000          31.0
# 557     12.000000          12.0
# 576     17.000000          17.0
# 624      8.000000           8.0
# 650     11.000000          11.0
# 686     12.022727          12.0
# 724     24.000000          24.0
# 793      7.000000           7.0
# 833     29.000000          29.0
# 890    225.461538         225.4
# 946      8.000000           8.0
# 999      6.000000           6.0
# 1019    67.028571          65.2
# 1065    67.312500          65.0
# 1097    46.027778          45.6
# 1123  1947.322581        1877.4
# 1165    45.181818          47.0
# 1202    45.000000          44.0
# 1247    82.422222          82.4
# 1277  4384.033333        4395.4
# 1315    18.000000          18.0
# 1335    22.488889          22.4
# 1399     8.000000           8.0
# 1454   396.523810         396.0
# 1468    16.152174          16.2
# 1547    37.468085          37.4
# 1592    11.000000          11.0
# 1641    11.000000          11.0
# 1686    21.488889          21.2
# 1716    55.300000          53.6
# 1748    45.562500          45.2
# 1801     5.000000           5.0
# 1845   344.346939         342.2
# 1873    41.567568          41.4
# 1927     8.000000           8.0

# %%
t["baseline"] = t.apply(
    (lambda row: f"{row['initial_sample_size']}/{row['baseline_alg']}"), axis=1
)
t["sampLNS"] = t.apply(
    (lambda row: f"{row['best_lns_ub']} (\\O {int(round(row['mean_lns_ub']))})"), axis=1
)


def shorten(s):
    if len(s) > 23:
        return s[:20] + "..."
    return s


# t["instance_details"] = t.apply((lambda row: f"{shorten(row['instance'])} ({row['#Variables']}/{row['#Clauses']})"), axis=1)
t["instance_details"] = t.apply((lambda row: f"{shorten(row['instance'])}"), axis=1)
t["reduction"] = 100 * (1 - t["samplns_yasa"] / t["best_baseline"])
t["rel_size_after_samplns"] = 100 * (t["samplns_yasa"] / t["best_baseline"])
t["savings"] = 100 * (1 - t["samplns_yasa"] / t["best_baseline"])
t["opt_1"] = t["best_baseline"] == t["best_lb"]
t["opt_2"] = t["samplns_yasa"].apply(lambda x: round(x)) == t["best_lb"]
t
# Out:
#                          instance  #Variables  #Clauses  \
# 52                          email          10        17
# 106                    ChatClient          14        20
# 158    toybox_2006-10-31_23-30-06          16        13
# 194    fiasco_2020-12-01_14-09-14         258      1542
# 250                        E-Shop         326       499
# 303                     calculate           9        15
# 352                   berkeleyDB1          76       147
# 404                           gpl          38        99
# 419                   SortingLine          39        77
# 504                          dell          46       244
# 557                           PPU          52       109
# 576                        Violet         101       203
# 624                      TightVNC          28        39
# 650                         axTLS          96       183
# 686                   berkeleyDB2         119       346
# 724   soletta_2015-06-26_18-38-56         129       192
# 793                           APL          23        35
# 833               BankingSoftware         176       280
# 890    fiasco_2017-09-26_11-30-56         230      1181
# 946                        FameDB          22        40
# 999                           lcm           9        16
# 1019                     aaed2000        1298      3036
# 1065                FreeBSD-8_0_0        1397     15692
# 1097                       ea2468        1408      3319
# 1123                   EMBToolkit        1179      5414
# 1165             atlas_mips32_4kc        1229      2875
# 1202                     XSEngine        1273      2942
# 1247            WaterlooGenerated         580       879
# 1277           financial_services         771      7238
# 1315               busybox-1_18_0         854      1164
# 1335  busybox_2020-12-16_21-53-05        1050       996
# 1399                   FeatureIDE          19        27
# 1454                fs_2017-05-22         557      4992
# 1468                         DMIE         366       627
# 1547  soletta_2017-03-09_21-02-40         458      1862
# 1592   toybox_2020-12-06_00-02-46         334        92
# 1641                     SafeBali          24        45
# 1686  busybox_2007-01-24_09-14-09         540       429
# 1716              eCos-3-0_i386pc        1245      3723
# 1748              integrator_arm7        1272      2980
# 1801                          car          16        33
# 1845                BattleofTanks         144       769
# 1873                     am31_sim        1178      2747
# 1927                    APL-Model          28        40
#
#                                          iteration_info     baseline_alg  \
# 52    [{'nbrhd_tuples': 70, 'nbrhd_confs': 6, 'itera...   FIDE-YASA(m=5)
# 106   [{'nbrhd_tuples': 176, 'nbrhd_confs': 8, 'iter...  FIDE-YASA(m=10)
# 158   [{'nbrhd_tuples': 208, 'nbrhd_confs': 7, 'iter...       YASA(m=10)
# 194   [{'nbrhd_tuples': 245, 'nbrhd_confs': 25, 'ite...  FIDE-YASA(m=10)
# 250   [{'nbrhd_tuples': 213, 'nbrhd_confs': 3, 'iter...  FIDE-YASA(m=10)
# 303   [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...   FIDE-YASA(m=5)
# 352   [{'nbrhd_tuples': 188, 'nbrhd_confs': 9, 'iter...       YASA(m=10)
# 404   [{'nbrhd_tuples': 240, 'nbrhd_confs': 12, 'ite...       YASA(m=10)
# 419   [{'nbrhd_tuples': 179, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 504   [{'nbrhd_tuples': 238, 'nbrhd_confs': 20, 'ite...       YASA(m=10)
# 557   [{'nbrhd_tuples': 231, 'nbrhd_confs': 8, 'iter...   FIDE-YASA(m=3)
# 576   [{'nbrhd_tuples': 163, 'nbrhd_confs': 3, 'iter...  FIDE-YASA(m=10)
# 624   [{'nbrhd_tuples': 192, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 650   [{'nbrhd_tuples': 126, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
# 686   [{'nbrhd_tuples': 223, 'nbrhd_confs': 5, 'iter...        YASA(m=5)
# 724   [{'nbrhd_tuples': 241, 'nbrhd_confs': 11, 'ite...  FIDE-YASA(m=10)
# 793   [{'nbrhd_tuples': 207, 'nbrhd_confs': 8, 'iter...        YASA(m=3)
# 833   [{'nbrhd_tuples': 227, 'nbrhd_confs': 10, 'ite...  FIDE-YASA(m=10)
# 890   [{'nbrhd_tuples': 246, 'nbrhd_confs': 28, 'ite...        YASA(m=5)
# 946   [{'nbrhd_tuples': 224, 'nbrhd_confs': 7, 'iter...       YASA(m=10)
# 999   [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...   FIDE-YASA(m=5)
# 1019  [{'nbrhd_tuples': 246, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 1065  [{'nbrhd_tuples': 96, 'nbrhd_confs': 5, 'itera...        YASA(m=3)
# 1097  [{'nbrhd_tuples': 247, 'nbrhd_confs': 4, 'iter...        YASA(m=5)
# 1123  [{'nbrhd_tuples': 249, 'nbrhd_confs': 108, 'it...        YASA(m=1)
# 1165  [{'nbrhd_tuples': 50, 'nbrhd_confs': 2, 'itera...  FIDE-YASA(m=10)
# 1202  [{'nbrhd_tuples': 115, 'nbrhd_confs': 3, 'iter...  FIDE-YASA(m=10)
# 1247  [{'nbrhd_tuples': 171, 'nbrhd_confs': 11, 'ite...  FIDE-YASA(m=10)
# 1277  [{'nbrhd_tuples': 249, 'nbrhd_confs': 161, 'it...  FIDE-YASA(m=10)
# 1315  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...  FIDE-YASA(m=10)
# 1335  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...  FIDE-YASA(m=10)
# 1399  [{'nbrhd_tuples': 169, 'nbrhd_confs': 8, 'iter...        YASA(m=5)
# 1454  [{'nbrhd_tuples': 3, 'nbrhd_confs': 3, 'iterat...  FIDE-YASA(m=10)
# 1468  [{'nbrhd_tuples': 227, 'nbrhd_confs': 5, 'iter...        YASA(m=5)
# 1547  [{'nbrhd_tuples': 188, 'nbrhd_confs': 7, 'iter...  FIDE-YASA(m=10)
# 1592  [{'nbrhd_tuples': 206, 'nbrhd_confs': 5, 'iter...  FIDE-YASA(m=10)
# 1641  [{'nbrhd_tuples': 141, 'nbrhd_confs': 11, 'ite...       YASA(m=10)
# 1686  [{'nbrhd_tuples': 209, 'nbrhd_confs': 2, 'iter...  FIDE-YASA(m=10)
# 1716  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...  FIDE-YASA(m=10)
# 1748  [{'nbrhd_tuples': 52, 'nbrhd_confs': 1, 'itera...  FIDE-YASA(m=10)
# 1801  [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...       YASA(m=10)
# 1845  [{'nbrhd_tuples': 248, 'nbrhd_confs': 74, 'ite...       YASA(m=10)
# 1873  [{'nbrhd_tuples': 222, 'nbrhd_confs': 3, 'iter...        YASA(m=3)
# 1927  [{'nbrhd_tuples': 159, 'nbrhd_confs': 6, 'iter...       YASA(m=10)
#
#                            initial_sample_path  initial_sample_size  \
# 52      2023-03-01_13-51-03/3_1_5_4_sample.csv                    6
# 106     2023-03-01_13-51-03/4_1_6_5_sample.csv                    8
# 158    2023-03-01_13-51-03/5_1_10_5_sample.csv                    9
# 194    2023-03-01_13-51-03/25_1_6_5_sample.csv                  214
# 250    2023-03-01_13-51-03/28_1_6_5_sample.csv                   20
# 303     2023-03-01_13-51-03/1_1_5_5_sample.csv                    9
# 352   2023-03-01_13-51-03/17_1_10_2_sample.csv                   19
# 404   2023-03-01_13-51-03/13_1_10_4_sample.csv                   18
# 419    2023-03-01_13-51-03/14_1_6_5_sample.csv                   12
# 504   2023-03-01_13-51-03/15_1_10_4_sample.csv                   34
# 557    2023-03-01_13-51-03/16_1_4_5_sample.csv                   12
# 576    2023-03-01_13-51-03/19_1_6_4_sample.csv                   23
# 624   2023-03-01_13-51-03/11_1_10_5_sample.csv                   10
# 650   2023-03-01_13-51-03/18_1_10_2_sample.csv                   16
# 686    2023-03-01_13-51-03/20_1_9_3_sample.csv                   21
# 724    2023-03-01_13-51-03/21_1_6_4_sample.csv                   30
# 793     2023-03-01_13-51-03/9_1_8_5_sample.csv                    9
# 833    2023-03-01_13-51-03/23_1_6_5_sample.csv                   40
# 890    2023-03-01_13-51-03/24_1_9_1_sample.csv                  237
# 946    2023-03-01_13-51-03/8_1_10_3_sample.csv                    8
# 999     2023-03-01_13-51-03/2_1_5_5_sample.csv                    8
# 1019   2023-03-01_13-51-03/45_1_6_5_sample.csv                   89
# 1065   2023-03-01_13-51-03/46_1_8_4_sample.csv                   76
# 1097   2023-03-01_13-51-03/47_1_9_2_sample.csv                   67
# 1123   2023-03-01_13-51-03/40_1_7_5_sample.csv                 1883
# 1165   2023-03-01_13-51-03/41_1_6_5_sample.csv                   66
# 1202   2023-03-01_13-51-03/44_1_6_4_sample.csv                   63
# 1247   2023-03-01_13-51-03/34_1_6_5_sample.csv                  144
# 1277   2023-03-01_13-51-03/35_1_6_5_sample.csv                 4396
# 1315   2023-03-01_13-51-03/36_1_6_4_sample.csv                   29
# 1335   2023-03-01_13-51-03/38_1_6_5_sample.csv                   34
# 1399    2023-03-01_13-51-03/7_1_9_4_sample.csv                   11
# 1454   2023-03-01_13-51-03/33_1_6_5_sample.csv                  398
# 1468   2023-03-01_13-51-03/30_1_9_3_sample.csv                   25
# 1547   2023-03-01_13-51-03/31_1_6_5_sample.csv                   57
# 1592   2023-03-01_13-51-03/29_1_6_5_sample.csv                   18
# 1641  2023-03-01_13-51-03/10_1_10_1_sample.csv                   11
# 1686   2023-03-01_13-51-03/32_1_6_5_sample.csv                   36
# 1716   2023-03-01_13-51-03/42_1_6_5_sample.csv                   66
# 1748   2023-03-01_13-51-03/43_1_6_5_sample.csv                   66
# 1801   2023-03-01_13-51-03/6_1_10_1_sample.csv                    6
# 1845  2023-03-01_13-51-03/22_1_10_3_sample.csv                  444
# 1873   2023-03-01_13-51-03/39_1_8_5_sample.csv                   63
# 1927  2023-03-01_13-51-03/12_1_10_2_sample.csv                   10
#
#       lower_bound  optimized_sample_size  best_baseline  ...  mean_lns_ub  \
# 52              6                      6              6  ...     6.000000
# 106             7                      7              8  ...     7.000000
# 158             8                      8              9  ...     8.000000
# 194           196                    197            214  ...   197.111111
# 250             8                     12             20  ...    12.446809
# 303             5                      5              9  ...     5.000000
# 352            15                     15             19  ...    15.000000
# 404            16                     16             18  ...    16.000000
# 419             9                      9             12  ...     9.000000
# 504            31                     31             34  ...    31.000000
# 557            12                     12             12  ...    12.000000
# 576            13                     17             23  ...    17.000000
# 624             8                      8             10  ...     8.000000
# 650            10                     11             16  ...    11.000000
# 686            11                     12             21  ...    12.022727
# 724            24                     24             30  ...    24.000000
# 793             7                      7              9  ...     7.000000
# 833            28                     29             40  ...    29.000000
# 890           224                    225            237  ...   225.461538
# 946             8                      8              8  ...     8.000000
# 999             6                      6              8  ...     6.000000
# 1019           50                     62             89  ...    67.028571
# 1065           23                     63             76  ...    67.312500
# 1097           30                     45             67  ...    46.027778
# 1123         1818                   1880           1883  ...  1947.322581
# 1165           31                     45             66  ...    45.181818
# 1202           28                     45             63  ...    45.000000
# 1247           82                     83            144  ...    82.422222
# 1277         4144                   4383           4396  ...  4384.033333
# 1315           12                     18             29  ...    18.000000
# 1335           16                     22             34  ...    22.488889
# 1399            7                      8             11  ...     8.000000
# 1454          396                    396            398  ...   396.523810
# 1468           16                     17             25  ...    16.152174
# 1547           28                     37             57  ...    37.468085
# 1592            9                     11             18  ...    11.000000
# 1641           11                     11             11  ...    11.000000
# 1686           21                     21             36  ...    21.488889
# 1716           25                     54             66  ...    55.300000
# 1748           25                     45             66  ...    45.562500
# 1801            5                      5              6  ...     5.000000
# 1845          256                    343            444  ...   344.346939
# 1873           22                     42             63  ...    41.567568
# 1927            7                      8             10  ...     8.000000
#
#       samplns_yasa              baseline         sampLNS  \
# 52             6.0      6/FIDE-YASA(m=5)        6 (\O 6)
# 106            7.0     8/FIDE-YASA(m=10)        7 (\O 7)
# 158            8.0          9/YASA(m=10)        8 (\O 8)
# 194          197.6   214/FIDE-YASA(m=10)    196 (\O 197)
# 250           12.2    20/FIDE-YASA(m=10)      12 (\O 12)
# 303            5.0      9/FIDE-YASA(m=5)        5 (\O 5)
# 352           15.0         19/YASA(m=10)      15 (\O 15)
# 404           16.0         18/YASA(m=10)      16 (\O 16)
# 419            9.0    12/FIDE-YASA(m=10)        9 (\O 9)
# 504           31.0         34/YASA(m=10)      31 (\O 31)
# 557           12.0     12/FIDE-YASA(m=3)      12 (\O 12)
# 576           17.0    23/FIDE-YASA(m=10)      17 (\O 17)
# 624            8.0         10/YASA(m=10)        8 (\O 8)
# 650           11.0         16/YASA(m=10)      11 (\O 11)
# 686           12.0          21/YASA(m=5)      12 (\O 12)
# 724           24.0    30/FIDE-YASA(m=10)      24 (\O 24)
# 793            7.0           9/YASA(m=3)        7 (\O 7)
# 833           29.0    40/FIDE-YASA(m=10)      29 (\O 29)
# 890          225.4         237/YASA(m=5)    225 (\O 225)
# 946            8.0          8/YASA(m=10)        8 (\O 8)
# 999            6.0      8/FIDE-YASA(m=5)        6 (\O 6)
# 1019          65.2    89/FIDE-YASA(m=10)      62 (\O 67)
# 1065          65.0          76/YASA(m=3)      61 (\O 67)
# 1097          45.6          67/YASA(m=5)      44 (\O 46)
# 1123        1877.4        1883/YASA(m=1)  1876 (\O 1947)
# 1165          47.0    66/FIDE-YASA(m=10)      43 (\O 45)
# 1202          44.0    63/FIDE-YASA(m=10)      42 (\O 45)
# 1247          82.4   144/FIDE-YASA(m=10)      82 (\O 82)
# 1277        4395.4  4396/FIDE-YASA(m=10)  4375 (\O 4384)
# 1315          18.0    29/FIDE-YASA(m=10)      18 (\O 18)
# 1335          22.4    34/FIDE-YASA(m=10)      22 (\O 22)
# 1399           8.0          11/YASA(m=5)        8 (\O 8)
# 1454         396.0   398/FIDE-YASA(m=10)    396 (\O 397)
# 1468          16.2          25/YASA(m=5)      16 (\O 16)
# 1547          37.4    57/FIDE-YASA(m=10)      37 (\O 37)
# 1592          11.0    18/FIDE-YASA(m=10)      11 (\O 11)
# 1641          11.0         11/YASA(m=10)      11 (\O 11)
# 1686          21.2    36/FIDE-YASA(m=10)      21 (\O 21)
# 1716          53.6    66/FIDE-YASA(m=10)      49 (\O 55)
# 1748          45.2    66/FIDE-YASA(m=10)      43 (\O 46)
# 1801           5.0          6/YASA(m=10)        5 (\O 5)
# 1845         342.2        444/YASA(m=10)    331 (\O 344)
# 1873          41.4          63/YASA(m=3)      40 (\O 42)
# 1927           8.0         10/YASA(m=10)        8 (\O 8)
#
#              instance_details  reduction rel_size_after_samplns    savings  \
# 52                      email   0.000000             100.000000   0.000000
# 106                ChatClient  12.500000              87.500000  12.500000
# 158   toybox_2006-10-31_23...  11.111111              88.888889  11.111111
# 194   fiasco_2020-12-01_14...   7.663551              92.336449   7.663551
# 250                    E-Shop  39.000000              61.000000  39.000000
# 303                 calculate  44.444444              55.555556  44.444444
# 352               berkeleyDB1  21.052632              78.947368  21.052632
# 404                       gpl  11.111111              88.888889  11.111111
# 419               SortingLine  25.000000              75.000000  25.000000
# 504                      dell   8.823529              91.176471   8.823529
# 557                       PPU   0.000000             100.000000   0.000000
# 576                    Violet  26.086957              73.913043  26.086957
# 624                  TightVNC  20.000000              80.000000  20.000000
# 650                     axTLS  31.250000              68.750000  31.250000
# 686               berkeleyDB2  42.857143              57.142857  42.857143
# 724   soletta_2015-06-26_1...  20.000000              80.000000  20.000000
# 793                       APL  22.222222              77.777778  22.222222
# 833           BankingSoftware  27.500000              72.500000  27.500000
# 890   fiasco_2017-09-26_11...   4.894515              95.105485   4.894515
# 946                    FameDB   0.000000             100.000000   0.000000
# 999                       lcm  25.000000              75.000000  25.000000
# 1019                 aaed2000  26.741573              73.258427  26.741573
# 1065            FreeBSD-8_0_0  14.473684              85.526316  14.473684
# 1097                   ea2468  31.940299              68.059701  31.940299
# 1123               EMBToolkit   0.297398              99.702602   0.297398
# 1165         atlas_mips32_4kc  28.787879              71.212121  28.787879
# 1202                 XSEngine  30.158730              69.841270  30.158730
# 1247        WaterlooGenerated  42.777778              57.222222  42.777778
# 1277       financial_services   0.013649              99.986351   0.013649
# 1315           busybox-1_18_0  37.931034              62.068966  37.931034
# 1335  busybox_2020-12-16_2...  34.117647              65.882353  34.117647
# 1399               FeatureIDE  27.272727              72.727273  27.272727
# 1454            fs_2017-05-22   0.502513              99.497487   0.502513
# 1468                     DMIE  35.200000              64.800000  35.200000
# 1547  soletta_2017-03-09_2...  34.385965              65.614035  34.385965
# 1592  toybox_2020-12-06_00...  38.888889              61.111111  38.888889
# 1641                 SafeBali   0.000000             100.000000   0.000000
# 1686  busybox_2007-01-24_0...  41.111111              58.888889  41.111111
# 1716          eCos-3-0_i386pc  18.787879              81.212121  18.787879
# 1748          integrator_arm7  31.515152              68.484848  31.515152
# 1801                      car  16.666667              83.333333  16.666667
# 1845            BattleofTanks  22.927928              77.072072  22.927928
# 1873                 am31_sim  34.285714              65.714286  34.285714
# 1927                APL-Model  20.000000              80.000000  20.000000
#
#       opt_1  opt_2
# 52     True   True
# 106   False   True
# 158   False   True
# 194   False  False
# 250   False  False
# 303   False   True
# 352   False   True
# 404   False   True
# 419   False   True
# 504   False   True
# 557    True   True
# 576   False  False
# 624   False   True
# 650   False  False
# 686   False  False
# 724   False   True
# 793   False   True
# 833   False  False
# 890   False   True
# 946    True   True
# 999   False   True
# 1019  False  False
# 1065  False  False
# 1097  False  False
# 1123  False  False
# 1165  False  False
# 1202  False  False
# 1247  False   True
# 1277  False  False
# 1315  False  False
# 1335  False  False
# 1399  False  False
# 1454  False   True
# 1468  False   True
# 1547  False   True
# 1592  False  False
# 1641   True   True
# 1686  False   True
# 1716  False  False
# 1748  False  False
# 1801  False   True
# 1845  False  False
# 1873  False  False
# 1927  False   True
#
# [44 rows x 22 columns]

# %%
# Code to query the time of the last change in lower or upper bound.


# Collect the data from the iteration_info events.
class EventCollector:
    def __init__(self):
        self.events = {
            "time": [],
            "val": [],
            "type": [],
            "instance": [],
            "path": [],
            "alg": [],
            "initial_sample_size": [],
            "y": [],
            "final": [],
        }

    def __call__(self, row):
        it_data = row["iteration_info"]

        def add(val, lbub, time, final=False):
            if time > 900:
                return
            self.events["time"].append(time / 60)
            self.events["val"].append(val)
            self.events["type"].append(lbub)
            self.events["instance"].append(row["instance"])
            self.events["alg"].append(row["baseline_alg"])
            self.events["path"].append(row["initial_sample_path"])
            self.events["initial_sample_size"].append(row["initial_sample_size"])
            self.events["y"].append(100 * (val / row["best_lb"]))
            self.events["final"].append(final)

        # add a zero entry
        add(0, "Lower", 0)
        add(row["initial_sample_size"], "Upper", 0)
        for event in it_data:
            add(
                event["lb"],
                "Lower",
                event["time"],
                final=event["lb"] == row["lower_bound"],
            )
            add(
                event["ub"],
                "Upper",
                event["time"],
                final=event["ub"] == row["optimized_sample_size"],
            )


instance_infos = (
    data[["instance", "#Variables", "#Clauses"]]
    .drop_duplicates()
    .sort_values(by=["#Variables", "#Clauses"])
)

ec = EventCollector()
data[data["baseline_alg"] == "FIDE-YASA(m=1)"].sort_values(
    by=["#Variables", "#Clauses"]
).apply(ec, axis=1)
t_events = pd.DataFrame(ec.events)
t_ = t_events.groupby(["instance", "path"])["time"].max().reset_index()
unsolved_instances = t_[t_["time"] == 0]["instance"].unique().tolist()
solved_instances = [
    x for x in instance_infos["instance"].tolist() if x not in unsolved_instances
]

time_until_last_change = (
    t_events[t_events["final"] & (t_events["instance"].isin(solved_instances))]
    .groupby(["instance", "path", "type"])[["time"]]
    .min()
    .reset_index()
    .groupby(["instance", "type"])[["time"]]
    .mean()
)

unsolved_symbol = "$*$"


def get_time_info(instance):
    d = time_until_last_change.groupby("instance")["time"].max().to_dict()
    if instance not in d:
        return unsolved_symbol
    else:
        secs = round(d[instance] * 60)
        if secs == 0:
            return "$<\\SI{1}{\\second}$"
        return "\\SI{" + str(secs) + "}{\\second}"

# %%
tex_table = ""


def append(*args):
    global tex_table
    tex_table += f"{' '.join(str(x) for x in args)}\n"


t.sort_values(by=["#Variables", "#Clauses"], inplace=True)
for idx in t.index:
    unsolved = t["instance"][idx] in unsolved_instances
    append(
        t["instance_details"][idx].replace("_", "\\_"),
        "& \\num{",
        t["#Variables"][idx],
        "} & \\num{",
        t["#Clauses"][idx],
        "} &",
        ("\\textbf{" if t["opt_1"][idx] else "{") + "\\num[text-series-to-math=true]{",
        t["best_baseline"][idx],
        " }} &",
        unsolved_symbol
        if unsolved
        else (
            ("\\textbf{" if t["opt_2"][idx] else "{")
            + "\\num[text-series-to-math=true]{"
            + str(int(round(t["samplns_yasa"][idx])))
            + "}}"
        ),
        " & \\num{",
        round(t["best_lb"][idx]),
        "} &",
        unsolved_symbol
        if unsolved
        else "\\SI{" + f"{round(t['savings'][idx], 2):.2g}" + "}{\\percent}",
        "&",
        get_time_info(t["instance"][idx]),
        "\\\\",
    )

print(tex_table)
# Out:
# calculate & \num{ 9 } & \num{ 15 } & {\num[text-series-to-math=true]{ 9  }} & \textbf{\num[text-series-to-math=true]{5}}  & \num{ 5 } & \SI{44}{\percent} & $<\SI{1}{\second}$ \\
# lcm & \num{ 9 } & \num{ 16 } & {\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{6}}  & \num{ 6 } & \SI{25}{\percent} & $<\SI{1}{\second}$ \\
# email & \num{ 10 } & \num{ 17 } & \textbf{\num[text-series-to-math=true]{ 6  }} & \textbf{\num[text-series-to-math=true]{6}}  & \num{ 6 } & \SI{0}{\percent} & $<\SI{1}{\second}$ \\
# ChatClient & \num{ 14 } & \num{ 20 } & {\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{7}}  & \num{ 7 } & \SI{12}{\percent} & \SI{10}{\second} \\
# toybox\_2006-10-31\_23... & \num{ 16 } & \num{ 13 } & {\num[text-series-to-math=true]{ 9  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{11}{\percent} & \SI{6}{\second} \\
# car & \num{ 16 } & \num{ 33 } & {\num[text-series-to-math=true]{ 6  }} & \textbf{\num[text-series-to-math=true]{5}}  & \num{ 5 } & \SI{17}{\percent} & $<\SI{1}{\second}$ \\
# FeatureIDE & \num{ 19 } & \num{ 27 } & {\num[text-series-to-math=true]{ 11  }} & {\num[text-series-to-math=true]{8}}  & \num{ 7 } & \SI{27}{\percent} & \SI{24}{\second} \\
# FameDB & \num{ 22 } & \num{ 40 } & \textbf{\num[text-series-to-math=true]{ 8  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{0}{\percent} & \SI{5}{\second} \\
# APL & \num{ 23 } & \num{ 35 } & {\num[text-series-to-math=true]{ 9  }} & \textbf{\num[text-series-to-math=true]{7}}  & \num{ 7 } & \SI{22}{\percent} & \SI{11}{\second} \\
# SafeBali & \num{ 24 } & \num{ 45 } & \textbf{\num[text-series-to-math=true]{ 11  }} & \textbf{\num[text-series-to-math=true]{11}}  & \num{ 11 } & \SI{0}{\percent} & $<\SI{1}{\second}$ \\
# TightVNC & \num{ 28 } & \num{ 39 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{20}{\percent} & \SI{210}{\second} \\
# APL-Model & \num{ 28 } & \num{ 40 } & {\num[text-series-to-math=true]{ 10  }} & \textbf{\num[text-series-to-math=true]{8}}  & \num{ 8 } & \SI{20}{\percent} & \SI{195}{\second} \\
# gpl & \num{ 38 } & \num{ 99 } & {\num[text-series-to-math=true]{ 18  }} & \textbf{\num[text-series-to-math=true]{16}}  & \num{ 16 } & \SI{11}{\percent} & \SI{15}{\second} \\
# SortingLine & \num{ 39 } & \num{ 77 } & {\num[text-series-to-math=true]{ 12  }} & \textbf{\num[text-series-to-math=true]{9}}  & \num{ 9 } & \SI{25}{\percent} & \SI{84}{\second} \\
# dell & \num{ 46 } & \num{ 244 } & {\num[text-series-to-math=true]{ 34  }} & \textbf{\num[text-series-to-math=true]{31}}  & \num{ 31 } & \SI{8.8}{\percent} & \SI{146}{\second} \\
# PPU & \num{ 52 } & \num{ 109 } & \textbf{\num[text-series-to-math=true]{ 12  }} & \textbf{\num[text-series-to-math=true]{12}}  & \num{ 12 } & \SI{0}{\percent} & \SI{26}{\second} \\
# berkeleyDB1 & \num{ 76 } & \num{ 147 } & {\num[text-series-to-math=true]{ 19  }} & \textbf{\num[text-series-to-math=true]{15}}  & \num{ 15 } & \SI{21}{\percent} & \SI{475}{\second} \\
# axTLS & \num{ 96 } & \num{ 183 } & {\num[text-series-to-math=true]{ 16  }} & {\num[text-series-to-math=true]{11}}  & \num{ 10 } & \SI{31}{\percent} & $*$ \\
# Violet & \num{ 101 } & \num{ 203 } & {\num[text-series-to-math=true]{ 23  }} & {\num[text-series-to-math=true]{17}}  & \num{ 15 } & \SI{26}{\percent} & \SI{636}{\second} \\
# berkeleyDB2 & \num{ 119 } & \num{ 346 } & {\num[text-series-to-math=true]{ 21  }} & {\num[text-series-to-math=true]{12}}  & \num{ 11 } & \SI{43}{\percent} & \SI{309}{\second} \\
# soletta\_2015-06-26\_1... & \num{ 129 } & \num{ 192 } & {\num[text-series-to-math=true]{ 30  }} & \textbf{\num[text-series-to-math=true]{24}}  & \num{ 24 } & \SI{20}{\percent} & \SI{152}{\second} \\
# BattleofTanks & \num{ 144 } & \num{ 769 } & {\num[text-series-to-math=true]{ 444  }} & {\num[text-series-to-math=true]{342}}  & \num{ 256 } & \SI{23}{\percent} & \SI{873}{\second} \\
# BankingSoftware & \num{ 176 } & \num{ 280 } & {\num[text-series-to-math=true]{ 40  }} & {\num[text-series-to-math=true]{29}}  & \num{ 28 } & \SI{28}{\percent} & \SI{96}{\second} \\
# fiasco\_2017-09-26\_11... & \num{ 230 } & \num{ 1181 } & {\num[text-series-to-math=true]{ 237  }} & \textbf{\num[text-series-to-math=true]{225}}  & \num{ 225 } & \SI{4.9}{\percent} & \SI{545}{\second} \\
# fiasco\_2020-12-01\_14... & \num{ 258 } & \num{ 1542 } & {\num[text-series-to-math=true]{ 214  }} & {\num[text-series-to-math=true]{198}}  & \num{ 196 } & \SI{7.7}{\percent} & \SI{586}{\second} \\
# E-Shop & \num{ 326 } & \num{ 499 } & {\num[text-series-to-math=true]{ 20  }} & {\num[text-series-to-math=true]{12}}  & \num{ 9 } & \SI{39}{\percent} & \SI{426}{\second} \\
# toybox\_2020-12-06\_00... & \num{ 334 } & \num{ 92 } & {\num[text-series-to-math=true]{ 18  }} & {\num[text-series-to-math=true]{11}}  & \num{ 9 } & \SI{39}{\percent} & \SI{334}{\second} \\
# DMIE & \num{ 366 } & \num{ 627 } & {\num[text-series-to-math=true]{ 25  }} & \textbf{\num[text-series-to-math=true]{16}}  & \num{ 16 } & \SI{35}{\percent} & \SI{298}{\second} \\
# soletta\_2017-03-09\_2... & \num{ 458 } & \num{ 1862 } & {\num[text-series-to-math=true]{ 57  }} & \textbf{\num[text-series-to-math=true]{37}}  & \num{ 37 } & \SI{34}{\percent} & \SI{487}{\second} \\
# busybox\_2007-01-24\_0... & \num{ 540 } & \num{ 429 } & {\num[text-series-to-math=true]{ 36  }} & \textbf{\num[text-series-to-math=true]{21}}  & \num{ 21 } & \SI{41}{\percent} & \SI{430}{\second} \\
# fs\_2017-05-22 & \num{ 557 } & \num{ 4992 } & {\num[text-series-to-math=true]{ 398  }} & \textbf{\num[text-series-to-math=true]{396}}  & \num{ 396 } & \SI{0.5}{\percent} & \SI{591}{\second} \\
# WaterlooGenerated & \num{ 580 } & \num{ 879 } & {\num[text-series-to-math=true]{ 144  }} & \textbf{\num[text-series-to-math=true]{82}}  & \num{ 82 } & \SI{43}{\percent} & \SI{707}{\second} \\
# financial\_services & \num{ 771 } & \num{ 7238 } & {\num[text-series-to-math=true]{ 4396  }} & {\num[text-series-to-math=true]{4395}}  & \num{ 4248 } & \SI{0.01}{\percent} & \SI{870}{\second} \\
# busybox-1\_18\_0 & \num{ 854 } & \num{ 1164 } & {\num[text-series-to-math=true]{ 29  }} & {\num[text-series-to-math=true]{18}}  & \num{ 13 } & \SI{38}{\percent} & \SI{469}{\second} \\
# busybox\_2020-12-16\_2... & \num{ 1050 } & \num{ 996 } & {\num[text-series-to-math=true]{ 34  }} & {\num[text-series-to-math=true]{22}}  & \num{ 19 } & \SI{34}{\percent} & \SI{446}{\second} \\
# am31\_sim & \num{ 1178 } & \num{ 2747 } & {\num[text-series-to-math=true]{ 63  }} & {\num[text-series-to-math=true]{41}}  & \num{ 29 } & \SI{34}{\percent} & \SI{827}{\second} \\
# EMBToolkit & \num{ 1179 } & \num{ 5414 } & {\num[text-series-to-math=true]{ 1883  }} & {\num[text-series-to-math=true]{1877}}  & \num{ 1872 } & \SI{0.3}{\percent} & \SI{808}{\second} \\
# atlas\_mips32\_4kc & \num{ 1229 } & \num{ 2875 } & {\num[text-series-to-math=true]{ 66  }} & {\num[text-series-to-math=true]{47}}  & \num{ 33 } & \SI{29}{\percent} & \SI{751}{\second} \\
# eCos-3-0\_i386pc & \num{ 1245 } & \num{ 3723 } & {\num[text-series-to-math=true]{ 66  }} & {\num[text-series-to-math=true]{54}}  & \num{ 35 } & \SI{19}{\percent} & \SI{767}{\second} \\
# integrator\_arm7 & \num{ 1272 } & \num{ 2980 } & {\num[text-series-to-math=true]{ 66  }} & {\num[text-series-to-math=true]{45}}  & \num{ 32 } & \SI{32}{\percent} & \SI{842}{\second} \\
# XSEngine & \num{ 1273 } & \num{ 2942 } & {\num[text-series-to-math=true]{ 63  }} & {\num[text-series-to-math=true]{44}}  & \num{ 33 } & \SI{30}{\percent} & \SI{739}{\second} \\
# aaed2000 & \num{ 1298 } & \num{ 3036 } & {\num[text-series-to-math=true]{ 89  }} & {\num[text-series-to-math=true]{65}}  & \num{ 51 } & \SI{27}{\percent} & \SI{808}{\second} \\
# FreeBSD-8\_0\_0 & \num{ 1397 } & \num{ 15692 } & {\num[text-series-to-math=true]{ 76  }} & {\num[text-series-to-math=true]{65}}  & \num{ 29 } & \SI{14}{\percent} & \SI{819}{\second} \\
# ea2468 & \num{ 1408 } & \num{ 3319 } & {\num[text-series-to-math=true]{ 67  }} & {\num[text-series-to-math=true]{46}}  & \num{ 33 } & \SI{32}{\percent} & \SI{791}{\second} \\

# %%
len(t[t["best_baseline"] / t["best_lb"] <= 1.1])
# Out:
# 10
