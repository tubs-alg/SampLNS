# %% [markdown]
# # Convergence of upper and lower bound over time
#
# Note that the events in the plot are only based on the upper bound iterations.

# %%
import pandas as pd
from _conf import PREPROCESSDED_RESULTS

data = pd.read_json(PREPROCESSDED_RESULTS)
# data = data.drop_duplicates(subset=["instance"])
data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0          14           20    FIDE-YASA        t2_m1_null               205
# 1          52          109    FIDE-YASA        t2_m1_null               289
# 2          16           33    FIDE-YASA        t2_m1_null               155
# 3          16           33    FIDE-YASA        t2_m1_null               174
# 4        1408         3319    FIDE-YASA        t2_m1_null              4993
# ..        ...          ...          ...               ...               ...
# 225       557         4992    FIDE-YASA        t2_m1_null              2070
# 226      1018          997    FIDE-YASA        t2_m1_null              4184
# 227        76          147    FIDE-YASA        t2_m1_null               337
# 228        23           35    FIDE-YASA        t2_m1_null               300
# 229        23           35    FIDE-YASA        t2_m1_null               275
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      10   2023-03-01_13-51-03/4_1_3_1_sample.csv
# 1                      13  2023-03-01_13-51-03/16_1_3_5_sample.csv
# 2                       6   2023-03-01_13-51-03/6_1_3_4_sample.csv
# 3                       6   2023-03-01_13-51-03/6_1_3_2_sample.csv
# 4                      77  2023-03-01_13-51-03/47_1_3_3_sample.csv
# ..                    ...                                      ...
# 225                   400  2023-03-01_13-51-03/33_1_3_3_sample.csv
# 226                    44  2023-03-01_13-51-03/37_1_3_1_sample.csv
# 227                    21  2023-03-01_13-51-03/17_1_3_4_sample.csv
# 228                    11   2023-03-01_13-51-03/9_1_3_5_sample.csv
# 229                    11   2023-03-01_13-51-03/9_1_3_4_sample.csv
#
#                               archive_path  \
# 0    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 3    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 4    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# ..                                     ...
# 225  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 226  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 227  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 228  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 229  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
#                                             parameters   instance_name  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...      ChatClient
# 1    {'func': 'run_samplns', 'args': {'instance_nam...             PPU
# 2    {'func': 'run_samplns', 'args': {'instance_nam...             car
# 3    {'func': 'run_samplns', 'args': {'instance_nam...             car
# 4    {'func': 'run_samplns', 'args': {'instance_nam...          ea2468
# ..                                                 ...             ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...   fs_2017-05-22
# 226  {'func': 'run_samplns', 'args': {'instance_nam...  busybox-1_29_2
# 227  {'func': 'run_samplns', 'args': {'instance_nam...     berkeleyDB1
# 228  {'func': 'run_samplns', 'args': {'instance_nam...             APL
# 229  {'func': 'run_samplns', 'args': {'instance_nam...             APL
#
#      lower_bound  upper_bound  \
# 0              7            7
# 1             12           12
# 2              5            5
# 3              5            5
# 4             31           39
# ..           ...          ...
# 225          396          396
# 226           18           22
# 227           15           15
# 228            7            7
# 229            7            7
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.205
# 1    [{'nbrhd_tuples': 164, 'nbrhd_confs': 7, 'iter...              0.289
# 2    [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...              0.155
# 3    [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...              0.174
# 4    [{'nbrhd_tuples': 178, 'nbrhd_confs': 6, 'iter...              4.993
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...              2.070
# 226  [{'nbrhd_tuples': 228, 'nbrhd_confs': 4, 'iter...              4.184
# 227  [{'nbrhd_tuples': 204, 'nbrhd_confs': 10, 'ite...              0.337
# 228  [{'nbrhd_tuples': 207, 'nbrhd_confs': 10, 'ite...              0.300
# 229  [{'nbrhd_tuples': 207, 'nbrhd_confs': 10, 'ite...              0.275
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit
# 0                10799.795          True         8.636926       10800
# 1                10799.711          True         6.240633       10800
# 2                10799.845          True         0.062622       10800
# 3                10799.826          True         0.043420       10800
# 4                10795.007          True     10938.016142       10800
# ..                     ...           ...              ...         ...
# 225              10797.930          True       433.986984       10800
# 226              10795.816          True     10859.846727       10800
# 227              10799.663          True       559.524486       10800
# 228              10799.700          True         8.174069       10800
# 229              10799.725          True         8.028703       10800
#
# [230 rows x 18 columns]

# %%
from _conf import EXTERNAL_BOUNDS

best_lower_bound = (
    data.groupby(["instance_name"])["lower_bound"]
    .max()
    .reset_index()
    .rename(columns={"lower_bound": "best_lower_bound"})
)
best_lower_bound["internal_best_lower_bound"] = best_lower_bound["best_lower_bound"]
external_best_lb = (
    pd.concat([pd.read_csv(p) for p in EXTERNAL_BOUNDS])
    .groupby(["instance_name"])["best_lower_bound"]
    .max()
    .reset_index()
)
best_lower_bound = (
    pd.concat([best_lower_bound, external_best_lb])
    .groupby(["instance_name"])[["best_lower_bound", "internal_best_lower_bound"]]
    .max()
    .reset_index()
)
best_lower_bound
# Out:
#                   instance_name  best_lower_bound  internal_best_lower_bound
# 0                           APL                 7                        7.0
# 1                     APL-Model                 8                        8.0
# 2               BankingSoftware                29                       29.0
# 3                 BattleofTanks               256                      256.0
# 4                    ChatClient                 7                        7.0
# 5                          DMIE                16                       16.0
# 6                        E-Shop                 9                        9.0
# 7                    EMBToolkit              1872                     1872.0
# 8                        FameDB                 8                        8.0
# 9                    FeatureIDE                 7                        7.0
# 10                FreeBSD-8_0_0                29                       29.0
# 11                          PPU                12                       12.0
# 12                     SafeBali                11                       11.0
# 13                  SortingLine                 9                        9.0
# 14                     TightVNC                 8                        8.0
# 15                       Violet                16                       16.0
# 16            WaterlooGenerated                82                       82.0
# 17                     XSEngine                32                       32.0
# 18                     aaed2000                51                       51.0
# 19                     am31_sim                26                       26.0
# 20             atlas_mips32_4kc                33                       33.0
# 21                        axTLS                10                       10.0
# 22                  berkeleyDB1                15                       15.0
# 23                  berkeleyDB2                12                       12.0
# 24               busybox-1_18_0                13                       13.0
# 25               busybox-1_29_2                20                       20.0
# 26  busybox_2007-01-24_09-14-09                21                       21.0
# 27  busybox_2020-12-16_21-53-05                19                       19.0
# 28                    calculate                 5                        5.0
# 29                          car                 5                        5.0
# 30                         dell                31                       31.0
# 31              eCos-3-0_i386pc                33                       33.0
# 32                       ea2468                32                       32.0
# 33                        email                 6                        6.0
# 34   fiasco_2017-09-26_11-30-56               225                      225.0
# 35   fiasco_2020-12-01_14-09-14               196                      196.0
# 36           financial_services              4336                     4336.0
# 37                fs_2017-05-22               396                      396.0
# 38                          gpl                16                       16.0
# 39              integrator_arm7                33                       33.0
# 40                          lcm                 6                        6.0
# 41  soletta_2015-06-26_18-38-56                24                       24.0
# 42   toybox_2006-10-31_23-30-06                 8                        8.0
# 43   toybox_2020-12-06_00-02-46                 8                        8.0
# 44   uclibc_2008-06-05_13-46-47               505                      505.0
# 45   uclibc_2020-12-24_11-54-53               365                      365.0

# %% [markdown]
# ## Extend the data by some additional information on the best values

# %%
# Find the best values for each instance as reference.

# add them to the data as reference
data = data.merge(best_lower_bound, left_on="instance_name", right_on="instance_name")
data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0          14           20    FIDE-YASA        t2_m1_null               205
# 1          14           20    FIDE-YASA        t2_m1_null               202
# 2          14           20    FIDE-YASA        t2_m1_null               208
# 3          14           20    FIDE-YASA        t2_m1_null               234
# 4          14           20    FIDE-YASA        t2_m1_null               200
# ..        ...          ...          ...               ...               ...
# 225        76          147    FIDE-YASA        t2_m1_null               338
# 226        76          147    FIDE-YASA        t2_m1_null               329
# 227        76          147    FIDE-YASA        t2_m1_null               325
# 228        76          147    FIDE-YASA        t2_m1_null               333
# 229        76          147    FIDE-YASA        t2_m1_null               337
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      10   2023-03-01_13-51-03/4_1_3_1_sample.csv
# 1                      10   2023-03-01_13-51-03/4_1_3_5_sample.csv
# 2                      10   2023-03-01_13-51-03/4_1_3_2_sample.csv
# 3                      10   2023-03-01_13-51-03/4_1_3_3_sample.csv
# 4                      10   2023-03-01_13-51-03/4_1_3_4_sample.csv
# ..                    ...                                      ...
# 225                    21  2023-03-01_13-51-03/17_1_3_1_sample.csv
# 226                    21  2023-03-01_13-51-03/17_1_3_5_sample.csv
# 227                    21  2023-03-01_13-51-03/17_1_3_3_sample.csv
# 228                    21  2023-03-01_13-51-03/17_1_3_2_sample.csv
# 229                    21  2023-03-01_13-51-03/17_1_3_4_sample.csv
#
#                               archive_path  \
# 0    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 3    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 4    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# ..                                     ...
# 225  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 226  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 227  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 228  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 229  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
#                                             parameters instance_name  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 1    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 2    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 3    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 4    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# ..                                                 ...           ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 226  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 227  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 228  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 229  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
#
#      lower_bound  upper_bound  \
# 0              7            7
# 1              7            7
# 2              7            7
# 3              7            7
# 4              7            7
# ..           ...          ...
# 225           15           15
# 226           15           15
# 227           15           15
# 228           15           15
# 229           15           15
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.205
# 1    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.202
# 2    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.208
# 3    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.234
# 4    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.200
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 248, 'nbrhd_confs': 10, 'ite...              0.338
# 226  [{'nbrhd_tuples': 237, 'nbrhd_confs': 10, 'ite...              0.329
# 227  [{'nbrhd_tuples': 246, 'nbrhd_confs': 11, 'ite...              0.325
# 228  [{'nbrhd_tuples': 242, 'nbrhd_confs': 9, 'iter...              0.333
# 229  [{'nbrhd_tuples': 204, 'nbrhd_confs': 10, 'ite...              0.337
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit  \
# 0                10799.795          True         8.636926       10800
# 1                10799.798          True         9.147713       10800
# 2                10799.792          True         8.226347       10800
# 3                10799.766          True         9.428007       10800
# 4                10799.800          True         7.992122       10800
# ..                     ...           ...              ...         ...
# 225              10799.662          True      1078.348757       10800
# 226              10799.671          True       428.838173       10800
# 227              10799.675          True       301.098659       10800
# 228              10799.667          True       409.087457       10800
# 229              10799.663          True       559.524486       10800
#
#      best_lower_bound  internal_best_lower_bound
# 0                   7                        7.0
# 1                   7                        7.0
# 2                   7                        7.0
# 3                   7                        7.0
# 4                   7                        7.0
# ..                ...                        ...
# 225                15                       15.0
# 226                15                       15.0
# 227                15                       15.0
# 228                15                       15.0
# 229                15                       15.0
#
# [230 rows x 20 columns]

# %% [markdown]
# ## A look onto the data never hurts

# %%
data
# Out:
#      num_vars  num_clauses baseline_alg baseline_alg_conf  runtime_baseline  \
# 0          14           20    FIDE-YASA        t2_m1_null               205
# 1          14           20    FIDE-YASA        t2_m1_null               202
# 2          14           20    FIDE-YASA        t2_m1_null               208
# 3          14           20    FIDE-YASA        t2_m1_null               234
# 4          14           20    FIDE-YASA        t2_m1_null               200
# ..        ...          ...          ...               ...               ...
# 225        76          147    FIDE-YASA        t2_m1_null               338
# 226        76          147    FIDE-YASA        t2_m1_null               329
# 227        76          147    FIDE-YASA        t2_m1_null               325
# 228        76          147    FIDE-YASA        t2_m1_null               333
# 229        76          147    FIDE-YASA        t2_m1_null               337
#
#      baseline_sample_size                  path_to_baseline_sample  \
# 0                      10   2023-03-01_13-51-03/4_1_3_1_sample.csv
# 1                      10   2023-03-01_13-51-03/4_1_3_5_sample.csv
# 2                      10   2023-03-01_13-51-03/4_1_3_2_sample.csv
# 3                      10   2023-03-01_13-51-03/4_1_3_3_sample.csv
# 4                      10   2023-03-01_13-51-03/4_1_3_4_sample.csv
# ..                    ...                                      ...
# 225                    21  2023-03-01_13-51-03/17_1_3_1_sample.csv
# 226                    21  2023-03-01_13-51-03/17_1_3_5_sample.csv
# 227                    21  2023-03-01_13-51-03/17_1_3_3_sample.csv
# 228                    21  2023-03-01_13-51-03/17_1_3_2_sample.csv
# 229                    21  2023-03-01_13-51-03/17_1_3_4_sample.csv
#
#                               archive_path  \
# 0    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 1    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 2    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 3    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 4    ./EXTERNAL_INPUT/900_seconds_5_it.zip
# ..                                     ...
# 225  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 226  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 227  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 228  ./EXTERNAL_INPUT/900_seconds_5_it.zip
# 229  ./EXTERNAL_INPUT/900_seconds_5_it.zip
#
#                                             parameters instance_name  \
# 0    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 1    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 2    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 3    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# 4    {'func': 'run_samplns', 'args': {'instance_nam...    ChatClient
# ..                                                 ...           ...
# 225  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 226  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 227  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 228  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
# 229  {'func': 'run_samplns', 'args': {'instance_nam...   berkeleyDB1
#
#      lower_bound  upper_bound  \
# 0              7            7
# 1              7            7
# 2              7            7
# 3              7            7
# 4              7            7
# ..           ...          ...
# 225           15           15
# 226           15           15
# 227           15           15
# 228           15           15
# 229           15           15
#
#                                         iteration_info  time_used_by_yasa  \
# 0    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.205
# 1    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.202
# 2    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.208
# 3    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.234
# 4    [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...              0.200
# ..                                                 ...                ...
# 225  [{'nbrhd_tuples': 248, 'nbrhd_confs': 10, 'ite...              0.338
# 226  [{'nbrhd_tuples': 237, 'nbrhd_confs': 10, 'ite...              0.329
# 227  [{'nbrhd_tuples': 246, 'nbrhd_confs': 11, 'ite...              0.325
# 228  [{'nbrhd_tuples': 242, 'nbrhd_confs': 9, 'iter...              0.333
# 229  [{'nbrhd_tuples': 204, 'nbrhd_confs': 10, 'ite...              0.337
#
#      timelimit_for_samplns  samplns_used  runtime_samplns  time_limit  \
# 0                10799.795          True         8.636926       10800
# 1                10799.798          True         9.147713       10800
# 2                10799.792          True         8.226347       10800
# 3                10799.766          True         9.428007       10800
# 4                10799.800          True         7.992122       10800
# ..                     ...           ...              ...         ...
# 225              10799.662          True      1078.348757       10800
# 226              10799.671          True       428.838173       10800
# 227              10799.675          True       301.098659       10800
# 228              10799.667          True       409.087457       10800
# 229              10799.663          True       559.524486       10800
#
#      best_lower_bound  internal_best_lower_bound
# 0                   7                        7.0
# 1                   7                        7.0
# 2                   7                        7.0
# 3                   7                        7.0
# 4                   7                        7.0
# ..                ...                        ...
# 225                15                       15.0
# 226                15                       15.0
# 227                15                       15.0
# 228                15                       15.0
# 229                15                       15.0
#
# [230 rows x 20 columns]

# %% [markdown]
# The data field `iteration_info` contains a list of dicts for each iteration. This dict looks as follows:
# ```
# { 'nbrhd_tuples': 166,  # the tuples to be covered in this iteration
#   'nbrhd_confs': 5,     # the number of configurations deleted from the sample
#   'iteration': 0,       # the number of the iteration, in this case the first iteration
#   'lb': 3.0,            # the current best lb (global)
#   'ub': 23,             # the current best ub (global)
#   'time': 1.0297019481658936,    # overall time at the end of this iteration
#   'iteration_time': 0.48791050910949707,   # time in this iteration
#   'events': [[0.0350489616394043, 'neighborhood_selected'],   # times of events in this iteration. Good for finding the culprit of long runtimes.
#    [0.24133801460266113, 'local_cds_computed'],
#    [0.29517436027526855, 'model_built'],
#    [0.48662543296813965, 'model_optimized'],
#    [0.48789548873901367, 'neighborhood_optimized'],
#    [0.48791003227233887, 'global_lb_iteration_finished']]}
# ```

# %%
instance_infos = (
    data[["instance_name", "num_vars", "num_clauses"]]
    .drop_duplicates()
    .sort_values(by=["num_vars", "num_clauses"])
)
instance_infos
# Out:
#                    instance_name  num_vars  num_clauses
# 220                    calculate         9           15
# 85                           lcm         9           16
# 105                        email        10           17
# 0                     ChatClient        14           20
# 210   toybox_2006-10-31_23-30-06        16           13
# 10                           car        16           33
# 140                   FeatureIDE        19           27
# 75                        FameDB        22           40
# 180                          APL        23           35
# 30                      SafeBali        24           45
# 100                     TightVNC        28           39
# 200                    APL-Model        28           40
# 115                          gpl        38           99
# 50                   SortingLine        39           77
# 215                         dell        46          244
# 5                            PPU        52          109
# 225                  berkeleyDB1        76          147
# 90                         axTLS        96          183
# 55                        Violet       101          203
# 130                  berkeleyDB2       119          346
# 145  soletta_2015-06-26_18-38-56       129          192
# 205                BattleofTanks       144          769
# 35               BankingSoftware       176          280
# 190   fiasco_2017-09-26_11-30-56       230         1181
# 40    fiasco_2020-12-01_14-09-14       258         1542
# 95    uclibc_2008-06-05_13-46-47       263         1699
# 110   uclibc_2020-12-24_11-54-53       272         1670
# 125                       E-Shop       326          499
# 150   toybox_2020-12-06_00-02-46       334           92
# 185                         DMIE       366          627
# 135  busybox_2007-01-24_09-14-09       540          429
# 65                 fs_2017-05-22       557         4992
# 175            WaterlooGenerated       580          879
# 195           financial_services       771         7238
# 20                busybox-1_18_0       854         1164
# 170               busybox-1_29_2      1018          997
# 25   busybox_2020-12-16_21-53-05      1050          996
# 80                      am31_sim      1178         2747
# 45                    EMBToolkit      1179         5414
# 165             atlas_mips32_4kc      1229         2875
# 70               eCos-3-0_i386pc      1245         3723
# 160              integrator_arm7      1272         2980
# 60                      XSEngine      1273         2942
# 120                     aaed2000      1298         3036
# 155                FreeBSD-8_0_0      1397        15692
# 15                        ea2468      1408         3319

# %% [markdown]
# ## Extract the iteration data from each optimization
#
# Bring them in a format that can easily be plotted by seaborn.

# %%
import pandas as pd


# Collect the data from the iteration_info events.
class EventCollector:
    def __init__(self):
        self.events = {
            "time": [],
            "val": [],
            "type": [],
            "instance": [],
            "path": [],
            # "alg": [],
            "initial_sample_size": [],
            "y": [],
            "final": [],
        }

    def __call__(self, row):
        print(row)
        it_data = row["iteration_info"]

        def add(val, lbub, time, final=False):
            self.events["time"].append(time / 60)
            self.events["val"].append(val)
            self.events["type"].append(lbub)
            self.events["instance"].append(row["instance_name"])
            # self.events["alg"].append(row["baseline_alg"])
            self.events["path"].append(row["path_to_baseline_sample"])
            self.events["initial_sample_size"].append(row["baseline_sample_size"])
            self.events["y"].append(100 * (val / row["best_lower_bound"]))
            self.events["final"].append(final)

        # add a zero entry
        add(0, "Lower", 0)
        add(row["baseline_sample_size"], "Upper", 0)
        for event in it_data:
            add(
                event["lb"],
                "Lower",
                event["time"],
                final=event["lb"] == row["lower_bound"],
            )
            add(
                event["ub"],
                "Upper",
                event["time"],
                final=event["ub"] == row["upper_bound"],
            )


ec = EventCollector()
data.sort_values(by=["num_vars", "num_clauses"]).apply(ec, axis=1)
t = pd.DataFrame(ec.events)
# Out:
# num_vars                                                                     9
# num_clauses                                                                 15
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           173
# baseline_sample_size                                                         9
# path_to_baseline_sample                 2023-03-01_13-51-03/1_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                        calculate
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...
# time_used_by_yasa                                                        0.173
# timelimit_for_samplns                                                10799.827
# samplns_used                                                              True
# runtime_samplns                                                       0.075952
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 220, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 15
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           173
# baseline_sample_size                                                         9
# path_to_baseline_sample                 2023-03-01_13-51-03/1_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                        calculate
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...
# time_used_by_yasa                                                        0.173
# timelimit_for_samplns                                                10799.827
# samplns_used                                                              True
# runtime_samplns                                                       0.076036
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 221, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 15
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           210
# baseline_sample_size                                                         9
# path_to_baseline_sample                 2023-03-01_13-51-03/1_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                        calculate
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...
# time_used_by_yasa                                                         0.21
# timelimit_for_samplns                                                 10799.79
# samplns_used                                                              True
# runtime_samplns                                                        0.07347
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 222, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 15
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           157
# baseline_sample_size                                                         9
# path_to_baseline_sample                 2023-03-01_13-51-03/1_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                        calculate
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...
# time_used_by_yasa                                                        0.157
# timelimit_for_samplns                                                10799.843
# samplns_used                                                              True
# runtime_samplns                                                       0.117388
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 223, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 15
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           178
# baseline_sample_size                                                         9
# path_to_baseline_sample                 2023-03-01_13-51-03/1_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                        calculate
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 38, 'nbrhd_confs': 9, 'itera...
# time_used_by_yasa                                                        0.178
# timelimit_for_samplns                                                10799.822
# samplns_used                                                              True
# runtime_samplns                                                       0.128527
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 224, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 16
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           153
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/2_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              lcm
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.153
# timelimit_for_samplns                                                10799.847
# samplns_used                                                              True
# runtime_samplns                                                        0.08329
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 85, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 16
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           154
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/2_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              lcm
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.154
# timelimit_for_samplns                                                10799.846
# samplns_used                                                              True
# runtime_samplns                                                       0.057677
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 86, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 16
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           168
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/2_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              lcm
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.168
# timelimit_for_samplns                                                10799.832
# samplns_used                                                              True
# runtime_samplns                                                       0.062352
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 87, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 16
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           177
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/2_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              lcm
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.177
# timelimit_for_samplns                                                10799.823
# samplns_used                                                              True
# runtime_samplns                                                        0.05506
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 88, dtype: object
# num_vars                                                                     9
# num_clauses                                                                 16
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           175
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/2_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              lcm
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 37, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.175
# timelimit_for_samplns                                                10799.825
# samplns_used                                                              True
# runtime_samplns                                                       0.074248
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 89, dtype: object
# num_vars                                                                    10
# num_clauses                                                                 17
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           182
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/3_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                            email
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.182
# timelimit_for_samplns                                                10799.818
# samplns_used                                                              True
# runtime_samplns                                                       0.145982
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 105, dtype: object
# num_vars                                                                    10
# num_clauses                                                                 17
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           182
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/3_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                            email
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.182
# timelimit_for_samplns                                                10799.818
# samplns_used                                                              True
# runtime_samplns                                                       0.119431
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 106, dtype: object
# num_vars                                                                    10
# num_clauses                                                                 17
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           173
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/3_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                            email
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.173
# timelimit_for_samplns                                                10799.827
# samplns_used                                                              True
# runtime_samplns                                                       0.138966
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 107, dtype: object
# num_vars                                                                    10
# num_clauses                                                                 17
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           158
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/3_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                            email
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.158
# timelimit_for_samplns                                                10799.842
# samplns_used                                                              True
# runtime_samplns                                                         0.1132
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 108, dtype: object
# num_vars                                                                    10
# num_clauses                                                                 17
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           172
# baseline_sample_size                                                         8
# path_to_baseline_sample                 2023-03-01_13-51-03/3_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                            email
# lower_bound                                                                  6
# upper_bound                                                                  6
# iteration_info               [{'nbrhd_tuples': 70, 'nbrhd_confs': 8, 'itera...
# time_used_by_yasa                                                        0.172
# timelimit_for_samplns                                                10799.828
# samplns_used                                                              True
# runtime_samplns                                                       0.087554
# time_limit                                                               10800
# best_lower_bound                                                             6
# internal_best_lower_bound                                                  6.0
# Name: 109, dtype: object
# num_vars                                                                    14
# num_clauses                                                                 20
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           205
# baseline_sample_size                                                        10
# path_to_baseline_sample                 2023-03-01_13-51-03/4_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                       ChatClient
# lower_bound                                                                  7
# upper_bound                                                                  7
# iteration_info               [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.205
# timelimit_for_samplns                                                10799.795
# samplns_used                                                              True
# runtime_samplns                                                       8.636926
# time_limit                                                               10800
# best_lower_bound                                                             7
# internal_best_lower_bound                                                  7.0
# Name: 0, dtype: object
# num_vars                                                                    14
# num_clauses                                                                 20
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           202
# baseline_sample_size                                                        10
# path_to_baseline_sample                 2023-03-01_13-51-03/4_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                       ChatClient
# lower_bound                                                                  7
# upper_bound                                                                  7
# iteration_info               [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.202
# timelimit_for_samplns                                                10799.798
# samplns_used                                                              True
# runtime_samplns                                                       9.147713
# time_limit                                                               10800
# best_lower_bound                                                             7
# internal_best_lower_bound                                                  7.0
# Name: 1, dtype: object
# num_vars                                                                    14
# num_clauses                                                                 20
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           208
# baseline_sample_size                                                        10
# path_to_baseline_sample                 2023-03-01_13-51-03/4_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                       ChatClient
# lower_bound                                                                  7
# upper_bound                                                                  7
# iteration_info               [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.208
# timelimit_for_samplns                                                10799.792
# samplns_used                                                              True
# runtime_samplns                                                       8.226347
# time_limit                                                               10800
# best_lower_bound                                                             7
# internal_best_lower_bound                                                  7.0
# Name: 2, dtype: object
# num_vars                                                                    14
# num_clauses                                                                 20
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           234
# baseline_sample_size                                                        10
# path_to_baseline_sample                 2023-03-01_13-51-03/4_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                       ChatClient
# lower_bound                                                                  7
# upper_bound                                                                  7
# iteration_info               [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.234
# timelimit_for_samplns                                                10799.766
# samplns_used                                                              True
# runtime_samplns                                                       9.428007
# time_limit                                                               10800
# best_lower_bound                                                             7
# internal_best_lower_bound                                                  7.0
# Name: 3, dtype: object
# num_vars                                                                    14
# num_clauses                                                                 20
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           200
# baseline_sample_size                                                        10
# path_to_baseline_sample                 2023-03-01_13-51-03/4_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                       ChatClient
# lower_bound                                                                  7
# upper_bound                                                                  7
# iteration_info               [{'nbrhd_tuples': 176, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                          0.2
# timelimit_for_samplns                                                  10799.8
# samplns_used                                                              True
# runtime_samplns                                                       7.992122
# time_limit                                                               10800
# best_lower_bound                                                             7
# internal_best_lower_bound                                                  7.0
# Name: 4, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 13
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           267
# baseline_sample_size                                                        12
# path_to_baseline_sample                 2023-03-01_13-51-03/5_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                       toybox_2006-10-31_23-30-06
# lower_bound                                                                  8
# upper_bound                                                                  8
# iteration_info               [{'nbrhd_tuples': 223, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.267
# timelimit_for_samplns                                                10799.733
# samplns_used                                                              True
# runtime_samplns                                                       4.264276
# time_limit                                                               10800
# best_lower_bound                                                             8
# internal_best_lower_bound                                                  8.0
# Name: 210, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 13
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           290
# baseline_sample_size                                                        12
# path_to_baseline_sample                 2023-03-01_13-51-03/5_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                       toybox_2006-10-31_23-30-06
# lower_bound                                                                  8
# upper_bound                                                                  8
# iteration_info               [{'nbrhd_tuples': 245, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                         0.29
# timelimit_for_samplns                                                 10799.71
# samplns_used                                                              True
# runtime_samplns                                                       4.253918
# time_limit                                                               10800
# best_lower_bound                                                             8
# internal_best_lower_bound                                                  8.0
# Name: 211, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 13
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           245
# baseline_sample_size                                                        12
# path_to_baseline_sample                 2023-03-01_13-51-03/5_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                       toybox_2006-10-31_23-30-06
# lower_bound                                                                  8
# upper_bound                                                                  8
# iteration_info               [{'nbrhd_tuples': 245, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.245
# timelimit_for_samplns                                                10799.755
# samplns_used                                                              True
# runtime_samplns                                                       9.303703
# time_limit                                                               10800
# best_lower_bound                                                             8
# internal_best_lower_bound                                                  8.0
# Name: 212, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 13
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           254
# baseline_sample_size                                                        12
# path_to_baseline_sample                 2023-03-01_13-51-03/5_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                       toybox_2006-10-31_23-30-06
# lower_bound                                                                  8
# upper_bound                                                                  8
# iteration_info               [{'nbrhd_tuples': 238, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.254
# timelimit_for_samplns                                                10799.746
# samplns_used                                                              True
# runtime_samplns                                                       4.619652
# time_limit                                                               10800
# best_lower_bound                                                             8
# internal_best_lower_bound                                                  8.0
# Name: 213, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 13
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           271
# baseline_sample_size                                                        12
# path_to_baseline_sample                 2023-03-01_13-51-03/5_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                       toybox_2006-10-31_23-30-06
# lower_bound                                                                  8
# upper_bound                                                                  8
# iteration_info               [{'nbrhd_tuples': 245, 'nbrhd_confs': 10, 'ite...
# time_used_by_yasa                                                        0.271
# timelimit_for_samplns                                                10799.729
# samplns_used                                                              True
# runtime_samplns                                                       6.613622
# time_limit                                                               10800
# best_lower_bound                                                             8
# internal_best_lower_bound                                                  8.0
# Name: 214, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 33
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           155
# baseline_sample_size                                                         6
# path_to_baseline_sample                 2023-03-01_13-51-03/6_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              car
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...
# time_used_by_yasa                                                        0.155
# timelimit_for_samplns                                                10799.845
# samplns_used                                                              True
# runtime_samplns                                                       0.062622
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 10, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 33
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           174
# baseline_sample_size                                                         6
# path_to_baseline_sample                 2023-03-01_13-51-03/6_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              car
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...
# time_used_by_yasa                                                        0.174
# timelimit_for_samplns                                                10799.826
# samplns_used                                                              True
# runtime_samplns                                                        0.04342
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 11, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 33
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           170
# baseline_sample_size                                                         6
# path_to_baseline_sample                 2023-03-01_13-51-03/6_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              car
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...
# time_used_by_yasa                                                         0.17
# timelimit_for_samplns                                                 10799.83
# samplns_used                                                              True
# runtime_samplns                                                       0.082558
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 12, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 33
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           173
# baseline_sample_size                                                         6
# path_to_baseline_sample                 2023-03-01_13-51-03/6_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              car
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...
# time_used_by_yasa                                                        0.173
# timelimit_for_samplns                                                10799.827
# samplns_used                                                              True
# runtime_samplns                                                        0.07929
# time_limit                                                               10800
# best_lower_bound                                                             5
# internal_best_lower_bound                                                  5.0
# Name: 13, dtype: object
# num_vars                                                                    16
# num_clauses                                                                 33
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           154
# baseline_sample_size                                                         6
# path_to_baseline_sample                 2023-03-01_13-51-03/6_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              car
# lower_bound                                                                  5
# upper_bound                                                                  5
# iteration_info               [{'nbrhd_tuples': 77, 'nbrhd_confs': 6, 'itera...
# time_used_by_yasa                                                        0.154
# timelimit_for_samplns                                                10799.846
# samplns_used                                                              True
# runtime_samplns                                                       0.081794
# time_limit                                                               10800
# ...
# num_clauses                                                              15692
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                         14090
# baseline_sample_size                                                        91
# path_to_baseline_sample                2023-03-01_13-51-03/46_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    FreeBSD-8_0_0
# lower_bound                                                                 29
# upper_bound                                                                 45
# iteration_info               [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...
# time_used_by_yasa                                                        14.09
# timelimit_for_samplns                                                 10785.91
# samplns_used                                                              True
# runtime_samplns                                                   10833.261165
# time_limit                                                               10800
# best_lower_bound                                                            29
# internal_best_lower_bound                                                 29.0
# Name: 155, dtype: object
# num_vars                                                                  1397
# num_clauses                                                              15692
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                         14039
# baseline_sample_size                                                        91
# path_to_baseline_sample                2023-03-01_13-51-03/46_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    FreeBSD-8_0_0
# lower_bound                                                                 28
# upper_bound                                                                 46
# iteration_info               [{'nbrhd_tuples': 240, 'nbrhd_confs': 3, 'iter...
# time_used_by_yasa                                                       14.039
# timelimit_for_samplns                                                10785.961
# samplns_used                                                              True
# runtime_samplns                                                   10829.453047
# time_limit                                                               10800
# best_lower_bound                                                            29
# internal_best_lower_bound                                                 29.0
# Name: 156, dtype: object
# num_vars                                                                  1397
# num_clauses                                                              15692
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                         14061
# baseline_sample_size                                                        91
# path_to_baseline_sample                2023-03-01_13-51-03/46_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    FreeBSD-8_0_0
# lower_bound                                                                 28
# upper_bound                                                                 47
# iteration_info               [{'nbrhd_tuples': 156, 'nbrhd_confs': 4, 'iter...
# time_used_by_yasa                                                       14.061
# timelimit_for_samplns                                                10785.939
# samplns_used                                                              True
# runtime_samplns                                                   10798.858521
# time_limit                                                               10800
# best_lower_bound                                                            29
# internal_best_lower_bound                                                 29.0
# Name: 157, dtype: object
# num_vars                                                                  1397
# num_clauses                                                              15692
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                         14084
# baseline_sample_size                                                        91
# path_to_baseline_sample                2023-03-01_13-51-03/46_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    FreeBSD-8_0_0
# lower_bound                                                                 29
# upper_bound                                                                 45
# iteration_info               [{'nbrhd_tuples': 105, 'nbrhd_confs': 4, 'iter...
# time_used_by_yasa                                                       14.084
# timelimit_for_samplns                                                10785.916
# samplns_used                                                              True
# runtime_samplns                                                   10934.526077
# time_limit                                                               10800
# best_lower_bound                                                            29
# internal_best_lower_bound                                                 29.0
# Name: 158, dtype: object
# num_vars                                                                  1397
# num_clauses                                                              15692
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                         14082
# baseline_sample_size                                                        91
# path_to_baseline_sample                2023-03-01_13-51-03/46_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    FreeBSD-8_0_0
# lower_bound                                                                 28
# upper_bound                                                                 45
# iteration_info               [{'nbrhd_tuples': 118, 'nbrhd_confs': 5, 'iter...
# time_used_by_yasa                                                       14.082
# timelimit_for_samplns                                                10785.918
# samplns_used                                                              True
# runtime_samplns                                                   10800.257955
# time_limit                                                               10800
# best_lower_bound                                                            29
# internal_best_lower_bound                                                 29.0
# Name: 159, dtype: object
# num_vars                                                                  1408
# num_clauses                                                               3319
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          4993
# baseline_sample_size                                                        77
# path_to_baseline_sample                2023-03-01_13-51-03/47_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                           ea2468
# lower_bound                                                                 31
# upper_bound                                                                 39
# iteration_info               [{'nbrhd_tuples': 178, 'nbrhd_confs': 6, 'iter...
# time_used_by_yasa                                                        4.993
# timelimit_for_samplns                                                10795.007
# samplns_used                                                              True
# runtime_samplns                                                   10938.016142
# time_limit                                                               10800
# best_lower_bound                                                            32
# internal_best_lower_bound                                                 32.0
# Name: 15, dtype: object
# num_vars                                                                  1408
# num_clauses                                                               3319
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          4968
# baseline_sample_size                                                        77
# path_to_baseline_sample                2023-03-01_13-51-03/47_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                           ea2468
# lower_bound                                                                 31
# upper_bound                                                                 40
# iteration_info               [{'nbrhd_tuples': 167, 'nbrhd_confs': 2, 'iter...
# time_used_by_yasa                                                        4.968
# timelimit_for_samplns                                                10795.032
# samplns_used                                                              True
# runtime_samplns                                                   10870.947752
# time_limit                                                               10800
# best_lower_bound                                                            32
# internal_best_lower_bound                                                 32.0
# Name: 16, dtype: object
# num_vars                                                                  1408
# num_clauses                                                               3319
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          4915
# baseline_sample_size                                                        77
# path_to_baseline_sample                2023-03-01_13-51-03/47_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                           ea2468
# lower_bound                                                                 31
# upper_bound                                                                 39
# iteration_info               [{'nbrhd_tuples': 212, 'nbrhd_confs': 3, 'iter...
# time_used_by_yasa                                                        4.915
# timelimit_for_samplns                                                10795.085
# samplns_used                                                              True
# runtime_samplns                                                   10859.222434
# time_limit                                                               10800
# best_lower_bound                                                            32
# internal_best_lower_bound                                                 32.0
# Name: 17, dtype: object
# num_vars                                                                  1408
# num_clauses                                                               3319
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          5024
# baseline_sample_size                                                        77
# path_to_baseline_sample                2023-03-01_13-51-03/47_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                           ea2468
# lower_bound                                                                 32
# upper_bound                                                                 39
# iteration_info               [{'nbrhd_tuples': 216, 'nbrhd_confs': 5, 'iter...
# time_used_by_yasa                                                        5.024
# timelimit_for_samplns                                                10794.976
# samplns_used                                                              True
# runtime_samplns                                                   10830.055082
# time_limit                                                               10800
# best_lower_bound                                                            32
# internal_best_lower_bound                                                 32.0
# Name: 18, dtype: object
# num_vars                                                                  1408
# num_clauses                                                               3319
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          4942
# baseline_sample_size                                                        77
# path_to_baseline_sample                2023-03-01_13-51-03/47_1_3_2_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                           ea2468
# lower_bound                                                                 27
# upper_bound                                                                 39
# iteration_info               [{'nbrhd_tuples': 130, 'nbrhd_confs': 4, 'iter...
# time_used_by_yasa                                                        4.942
# timelimit_for_samplns                                                10795.058
# samplns_used                                                              True
# runtime_samplns                                                   10829.403069
# time_limit                                                               10800
# best_lower_bound                                                            32
# internal_best_lower_bound                                                 32.0
# Name: 19, dtype: object

# %%
t
# Out:
#              time   val   type   instance  \
# 0        0.000000   0.0  Lower  calculate
# 1        0.000000   9.0  Upper  calculate
# 2        0.000867   5.0  Lower  calculate
# 3        0.000867   5.0  Upper  calculate
# 4        0.000000   0.0  Lower  calculate
# ...           ...   ...    ...        ...
# 21173  174.197881  39.0  Upper     ea2468
# 21174  177.309222  27.0  Lower     ea2468
# 21175  177.309222  39.0  Upper     ea2468
# 21176  180.092823  27.0  Lower     ea2468
# 21177  180.092823  39.0  Upper     ea2468
#
#                                           path  initial_sample_size        y  \
# 0       2023-03-01_13-51-03/1_1_3_2_sample.csv                    9    0.000
# 1       2023-03-01_13-51-03/1_1_3_2_sample.csv                    9  180.000
# 2       2023-03-01_13-51-03/1_1_3_2_sample.csv                    9  100.000
# 3       2023-03-01_13-51-03/1_1_3_2_sample.csv                    9  100.000
# 4       2023-03-01_13-51-03/1_1_3_5_sample.csv                    9    0.000
# ...                                        ...                  ...      ...
# 21173  2023-03-01_13-51-03/47_1_3_2_sample.csv                   77  121.875
# 21174  2023-03-01_13-51-03/47_1_3_2_sample.csv                   77   84.375
# 21175  2023-03-01_13-51-03/47_1_3_2_sample.csv                   77  121.875
# 21176  2023-03-01_13-51-03/47_1_3_2_sample.csv                   77   84.375
# 21177  2023-03-01_13-51-03/47_1_3_2_sample.csv                   77  121.875
#
#        final
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
# ...      ...
# 21173   True
# 21174   True
# 21175   True
# 21176   True
# 21177   True
#
# [21178 rows x 8 columns]

# %% [markdown]
# ## Feature Models on which SampLNS did not finish a single iteration in time
#
# These models have very large initial samples (more than a thousand configurations), for which the current implementation is not equipped.
# The problem lies more in the data structures than the actual approach.
# They should be feasible with some extra effort in making those data structures more efficient.
#
# *A lower bound is still computed for these instances, but without iterations of SampLNS, only the final lower bound is saved after SampLNS aborted.*

# %%
t_ = t.groupby(["instance", "path"])["time"].max().reset_index()
unsolved_instances = t_[t_["time"] == 0]["instance"].unique().tolist()
unsolved_instances
# Out:
# []

# %% [markdown]
# ## Plot the convergence for all other models.

# %%
solved_instances = [
    x for x in instance_infos["instance_name"].tolist() if x not in unsolved_instances
]

# %%
# Prepare plotting
import seaborn as sns

sns.set_theme()
import matplotlib.pyplot as plt

# %%
def plot_lb_ub_progress(data, axis, xmax=16, single_instance=False):
    instance_descr = "Model"
    bound_descr = "Bound"
    t_ = data.rename(columns={"instance": instance_descr, "type": bound_descr})
    if single_instance:
        sns.lineplot(
            data=t_,
            ax=axis,
            x="time",
            y="y",
            style=bound_descr,
            hue="path",
            units="path",
            estimator=None,
            markers=False,
            palette="tab10",
            drawstyle="steps-post",
            dashes=[(1.5, 1.5), (3, 3)],
            legend=False,
        )
        sns.scatterplot(
            data=t_[t_[bound_descr] == "Upper"],
            ax=axis,
            x="time",
            y="y",
            hue="path",
            marker="X",
            palette="tab10",
            legend=False,
        )
    else:
        sns.lineplot(
            data=t_,
            ax=axis,
            x="time",
            y="y",
            style=bound_descr,
            hue=instance_descr,
            units="path",
            estimator=None,
            markers=False,
            palette="tab10",
            drawstyle="steps-post",
            dashes=[(1.5, 1.5), (3, 3)],
        )
        sns.scatterplot(
            data=t_[t_[bound_descr] == "Upper"],
            ax=axis,
            x="time",
            y="y",
            hue=instance_descr,
            marker="X",
            palette="tab10",
            legend=False,
        )
    axis.set_xlim(-0.1, xmax)
    axis.set_xlabel("Time in (min)")
    axis.set_ylabel("Relative to best lower bound (%)")
    if single_instance:
        axis.set_title(
            f"Convergence of upper and lower bound - {data['instance'].tolist()[0]}"
        )
    else:
        axis.set_title("Convergence of upper and lower bound")

# %% [markdown]
# ### All models in one plot
#
# This shows us that most models really make quick progress and only a few take a little longer.

# %%
plt.figure(figsize=(15, 13))
plot_lb_ub_progress(t[t["instance"].isin(solved_instances)], plt.gca(), xmax=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Every model with all its five runs.

# %%
for i in range(1, len(solved_instances), 1):
    plt.figure(figsize=(10, 5))
    plot_lb_ub_progress(
        t[t["instance"].isin(solved_instances[i : i + 1])],
        plt.gca(),
        xmax=180,
        single_instance=True,
    )
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Looking onto a selection of instances in a single plot

# %%
ec = EventCollector()
selection = [
    "PPU",
    # small, optimal initial sample, no improvement, reached lower bound, progress within seconds + largest system for which an existing sampling algorithm is optimal
    "axTLS",
    # small, bad initial sample, large improvement, tight lower bound, progress for 0/1 min + smallest system that we cannot optimally solve
    "berkeleyDB2",
    # small, bad initial sample, large improvement, reached lower bound, progress for 6/3 min + one of the most significant improvements (43% + optimal afterwards)
    "fs_2017-05-22",
    # medium, good initial sample, small improvement, tight lower bound, progress for 0/10 min + smallest improvement (near-optimal sample still improved)
    "busybox_2020-12-16_21-53-05",
    # medium, bad initial sample, improvement over ~6 minutes, quick progress on lb.
    "FreeBSD-8_0_0"
    # medium, bad initial sample, large improvement, far lower bound, progress for 15/15 min + system with the largest remaining gap between LB=30 and sample=59 (almost 100%)
]
data[data["instance_name"].isin(selection)].drop_duplicates(
    subset=["instance_name"]
).sort_values(by=["num_vars", "num_clauses"]).apply(ec, axis=1)
t_selected = pd.DataFrame(ec.events)
t_selected["instance"] = t_selected["instance"].apply(lambda s: s[:15])
# Out:
# num_vars                                                                    52
# num_clauses                                                                109
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           289
# baseline_sample_size                                                        13
# path_to_baseline_sample                2023-03-01_13-51-03/16_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                              PPU
# lower_bound                                                                 12
# upper_bound                                                                 12
# iteration_info               [{'nbrhd_tuples': 164, 'nbrhd_confs': 7, 'iter...
# time_used_by_yasa                                                        0.289
# timelimit_for_samplns                                                10799.711
# samplns_used                                                              True
# runtime_samplns                                                       6.240633
# time_limit                                                               10800
# best_lower_bound                                                            12
# internal_best_lower_bound                                                 12.0
# Name: 5, dtype: object
# num_vars                                                                    96
# num_clauses                                                                183
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           337
# baseline_sample_size                                                        20
# path_to_baseline_sample                2023-03-01_13-51-03/18_1_3_5_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                            axTLS
# lower_bound                                                                 10
# upper_bound                                                                 11
# iteration_info               [{'nbrhd_tuples': 167, 'nbrhd_confs': 9, 'iter...
# time_used_by_yasa                                                        0.337
# timelimit_for_samplns                                                10799.663
# samplns_used                                                              True
# runtime_samplns                                                   10899.861542
# time_limit                                                               10800
# best_lower_bound                                                            10
# internal_best_lower_bound                                                 10.0
# Name: 90, dtype: object
# num_vars                                                                   119
# num_clauses                                                                346
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                           407
# baseline_sample_size                                                        26
# path_to_baseline_sample                2023-03-01_13-51-03/20_1_3_1_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                      berkeleyDB2
# lower_bound                                                                 12
# upper_bound                                                                 12
# iteration_info               [{'nbrhd_tuples': 157, 'nbrhd_confs': 5, 'iter...
# time_used_by_yasa                                                        0.407
# timelimit_for_samplns                                                10799.593
# samplns_used                                                              True
# runtime_samplns                                                      603.14654
# time_limit                                                               10800
# best_lower_bound                                                            12
# internal_best_lower_bound                                                 12.0
# Name: 130, dtype: object
# num_vars                                                                   557
# num_clauses                                                               4992
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          2070
# baseline_sample_size                                                       400
# path_to_baseline_sample                2023-03-01_13-51-03/33_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    fs_2017-05-22
# lower_bound                                                                396
# upper_bound                                                                396
# iteration_info               [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...
# time_used_by_yasa                                                         2.07
# timelimit_for_samplns                                                 10797.93
# samplns_used                                                              True
# runtime_samplns                                                     755.461193
# time_limit                                                               10800
# best_lower_bound                                                           396
# internal_best_lower_bound                                                396.0
# Name: 65, dtype: object
# num_vars                                                                  1050
# num_clauses                                                                996
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                          4342
# baseline_sample_size                                                        45
# path_to_baseline_sample                2023-03-01_13-51-03/38_1_3_3_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                      busybox_2020-12-16_21-53-05
# lower_bound                                                                 19
# upper_bound                                                                 21
# iteration_info               [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...
# time_used_by_yasa                                                        4.342
# timelimit_for_samplns                                                10795.658
# samplns_used                                                              True
# runtime_samplns                                                   10841.816137
# time_limit                                                               10800
# best_lower_bound                                                            19
# internal_best_lower_bound                                                 19.0
# Name: 25, dtype: object
# num_vars                                                                  1397
# num_clauses                                                              15692
# baseline_alg                                                         FIDE-YASA
# baseline_alg_conf                                                   t2_m1_null
# runtime_baseline                                                         14090
# baseline_sample_size                                                        91
# path_to_baseline_sample                2023-03-01_13-51-03/46_1_3_4_sample.csv
# archive_path                             ./EXTERNAL_INPUT/900_seconds_5_it.zip
# parameters                   {'func': 'run_samplns', 'args': {'instance_nam...
# instance_name                                                    FreeBSD-8_0_0
# lower_bound                                                                 29
# upper_bound                                                                 45
# iteration_info               [{'nbrhd_tuples': 0, 'nbrhd_confs': 0, 'iterat...
# time_used_by_yasa                                                        14.09
# timelimit_for_samplns                                                 10785.91
# samplns_used                                                              True
# runtime_samplns                                                   10833.261165
# time_limit                                                               10800
# best_lower_bound                                                            29
# internal_best_lower_bound                                                 29.0
# Name: 155, dtype: object

# %%
plt.figure(figsize=(6, 4.5))
plot_lb_ub_progress(t_selected, plt.gca(), xmax=60)
plt.legend(ncols=3, loc="lower right", prop={"size": 10})
plt.tight_layout()
plt.savefig("./plots/01_12_convergence_of_selected_models.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/krupke/Repositories/SampLNS/evaluation/04_super_long_samplns/08_convergence.ipynb Cell 25 line 5
#       <a href='vscode-notebook-cell:/Users/krupke/Repositories/SampLNS/evaluation/04_super_long_samplns/08_convergence.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> plt.legend(ncols=3, loc="lower right", prop={"size": 10})
#       <a href='vscode-notebook-cell:/Users/krupke/Repositories/SampLNS/evaluation/04_super_long_samplns/08_convergence.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> plt.tight_layout()
# ----> <a href='vscode-notebook-cell:/Users/krupke/Repositories/SampLNS/evaluation/04_super_long_samplns/08_convergence.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> plt.savefig("./plots/01_12_convergence_of_selected_models.pdf")
#       <a href='vscode-notebook-cell:/Users/krupke/Repositories/SampLNS/evaluation/04_super_long_samplns/08_convergence.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
#    3341             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3343 self.canvas.print_figure(fname, **kwargs)
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:2808, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2806     file = filename._file
#    2807 else:
# -> 2808     file = PdfFile(filename, metadata=metadata)
#    2809 try:
#    2810     file.newPage(width, height)
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:713, in PdfFile.__init__(self, filename, metadata)
#     711 self.original_file_like = None
#     712 self.tell_base = 0
# --> 713 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     714 if not opened:
#     715     try:
#
# File ~/Library/anaconda3/envs/mo310/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:489, in to_filehandle(fname, flag, return_opened, encoding)
#     487         fh = bz2.BZ2File(fname, flag)
#     488     else:
# --> 489         fh = open(fname, flag, encoding=encoding)
#     490     opened = True
#     491 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './plots/01_12_convergence_of_selected_models.pdf'

# %% [markdown]
# ## Time of last change
#
# To get a better grasp of the necessary time.

# %%
time_until_last_change = (
    t[t["final"] & (t["instance"].isin(solved_instances))]
    .groupby(["instance", "path", "type"])[["time"]]
    .min()
    .reset_index()
    .groupby(["instance", "type"])[["time"]]
    .mean()
)
time_until_last_change
# Out:
#                                        time
# instance                   type
# APL                        Lower   0.128374
#                            Upper   0.038853
# APL-Model                  Lower   2.095375
#                            Upper   0.348868
# BankingSoftware            Lower  72.695062
# ...                                     ...
# toybox_2020-12-06_00-02-46 Upper  27.039110
# uclibc_2008-06-05_13-46-47 Lower   9.548287
#                            Upper   1.629486
# uclibc_2020-12-24_11-54-53 Lower   5.725083
#                            Upper   1.241885
#
# [92 rows x 1 columns]

# %%
time_seconds = time_until_last_change.groupby("instance")[["time"]].max() * 60
from _conf import EXPORT_AVG_FINAL_TIME

time_seconds.to_csv(EXPORT_AVG_FINAL_TIME)
time_seconds
# Out:
#                                      time
# instance
# APL                              7.702429
# APL-Model                      125.722471
# BankingSoftware               4361.703720
# BattleofTanks                10228.574991
# ChatClient                       8.646938
# DMIE                           379.033720
# E-Shop                        1118.561733
# EMBToolkit                    3717.518094
# FameDB                           4.240245
# FeatureIDE                      17.513145
# FreeBSD-8_0_0                 8722.083714
# PPU                             18.894506
# SafeBali                         0.063709
# SortingLine                     52.758081
# TightVNC                       155.616319
# Violet                        2447.482136
# WaterlooGenerated              415.452692
# XSEngine                      4867.334572
# aaed2000                      6177.060370
# am31_sim                      4542.737583
# atlas_mips32_4kc              6060.701189
# axTLS                           76.652048
# berkeleyDB1                    504.394083
# berkeleyDB2                    636.140470
# busybox-1_18_0                1330.302273
# busybox-1_29_2                2388.108667
# busybox_2007-01-24_09-14-09    806.371356
# busybox_2020-12-16_21-53-05   3958.388456
# calculate                        0.064593
# car                              0.051858
# dell                           111.308158
# eCos-3-0_i386pc               7138.307221
# ea2468                        5179.090951
# email                            0.090172
# fiasco_2017-09-26_11-30-56    5408.900796
# fiasco_2020-12-01_14-09-14    1943.808821
# financial_services            9014.047602
# fs_2017-05-22                  557.030006
# gpl                             18.336925
# integrator_arm7               5691.330894
# lcm                              0.051735
# soletta_2015-06-26_18-38-56    121.706388
# toybox_2006-10-31_23-30-06       5.791551
# toybox_2020-12-06_00-02-46    3146.612723
# uclibc_2008-06-05_13-46-47     572.897208
# uclibc_2020-12-24_11-54-53     343.504994

# %%
(time_until_last_change.groupby("instance")[["time"]].max() < 3).sum()
# Out:
# time    18
# dtype: int64

# %%
time_until_last_change.reset_index().groupby("type")[["time"]].mean()
# Out:
#             time
# type
# Lower  25.374705
# Upper  31.850122
